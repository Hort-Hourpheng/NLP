# %% [markdown]
# # I. Loading Packages and Data

# %% [markdown]
# <p>In this notebook, we'll scrape the novel <em>Moby Dick</em> from the website <a "https://www.gutenberg.org/">Project Gutenberg.</a> The source is an online book HTML page: <a href="https://www.gutenberg.org/cache/epub/2701/pg2701-images.html"> https://www.gutenberg.org/cache/epub/2701/pg2701-images.html. </a> </p>

# %%
import string
import requests
from bs4 import BeautifulSoup
import nltk
# nltk.download()
from collections import Counter

# Getting the Moby Dick HTML  
r = requests.get('https://s3.amazonaws.com/assets.datacamp.com/production/project_147/datasets/2701-h.htm')

# Setting the correct text encoding of the HTML page
r.encoding = 'utf-8'

# Extracting the HTML from the request object
html = r.text

# Creating a BeautifulSoup object from the HTML
soup = BeautifulSoup(html, "html.parser")

# Getting the text out of the soup
text = soup.get_text()

# Printing out text between characters 32000 and 34000
# print(text[32000:34000])

# %% [markdown]
# ## 1.1 Data Description:

# %%
print(f"There are a total of {len(text)} tokens in the novel.")
print(f"There are a total of {len(set(text))} types in the novel.")
# Out:
# There are a total of 1382841 tokens in the novel.
# There are a total of 103 types in the novel.

# %% [markdown]
# <p>As we can see, the html page was successfully scraped using <code>BeautifulSoup</code>. Before Preprocessing, there are a total of <span style="color:red;"> <u>1382615</u></span> tokens and <span style="color:red;"> <u><u> only 104</u></u></span> types. Thus, the next step will be preprocessing the novel. And we will explore data description after cleaning as well. </p>

# %% [markdown]
# # II. Text Preprocessing:

# %% [markdown]
# In this mini project-Text Generation, there are some proposed preposing steps as following *(we also assume that there are no wrong spelling in this corpus)*:
#
# 1. **Text Cleaning** : including <u>Lowercasing</u>, <u>Removing contractions</u>, and <u>Removing some Special Characters</u> that are not needed.
#
# 2. **Normalization** : We will practice <u>Stemming </u> and <u>Lemmatization</u> to reduce `types` and result in better performance model.
#
# 3. **Removing Stopwords** : There are some uncertainty regarding <u>*how will we remove stopwords*</u>, since there will certainly some stopwords holding contextual meaning and grammatical rules.
#
# 4. **Handling Less Occurrence Words** : Replacing them with `<UNK>`.
#
# 5. **Tokenization** : We will do <u>Sentence Tokenization</u> to split the whole corpus into training set *(70% of the whole corpus)* and testing set *(30% of the whole corpus)* in advanced and <u>Word Tokenization</u> to build the model.

# %% [markdown]
# ## 2.1 Text Cleaning:

# %%
nltk.download('punkt')
from nltk.tokenize import word_tokenize
import contractions
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hort\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def clean_text(text):
    expanded_words = []    
    for word in text.split():
        expanded_words.append(contractions.fix(word))
    expanded_text = ' '.join(expanded_words).lower()
    # clean_text = ''.join([char for char in expanded_text if char in string.ascii_letters + ' '+'.'+'?'+'!'])
    clean_text = ''.join([char for char in expanded_text if char in string.ascii_letters + ' '+'.'])
    # clean_text = ''.join([char for char in expanded_text if char in string.ascii_letters + ' '])
    clean_words = word_tokenize(clean_text)
    return clean_words

# %%
clean_words = clean_text(text)
clean_words[:10]
# Out:
# ['moby',
#  'dick',
#  'or',
#  'the',
#  'whale',
#  'by',
#  'herman',
#  'melville',
#  'the',
#  'project']

# %% [markdown]
# After cleaning:

# %%
print(f"There are a total of {len(clean_words)} tokens in the novel.")
print(f"There are a total of {len(set(clean_words))} types in the novel.")
# Out:
# There are a total of 224339 tokens in the novel.
# There are a total of 19928 types in the novel.

# %% [markdown]
# ## 2.2 Normalization:

# %%
from pattern.en import lemma

# %%
lemmatized_words = []
for word in clean_words:
    try:
        lemma_word = lemma(word)
        lemmatized_words.append(lemma_word)
    except StopIteration:
        # Handle the StopIteration error gracefully
        print(f"StopIteration raised for word: {word}")
        lemmatized_words.append(word)

# %% [markdown]
# After normalization:

# %%
print(f"There are a total of {len(lemmatized_words)} tokens in the novel.")
print(f"There are a total of {len(set(lemmatized_words))} types in the novel.")
# Out:
# There are a total of 224339 tokens in the novel.
# There are a total of 14925 types in the novel.

# %% [markdown]
# ## 2.3 Removing Stopwords

# %%
from nltk.corpus import stopwords
import random
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Hort\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
english_stopwords = set(stopwords.words("english"))
words_ns = [word for word in lemmatized_words if word not in english_stopwords]

# %%
# Initialize a Counter object from our processed list of words
count_ns = Counter(words_ns)

# Store 10 most common words and their counts as top_ten
top_ten_ns = count_ns.most_common(10)

# Print the top ten words and their counts
print(f"After preprocessing: {top_ten_ns}")
# Out:
# After preprocessing: [('.', 7797), ('hi', 2522), ('whale', 1481), ('thi', 1411), ('one', 921), ('say', 603), ('like', 580), ('see', 573), ('upon', 567), ('ship', 556)]

# %%
# Initialize a Counter object from our processed list of words
count = Counter(lemmatized_words)

# Store 10 most common words and their counts as top_ten
top_ten = count.most_common(10)

# Print the top ten words and their counts
print(f"After preprocessing: {top_ten}")
# Out:
# After preprocessing: [('the', 14615), ('.', 7797), ('be', 6999), ('of', 6723), ('and', 6449), ('a', 6426), ('to', 4659), ('in', 4212), ('that', 3030), ('it', 2880)]

# %% [markdown]
# From this point onward, we will make use the `no_stopwords` to do the next steps.

# %% [markdown]
# ## 2.4 Handling Less Occurrence Words:

# %%
for i, count in enumerate(Counter(words_ns).most_common()):
  print(i+1, count)
# Out:
# 1 ('.', 7797)
# 2 ('hi', 2522)
# 3 ('whale', 1481)
# 4 ('thi', 1411)
# 5 ('one', 921)
# 6 ('say', 603)
# 7 ('like', 580)
# 8 ('see', 573)
# 9 ('upon', 567)
# 10 ('ship', 556)
# 11 ('ahab', 498)
# 12 ('man', 498)
# 13 ('ye', 486)
# 14 ('go', 482)
# 15 ('sea', 466)
# 16 ('would', 460)
# 17 ('seem', 459)
# 18 ('old', 442)
# 19 ('time', 433)
# 20 ('boat', 424)
# 21 ('come', 406)
# 22 ('make', 372)
# 23 ('though', 366)
# 24 ('yet', 339)
# 25 ('captain', 337)
# 26 ('head', 333)
# 27 ('hand', 329)
# 28 ('look', 323)
# 29 ('long', 320)
# 30 ('chapter', 314)
# 31 ('think', 314)
# 32 ('thing', 312)
# 33 ('know', 311)
# 34 ('take', 309)
# 35 ('still', 307)
# 36 ('great', 305)
# 37 ('must', 292)
# 38 ('stand', 292)
# 39 ('two', 286)
# 40 ('last', 278)
# 41 ('way', 278)
# 42 ('thou', 264)
# 43 ('stubb', 257)
# 44 ('round', 254)
# 45 ('white', 251)
# 46 ('may', 250)
# 47 ('u', 250)
# 48 ('little', 249)
# 49 ('day', 248)
# 50 ('sperm', 241)
# 51 ('eye', 241)
# 52 ('three', 240)
# 53 ('queequeg', 239)
# 54 ('first', 236)
# 55 ('water', 231)
# 56 ('every', 230)
# 57 ('men', 230)
# 58 ('much', 222)
# 59 ('well', 216)
# 60 ('side', 214)
# 61 ('turn', 213)
# 62 ('give', 206)
# 63 ('never', 206)
# 64 ('even', 204)
# 65 ('cry', 204)
# 66 ('part', 201)
# 67 ('tell', 200)
# 68 ('good', 196)
# 69 ('almost', 195)
# 70 ('ever', 192)
# 71 ('call', 190)
# 72 ('find', 190)
# 73 ('starbuck', 189)
# 74 ('hear', 187)
# 75 ('sail', 185)
# 76 ('might', 182)
# 77 ('deck', 181)
# 78 ('away', 176)
# 79 ('world', 176)
# 80 ('pequod', 175)
# 81 ('hold', 175)
# 82 ('work', 172)
# 83 ('place', 171)
# 84 ('sort', 171)
# 85 ('get', 171)
# 86 ('back', 169)
# 87 ('many', 167)
# 88 ('among', 167)
# 89 ('live', 166)
# 90 ('sir', 161)
# 91 ('without', 161)
# 92 ('far', 159)
# 93 ('god', 159)
# 94 ('let', 159)
# 95 ('crew', 155)
# 96 ('right', 154)
# 97 ('line', 152)
# 98 ('night', 143)
# 99 ('life', 143)
# 100 ('feel', 141)
# 101 ('oh', 138)
# 102 ('air', 137)
# 103 ('keep', 137)
# 104 ('whole', 137)
# 105 ('aye', 135)
# 106 ('thu', 133)
# 107 ('harpooneer', 132)
# 108 ('sailor', 130)
# 109 ('thee', 129)
# 110 ('soon', 129)
# 111 ('run', 127)
# 112 ('feet', 126)
# 113 ('arm', 125)
# 114 ('full', 125)
# 115 ('small', 125)
# 116 ('leg', 124)
# 117 ('till', 122)
# 118 ('point', 122)
# 119 ('year', 120)
# 120 ('end', 119)
# 121 ('body', 119)
# 122 ('somethe', 119)
# 123 ('voyage', 118)
# 124 ('sight', 118)
# 125 ('moment', 116)
# 126 ('toward', 115)
# 127 ('face', 115)
# 128 ('mean', 114)
# 129 ('another', 113)
# 130 ('thy', 113)
# 131 ('heart', 112)
# 132 ('mate', 112)
# 133 ('leviathan', 111)
# 134 ('nothe', 111)
# 135 ('along', 110)
# 136 ('harpoon', 109)
# 137 ('wind', 108)
# 138 ('poor', 107)
# 139 ('fish', 107)
# 140 ('present', 107)
# 141 ('project', 106)
# 142 ('flask', 105)
# 143 ('roll', 105)
# 144 ('strike', 105)
# 145 ('speak', 103)
# 146 ('soul', 103)
# 147 ('lower', 102)
# 148 ('light', 102)
# 149 ('word', 101)
# 150 ('bow', 101)
# 151 ('set', 100)
# 152 ('high', 100)
# 153 ('begin', 100)
# 154 ('break', 100)
# 155 ('shall', 98)
# 156 ('matter', 98)
# 157 ('case', 97)
# 158 ('form', 97)
# 159 ('new', 97)
# 160 ('pass', 97)
# 161 ('nantucket', 96)
# 162 ('order', 96)
# 163 ('strange', 96)
# 164 ('land', 95)
# 165 ('open', 94)
# 166 ('also', 93)
# 167 ('name', 92)
# 168 ('mind', 92)
# 169 ('sun', 92)
# 170 ('certain', 91)
# 171 ('dead', 91)
# 172 ('iron', 91)
# 173 ('remain', 91)
# 174 ('however', 90)
# 175 ('draw', 90)
# 176 ('black', 90)
# 177 ('half', 89)
# 178 ('mark', 88)
# 179 ('touch', 88)
# 180 ('whether', 88)
# 181 ('ocean', 88)
# 182 ('indee', 88)
# 183 ('tail', 87)
# 184 ('sometime', 87)
# 185 ('perhap', 87)
# 186 ('whose', 86)
# 187 ('sit', 86)
# 188 ('carry', 86)
# 189 ('moby', 85)
# 190 ('true', 85)
# 191 ('dick', 84)
# 192 ('jonah', 84)
# 193 ('bear', 83)
# 194 ('wild', 83)
# 195 ('rise', 83)
# 196 ('dart', 82)
# 197 ('jaw', 82)
# 198 ('hard', 81)
# 199 ('bone', 81)
# 200 ('hour', 81)
# 201 ('within', 80)
# 202 ('length', 80)
# 203 ('oil', 80)
# 204 ('alway', 80)
# 205 ('death', 79)
# 206 ('swim', 79)
# 207 ('young', 79)
# 208 ('pull', 79)
# 209 ('near', 78)
# 210 ('large', 78)
# 211 ('reason', 78)
# 212 ('follow', 78)
# 213 ('chase', 78)
# 214 ('ere', 78)
# 215 ('cabin', 77)
# 216 ('spout', 77)
# 217 ('start', 76)
# 218 ('watch', 76)
# 219 ('sleep', 76)
# 220 ('beneath', 76)
# 221 ('instant', 76)
# 222 ('shark', 75)
# 223 ('cut', 75)
# 224 ('vessel', 75)
# 225 ('creature', 75)
# 226 ('lay', 75)
# 227 ('drop', 75)
# 228 ('put', 75)
# 229 ('bed', 75)
# 230 ('bildad', 75)
# 231 ('least', 74)
# 232 ('enough', 74)
# 233 ('morn', 74)
# 234 ('leave', 73)
# 235 ('vast', 73)
# 236 ('used', 73)
# 237 ('book', 72)
# 238 ('sound', 72)
# 239 ('often', 72)
# 240 ('king', 71)
# 241 ('board', 71)
# 242 ('fall', 71)
# 243 ('peleg', 71)
# 244 ('pip', 71)
# 245 ('deep', 70)
# 246 ('whalemen', 70)
# 247 ('general', 70)
# 248 ('die', 69)
# 249 ('lord', 69)
# 250 ('wave', 69)
# 251 ('bring', 69)
# 252 ('masthead', 68)
# 253 ('fly', 68)
# 254 ('chance', 68)
# 255 ('fire', 68)
# 256 ('rather', 68)
# 257 ('consider', 68)
# 258 ('kill', 67)
# 259 ('mouth', 67)
# 260 ('four', 67)
# 261 ('boy', 67)
# 262 ('busines', 67)
# 263 ('become', 67)
# 264 ('rest', 67)
# 265 ('therefore', 66)
# 266 ('catch', 66)
# 267 ('thousand', 66)
# 268 ('show', 66)
# 269 ('devil', 65)
# 270 ('best', 65)
# 271 ('lie', 65)
# 272 ('left', 65)
# 273 ('lose', 64)
# 274 ('close', 64)
# 275 ('try', 64)
# 276 ('better', 64)
# 277 ('lance', 64)
# 278 ('meet', 63)
# 279 ('heaven', 63)
# 280 ('since', 63)
# 281 ('fishery', 63)
# 282 ('grow', 62)
# 283 ('float', 62)
# 284 ('throw', 62)
# 285 ('oar', 62)
# 286 ('savage', 61)
# 287 ('second', 61)
# 288 ('together', 61)
# 289 ('concern', 61)
# 290 ('story', 60)
# 291 ('view', 60)
# 292 ('indian', 60)
# 293 ('particular', 60)
# 294 ('help', 60)
# 295 ('want', 60)
# 296 ('receive', 59)
# 297 ('themselve', 59)
# 298 ('cook', 59)
# 299 ('blow', 59)
# 300 ('hang', 59)
# 301 ('hint', 59)
# 302 ('suppose', 58)
# 303 ('mr.', 58)
# 304 ('forth', 58)
# 305 ('command', 58)
# 306 ('fine', 57)
# 307 ('sign', 57)
# 308 ('gutenbergtm', 57)
# 309 ('beside', 56)
# 310 ('fellow', 56)
# 311 ('peculiar', 56)
# 312 ('home', 56)
# 313 ('interval', 56)
# 314 ('next', 56)
# 315 ('advance', 56)
# 316 ('coffin', 55)
# 317 ('aloft', 55)
# 318 ('state', 55)
# 319 ('stern', 55)
# 320 ('forward', 55)
# 321 ('short', 55)
# 322 ('dark', 55)
# 323 ('stranger', 55)
# 324 ('les', 54)
# 325 ('carpenter', 54)
# 326 ('glance', 54)
# 327 ('voice', 54)
# 328 ('blood', 54)
# 329 ('wake', 54)
# 330 ('curiou', 54)
# 331 ('entire', 54)
# 332 ('tashtego', 54)
# 333 ('grand', 53)
# 334 ('monster', 53)
# 335 ('mast', 53)
# 336 ('account', 53)
# 337 ('rope', 53)
# 338 ('smoke', 53)
# 339 ('circumstance', 53)
# 340 ('bottom', 53)
# 341 ('slowly', 52)
# 342 ('broad', 52)
# 343 ('fact', 52)
# 344 ('wonder', 52)
# 345 ('clear', 51)
# 346 ('people', 51)
# 347 ('craft', 51)
# 348 ('hunt', 51)
# 349 ('ten', 50)
# 350 ('hundr', 50)
# 351 ('object', 50)
# 352 ('suddenly', 50)
# 353 ('shoot', 50)
# 354 ('common', 50)
# 355 ('nevertheles', 50)
# 356 ('ivory', 50)
# 357 ('gaze', 50)
# 358 ('seek', 50)
# 359 ('english', 49)
# 360 ('behind', 49)
# 361 ('mortal', 49)
# 362 ('seat', 49)
# 363 ('behold', 49)
# 364 ('hoist', 49)
# 365 ('fast', 49)
# 366 ('several', 48)
# 367 ('purpose', 48)
# 368 ('green', 48)
# 369 ('answer', 48)
# 370 ('rush', 48)
# 371 ('instance', 48)
# 372 ('stop', 48)
# 373 ('plank', 48)
# 374 ('sink', 48)
# 375 ('teeth', 47)
# 376 ('island', 47)
# 377 ('mighty', 47)
# 378 ('reach', 47)
# 379 ('toss', 47)
# 380 ('use', 46)
# 381 ('whatever', 46)
# 382 ('shake', 46)
# 383 ('whaleman', 46)
# 384 ('mass', 46)
# 385 ('else', 46)
# 386 ('swing', 46)
# 387 ('room', 46)
# 388 ('course', 46)
# 389 ('pipe', 45)
# 390 ('doubt', 45)
# 391 ('mariner', 45)
# 392 ('wide', 45)
# 393 ('sure', 45)
# 394 ('rig', 45)
# 395 ('anythe', 45)
# 396 ('cross', 45)
# 397 ('door', 45)
# 398 ('power', 45)
# 399 ('somehow', 44)
# 400 ('art', 44)
# 401 ('nature', 44)
# 402 ('coast', 44)
# 403 ('rock', 44)
# 404 ('leap', 44)
# 405 ('especially', 44)
# 406 ('heave', 44)
# 407 ('hammer', 44)
# 408 ('friend', 43)
# 409 ('brain', 43)
# 410 ('noble', 43)
# 411 ('drive', 43)
# 412 ('layer', 43)
# 413 ('straight', 43)
# 414 ('sudden', 43)
# 415 ('hail', 43)
# 416 ('term', 42)
# 417 ('wood', 42)
# 418 ('alone', 42)
# 419 ('earth', 42)
# 420 ('calm', 42)
# 421 ('fear', 42)
# 422 ('send', 42)
# 423 ('nigh', 42)
# 424 ('blue', 42)
# 425 ('need', 42)
# 426 ('house', 42)
# 427 ('jet', 42)
# 428 ('plain', 42)
# 429 ('fill', 42)
# 430 ('seamen', 42)
# 431 ('brow', 42)
# 432 ('aspect', 42)
# 433 ('wondrou', 42)
# 434 ('forecastle', 41)
# 435 ('regard', 41)
# 436 ('hat', 41)
# 437 ('mere', 41)
# 438 ('learn', 41)
# 439 ('fix', 41)
# 440 ('move', 41)
# 441 ('distance', 41)
# 442 ('step', 41)
# 443 ('lean', 41)
# 444 ('quite', 41)
# 445 ('age', 41)
# 446 ('read', 41)
# 447 ('terror', 41)
# 448 ('dash', 41)
# 449 ('encounter', 41)
# 450 ('surface', 41)
# 451 ('queer', 40)
# 452 ('raise', 40)
# 453 ('wear', 40)
# 454 ('belong', 40)
# 455 ('return', 40)
# 456 ('american', 40)
# 457 ('happen', 40)
# 458 ('mine', 40)
# 459 ('shipmate', 40)
# 460 ('question', 40)
# 461 ('sky', 40)
# 462 ('grind', 40)
# 463 ('circle', 40)
# 464 ('seize', 40)
# 465 ('enter', 39)
# 466 ('skeleton', 39)
# 467 ('fancy', 39)
# 468 ('tear', 39)
# 469 ('plainly', 39)
# 470 ('lead', 39)
# 471 ('whaleship', 39)
# 472 ('variou', 39)
# 473 ('idea', 39)
# 474 ('forehead', 39)
# 475 ('company', 39)
# 476 ('fluke', 39)
# 477 ('drag', 39)
# 478 ('hope', 39)
# 479 ('cast', 39)
# 480 ('steelkilt', 39)
# 481 ('picture', 38)
# 482 ('talk', 38)
# 483 ('either', 38)
# 484 ('around', 38)
# 485 ('hunter', 38)
# 486 ('person', 38)
# 487 ('manner', 38)
# 488 ('single', 38)
# 489 ('conclude', 38)
# 490 ('sharp', 38)
# 491 ('minute', 38)
# 492 ('slide', 38)
# 493 ('flame', 38)
# 494 ('gain', 38)
# 495 ('whaler', 38)
# 496 ('copy', 37)
# 497 ('scene', 37)
# 498 ('pacific', 37)
# 499 ('bulwark', 37)
# 500 ('rib', 37)
# 501 ('suspend', 37)
# 502 ('observe', 37)
# 503 ('quick', 37)
# 504 ('cape', 37)
# 505 ('famou', 37)
# 506 ('burn', 37)
# 507 ('ear', 37)
# 508 ('wall', 37)
# 509 ('human', 37)
# 510 ('ready', 37)
# 511 ('five', 37)
# 512 ('truth', 37)
# 513 ('level', 37)
# 514 ('keel', 37)
# 515 ('hull', 37)
# 516 ('sing', 36)
# 517 ('beat', 36)
# 518 ('secure', 36)
# 519 ('greenland', 36)
# 520 ('horn', 36)
# 521 ('nearly', 36)
# 522 ('mile', 36)
# 523 ('previou', 36)
# 524 ('act', 36)
# 525 ('middle', 36)
# 526 ('low', 36)
# 527 ('unknown', 36)
# 528 ('top', 36)
# 529 ('lift', 36)
# 530 ('except', 36)
# 531 ('natural', 36)
# 532 ('gentlemen', 36)
# 533 ('include', 35)
# 534 ('love', 35)
# 535 ('strong', 35)
# 536 ('tow', 35)
# 537 ('mention', 35)
# 538 ('passage', 35)
# 539 ('free', 35)
# 540 ('officer', 35)
# 541 ('easy', 35)
# 542 ('peril', 35)
# 543 ('hide', 35)
# 544 ('third', 35)
# 545 ('law', 35)
# 546 ('burst', 35)
# 547 ('nose', 35)
# 548 ('daggoo', 35)
# 549 ('play', 34)
# 550 ('fifty', 34)
# 551 ('ashore', 34)
# 552 ('add', 34)
# 553 ('lad', 34)
# 554 ('sweep', 34)
# 555 ('spring', 34)
# 556 ('red', 34)
# 557 ('inch', 34)
# 558 ('table', 34)
# 559 ('number', 34)
# 560 ('skin', 34)
# 561 ('thought', 34)
# 562 ('heavy', 34)
# 563 ('gold', 34)
# 564 ('fit', 34)
# 565 ('de', 34)
# 566 ('proceed', 33)
# 567 ('bulk', 33)
# 568 ('force', 33)
# 569 ('bit', 33)
# 570 ('storm', 33)
# 571 ('pause', 33)
# 572 ('chief', 33)
# 573 ('invest', 33)
# 574 ('believe', 33)
# 575 ('already', 33)
# 576 ('landlord', 33)
# 577 ('weather', 33)
# 578 ('hammock', 33)
# 579 ('fair', 33)
# 580 ('none', 33)
# 581 ('completely', 33)
# 582 ('hardly', 33)
# 583 ('whaleboat', 33)
# 584 ('fin', 33)
# 585 ('blind', 33)
# 586 ('shore', 32)
# 587 ('ago', 32)
# 588 ('capture', 32)
# 589 ('mad', 32)
# 590 ('cruise', 32)
# 591 ('unles', 32)
# 592 ('ha', 32)
# 593 ('row', 32)
# 594 ('pitch', 32)
# 595 ('furnish', 32)
# 596 ('dure', 32)
# 597 ('glide', 32)
# 598 ('complete', 32)
# 599 ('proper', 32)
# 600 ('substance', 32)
# 601 ('hence', 32)
# 602 ('woe', 32)
# 603 ('coil', 32)
# 604 ('foundation', 32)
# 605 ('gutenberg', 31)
# 606 ('quarterdeck', 31)
# 607 ('generally', 31)
# 608 ('yard', 31)
# 609 ('motion', 31)
# 610 ('degree', 31)
# 611 ('specy', 31)
# 612 ('steady', 31)
# 613 ('eat', 31)
# 614 ('darknes', 31)
# 615 ('foot', 31)
# 616 ('prove', 31)
# 617 ('thrust', 31)
# 618 ('shadow', 31)
# 619 ('visible', 31)
# 620 ('swear', 31)
# 621 ('mount', 31)
# 622 ('acros', 31)
# 623 ('nantucketer', 31)
# 624 ('steer', 31)
# 625 ('dye', 31)
# 626 ('late', 30)
# 627 ('country', 30)
# 628 ('huge', 30)
# 629 ('kind', 30)
# 630 ('steel', 30)
# 631 ('interest', 30)
# 632 ('thunder', 30)
# 633 ('possible', 30)
# 634 ('upper', 30)
# 635 ('possibly', 30)
# 636 ('really', 30)
# 637 ('cold', 30)
# 638 ('hump', 30)
# 639 ('wrinkle', 30)
# 640 ('soft', 30)
# 641 ('fight', 30)
# 642 ('laugh', 30)
# 643 ('father', 30)
# 644 ('sideway', 30)
# 645 ('helm', 30)
# 646 ('aft', 30)
# 647 ('born', 30)
# 648 ('cask', 30)
# 649 ('supper', 29)
# 650 ('altogether', 29)
# 651 ('front', 29)
# 652 ('pretty', 29)
# 653 ('fresh', 29)
# 654 ('entirely', 29)
# 655 ('gale', 29)
# 656 ('vain', 29)
# 657 ('jump', 29)
# 658 ('port', 29)
# 659 ('drink', 29)
# 660 ('final', 29)
# 661 ('subject', 29)
# 662 ('cannibal', 29)
# 663 ('certainly', 29)
# 664 ('anchor', 29)
# 665 ('skull', 29)
# 666 ('descend', 29)
# 667 ('secret', 29)
# 668 ('swell', 29)
# 669 ('lurk', 29)
# 670 ('owner', 29)
# 671 ('strain', 29)
# 672 ('strangely', 29)
# 673 ('leeward', 29)
# 674 ('elephant', 29)
# 675 ('pole', 29)
# 676 ('content', 28)
# 677 ('fedallah', 28)
# 678 ('honor', 28)
# 679 ('doubloon', 28)
# 680 ('appear', 28)
# 681 ('ancient', 28)
# 682 ('hast', 28)
# 683 ('fishermen', 28)
# 684 ('royal', 28)
# 685 ('roar', 28)
# 686 ('cover', 28)
# 687 ('dive', 28)
# 688 ('bound', 28)
# 689 ('tree', 28)
# 690 ('separate', 28)
# 691 ('mild', 28)
# 692 ('considerable', 28)
# 693 ('astern', 28)
# 694 ('offer', 28)
# 695 ('meanwhile', 28)
# 696 ('push', 28)
# 697 ('i.', 28)
# 698 ('spot', 28)
# 699 ('chest', 28)
# 700 ('pagan', 28)
# 701 ('dare', 28)
# 702 ('spread', 28)
# 703 ('latitude', 28)
# 704 ('gunwale', 28)
# 705 ('coat', 27)
# 706 ('please', 27)
# 707 ('visit', 27)
# 708 ('lock', 27)
# 709 ('respect', 27)
# 710 ('write', 27)
# 711 ('finally', 27)
# 712 ('rear', 27)
# 713 ('isle', 27)
# 714 ('pace', 27)
# 715 ('wooden', 27)
# 716 ('blubber', 27)
# 717 ('lip', 27)
# 718 ('kick', 27)
# 719 ('dream', 27)
# 720 ('duty', 27)
# 721 ('eyee', 27)
# 722 ('figure', 27)
# 723 ('aside', 27)
# 724 ('walk', 27)
# 725 ('provide', 27)
# 726 ('spirit', 27)
# 727 ('wholly', 27)
# 728 ('alongside', 27)
# 729 ('electronic', 27)
# 730 ('street', 26)
# 731 ('midnight', 26)
# 732 ('whitenes', 26)
# 733 ('paint', 26)
# 734 ('dutch', 26)
# 735 ('pick', 26)
# 736 ('warm', 26)
# 737 ('swallow', 26)
# 738 ('thirty', 26)
# 739 ('battle', 26)
# 740 ('smell', 26)
# 741 ('enormou', 26)
# 742 ('silent', 26)
# 743 ('pay', 26)
# 744 ('dog', 26)
# 745 ('base', 26)
# 746 ('hair', 26)
# 747 ('measure', 26)
# 748 ('somewhat', 26)
# 749 ('shout', 26)
# 750 ('otherwise', 26)
# 751 ('contain', 26)
# 752 ('notice', 26)
# 753 ('experience', 26)
# 754 ('sweet', 26)
# 755 ('descry', 26)
# 756 ('bodily', 26)
# 757 ('reveal', 26)
# 758 ('herd', 26)
# 759 ('accord', 26)
# 760 ('supply', 25)
# 761 ('mountain', 25)
# 762 ('blacksmith', 25)
# 763 ('letter', 25)
# 764 ('bird', 25)
# 765 ('history', 25)
# 766 ('seldom', 25)
# 767 ('bright', 25)
# 768 ('christian', 25)
# 769 ('pilot', 25)
# 770 ('different', 25)
# 771 ('pursuit', 25)
# 772 ('nail', 25)
# 773 ('unite', 25)
# 774 ('perceive', 25)
# 775 ('nay', 25)
# 776 ('thick', 25)
# 777 ('afterward', 25)
# 778 ('precisely', 25)
# 779 ('lash', 25)
# 780 ('similar', 25)
# 781 ('strip', 25)
# 782 ('son', 25)
# 783 ('season', 25)
# 784 ('forget', 25)
# 785 ('shape', 25)
# 786 ('squall', 25)
# 787 ('ahead', 25)
# 788 ('evince', 25)
# 789 ('parsee', 25)
# 790 ('glory', 24)
# 791 ('trouble', 24)
# 792 ('shoulder', 24)
# 793 ('globe', 24)
# 794 ('stuff', 24)
# 795 ('shroud', 24)
# 796 ('crack', 24)
# 797 ('regular', 24)
# 798 ('watery', 24)
# 799 ('crowd', 24)
# 800 ('compass', 24)
# 801 ('desire', 24)
# 802 ('exactly', 24)
# 803 ('understand', 24)
# 804 ('repeat', 24)
# 805 ('blast', 24)
# 806 ('swift', 24)
# 807 ('spend', 24)
# 808 ('remember', 24)
# 809 ('continue', 24)
# 810 ('event', 24)
# 811 ('instead', 24)
# 812 ('overboard', 24)
# 813 ('upward', 24)
# 814 ('ring', 24)
# 815 ('billow', 24)
# 816 ('ask', 24)
# 817 ('escape', 24)
# 818 ('twenty', 24)
# 819 ('strength', 24)
# 820 ('declare', 24)
# 821 ('thyself', 24)
# 822 ('owe', 24)
# 823 ('wreck', 24)
# 824 ('forge', 23)
# 825 ('french', 23)
# 826 ('empty', 23)
# 827 ('six', 23)
# 828 ('stretch', 23)
# 829 ('breath', 23)
# 830 ('master', 23)
# 831 ('barb', 23)
# 832 ('hook', 23)
# 833 ('breeze', 23)
# 834 ('hollow', 23)
# 835 ('beach', 23)
# 836 ('beyond', 23)
# 837 ('mutter', 23)
# 838 ('tall', 23)
# 839 ('fiery', 23)
# 840 ('centre', 23)
# 841 ('yield', 23)
# 842 ('handle', 23)
# 843 ('curse', 23)
# 844 ('settle', 23)
# 845 ('jacket', 23)
# 846 ('finger', 23)
# 847 ('hole', 23)
# 848 ('spare', 23)
# 849 ('stay', 23)
# 850 ('square', 23)
# 851 ('hot', 23)
# 852 ('real', 23)
# 853 ('remove', 23)
# 854 ('mother', 23)
# 855 ('instantly', 23)
# 856 ('pile', 23)
# 857 ('month', 23)
# 858 ('alive', 23)
# 859 ('porpoise', 23)
# 860 ('insert', 23)
# 861 ('prow', 23)
# 862 ('direction', 23)
# 863 ('affair', 23)
# 864 ('haul', 23)
# 865 ('attach', 23)
# 866 ('tackle', 23)
# 867 ('st.', 23)
# 868 ('lakeman', 23)
# 869 ('produce', 22)
# 870 ('aboard', 22)
# 871 ('queen', 22)
# 872 ('lamp', 22)
# 873 ('magnitude', 22)
# 874 ('log', 22)
# 875 ('original', 22)
# 876 ('animal', 22)
# 877 ('glass', 22)
# 878 ('exceed', 22)
# 879 ('south', 22)
# 880 ('colour', 22)
# 881 ('forty', 22)
# 882 ('stove', 22)
# 883 ('eight', 22)
# 884 ('surprise', 22)
# 885 ('strive', 22)
# 886 ('virtue', 22)
# 887 ('phantom', 22)
# 888 ('toil', 22)
# 889 ('horse', 22)
# 890 ('fate', 22)
# 891 ('jolly', 22)
# 892 ('arrive', 22)
# 893 ('piece', 22)
# 894 ('negro', 22)
# 895 ('howl', 22)
# 896 ('wonderful', 22)
# 897 ('higher', 22)
# 898 ('stick', 22)
# 899 ('terrible', 22)
# 900 ('palm', 22)
# 901 ('dry', 22)
# 902 ('bend', 22)
# 903 ('flesh', 22)
# 904 ('bury', 22)
# 905 ('deadly', 22)
# 906 ('century', 22)
# 907 ('divide', 22)
# 908 ('loose', 22)
# 909 ('meantime', 22)
# 910 ('flank', 22)
# 911 ('.e', 22)
# 912 ('lee', 21)
# 913 ('delight', 21)
# 914 ('attend', 21)
# 915 ('mistake', 21)
# 916 ('charge', 21)
# 917 ('fail', 21)
# 918 ('somewhere', 21)
# 919 ('dim', 21)
# 920 ('engage', 21)
# 921 ('demand', 21)
# 922 ('directly', 21)
# 923 ('town', 21)
# 924 ('torment', 21)
# 925 ('drown', 21)
# 926 ('spar', 21)
# 927 ('truly', 21)
# 928 ('whisper', 21)
# 929 ('contrast', 21)
# 930 ('change', 21)
# 931 ('disappear', 21)
# 932 ('likewise', 21)
# 933 ('save', 21)
# 934 ('snatch', 21)
# 935 ('wife', 21)
# 936 ('shock', 21)
# 937 ('quickly', 21)
# 938 ('solitary', 21)
# 939 ('silence', 21)
# 940 ('lady', 21)
# 941 ('plant', 21)
# 942 ('lofty', 21)
# 943 ('direct', 21)
# 944 ('crown', 21)
# 945 ('flash', 21)
# 946 ('mainmast', 21)
# 947 ('period', 21)
# 948 ('windlass', 21)
# 949 ('windward', 21)
# 950 ('example', 21)
# 951 ('perch', 21)
# 952 ('tub', 21)
# 953 ('pump', 21)
# 954 ('radney', 21)
# 955 ('bucket', 20)
# 956 ('gabriel', 20)
# 957 ('prepare', 20)
# 958 ('former', 20)
# 959 ('size', 20)
# 960 ('stream', 20)
# 961 ('holy', 20)
# 962 ('spermaceti', 20)
# 963 ('important', 20)
# 964 ('serve', 20)
# 965 ('everythe', 20)
# 966 ('discover', 20)
# 967 ('lookout', 20)
# 968 ('vicinity', 20)
# 969 ('distant', 20)
# 970 ('ah', 20)
# 971 ('bag', 20)
# 972 ('hover', 20)
# 973 ('gigantic', 20)
# 974 ('fling', 20)
# 975 ('downward', 20)
# 976 ('carve', 20)
# 977 ('space', 20)
# 978 ('fain', 20)
# 979 ('bless', 20)
# 980 ('floor', 20)
# 981 ('neck', 20)
# 982 ('outer', 20)
# 983 ('past', 20)
# 984 ('profound', 20)
# 985 ('slightest', 20)
# 986 ('native', 20)
# 987 ('erect', 20)
# 988 ('leak', 20)
# 989 ('moreover', 20)
# 990 ('foe', 20)
# 991 ('dost', 20)
# 992 ('canst', 20)
# 993 ('dignity', 20)
# 994 ('golden', 20)
# 995 ('dat', 20)
# 996 ('license', 19)
# 997 ('pulpit', 19)
# 998 ('prophet', 19)
# 999 ('trywork', 19)
# 1000 ('lightn', 19)
# 1001 ('needle', 19)
# 1002 ('compare', 19)
# 1003 ('pale', 19)
# 1004 ('pain', 19)
# 1005 ('modern', 19)
# 1006 ('largest', 19)
# 1007 ('approach', 19)
# 1008 ('ordinary', 19)
# 1009 ('bore', 19)
# 1010 ('atlantic', 19)
# 1011 ('hill', 19)
# 1012 ('paper', 19)
# 1013 ('snap', 19)
# 1014 ('employ', 19)
# 1015 ('occur', 19)
# 1016 ('comrade', 19)
# 1017 ('depart', 19)
# 1018 ('ishmael', 19)
# 1019 ('quietly', 19)
# 1020 ('trunk', 19)
# 1021 ('deeper', 19)
# 1022 ('difference', 19)
# 1023 ('breathe', 19)
# 1024 ('quit', 19)
# 1025 ('window', 19)
# 1026 ('quarter', 19)
# 1027 ('church', 19)
# 1028 ('worse', 19)
# 1029 ('england', 19)
# 1030 ('taper', 19)
# 1031 ('avast', 19)
# 1032 ('height', 19)
# 1033 ('tower', 19)
# 1034 ('hurry', 19)
# 1035 ('yellow', 19)
# 1036 ('coward', 19)
# 1037 ('game', 19)
# 1038 ('precise', 19)
# 1039 ('awful', 19)
# 1040 ('individual', 19)
# 1041 ('reel', 19)
# 1042 ('brave', 19)
# 1043 ('marble', 19)
# 1044 ('eternal', 19)
# 1045 ('depth', 19)
# 1046 ('swiftly', 19)
# 1047 ('future', 19)
# 1048 ('merely', 19)
# 1049 ('wise', 19)
# 1050 ('gentleman', 19)
# 1051 ('wing', 19)
# 1052 ('fasten', 19)
# 1053 ('murder', 19)
# 1054 ('horizon', 19)
# 1055 ('retain', 19)
# 1056 ('ghost', 19)
# 1057 ('rapidly', 19)
# 1058 ('scuttle', 19)
# 1059 ('load', 19)
# 1060 ('bubble', 19)
# 1061 ('derive', 19)
# 1062 ('race', 19)
# 1063 ('distribute', 19)
# 1064 ('..', 19)
# 1065 ('star', 18)
# 1066 ('school', 18)
# 1067 ('arch', 18)
# 1068 ('afford', 18)
# 1069 ('slay', 18)
# 1070 ('foam', 18)
# 1071 ('wherea', 18)
# 1072 ('belly', 18)
# 1073 ('attack', 18)
# 1074 ('stroke', 18)
# 1075 ('element', 18)
# 1076 ('destroy', 18)
# 1077 ('withdraw', 18)
# 1078 ('wheel', 18)
# 1079 ('city', 18)
# 1080 ('slip', 18)
# 1081 ('field', 18)
# 1082 ('yonder', 18)
# 1083 ('plunge', 18)
# 1084 ('fowl', 18)
# 1085 ('nameles', 18)
# 1086 ('conceit', 18)
# 1087 ('bedford', 18)
# 1088 ('pocket', 18)
# 1089 ('ice', 18)
# 1090 ('weary', 18)
# 1091 ('presently', 18)
# 1092 ('doom', 18)
# 1093 ('corner', 18)
# 1094 ('opposite', 18)
# 1095 ('chap', 18)
# 1096 ('rate', 18)
# 1097 ('resolve', 18)
# 1098 ('sake', 18)
# 1099 ('inside', 18)
# 1100 ('guess', 18)
# 1101 ('thereby', 18)
# 1102 ('fool', 18)
# 1103 ('prodigiou', 18)
# 1104 ('fold', 18)
# 1105 ('effect', 18)
# 1106 ('heat', 18)
# 1107 ('clothe', 18)
# 1108 ('peculiarity', 18)
# 1109 ('spite', 18)
# 1110 ('cheer', 18)
# 1111 ('fashion', 18)
# 1112 ('feature', 18)
# 1113 ('strait', 18)
# 1114 ('roman', 18)
# 1115 ('token', 18)
# 1116 ('regularly', 18)
# 1117 ('worship', 18)
# 1118 ('commander', 18)
# 1119 ('intense', 18)
# 1120 ('chiefly', 18)
# 1121 ('revolve', 18)
# 1122 ('preciou', 18)
# 1123 ('folio', 18)
# 1124 ('german', 18)
# 1125 ('thin', 18)
# 1126 ('rod', 18)
# 1127 ('perth', 18)
# 1128 ('agreement', 18)
# 1129 ('ebook', 17)
# 1130 ('chart', 17)
# 1131 ('tun', 17)
# 1132 ('nation', 17)
# 1133 ('immediately', 17)
# 1134 ('sword', 17)
# 1135 ('boil', 17)
# 1136 ('barrel', 17)
# 1137 ('whalebone', 17)
# 1138 ('weight', 17)
# 1139 ('require', 17)
# 1140 ('address', 17)
# 1141 ('express', 17)
# 1142 ('numerou', 17)
# 1143 ('bold', 17)
# 1144 ('hussey', 17)
# 1145 ('pursue', 17)
# 1146 ('report', 17)
# 1147 ('damn', 17)
# 1148 ('reply', 17)
# 1149 ('tie', 17)
# 1150 ('east', 17)
# 1151 ('west', 17)
# 1152 ('grasp', 17)
# 1153 ('care', 17)
# 1154 ('grin', 17)
# 1155 ('merchant', 17)
# 1156 ('influence', 17)
# 1157 ('sway', 17)
# 1158 ('careful', 17)
# 1159 ('shudder', 17)
# 1160 ('bad', 17)
# 1161 ('miss', 17)
# 1162 ('fetch', 17)
# 1163 ('tomahawk', 17)
# 1164 ('previously', 17)
# 1165 ('fatal', 17)
# 1166 ('child', 17)
# 1167 ('stir', 17)
# 1168 ('lo', 17)
# 1169 ('whence', 17)
# 1170 ('join', 17)
# 1171 ('cause', 17)
# 1172 ('thine', 17)
# 1173 ('starboard', 17)
# 1174 ('hitherto', 17)
# 1175 ('alarm', 17)
# 1176 ('heed', 17)
# 1177 ('bid', 17)
# 1178 ('hum', 17)
# 1179 ('harbor', 17)
# 1180 ('chain', 17)
# 1181 ('brace', 17)
# 1182 ('shiver', 17)
# 1183 ('madnes', 17)
# 1184 ('spine', 17)
# 1185 ('originally', 17)
# 1186 ('deem', 17)
# 1187 ('foolish', 17)
# 1188 ('steward', 17)
# 1189 ('longer', 17)
# 1190 ('involve', 17)
# 1191 ('lantern', 17)
# 1192 ('weave', 17)
# 1193 ('solid', 17)
# 1194 ('continually', 17)
# 1195 ('dance', 17)
# 1196 ('anywhere', 16)
# 1197 ('character', 16)
# 1198 ('fastfish', 16)
# 1199 ('loosefish', 16)
# 1200 ('squeeze', 16)
# 1201 ('candle', 16)
# 1202 ('flag', 16)
# 1203 ('immense', 16)
# 1204 ('summer', 16)
# 1205 ('agree', 16)
# 1206 ('obey', 16)
# 1207 ('special', 16)
# 1208 ('dread', 16)
# 1209 ('reference', 16)
# 1210 ('pirate', 16)
# 1211 ('joy', 16)
# 1212 ('main', 16)
# 1213 ('children', 16)
# 1214 ('wish', 16)
# 1215 ('possess', 16)
# 1216 ('weapon', 16)
# 1217 ('gather', 16)
# 1218 ('hit', 16)
# 1219 ('mystic', 16)
# 1220 ('impossible', 16)
# 1221 ('rare', 16)
# 1222 ('whenever', 16)
# 1223 ('knock', 16)
# 1224 ('surround', 16)
# 1225 ('cool', 16)
# 1226 ('lung', 16)
# 1227 ('salt', 16)
# 1228 ('putt', 16)
# 1229 ('keen', 16)
# 1230 ('earthly', 16)
# 1231 ('invisible', 16)
# 1232 ('unaccountable', 16)
# 1233 ('connect', 16)
# 1234 ('canoe', 16)
# 1235 ('block', 16)
# 1236 ('angel', 16)
# 1237 ('pleasant', 16)
# 1238 ('shade', 16)
# 1239 ('fairly', 16)
# 1240 ('opinion', 16)
# 1241 ('clean', 16)
# 1242 ('grass', 16)
# 1243 ('range', 16)
# 1244 ('sheet', 16)
# 1245 ('steal', 16)
# 1246 ('actually', 16)
# 1247 ('twist', 16)
# 1248 ('bolt', 16)
# 1249 ('puff', 16)
# 1250 ('cloud', 16)
# 1251 ('odd', 16)
# 1252 ('hue', 16)
# 1253 ('calculate', 16)
# 1254 ('civilize', 16)
# 1255 ('maintain', 16)
# 1256 ('admit', 16)
# 1257 ('fully', 16)
# 1258 ('distinct', 16)
# 1259 ('freely', 16)
# 1260 ('amid', 16)
# 1261 ('yell', 16)
# 1262 ('embrace', 16)
# 1263 ('issue', 16)
# 1264 ('fro', 16)
# 1265 ('superior', 16)
# 1266 ('yojo', 16)
# 1267 ('uncommon', 16)
# 1268 ('beef', 16)
# 1269 ('insult', 16)
# 1270 ('flow', 16)
# 1271 ('vapor', 16)
# 1272 ('usage', 16)
# 1273 ('elevate', 16)
# 1274 ('link', 16)
# 1275 ('doughboy', 16)
# 1276 ('scientific', 16)
# 1277 ('horizontal', 16)
# 1278 ('obtain', 16)
# 1279 ('additional', 16)
# 1280 ('hate', 16)
# 1281 ('cling', 16)
# 1282 ('oarsmen', 16)
# 1283 ('donation', 16)
# 1284 ('extract', 15)
# 1285 ('hark', 15)
# 1286 ('note', 15)
# 1287 ('preserve', 15)
# 1288 ('public', 15)
# 1289 ('create', 15)
# 1290 ('job', 15)
# 1291 ('twelve', 15)
# 1292 ('frequently', 15)
# 1293 ('hoop', 15)
# 1294 ('afraid', 15)
# 1295 ('article', 15)
# 1296 ('strand', 15)
# 1297 ('shoal', 15)
# 1298 ('hell', 15)
# 1299 ('appearance', 15)
# 1300 ('bethink', 15)
# 1301 ('occasion', 15)
# 1302 ('bench', 15)
# 1303 ('ourselve', 15)
# 1304 ('sense', 15)
# 1305 ('marvellou', 15)
# 1306 ('ill', 15)
# 1307 ('marvel', 15)
# 1308 ('horror', 15)
# 1309 ('endles', 15)
# 1310 ('boot', 15)
# 1311 ('spray', 15)
# 1312 ('plenty', 15)
# 1313 ('spear', 15)
# 1314 ('sell', 15)
# 1315 ('pour', 15)
# 1316 ('clock', 15)
# 1317 ('violent', 15)
# 1318 ('cord', 15)
# 1319 ('dinner', 15)
# 1320 ('escap', 15)
# 1321 ('apply', 15)
# 1322 ('succeed', 15)
# 1323 ('increase', 15)
# 1324 ('thank', 15)
# 1325 ('exceedingly', 15)
# 1326 ('ho', 15)
# 1327 ('glimpse', 15)
# 1328 ('apart', 15)
# 1329 ('memory', 15)
# 1330 ('faith', 15)
# 1331 ('immortal', 15)
# 1332 ('utmost', 15)
# 1333 ('appall', 15)
# 1334 ('sleeper', 15)
# 1335 ('fore', 15)
# 1336 ('conduct', 15)
# 1337 ('silently', 15)
# 1338 ('retreat', 15)
# 1339 ('position', 15)
# 1340 ('sank', 15)
# 1341 ('perilou', 15)
# 1342 ('impression', 15)
# 1343 ('fee', 15)
# 1344 ('noon', 15)
# 1345 ('eh', 15)
# 1346 ('nearer', 15)
# 1347 ('volume', 15)
# 1348 ('party', 15)
# 1349 ('frantic', 15)
# 1350 ('latter', 15)
# 1351 ('elijah', 15)
# 1352 ('intent', 15)
# 1353 ('grey', 15)
# 1354 ('split', 15)
# 1355 ('weld', 15)
# 1356 ('critical', 15)
# 1357 ('limb', 15)
# 1358 ('canal', 15)
# 1359 ('mood', 15)
# 1360 ('binnacle', 15)
# 1361 ('ii', 15)
# 1362 ('smite', 15)
# 1363 ('horrible', 15)
# 1364 ('cun', 15)
# 1365 ('contact', 15)
# 1366 ('warp', 15)
# 1367 ('corpse', 15)
# 1368 ('breakfast', 14)
# 1369 ('townho', 14)
# 1370 ('ambergri', 14)
# 1371 ('archive', 14)
# 1372 ('gay', 14)
# 1373 ('tongue', 14)
# 1374 ('splinter', 14)
# 1375 ('sixty', 14)
# 1376 ('equal', 14)
# 1377 ('consideration', 14)
# 1378 ('london', 14)
# 1379 ('extend', 14)
# 1380 ('flood', 14)
# 1381 ('pair', 14)
# 1382 ('expand', 14)
# 1383 ('probably', 14)
# 1384 ('noise', 14)
# 1385 ('indirectly', 14)
# 1386 ('possession', 14)
# 1387 ('money', 14)
# 1388 ('extreme', 14)
# 1389 ('week', 14)
# 1390 ('desert', 14)
# 1391 ('family', 14)
# 1392 ('assure', 14)
# 1393 ('partly', 14)
# 1394 ('yea', 14)
# 1395 ('study', 14)
# 1396 ('mix', 14)
# 1397 ('share', 14)
# 1398 ('box', 14)
# 1399 ('presume', 14)
# 1400 ('tumble', 14)
# 1401 ('march', 14)
# 1402 ('rage', 14)
# 1403 ('mystery', 14)
# 1404 ('tattoo', 14)
# 1405 ('screw', 14)
# 1406 ('accompany', 14)
# 1407 ('comply', 14)
# 1408 ('blend', 14)
# 1409 ('crawl', 14)
# 1410 ('closely', 14)
# 1411 ('naught', 14)
# 1412 ('treat', 14)
# 1413 ('worth', 14)
# 1414 ('canva', 14)
# 1415 ('sleet', 14)
# 1416 ('grave', 14)
# 1417 ('taste', 14)
# 1418 ('unseen', 14)
# 1419 ('plate', 14)
# 1420 ('continual', 14)
# 1421 ('lesson', 14)
# 1422 ('coin', 14)
# 1423 ('whirl', 14)
# 1424 ('hatch', 14)
# 1425 ('listen', 14)
# 1426 ('murmur', 14)
# 1427 ('priest', 14)
# 1428 ('promise', 14)
# 1429 ('post', 14)
# 1430 ('file', 14)
# 1431 ('blade', 14)
# 1432 ('pot', 14)
# 1433 ('resume', 14)
# 1434 ('food', 14)
# 1435 ('clap', 14)
# 1436 ('stump', 14)
# 1437 ('lively', 14)
# 1438 ('firm', 14)
# 1439 ('terrific', 14)
# 1440 ('external', 14)
# 1441 ('assume', 14)
# 1442 ('customary', 14)
# 1443 ('knife', 14)
# 1444 ('simultaneously', 14)
# 1445 ('occasionally', 14)
# 1446 ('loom', 14)
# 1447 ('oarsman', 14)
# 1448 ('curl', 14)
# 1449 ('dam', 14)
# 1450 ('spade', 14)
# 1451 ('paragraph', 14)
# 1452 ('author', 13)
# 1453 ('ramadan', 13)
# 1454 ('stone', 13)
# 1455 ('fountain', 13)
# 1456 ('musket', 13)
# 1457 ('sunrise', 13)
# 1458 ('describe', 13)
# 1459 ('quantity', 13)
# 1460 ('breed', 13)
# 1461 ('ponderou', 13)
# 1462 ('america', 13)
# 1463 ('doubtles', 13)
# 1464 ('pray', 13)
# 1465 ('ground', 13)
# 1466 ('polar', 13)
# 1467 ('bread', 13)
# 1468 ('endure', 13)
# 1469 ('utterly', 13)
# 1470 ('dangerou', 13)
# 1471 ('ball', 13)
# 1472 ('elsewhere', 13)
# 1473 ('naturalist', 13)
# 1474 ('cherish', 13)
# 1475 ('lake', 13)
# 1476 ('enchant', 13)
# 1477 ('score', 13)
# 1478 ('image', 13)
# 1479 ('awe', 13)
# 1480 ('paid', 13)
# 1481 ('wherefore', 13)
# 1482 ('lodge', 13)
# 1483 ('snow', 13)
# 1484 ('inn', 13)
# 1485 ('peer', 13)
# 1486 ('represent', 13)
# 1487 ('oriental', 13)
# 1488 ('freeze', 13)
# 1489 ('attempt', 13)
# 1490 ('private', 13)
# 1491 ('calmly', 13)
# 1492 ('big', 13)
# 1493 ('seaman', 13)
# 1494 ('mat', 13)
# 1495 ('cheek', 13)
# 1496 ('honest', 13)
# 1497 ('idol', 13)
# 1498 ('scorch', 13)
# 1499 ('spell', 13)
# 1500 ('sprang', 13)
# 1501 ('scatter', 13)
# 1502 ('subsequent', 13)
# 1503 ('wrapped', 13)
# 1504 ('crush', 13)
# 1505 ('stave', 13)
# 1506 ('backward', 13)
# 1507 ('linger', 13)
# 1508 ('slightly', 13)
# 1509 ('hither', 13)
# 1510 ('mist', 13)
# 1511 ('widow', 13)
# 1512 ('affect', 13)
# 1513 ('ascend', 13)
# 1514 ('bible', 13)
# 1515 ('authority', 13)
# 1516 ('speed', 13)
# 1517 ('consist', 13)
# 1518 ('sooner', 13)
# 1519 ('tide', 13)
# 1520 ('conscience', 13)
# 1521 ('arise', 13)
# 1522 ('eager', 13)
# 1523 ('straightway', 13)
# 1524 ('temple', 13)
# 1525 ('leane', 13)
# 1526 ('press', 13)
# 1527 ('greater', 13)
# 1528 ('fathom', 13)
# 1529 ('knee', 13)
# 1530 ('jerk', 13)
# 1531 ('mrs.', 13)
# 1532 ('tiller', 13)
# 1533 ('stout', 13)
# 1534 ('quaker', 13)
# 1535 ('practical', 13)
# 1536 ('neither', 13)
# 1537 ('relieve', 13)
# 1538 ('fork', 13)
# 1539 ('remarkable', 13)
# 1540 ('readily', 13)
# 1541 ('repose', 13)
# 1542 ('host', 13)
# 1543 ('hearse', 13)
# 1544 ('fiend', 13)
# 1545 ('league', 13)
# 1546 ('fleece', 13)
# 1547 ('fourth', 13)
# 1548 ('derick', 13)
# 1549 ('bunger', 13)
# 1550 ('copyright', 13)
# 1551 ('literary', 13)
# 1552 ('chapel', 12)
# 1553 ('sunset', 12)
# 1554 ('monstrou', 12)
# 1555 ('dish', 12)
# 1556 ('blanket', 12)
# 1557 ('prairie', 12)
# 1558 ('virgin', 12)
# 1559 ('perish', 12)
# 1560 ('dust', 12)
# 1561 ('spanish', 12)
# 1562 ('allusion', 12)
# 1563 ('tribe', 12)
# 1564 ('wine', 12)
# 1565 ('narrative', 12)
# 1566 ('a.d.', 12)
# 1567 ('fat', 12)
# 1568 ('wound', 12)
# 1569 ('prey', 12)
# 1570 ('edge', 12)
# 1571 ('deal', 12)
# 1572 ('southern', 12)
# 1573 ('john', 12)
# 1574 ('twice', 12)
# 1575 ('stage', 12)
# 1576 ('excite', 12)
# 1577 ('display', 12)
# 1578 ('breach', 12)
# 1579 ('commodore', 12)
# 1580 ('root', 12)
# 1581 ('principle', 12)
# 1582 ('charm', 12)
# 1583 ('sand', 12)
# 1584 ('travel', 12)
# 1585 ('sadly', 12)
# 1586 ('contrary', 12)
# 1587 ('perform', 12)
# 1588 ('judgment', 12)
# 1589 ('social', 12)
# 1590 ('north', 12)
# 1591 ('ash', 12)
# 1592 ('loud', 12)
# 1593 ('interior', 12)
# 1594 ('quiet', 12)
# 1595 ('chip', 12)
# 1596 ('lengthwise', 12)
# 1597 ('scrape', 12)
# 1598 ('oath', 12)
# 1599 ('faint', 12)
# 1600 ('resemble', 12)
# 1601 ('knot', 12)
# 1602 ('central', 12)
# 1603 ('depend', 12)
# 1604 ('plan', 12)
# 1605 ('wrist', 12)
# 1606 ('pine', 12)
# 1607 ('mend', 12)
# 1608 ('clam', 12)
# 1609 ('double', 12)
# 1610 ('dress', 12)
# 1611 ('greatest', 12)
# 1612 ('unusual', 12)
# 1613 ('movement', 12)
# 1614 ('dent', 12)
# 1615 ('vengeance', 12)
# 1616 ('malice', 12)
# 1617 ('scarce', 12)
# 1618 ('allow', 12)
# 1619 ('traveller', 12)
# 1620 ('distinguish', 12)
# 1621 ('trowser', 12)
# 1622 ('refuse', 12)
# 1623 ('girl', 12)
# 1624 ('moody', 12)
# 1625 ('reign', 12)
# 1626 ('shriek', 12)
# 1627 ('survive', 12)
# 1628 ('countenance', 12)
# 1629 ('accident', 12)
# 1630 ('despair', 12)
# 1631 ('mankind', 12)
# 1632 ('contract', 12)
# 1633 ('solemn', 12)
# 1634 ('record', 12)
# 1635 ('page', 12)
# 1636 ('murderer', 12)
# 1637 ('expose', 12)
# 1638 ('flight', 12)
# 1639 ('bowel', 12)
# 1640 ('afloat', 12)
# 1641 ('commotion', 12)
# 1642 ('excellent', 12)
# 1643 ('lonely', 12)
# 1644 ('naturally', 12)
# 1645 ('quality', 12)
# 1646 ('shut', 12)
# 1647 ('nake', 12)
# 1648 ('fearful', 12)
# 1649 ('bull', 12)
# 1650 ('permit', 12)
# 1651 ('utter', 12)
# 1652 ('didst', 12)
# 1653 ('agent', 12)
# 1654 ('hearty', 12)
# 1655 ('incline', 12)
# 1656 ('seven', 12)
# 1657 ('warn', 12)
# 1658 ('rapid', 12)
# 1659 ('den', 12)
# 1660 ('capstan', 12)
# 1661 ('beware', 12)
# 1662 ('fleet', 12)
# 1663 ('wrench', 12)
# 1664 ('narwhale', 12)
# 1665 ('system', 12)
# 1666 ('octavo', 12)
# 1667 ('iii', 12)
# 1668 ('correspond', 12)
# 1669 ('detail', 12)
# 1670 ('dumb', 12)
# 1671 ('symbol', 12)
# 1672 ('firmly', 12)
# 1673 ('seal', 12)
# 1674 ('ginger', 12)
# 1675 ('guernseyman', 12)
# 1676 ('chowder', 11)
# 1677 ('cetology', 11)
# 1678 ('crotch', 11)
# 1679 ('lifebuoy', 11)
# 1680 ('teach', 11)
# 1681 ('ignorance', 11)
# 1682 ('greek', 11)
# 1683 ('valuable', 11)
# 1684 ('fare', 11)
# 1685 ('foul', 11)
# 1686 ('baleen', 11)
# 1687 ('afternoon', 11)
# 1688 ('fifteen', 11)
# 1689 ('inferior', 11)
# 1690 ('cuvier', 11)
# 1691 ('mysteriou', 11)
# 1692 ('gleam', 11)
# 1693 ('whip', 11)
# 1694 ('convenient', 11)
# 1695 ('extremity', 11)
# 1696 ('adventure', 11)
# 1697 ('samuel', 11)
# 1698 ('brother', 11)
# 1699 ('northern', 11)
# 1700 ('current', 11)
# 1701 ('upright', 11)
# 1702 ('exclaim', 11)
# 1703 ('grim', 11)
# 1704 ('involuntarily', 11)
# 1705 ('wash', 11)
# 1706 ('peep', 11)
# 1707 ('infallibly', 11)
# 1708 ('valley', 11)
# 1709 ('crazy', 11)
# 1710 ('passenger', 11)
# 1711 ('egyptian', 11)
# 1712 ('weigh', 11)
# 1713 ('slave', 11)
# 1714 ('suspect', 11)
# 1715 ('recall', 11)
# 1716 ('remote', 11)
# 1717 ('shirt', 11)
# 1718 ('gloom', 11)
# 1719 ('frost', 11)
# 1720 ('service', 11)
# 1721 ('blacknes', 11)
# 1722 ('judge', 11)
# 1723 ('pity', 11)
# 1724 ('moor', 11)
# 1725 ('perpendicular', 11)
# 1726 ('winter', 11)
# 1727 ('cup', 11)
# 1728 ('steak', 11)
# 1729 ('muffle', 11)
# 1730 ('beard', 11)
# 1731 ('announce', 11)
# 1732 ('wait', 11)
# 1733 ('plane', 11)
# 1734 ('narrow', 11)
# 1735 ('early', 11)
# 1736 ('beget', 11)
# 1737 ('unearthly', 11)
# 1738 ('war', 11)
# 1739 ('carefully', 11)
# 1740 ('operation', 11)
# 1741 ('comprehend', 11)
# 1742 ('explain', 11)
# 1743 ('dawn', 11)
# 1744 ('dip', 11)
# 1745 ('japan', 11)
# 1746 ('significant', 11)
# 1747 ('entitle', 11)
# 1748 ('vital', 11)
# 1749 ('spiritual', 11)
# 1750 ('ladder', 11)
# 1751 ('trace', 11)
# 1752 ('prolong', 11)
# 1753 ('tone', 11)
# 1754 ('cable', 11)
# 1755 ('flee', 11)
# 1756 ('wharf', 11)
# 1757 ('search', 11)
# 1758 ('evil', 11)
# 1759 ('fright', 11)
# 1760 ('berth', 11)
# 1761 ('obviou', 11)
# 1762 ('wic', 11)
# 1763 ('stagger', 11)
# 1764 ('attitude', 11)
# 1765 ('suck', 11)
# 1766 ('occupy', 11)
# 1767 ('waist', 11)
# 1768 ('rule', 11)
# 1769 ('peace', 11)
# 1770 ('exist', 11)
# 1771 ('paddle', 11)
# 1772 ('desperate', 11)
# 1773 ('vocation', 11)
# 1774 ('shift', 11)
# 1775 ('cod', 11)
# 1776 ('emperor', 11)
# 1777 ('precede', 11)
# 1778 ('strongly', 11)
# 1779 ('aught', 11)
# 1780 ('typhoon', 11)
# 1781 ('barbaric', 11)
# 1782 ('helmsman', 11)
# 1783 ('clutch', 11)
# 1784 ('temporary', 11)
# 1785 ('indispensable', 11)
# 1786 ('lovely', 11)
# 1787 ('spectacle', 11)
# 1788 ('knowledge', 11)
# 1789 ('steadily', 11)
# 1790 ('luck', 11)
# 1791 ('comprise', 11)
# 1792 ('expect', 11)
# 1793 ('wet', 11)
# 1794 ('invariably', 11)
# 1795 ('grant', 11)
# 1796 ('band', 11)
# 1797 ('action', 11)
# 1798 ('abound', 11)
# 1799 ('indifferent', 11)
# 1800 ('subtle', 11)
# 1801 ('emotion', 11)
# 1802 ('bite', 11)
# 1803 ('perseu', 11)
# 1804 ('thread', 11)
# 1805 ('throughout', 11)
# 1806 ('heap', 11)
# 1807 ('hiss', 11)
# 1808 ('smaller', 11)
# 1809 ('bestow', 11)
# 1810 ('detach', 11)
# 1811 ('recognise', 11)
# 1812 ('intend', 11)
# 1813 ('summit', 11)
# 1814 ('glad', 11)
# 1815 ('rail', 11)
# 1816 ('snowwhite', 11)
# 1817 ('monomaniac', 11)
# 1818 ('combine', 11)
# 1819 ('organ', 11)
# 1820 ('spouthole', 11)
# 1821 ('lid', 11)
# 1822 ('um', 11)
# 1823 ('access', 11)
# 1824 ('bosom', 10)
# 1825 ('merry', 10)
# 1826 ('albatros', 10)
# 1827 ('gam', 10)
# 1828 ('brit', 10)
# 1829 ('jeroboam', 10)
# 1830 ('bachelor', 10)
# 1831 ('mildly', 10)
# 1832 ('remind', 10)
# 1833 ('sacre', 10)
# 1834 ('pierce', 10)
# 1835 ('retire', 10)
# 1836 ('skill', 10)
# 1837 ('threaten', 10)
# 1838 ('choose', 10)
# 1839 ('prevent', 10)
# 1840 ('active', 10)
# 1841 ('fierce', 10)
# 1842 ('property', 10)
# 1843 ('velocity', 10)
# 1844 ('waste', 10)
# 1845 ('build', 10)
# 1846 ('cooper', 10)
# 1847 ('scoresby', 10)
# 1848 ('curiosity', 10)
# 1849 ('emerge', 10)
# 1850 ('landsmen', 10)
# 1851 ('pen', 10)
# 1852 ('limit', 10)
# 1853 ('thither', 10)
# 1854 ('handful', 10)
# 1855 ('silver', 10)
# 1856 ('key', 10)
# 1857 ('abandon', 10)
# 1858 ('office', 10)
# 1859 ('simple', 10)
# 1860 ('brief', 10)
# 1861 ('induce', 10)
# 1862 ('embark', 10)
# 1863 ('gradually', 10)
# 1864 ('dear', 10)
# 1865 ('pack', 10)
# 1866 ('sole', 10)
# 1867 ('outside', 10)
# 1868 ('glitter', 10)
# 1869 ('equator', 10)
# 1870 ('society', 10)
# 1871 ('earnest', 10)
# 1872 ('ala', 10)
# 1873 ('midst', 10)
# 1874 ('remotest', 10)
# 1875 ('tar', 10)
# 1876 ('stoop', 10)
# 1877 ('meat', 10)
# 1878 ('direful', 10)
# 1879 ('spoil', 10)
# 1880 ('ought', 10)
# 1881 ('chair', 10)
# 1882 ('tomorrow', 10)
# 1883 ('stair', 10)
# 1884 ('surgeon', 10)
# 1885 ('baby', 10)
# 1886 ('glisten', 10)
# 1887 ('biscuit', 10)
# 1888 ('blaze', 10)
# 1889 ('awake', 10)
# 1890 ('softly', 10)
# 1891 ('seriou', 10)
# 1892 ('stare', 10)
# 1893 ('stock', 10)
# 1894 ('joke', 10)
# 1895 ('zone', 10)
# 1896 ('reflection', 10)
# 1897 ('affright', 10)
# 1898 ('chat', 10)
# 1899 ('mostly', 10)
# 1900 ('frighten', 10)
# 1901 ('women', 10)
# 1902 ('shortly', 10)
# 1903 ('grief', 10)
# 1904 ('tablet', 10)
# 1905 ('yesterday', 10)
# 1906 ('comfort', 10)
# 1907 ('feed', 10)
# 1908 ('methink', 10)
# 1909 ('venerable', 10)
# 1910 ('contrivance', 10)
# 1911 ('uplift', 10)
# 1912 ('prayer', 10)
# 1913 ('smallest', 10)
# 1914 ('sin', 10)
# 1915 ('gasp', 10)
# 1916 ('heel', 10)
# 1917 ('prick', 10)
# 1918 ('hideou', 10)
# 1919 ('startle', 10)
# 1920 ('smooth', 10)
# 1921 ('eddy', 10)
# 1922 ('gently', 10)
# 1923 ('count', 10)
# 1924 ('george', 10)
# 1925 ('woman', 10)
# 1926 ('print', 10)
# 1927 ('couple', 10)
# 1928 ('throne', 10)
# 1929 ('boldly', 10)
# 1930 ('ignorant', 10)
# 1931 ('expression', 10)
# 1932 ('consternation', 10)
# 1933 ('quohog', 10)
# 1934 ('navy', 10)
# 1935 ('vague', 10)
# 1936 ('pound', 10)
# 1937 ('nearest', 10)
# 1938 ('japanese', 10)
# 1939 ('alike', 10)
# 1940 ('wilt', 10)
# 1941 ('piou', 10)
# 1942 ('religion', 10)
# 1943 ('th', 10)
# 1944 ('accurse', 10)
# 1945 ('stricken', 10)
# 1946 ('hereafter', 10)
# 1947 ('preliminary', 10)
# 1948 ('domestic', 10)
# 1949 ('hatchway', 10)
# 1950 ('allude', 10)
# 1951 ('consume', 10)
# 1952 ('task', 10)
# 1953 ('imperial', 10)
# 1954 ('withstand', 10)
# 1955 ('valiant', 10)
# 1956 ('kingpost', 10)
# 1957 ('headsman', 10)
# 1958 ('quest', 10)
# 1959 ('tambourine', 10)
# 1960 ('heighten', 10)
# 1961 ('seam', 10)
# 1962 ('soil', 10)
# 1963 ('manxman', 10)
# 1964 ('peak', 10)
# 1965 ('claim', 10)
# 1966 ('deny', 10)
# 1967 ('cap', 10)
# 1968 ('problem', 10)
# 1969 ('murderou', 10)
# 1970 ('trade', 10)
# 1971 ('superstitiou', 10)
# 1972 ('lima', 10)
# 1973 ('associate', 10)
# 1974 ('whaleline', 10)
# 1975 ('easily', 10)
# 1976 ('vibrate', 10)
# 1977 ('hemp', 10)
# 1978 ('information', 10)
# 1979 ('canaller', 10)
# 1980 ('signal', 10)
# 1981 ('ton', 10)
# 1982 ('vice', 10)
# 1983 ('dense', 10)
# 1984 ('harem', 10)
# 1985 ('trademark', 10)
# 1986 ('refund', 10)
# 1987 ('.f', 10)
# 1988 ('surmise', 9)
# 1989 ('heidelburgh', 9)
# 1990 ('quadrant', 9)
# 1991 ('result', 9)
# 1992 ('domain', 9)
# 1993 ('statement', 9)
# 1994 ('shine', 9)
# 1995 ('beast', 9)
# 1996 ('scarcely', 9)
# 1997 ('incredible', 9)
# 1998 ('lowly', 9)
# 1999 ('breast', 9)
# 2000 ('sport', 9)
# 2001 ('climb', 9)
# 2002 ('garden', 9)
# 2003 ('creation', 9)
# 2004 ('larger', 9)
# 2005 ('branch', 9)
# 2006 ('spire', 9)
# 2007 ('million', 9)
# 2008 ('region', 9)
# 2009 ('assault', 9)
# 2010 ('tremendou', 9)
# 2011 ('nine', 9)
# 2012 ('curve', 9)
# 2013 ('entrance', 9)
# 2014 ('male', 9)
# 2015 ('damp', 9)
# 2016 ('china', 9)
# 2017 ('seemingly', 9)
# 2018 ('magic', 9)
# 2019 ('wed', 9)
# 2020 ('trance', 9)
# 2021 ('mystical', 9)
# 2022 ('jove', 9)
# 2023 ('river', 9)
# 2024 ('rag', 9)
# 2025 ('enjoy', 9)
# 2026 ('confess', 9)
# 2027 ('butter', 9)
# 2028 ('pyramid', 9)
# 2029 ('scale', 9)
# 2030 ('archangel', 9)
# 2031 ('activity', 9)
# 2032 ('everlast', 9)
# 2033 ('forbid', 9)
# 2034 ('anxiou', 9)
# 2035 ('inquire', 9)
# 2036 ('ray', 9)
# 2037 ('miserable', 9)
# 2038 ('glare', 9)
# 2039 ('connexion', 9)
# 2040 ('peter', 9)
# 2041 ('privilege', 9)
# 2042 ('nervou', 9)
# 2043 ('anon', 9)
# 2044 ('exasperate', 9)
# 2045 ('wildly', 9)
# 2046 ('yon', 9)
# 2047 ('chimney', 9)
# 2048 ('angle', 9)
# 2049 ('bitter', 9)
# 2050 ('button', 9)
# 2051 ('hurrah', 9)
# 2052 ('stiff', 9)
# 2053 ('anybody', 9)
# 2054 ('yoke', 9)
# 2055 ('immediate', 9)
# 2056 ('passion', 9)
# 2057 ('confidential', 9)
# 2058 ('render', 9)
# 2059 ('comfortable', 9)
# 2060 ('properly', 9)
# 2061 ('commence', 9)
# 2062 ('accomplish', 9)
# 2063 ('independent', 9)
# 2064 ('attention', 9)
# 2065 ('polish', 9)
# 2066 ('ease', 9)
# 2067 ('whereby', 9)
# 2068 ('harm', 9)
# 2069 ('daylight', 9)
# 2070 ('befall', 9)
# 2071 ('slight', 9)
# 2072 ('beg', 9)
# 2073 ('vigorou', 9)
# 2074 ('tropic', 9)
# 2075 ('slope', 9)
# 2076 ('sum', 9)
# 2077 ('attain', 9)
# 2078 ('mediterranean', 9)
# 2079 ('tempest', 9)
# 2080 ('match', 9)
# 2081 ('hardy', 9)
# 2082 ('blank', 9)
# 2083 ('unspeakable', 9)
# 2084 ('rumor', 9)
# 2085 ('eternity', 9)
# 2086 ('sufficiently', 9)
# 2087 ('mapple', 9)
# 2088 ('youth', 9)
# 2089 ('outward', 9)
# 2090 ('foremost', 9)
# 2091 ('founder', 9)
# 2092 ('mercy', 9)
# 2093 ('ensue', 9)
# 2094 ('slouch', 9)
# 2095 ('suspicion', 9)
# 2096 ('item', 9)
# 2097 ('intently', 9)
# 2098 ('usual', 9)
# 2099 ('timber', 9)
# 2100 ('moon', 9)
# 2101 ('refer', 9)
# 2102 ('await', 9)
# 2103 ('bowl', 9)
# 2104 ('robe', 9)
# 2105 ('singular', 9)
# 2106 ('philosopher', 9)
# 2107 ('intensity', 9)
# 2108 ('glow', 9)
# 2109 ('boom', 9)
# 2110 ('sensible', 9)
# 2111 ('phrase', 9)
# 2112 ('dollar', 9)
# 2113 ('bay', 9)
# 2114 ('intention', 9)
# 2115 ('feast', 9)
# 2116 ('duck', 9)
# 2117 ('nostril', 9)
# 2118 ('deserve', 9)
# 2119 ('launch', 9)
# 2120 ('animate', 9)
# 2121 ('maliciou', 9)
# 2122 ('apparently', 9)
# 2123 ('prospect', 9)
# 2124 ('variety', 9)
# 2125 ('determine', 9)
# 2126 ('material', 9)
# 2127 ('wigwam', 9)
# 2128 ('alter', 9)
# 2129 ('exhaust', 9)
# 2130 ('exact', 9)
# 2131 ('profit', 9)
# 2132 ('temporarily', 9)
# 2133 ('able', 9)
# 2134 ('sick', 9)
# 2135 ('los', 9)
# 2136 ('intolerable', 9)
# 2137 ('oppose', 9)
# 2138 ('simply', 9)
# 2139 ('reckon', 9)
# 2140 ('fade', 9)
# 2141 ('damage', 9)
# 2142 ('replace', 9)
# 2143 ('charity', 9)
# 2144 ('uncertain', 9)
# 2145 ('slumber', 9)
# 2146 ('apparition', 9)
# 2147 ('scream', 9)
# 2148 ('hereby', 9)
# 2149 ('expense', 9)
# 2150 ('discovery', 9)
# 2151 ('ascribe', 9)
# 2152 ('superstition', 9)
# 2153 ('courage', 9)
# 2154 ('hundred', 9)
# 2155 ('reasonable', 9)
# 2156 ('sparkle', 9)
# 2157 ('divine', 9)
# 2158 ('rack', 9)
# 2159 ('village', 9)
# 2160 ('fury', 9)
# 2161 ('quiver', 9)
# 2162 ('violently', 9)
# 2163 ('royalty', 9)
# 2164 ('halloa', 9)
# 2165 ('research', 9)
# 2166 ('argument', 9)
# 2167 ('finback', 9)
# 2168 ('clumsy', 9)
# 2169 ('brute', 9)
# 2170 ('convey', 9)
# 2171 ('impart', 9)
# 2172 ('re-serve', 9)
# 2173 ('lounge', 9)
# 2174 ('jam', 9)
# 2175 ('tumultuou', 9)
# 2176 ('vial', 9)
# 2177 ('specific', 9)
# 2178 ('necessity', 9)
# 2179 ('socket', 9)
# 2180 ('gun', 9)
# 2181 ('consequence', 9)
# 2182 ('dig', 9)
# 2183 ('cluster', 9)
# 2184 ('longitude', 9)
# 2185 ('vivid', 9)
# 2186 ('sad', 9)
# 2187 ('buffalo', 9)
# 2188 ('occasional', 9)
# 2189 ('slow', 9)
# 2190 ('churn', 9)
# 2191 ('waif', 9)
# 2192 ('wane', 9)
# 2193 ('struggle', 9)
# 2194 ('diminish', 9)
# 2195 ('sebastian', 9)
# 2196 ('section', 9)
# 2197 ('considerably', 9)
# 2198 ('lampfeeder', 9)
# 2199 ('duke', 9)
# 2200 ('enderby', 9)
# 2201 ('monkeyrope', 8)
# 2202 ('pitchpole', 8)
# 2203 ('schoolmaster', 8)
# 2204 ('castaway', 8)
# 2205 ('fossil', 8)
# 2206 ('vault', 8)
# 2207 ('generation', 8)
# 2208 ('hopeles', 8)
# 2209 ('path', 8)
# 2210 ('crook', 8)
# 2211 ('pliny', 8)
# 2212 ('....', 8)
# 2213 ('inward', 8)
# 2214 ('africa', 8)
# 2215 ('abide', 8)
# 2216 ('endeavor', 8)
# 2217 ('self', 8)
# 2218 ('flounder', 8)
# 2219 ('instinct', 8)
# 2220 ('moonlight', 8)
# 2221 ('amount', 8)
# 2222 ('agony', 8)
# 2223 ('opportunity', 8)
# 2224 ('witness', 8)
# 2225 ('ahoy', 8)
# 2226 ('largely', 8)
# 2227 ('haunt', 8)
# 2228 ('eagerly', 8)
# 2229 ('bloody', 8)
# 2230 ('perpendicularly', 8)
# 2231 ('colt', 8)
# 2232 ('song', 8)
# 2233 ('purse', 8)
# 2234 ('deliberately', 8)
# 2235 ('coral', 8)
# 2236 ('sleepy', 8)
# 2237 ('consciou', 8)
# 2238 ('particularly', 8)
# 2239 ('universal', 8)
# 2240 ('rub', 8)
# 2241 ('pure', 8)
# 2242 ('hood', 8)
# 2243 ('bowsprit', 8)
# 2244 ('dismal', 8)
# 2245 ('melt', 8)
# 2246 ('weep', 8)
# 2247 ('wretch', 8)
# 2248 ('pit', 8)
# 2249 ('entry', 8)
# 2250 ('puzzle', 8)
# 2251 ('unnatural', 8)
# 2252 ('beam', 8)
# 2253 ('tread', 8)
# 2254 ('ark', 8)
# 2255 ('bottle', 8)
# 2256 ('specimen', 8)
# 2257 ('tap', 8)
# 2258 ('jackknife', 8)
# 2259 ('monkey', 8)
# 2260 ('complexion', 8)
# 2261 ('brown', 8)
# 2262 ('bulkington', 8)
# 2263 ('pretend', 8)
# 2264 ('spin', 8)
# 2265 ('yarn', 8)
# 2266 ('tend', 8)
# 2267 ('highest', 8)
# 2268 ('stark', 8)
# 2269 ('string', 8)
# 2270 ('infernal', 8)
# 2271 ('eagernes', 8)
# 2272 ('symptom', 8)
# 2273 ('satisfy', 8)
# 2274 ('kille', 8)
# 2275 ('reality', 8)
# 2276 ('western', 8)
# 2277 ('timid', 8)
# 2278 ('foreign', 8)
# 2279 ('girdle', 8)
# 2280 ('milk', 8)
# 2281 ('august', 8)
# 2282 ('beautiful', 8)
# 2283 ('congregation', 8)
# 2284 ('bleed', 8)
# 2285 ('cave', 8)
# 2286 ('joint', 8)
# 2287 ('trick', 8)
# 2288 ('snowy', 8)
# 2289 ('shoe', 8)
# 2290 ('bell', 8)
# 2291 ('wherein', 8)
# 2292 ('joppa', 8)
# 2293 ('worthy', 8)
# 2294 ('wrong', 8)
# 2295 ('smile', 8)
# 2296 ('busy', 8)
# 2297 ('stab', 8)
# 2298 ('thrice', 8)
# 2299 ('anguish', 8)
# 2300 ('motionles', 8)
# 2301 ('proud', 8)
# 2302 ('popular', 8)
# 2303 ('sublime', 8)
# 2304 ('soothe', 8)
# 2305 ('grope', 8)
# 2306 ('mechanically', 8)
# 2307 ('rich', 8)
# 2308 ('serene', 8)
# 2309 ('undulate', 8)
# 2310 ('vow', 8)
# 2311 ('grace', 8)
# 2312 ('unlike', 8)
# 2313 ('effort', 8)
# 2314 ('snuff', 8)
# 2315 ('homage', 8)
# 2316 ('fearles', 8)
# 2317 ('noah', 8)
# 2318 ('inasmuch', 8)
# 2319 ('accordingly', 8)
# 2320 ('energy', 8)
# 2321 ('pry', 8)
# 2322 ('pin', 8)
# 2323 ('melancholy', 8)
# 2324 ('tent', 8)
# 2325 ('vineyard', 8)
# 2326 ('exclamation', 8)
# 2327 ('crow', 8)
# 2328 ('obliquely', 8)
# 2329 ('spil', 8)
# 2330 ('eventually', 8)
# 2331 ('landsman', 8)
# 2332 ('solemnly', 8)
# 2333 ('goodbye', 8)
# 2334 ('argue', 8)
# 2335 ('la', 8)
# 2336 ('remark', 8)
# 2337 ('topsail', 8)
# 2338 ('pronounce', 8)
# 2339 ('tong', 8)
# 2340 ('frequent', 8)
# 2341 ('bunch', 8)
# 2342 ('necessary', 8)
# 2343 ('narrate', 8)
# 2344 ('handspike', 8)
# 2345 ('whisker', 8)
# 2346 ('tusk', 8)
# 2347 ('cheese', 8)
# 2348 ('lone', 8)
# 2349 ('graze', 8)
# 2350 ('infinite', 8)
# 2351 ('operate', 8)
# 2352 ('distinctly', 8)
# 2353 ('vitality', 8)
# 2354 ('vicissitude', 8)
# 2355 ('hurl', 8)
# 2356 ('penetrate', 8)
# 2357 ('taffrail', 8)
# 2358 ('mould', 8)
# 2359 ('popularly', 8)
# 2360 ('pride', 8)
# 2361 ('tradition', 8)
# 2362 ('toe', 8)
# 2363 ('leviathanic', 8)
# 2364 ('veil', 8)
# 2365 ('science', 8)
# 2366 ('seventy', 8)
# 2367 ('macey', 8)
# 2368 ('duodecimo', 8)
# 2369 ('humor', 8)
# 2370 ('specially', 8)
# 2371 ('bank', 8)
# 2372 ('ripple', 8)
# 2373 ('structure', 8)
# 2374 ('huzza', 8)
# 2375 ('fluid', 8)
# 2376 ('copper', 8)
# 2377 ('official', 8)
# 2378 ('grandeur', 8)
# 2379 ('obedience', 8)
# 2380 ('daily', 8)
# 2381 ('turk', 8)
# 2382 ('dine', 8)
# 2383 ('comparatively', 8)
# 2384 ('vision', 8)
# 2385 ('inscrutable', 8)
# 2386 ('transparent', 8)
# 2387 ('measureles', 8)
# 2388 ('closer', 8)
# 2389 ('sustain', 8)
# 2390 ('hem', 8)
# 2391 ('frigate', 8)
# 2392 ('revenge', 8)
# 2393 ('fatality', 8)
# 2394 ('beauty', 8)
# 2395 ('medium', 8)
# 2396 ('breadth', 8)
# 2397 ('historical', 8)
# 2398 ('tooth', 8)
# 2399 ('volunteer', 8)
# 2400 ('stamp', 8)
# 2401 ('dimly', 8)
# 2402 ('publish', 8)
# 2403 ('shower', 8)
# 2404 ('drift', 8)
# 2405 ('equally', 8)
# 2406 ('bowsman', 8)
# 2407 ('sculpture', 8)
# 2408 ('rescue', 8)
# 2409 ('edition', 8)
# 2410 ('spiracle', 8)
# 2411 ('behead', 8)
# 2412 ('mayhew', 8)
# 2413 ('submerge', 8)
# 2414 ('holder', 8)
# 2415 ('drug', 8)
# 2416 ('vertebr', 8)
# 2417 ('spinal', 8)
# 2418 ('pod', 8)
# 2419 ('monsieur', 8)
# 2420 ('hey', 8)
# 2421 ('flip', 8)
# 2422 ('beer', 8)
# 2423 ('whatsoever', 7)
# 2424 ('language', 7)
# 2425 ('lazaru', 7)
# 2426 ('counterpane', 7)
# 2427 ('squire', 7)
# 2428 ('squid', 7)
# 2429 ('rachel', 7)
# 2430 ('version', 7)
# 2431 ('dan', 7)
# 2432 ('wallow', 7)
# 2433 ('therein', 7)
# 2434 ('serpent', 7)
# 2435 ('dragon', 7)
# 2436 ('bottomles', 7)
# 2437 ('gulf', 7)
# 2438 ('holland', 7)
# 2439 ('ruin', 7)
# 2440 ('grove', 7)
# 2441 ('disorder', 7)
# 2442 ('venture', 7)
# 2443 ('guard', 7)
# 2444 ('gallon', 7)
# 2445 ('gush', 7)
# 2446 ('enemy', 7)
# 2447 ('tale', 7)
# 2448 ('rainbow', 7)
# 2449 ('beale', 7)
# 2450 ('relate', 7)
# 2451 ('furiou', 7)
# 2452 ('onset', 7)
# 2453 ('portion', 7)
# 2454 ('arctic', 7)
# 2455 ('fisherman', 7)
# 2456 ('truck', 7)
# 2457 ('pistol', 7)
# 2458 ('flourish', 7)
# 2459 ('belt', 7)
# 2460 ('thence', 7)
# 2461 ('magnetic', 7)
# 2462 ('romantic', 7)
# 2463 ('meadow', 7)
# 2464 ('deliberate', 7)
# 2465 ('persian', 7)
# 2466 ('surely', 7)
# 2467 ('distinction', 7)
# 2468 ('honorable', 7)
# 2469 ('establish', 7)
# 2470 ('enable', 7)
# 2471 ('everybody', 7)
# 2472 ('earnestly', 7)
# 2473 ('leader', 7)
# 2474 ('bill', 7)
# 2475 ('motive', 7)
# 2476 ('sally', 7)
# 2477 ('risk', 7)
# 2478 ('destine', 7)
# 2479 ('halter', 7)
# 2480 ('everywhere', 7)
# 2481 ('patch', 7)
# 2482 ('tomb', 7)
# 2483 ('choke', 7)
# 2484 ('dock', 7)
# 2485 ('finish', 7)
# 2486 ('coal', 7)
# 2487 ('iceberg', 7)
# 2488 ('oldfashion', 7)
# 2489 ('confound', 7)
# 2490 ('resemblance', 7)
# 2491 ('parallel', 7)
# ...
# 14111 ('sailstunsail', 1)
# 14112 ('stunsailafter', 1)
# 14113 ('wager', 1)
# 14114 ('watchhe', 1)
# 14115 ('lookspale', 1)
# 14116 ('eyeslookit', 1)
# 14117 ('coatit', 1)
# 14118 ('sakei', 1)
# 14119 ('conjurehere', 1)
# 14120 ('icily', 1)
# 14121 ('petition', 1)
# 14122 ('shipi', 1)
# 14123 ('roundly', 1)
# 14124 ('itif', 1)
# 14125 ('wayfor', 1)
# 14126 ('onlyonly', 1)
# 14127 ('thatyou', 1)
# 14128 ('watchwhat', 1)
# 14129 ('icines', 1)
# 14130 ('unmisgive', 1)
# 14131 ('hardihood', 1)
# 14132 ('unenervate', 1)
# 14133 ('partiality', 1)
# 14134 ('undue', 1)
# 14135 ('boon', 1)
# 14136 ('ahabthough', 1)
# 14137 ('nowa', 1)
# 14138 ('tooye', 1)
# 14139 ('itrun', 1)
# 14140 ('ahabtouch', 1)
# 14141 ('prolongingly', 1)
# 14142 ('wordcaptain', 1)
# 14143 ('forgive', 1)
# 14144 ('rejection', 1)
# 14145 ('enchantment', 1)
# 14146 ('bigot', 1)
# 14147 ('fadeles', 1)
# 14148 ('manand', 1)
# 14149 ('crazybut', 1)
# 14150 ('likecureslike', 1)
# 14151 ('handmet', 1)
# 14152 ('thatgod', 1)
# 14153 ('airbut', 1)
# 14154 ('coatsmonsieur', 1)
# 14155 ('pipa', 1)
# 14156 ('hangdog', 1)
# 14157 ('cowardly', 1)
# 14158 ('onceseen', 1)
# 14159 ('cowards.hist', 1)
# 14160 ('ivoryoh', 1)
# 14161 ('downheart', 1)
# 14162 ('bulge', 1)
# 14163 ('ahaball', 1)
# 14164 ('sweptseem', 1)
# 14165 ('oceanfold', 1)
# 14166 ('dickand', 1)
# 14167 ('contrastingly', 1)
# 14168 ('clamp', 1)
# 14169 ('despot', 1)
# 14170 ('wan', 1)
# 14171 ('saywe', 1)
# 14172 ('watchmen', 1)
# 14173 ('limitsthe', 1)
# 14174 ('cabinscuttlehi', 1)
# 14175 ('nightdamp', 1)
# 14176 ('stonecarve', 1)
# 14177 ('sunshine', 1)
# 14178 ('mealsbreakfast', 1)
# 14179 ('unearth', 1)
# 14180 ('intermission', 1)
# 14181 ('speakone', 1)
# 14182 ('otherunles', 1)
# 14183 ('unmomentou', 1)
# 14184 ('polelike', 1)
# 14185 ('asunder', 1)
# 14186 ('forethrown', 1)
# 14187 ('ahabin', 1)
# 14188 ('commandingly', 1)
# 14189 ('subordinatesahab', 1)
# 14190 ('tyrant', 1)
# 14191 ('aftman', 1)
# 14192 ('mastheadsand', 1)
# 14193 ('heardwhat', 1)
# 14194 ('seesharp', 1)
# 14195 ('childrenseek', 1)
# 14196 ('myselfhe', 1)
# 14197 ('sheave', 1)
# 14198 ('downwardreeve', 1)
# 14199 ('saidtake', 1)
# 14200 ('siri', 1)
# 14201 ('milesahead', 1)
# 14202 ('thatwithin', 1)
# 14203 ('foothold', 1)
# 14204 ('deckend', 1)
# 14205 ('fastening', 1)
# 14206 ('carelessnes', 1)
# 14207 ('decisionone', 1)
# 14208 ('somewhatit', 1)
# 14209 ('redbil', 1)
# 14210 ('incommodiously', 1)
# 14211 ('untrackably', 1)
# 14212 ('mizenmasthead', 1)
# 14213 ('tanaquil', 1)
# 14214 ('lifebuoycoffin', 1)
# 14215 ('misname', 1)
# 14216 ('whalingship', 1)
# 14217 ('unrig', 1)
# 14218 ('halfunhinge', 1)
# 14219 ('hollowcheek', 1)
# 14220 ('sew', 1)
# 14221 ('exclaiminglook', 1)
# 14222 ('triply', 1)
# 14223 ('manseest', 1)
# 14224 ('thatpoint', 1)
# 14225 ('hammocki', 1)
# 14226 ('creware', 1)
# 14227 ('thenoh', 1)
# 14228 ('godadvance', 1)
# 14229 ('handsmay', 1)
# 14230 ('baptism', 1)
# 14231 ('deject', 1)
# 14232 ('steelblue', 1)
# 14233 ('separable', 1)
# 14234 ('pensive', 1)
# 14235 ('transparently', 1)
# 14236 ('manlike', 1)
# 14237 ('samson', 1)
# 14238 ('unspeckle', 1)
# 14239 ('masculine', 1)
# 14240 ('groom', 1)
# 14241 ('motionmost', 1)
# 14242 ('equatordenote', 1)
# 14243 ('haggardly', 1)
# 14244 ('unyield', 1)
# 14245 ('untotter', 1)
# 14246 ('clearnes', 1)
# 14247 ('innocency', 1)
# 14248 ('closecoil', 1)
# 14249 ('laughingey', 1)
# 14250 ('elve', 1)
# 14251 ('heedlessly', 1)
# 14252 ('gambol', 1)
# 14253 ('singe', 1)
# 14254 ('marge', 1)
# 14255 ('burntout', 1)
# 14256 ('aroma', 1)
# 14257 ('dispel', 1)
# 14258 ('cankerou', 1)
# 14259 ('cruelforbiddingnow', 1)
# 14260 ('wee', 1)
# 14261 ('dayvery', 1)
# 14262 ('thisi', 1)
# 14263 ('boyharpooneer', 1)
# 14264 ('fortyfortyforty', 1)
# 14265 ('agoago', 1)
# 14266 ('stormtime', 1)
# 14267 ('walledtown', 1)
# 14268 ('withoutoh', 1)
# 14269 ('heavines', 1)
# 14270 ('guineacoast', 1)
# 14271 ('slavery', 1)
# 14272 ('commandwhen', 1)
# 14273 ('halfsuspect', 1)
# 14274 ('beforeand', 1)
# 14275 ('farefit', 1)
# 14276 ('soilwhen', 1)
# 14277 ('poorest', 1)
# 14278 ('crustsaway', 1)
# 14279 ('girlwife', 1)
# 14280 ('pillowwife', 1)
# 14281 ('wiferather', 1)
# 14282 ('foamingly', 1)
# 14283 ('preymore', 1)
# 14284 ('manaye', 1)
# 14285 ('foolfoolold', 1)
# 14286 ('godcrack', 1)
# 14287 ('heartstave', 1)
# 14288 ('brainmockery', 1)
# 14289 ('boardlower', 1)
# 14290 ('starbuckswife', 1)
# 14291 ('sisterly', 1)
# 14292 ('playfellow', 1)
# 14293 ('awaythi', 1)
# 14294 ('themsome', 1)
# 14295 ('timeye', 1)
# 14296 ('loving', 1)
# 14297 ('longing', 1)
# 14298 ('errandboy', 1)
# 14299 ('albicore', 1)
# 14300 ('halfcut', 1)
# 14301 ('swathsstarbuck', 1)
# 14302 ('blanch', 1)
# 14303 ('motionlessly', 1)
# 14304 ('intervalsstep', 1)
# 14305 ('inspect', 1)
# 14306 ('dogvane', 1)
# 14307 ('acute', 1)
# 14308 ('vindicate', 1)
# 14309 ('metalliclike', 1)
# 14310 ('tiderip', 1)
# 14311 ('flatten', 1)
# 14312 ('sailsstunsail', 1)
# 14313 ('gulllike', 1)
# 14314 ('snowhill', 1)
# 14315 ('topgallantmast', 1)
# 14316 ('sameno', 1)
# 14317 ('attune', 1)
# 14318 ('prolonging', 1)
# 14319 ('lowerquick', 1)
# 14320 ('helmbrace', 1)
# 14321 ('hershiver', 1)
# 14322 ('herso', 1)
# 14323 ('boatsail', 1)
# 14324 ('setall', 1)
# 14325 ('deathglimmer', 1)
# 14326 ('nautilu', 1)
# 14327 ('noonmeadow', 1)
# 14328 ('turkishrug', 1)
# 14329 ('playfully', 1)
# 14330 ('interchangeably', 1)
# 14331 ('flagstaff', 1)
# 14332 ('softto', 1)
# 14333 ('skim', 1)
# 14334 ('joyousnessa', 1)
# 14335 ('ravish', 1)
# 14336 ('europa', 1)
# 14337 ('nuptial', 1)
# 14338 ('crete', 1)
# 14339 ('glorify', 1)
# 14340 ('sidecoincident', 1)
# 14341 ('awayon', 1)
# 14342 ('enticing', 1)
# 14343 ('namelessly', 1)
# 14344 ('entice', 1)
# 14345 ('glidest', 1)
# 14346 ('bejuggle', 1)
# 14347 ('handclapping', 1)
# 14348 ('rapture', 1)
# 14349 ('marbleize', 1)
# 14350 ('warningly', 1)
# 14351 ('hoveringly', 1)
# 14352 ('apeak', 1)
# 14353 ('woo', 1)
# 14354 ('birdsthe', 1)
# 14355 ('expectant', 1)
# 14356 ('keener', 1)
# 14357 ('weasel', 1)
# 14358 ('undiscoverable', 1)
# 14359 ('opendoor', 1)
# 14360 ('stratagem', 1)
# 14361 ('sidelingly', 1)
# 14362 ('pearlwhite', 1)
# 14363 ('unastonish', 1)
# 14364 ('dally', 1)
# 14365 ('gripe', 1)
# 14366 ('frail', 1)
# 14367 ('sternwreck', 1)
# 14368 ('crafty', 1)
# 14369 ('upraise', 1)
# 14370 ('flatface', 1)
# 14371 ('ripplingly', 1)
# 14372 ('rosesome', 1)
# 14373 ('waterthe', 1)
# 14374 ('vindictively', 1)
# 14375 ('overleap', 1)
# 14376 ('designation', 1)
# 14377 ('comprehensively', 1)
# 14378 ('mulberry', 1)
# 14379 ('antiochus', 1)
# 14380 ('maccabee', 1)
# 14381 ('insolent', 1)
# 14382 ('swimthough', 1)
# 14383 ('incuriously', 1)
# 14384 ('revolvingly', 1)
# 14385 ('planetarily', 1)
# 14386 ('hersail', 1)
# 14387 ('thebut', 1)
# 14388 ('shoutedsail', 1)
# 14389 ('whaledrive', 1)
# 14390 ('ravine', 1)
# 14391 ('prostration', 1)
# 14392 ('abbreviate', 1)
# 14393 ('feebler', 1)
# 14394 ('pointles', 1)
# 14395 ('draggingly', 1)
# 14396 ('armi', 1)
# 14397 ('meany', 1)
# 14398 ('fivethere', 1)
# 14399 ('good.help', 1)
# 14400 ('spouthand', 1)
# 14401 ('doublebank', 1)
# 14402 ('treblebank', 1)
# 14403 ('cranesthe', 1)
# 14404 ('herand', 1)
# 14405 ('doublejoint', 1)
# 14406 ('mobydick', 1)
# 14407 ('binnaclewatch', 1)
# 14408 ('allot', 1)
# 14409 ('heard.whose', 1)
# 14410 ('breadththu', 1)
# 14411 ('exclaimedthe', 1)
# 14412 ('soulles', 1)
# 14413 ('omenthe', 1)
# 14414 ('honorably', 1)
# 14415 ('darkle', 1)
# 14416 ('hint.begone', 1)
# 14417 ('coldi', 1)
# 14418 ('shiverhow', 1)
# 14419 ('sirtoo', 1)
# 14420 ('darkcry', 1)
# 14421 ('sirstraight', 1)
# 14422 ('slower', 1)
# 14423 ('windaloft', 1)
# 14424 ('downmr', 1)
# 14425 ('morning.then', 1)
# 14426 ('mainmastmen', 1)
# 14427 ('punctually', 1)
# 14428 ('forthe', 1)
# 14429 ('sailsaye', 1)
# 14430 ('matterit', 1)
# 14431 ('pertinaciou', 1)
# 14432 ('prescience', 1)
# 14433 ('invincible', 1)
# 14434 ('geniuse', 1)
# 14435 ('foretell', 1)
# 14436 ('trend', 1)
# 14437 ('proverbial', 1)
# 14438 ('evanescence', 1)
# 14439 ('acutenes', 1)
# 14440 ('windbound', 1)
# 14441 ('ninetythree', 1)
# 14442 ('inferable', 1)
# 14443 ('furrow', 1)
# 14444 ('missent', 1)
# 14445 ('ploughshare', 1)
# 14446 ('fellowsha', 1)
# 14447 ('spinewise', 1)
# 14448 ('seafor', 1)
# 14449 ('liveoak', 1)
# 14450 ('blowsright', 1)
# 14451 ('itye', 1)
# 14452 ('escapeblow', 1)
# 14453 ('trumpblister', 1)
# 14454 ('lungsahab', 1)
# 14455 ('miller', 1)
# 14456 ('watergate', 1)
# 14457 ('enslave', 1)
# 14458 ('thingsoak', 1)
# 14459 ('maple', 1)
# 14460 ('hempyet', 1)
# 14461 ('valor', 1)
# 14462 ('guiltines', 1)
# 14463 ('onenes', 1)
# 14464 ('outspreadingly', 1)
# 14465 ('waving', 1)
# 14466 ('bluenes', 1)
# 14467 ('whalespout', 1)
# 14468 ('keynote', 1)
# 14469 ('orchestra', 1)
# 14470 ('asmuch', 1)
# 14471 ('aheadmoby', 1)
# 14472 ('bravadoe', 1)
# 14473 ('salmonlike', 1)
# 14474 ('bluer', 1)
# 14475 ('mistines', 1)
# 14476 ('handdown', 1)
# 14477 ('boatsstand', 1)
# 14478 ('ropeladder', 1)
# 14479 ('dartingly', 1)
# 14480 ('thinekeep', 1)
# 14481 ('headandheadthat', 1)
# 14482 ('foreheada', 1)
# 14483 ('slogan', 1)
# 14484 ('untraceable', 1)
# 14485 ('foreshorten', 1)
# 14486 ('againhop', 1)
# 14487 ('disencumber', 1)
# 14488 ('snarlswhen', 1)
# 14489 ('loa', 1)
# 14490 ('twistedcorkscrew', 1)
# 14491 ('withinthroughand', 1)
# 14492 ('withoutthe', 1)
# 14493 ('chocksdrop', 1)
# 14494 ('fagot', 1)
# 14495 ('husk', 1)
# 14496 ('surfbeaten', 1)
# 14497 ('nutmeg', 1)
# 14498 ('aslope', 1)
# 14499 ('lustily', 1)
# 14500 ('ladle', 1)
# 14501 ('linenow', 1)
# 14502 ('partingadmit', 1)
# 14503 ('couldin', 1)
# 14504 ('perilsahab', 1)
# 14505 ('unstricken', 1)
# 14506 ('wiresa', 1)
# 14507 ('arrowlike', 1)
# 14508 ('againgunwale', 1)
# 14509 ('downwardsand', 1)
# 14510 ('whalemodify', 1)
# 14511 ('surfaceinvoluntarily', 1)
# 14512 ('crumb', 1)
# 14513 ('intertangle', 1)
# 14514 ('contusion', 1)
# 14515 ('inextricable', 1)
# 14516 ('halfhung', 1)
# 14517 ('leaner', 1)
# 14518 ('stubbdye', 1)
# 14519 ('it.but', 1)
# 14520 ('roofaloft', 1)
# 14521 ('themmr', 1)
# 14522 ('canethere', 1)
# 14523 ('bemissingquick', 1)
# 14524 ('stubbhe', 1)
# 14525 ('theerun', 1)
# 14526 ('forecastlefind', 1)
# 14527 ('himnot', 1)
# 14528 ('gonenot', 1)
# 14529 ('stubbcaught', 1)
# 14530 ('linei', 1)
# 14531 ('gonegone', 1)
# 14532 ('wordwhat', 1)
# 14533 ('deathknell', 1)
# 14534 ('tootos', 1)
# 14535 ('theredye', 1)
# 14536 ('whalesno', 1)
# 14537 ('noblister', 1)
# 14538 ('fishaloft', 1)
# 14539 ('nailedquickall', 1)
# 14540 ('boatscollect', 1)
# 14541 ('oarsharpooneer', 1)
# 14542 ('ironshoist', 1)
# 14543 ('highera', 1)
# 14544 ('sheetshelm', 1)
# 14545 ('unmeasure', 1)
# 14546 ('manin', 1)
# 14547 ('goneall', 1)
# 14548 ('warningswhat', 1)
# 14549 ('haveshall', 1)
# 14550 ('ohimpiety', 1)
# 14551 ('sawthou', 1)
# 14552 ('handa', 1)
# 14553 ('liples', 1)
# 14554 ('unfeature', 1)
# 14555 ('immutably', 1)
# 14556 ('billion', 1)
# 14557 ('underle', 1)
# 14558 ('obeyest', 1)
# 14559 ('mine.stand', 1)
# 14560 ('ahabhi', 1)
# 14561 ('centipede', 1)
# 14562 ('encore', 1)
# 14563 ('dicktwo', 1)
# 14564 ('floatedtomorrow', 1)
# 14565 ('morebut', 1)
# 14566 ('minethe', 1)
# 14567 ('parseethe', 1)
# 14568 ('parseegone', 1)
# 14569 ('beforebut', 1)
# 14570 ('perishhow', 1)
# 14571 ('thatthere', 1)
# 14572 ('judgeslike', 1)
# 14573 ('heliotrope', 1)
# 14574 ('nightman', 1)
# 14575 ('newmade', 1)
# 14576 ('summerhouse', 1)
# 14577 ('fairer', 1)
# 14578 ('calmfrozen', 1)
# 14579 ('lava', 1)
# 14580 ('corridor', 1)
# 14581 ('ventilate', 1)
# 14582 ('taint', 1)
# 14583 ('braver', 1)
# 14584 ('thinga', 1)
# 14585 ('veer', 1)
# 14586 ('baser', 1)
# 14587 ('mississippy', 1)
# 14588 ('themsomethe', 1)
# 14589 ('unchangeable', 1)
# 14590 ('oversail', 1)
# 14591 ('linesthe', 1)
# 14592 ('rechurn', 1)
# 14593 ('newhaul', 1)
# 14594 ('mainbrace', 1)
# 14595 ('misdoubt', 1)
# 14596 ('goldbeaten', 1)
# 14597 ('therebrace', 1)
# 14598 ('sandhill', 1)
# 14599 ('leewarding', 1)
# 14600 ('somewhereto', 1)
# 14601 ('bitterer', 1)
# 14602 ('thisgreen', 1)
# 14603 ('tiny', 1)
# 14604 ('toldst', 1)
# 14605 ('mastheadkeep', 1)
# 14606 ('shallop', 1)
# 14607 ('matewho', 1)
# 14608 ('tacklerope', 1)
# 14609 ('deckand', 1)
# 14610 ('floodand', 1)
# 14611 ('oldshake', 1)
# 14612 ('captainnoble', 1)
# 14613 ('heartgo', 1)
# 14614 ('notgo', 1)
# 14615 ('awaycry', 1)
# 14616 ('cabinwindow', 1)
# 14617 ('maliciously', 1)
# 14618 ('prescient', 1)
# 14619 ('regiment', 1)
# 14620 ('sharksa', 1)
# 14621 ('themhowever', 1)
# 14622 ('boatcanst', 1)
# 14623 ('sightlower', 1)
# 14624 ('raven', 1)
# 14625 ('dayfor', 1)
# 14626 ('thingbe', 1)
# 14627 ('expectantfix', 1)
# 14628 ('fadest', 1)
# 14629 ('betweeni', 1)
# 14630 ('heartbeat', 1)
# 14631 ('starbuckstave', 1)
# 14632 ('offmove', 1)
# 14633 ('aloudmasthead', 1)
# 14634 ('hillcrazedaloft', 1)
# 14635 ('therekeep', 1)
# 14636 ('boatsmark', 1)
# 14637 ('whaleho', 1)
# 14638 ('againdrive', 1)
# 14639 ('peckshe', 1)
# 14640 ('vanepoint', 1)
# 14641 ('maintruckha', 1)
# 14642 ('ahabshudder', 1)
# 14643 ('mastheadsa', 1)
# 14644 ('headbeat', 1)
# 14645 ('mineand', 1)
# 14646 ('bedraggle', 1)
# 14647 ('brokenly', 1)
# 14648 ('combinedly', 1)
# 14649 ('tier', 1)
# 14650 ('befool', 1)
# 14651 ('befooleddraw', 1)
# 14652 ('breathaye', 1)
# 14653 ('again.aye', 1)
# 14654 ('diedown', 1)
# 14655 ('me.where', 1)
# 14656 ('shipwhich', 1)
# 14657 ('seekest', 1)
# 14658 ('judiciou', 1)
# 14659 ('vane', 1)
# 14660 ('pertinaciously', 1)
# 14661 ('onbut', 1)
# 14662 ('tellhe', 1)
# 14663 ('mutteredwhether', 1)
# 14664 ('ahabbut', 1)
# 14665 ('nowwe', 1)
# 14666 ('passand', 1)
# 14667 ('advancea', 1)
# 14668 ('willand', 1)
# 14669 ('monadnock', 1)
# 14670 ('fiercer', 1)
# 14671 ('oarsmenwho', 1)
# 14672 ('foreknow', 1)
# 14673 ('unprepare', 1)
# 14674 ('effectsthese', 1)
# 14675 ('ungraduat', 1)
# 14676 ('cracksit', 1)
# 14677 ('seacrash', 1)
# 14678 ('persecution', 1)
# 14679 ('bea', 1)
# 14680 ('sledgehammer', 1)
# 14681 ('whalesmitten', 1)
# 14682 ('bowend', 1)
# 14683 ('halfwade', 1)
# 14684 ('gap', 1)
# 14685 ('halfwrap', 1)
# 14686 ('plaid', 1)
# 14687 ('forwardflow', 1)
# 14688 ('downcome', 1)
# 14689 ('sayye', 1)
# 14690 ('unappeasable', 1)
# 14691 ('unwink', 1)
# 14692 ('mattras', 1)
# 14693 ('brushwood', 1)
# 14694 ('assassin', 1)
# 14695 ('thoughcherry', 1)
# 14696 ('partpay', 1)
# 14697 ('inactive', 1)
# 14698 ('dislodge', 1)
# 14699 ('bulllike', 1)
# 14700 ('flume', 1)
# 14701 ('hearsethe', 1)
# 14702 ('unsurrender', 1)
# 14703 ('uncrac', 1)
# 14704 ('godbully', 1)
# 14705 ('polepoint', 1)
# 14706 ('prowdeathgloriou', 1)
# 14707 ('foregone', 1)
# 14708 ('comber', 1)
# 14709 ('alldestroy', 1)
# 14710 ('unconquer', 1)
# 14711 ('groovesran', 1)
# 14712 ('voicelessly', 1)
# 14713 ('bowstre', 1)
# 14714 ('starkempty', 1)
# 14715 ('gaseou', 1)
# 14716 ('fata', 1)
# 14717 ('morgana', 1)
# 14718 ('infatuation', 1)
# 14719 ('lancepole', 1)
# 14720 ('inanimate', 1)
# 14721 ('whelming', 1)
# 14722 ('intermixingly', 1)
# 14723 ('ironical', 1)
# 14724 ('coinciding', 1)
# 14725 ('touchedat', 1)
# 14726 ('backwardly', 1)
# 14727 ('skyhawk', 1)
# 14728 ('tauntingly', 1)
# 14729 ('incommode', 1)
# 14730 ('etherial', 1)
# 14731 ('deathgasp', 1)
# 14732 ('forthbecause', 1)
# 14733 ('halfspent', 1)
# 14734 ('suction', 1)
# 14735 ('buttonlike', 1)
# 14736 ('ixion', 1)
# 14737 ('liberate', 1)
# 14738 ('dirgelike', 1)
# 14739 ('deviouscruis', 1)
# 14740 ('h.htm', 1)
# 14741 ('h.zip', 1)
# 14742 ('onethe', 1)
# 14743 ('rename', 1)
# 14744 ('awayyou', 1)
# 14745 ('httpgutenberg.orglicense', 1)
# 14746 ('.a', 1)
# 14747 ('trademarkcopyright', 1)
# 14748 ('.b', 1)
# 14749 ('pglaf', 1)
# 14750 ('.d', 1)
# 14751 ('download', 1)
# 14752 ('representation', 1)
# 14753 ('unlink', 1)
# 14754 ('binary', 1)
# 14755 ('nonproprietary', 1)
# 14756 ('proprietary', 1)
# 14757 ('hypertext', 1)
# 14758 ('legally', 1)
# 14759 ('periodic', 1)
# 14760 ('discontinue', 1)
# 14761 ('proofread', 1)
# 14762 ('inaccurate', 1)
# 14763 ('data', 1)
# 14764 ('transcription', 1)
# 14765 ('infringement', 1)
# 14766 ('viru', 1)
# 14767 ('disclaim', 1)
# 14768 ('remedy', 1)
# 14769 ('negligence', 1)
# 14770 ('f.', 1)
# 14771 ('distributor', 1)
# 14772 ('consequential', 1)
# 14773 ('punitive', 1)
# 14774 ('asi', 1)
# 14775 ('merchantibility', 1)
# 14776 ('maximum', 1)
# 14777 ('invalidity', 1)
# 14778 ('unenforceability', 1)
# 14779 ('indemnity', 1)
# 14780 ('indemnify', 1)
# 14781 ('b', 1)
# 14782 ('alteration', 1)
# 14783 ('deletion', 1)
# 14784 ('synonymou', 1)
# 14785 ('middleag', 1)
# 14786 ('financial', 1)
# 14787 ('ensure', 1)
# 14788 ('httpwww.pglaf.org', 1)
# 14789 ('educational', 1)
# 14790 ('corporation', 1)
# 14791 ('ein', 1)
# 14792 ('identification', 1)
# 14793 ('httppglaf.orgfundrais', 1)
# 14794 ('deductible', 1)
# 14795 ('melan', 1)
# 14796 ('fairbank', 1)
# 14797 ('ak', 1)
# 14798 ('ut', 1)
# 14799 ('businesspglaf.org', 1)
# 14800 ('gregory', 1)
# 14801 ('b.', 1)
# 14802 ('newby', 1)
# 14803 ('executive', 1)
# 14804 ('director', 1)
# 14805 ('gbnewbypglaf.org', 1)
# 14806 ('outdate', 1)
# 14807 ('ir', 1)
# 14808 ('paperwork', 1)
# 14809 ('solicitation', 1)
# 14810 ('prohibition', 1)
# 14811 ('donor', 1)
# 14812 ('international', 1)
# 14813 ('gratefully', 1)
# 14814 ('treatment', 1)
# 14815 ('httppglaf.orgdonate', 1)
# 14816 ('originator', 1)
# 14817 ('confirm', 1)
# 14818 ('pg', 1)
# 14819 ('newsletter', 1)

# %%
fq = dict(Counter(words_ns).most_common())
tokens_new = []
for token in words_ns:
  if fq[token] > 1:
    tokens_new.append(token)
  else:
    tokens_new.append('UNK')
print(tokens_new)
# Out:
# ['moby', 'dick', 'whale', 'herman', 'melville', 'project', 'gutenberg', 'ebook', 'moby', 'dick', 'whale', 'herman', 'melville', 'thi', 'ebook', 'use', 'anyone', 'anywhere', 'cost', 'almost', 'restriction', 'whatsoever', '.', 'may', 'copy', 'give', 'away', 'reuse', 'term', 'project', 'gutenberg', 'license', 'include', 'thi', 'ebook', 'online', 'www.gutenberg.org', 'title', 'moby', 'dick', 'whale', 'author', 'herman', 'melville', 'UNK', 'date', 'december', 'ebook', 'last', 'update', 'december', 'language', 'english', 'character', 'set', 'UNK', 'UNK', 'start', 'thi', 'project', 'gutenberg', 'ebook', 'moby', 'dick', 'whale', 'produce', 'daniel', 'lazaru', 'jonesey', 'david', 'widger', 'UNK', 'whale', '.', 'herman', 'melville', 'content', 'etymology', '.', 'extract', 'supply', 'subsublibrarian', '.', 'chapter', '.', 'looming', '.', 'chapter', '.', 'carpetbag', '.', 'chapter', '.', 'spouterinn', '.', 'chapter', '.', 'counterpane', '.', 'chapter', '.', 'breakfast', '.', 'chapter', '.', 'street', '.', 'chapter', '.', 'chapel', '.', 'chapter', '.', 'pulpit', '.', 'chapter', '.', 'sermon', '.', 'chapter', '.', 'bosom', 'friend', '.', 'chapter', '.', 'nightgown', '.', 'chapter', '.', 'biographical', '.', 'chapter', '.', 'wheelbarrow', '.', 'chapter', '.', 'nantucket', '.', 'chapter', '.', 'chowder', '.', 'chapter', '.', 'ship', '.', 'chapter', '.', 'ramadan', '.', 'chapter', '.', 'hi', 'mark', '.', 'chapter', '.', 'prophet', '.', 'chapter', '.', 'astir', '.', 'chapter', '.', 'go', 'aboard', '.', 'chapter', '.', 'merry', 'christma', '.', 'chapter', '.', 'lee', 'shore', '.', 'chapter', '.', 'advocate', '.', 'chapter', '.', 'postscript', '.', 'chapter', '.', 'knight', 'squire', '.', 'chapter', '.', 'knight', 'squire', '.', 'chapter', '.', 'ahab', '.', 'chapter', '.', 'enter', 'ahab', 'stubb', '.', 'chapter', '.', 'pipe', '.', 'chapter', '.', 'queen', 'mab', '.', 'chapter', '.', 'cetology', '.', 'chapter', '.', 'specksnyder', '.', 'chapter', '.', 'cabintable', '.', 'chapter', '.', 'masthead', '.', 'chapter', '.', 'quarterdeck', '.', 'chapter', '.', 'sunset', '.', 'chapter', '.', 'dusk', '.', 'chapter', '.', 'first', 'nightwatch', '.', 'chapter', '.', 'midnight', 'forecastle', '.', 'chapter', '.', 'moby', 'dick', '.', 'chapter', '.', 'whitenes', 'whale', '.', 'chapter', '.', 'hark', 'chapter', '.', 'chart', '.', 'chapter', '.', 'affidavit', '.', 'chapter', '.', 'surmise', '.', 'chapter', '.', 'matmaker', '.', 'chapter', '.', 'first', 'lower', '.', 'chapter', '.', 'hyena', '.', 'chapter', '.', 'ahab', 'boat', 'crew', '.', 'fedallah', '.', 'chapter', '.', 'spiritspout', '.', 'chapter', '.', 'albatros', '.', 'chapter', '.', 'gam', '.', 'chapter', '.', 'townho', 'story', '.', 'chapter', '.', 'monstrou', 'picture', 'whale', '.', 'chapter', '.', 'les', 'erroneou', 'picture', 'whale', 'true', 'picture', 'whale', 'scene', '.', 'chapter', '.', 'whale', 'paint', 'teeth', 'wood', 'sheetiron', 'stone', 'mountain', 'star', '.', 'chapter', '.', 'brit', '.', 'chapter', '.', 'squid', '.', 'chapter', '.', 'line', '.', 'chapter', '.', 'stubb', 'kill', 'whale', '.', 'chapter', '.', 'dart', '.', 'chapter', '.', 'crotch', '.', 'chapter', '.', 'stubb', 'supper', '.', 'chapter', '.', 'whale', 'dish', '.', 'chapter', '.', 'shark', 'massacre', '.', 'chapter', '.', 'cut', '.', 'chapter', '.', 'blanket', '.', 'chapter', '.', 'funeral', '.', 'chapter', '.', 'sphynx', '.', 'chapter', '.', 'jeroboam', 'story', '.', 'chapter', '.', 'monkeyrope', '.', 'chapter', '.', 'stubb', 'flask', 'kill', 'right', 'whale', 'talk', '.', 'chapter', '.', 'sperm', 'whale', 'headcontrast', 'view', '.', 'chapter', '.', 'right', 'whale', 'headcontrast', 'view', '.', 'chapter', '.', 'batteringram', '.', 'chapter', '.', 'great', 'heidelburgh', 'tun', '.', 'chapter', '.', 'cistern', 'bucket', '.', 'chapter', '.', 'prairie', '.', 'chapter', '.', 'nut', '.', 'chapter', '.', 'pequod', 'meet', 'virgin', '.', 'chapter', '.', 'honor', 'glory', 'whale', '.', 'chapter', '.', 'jonah', 'historically', 'reg ...

# %%
print(f"There are a total of {len(tokens_new)} tokens in the novel.")
print(f"There are a total of {len(set(tokens_new))} types in the novel.")
# Out:
# There are a total of 121297 tokens in the novel.
# There are a total of 7498 types in the novel.

# %% [markdown]
# ## 2.5 Train-Test Split:

# %%
period_indices = [i for i, word in enumerate(tokens_new) if word == "."]
def nearest_period_indices(how_to_split):
    differences = [abs(num - how_to_split) for num in period_indices]
    nearest_period_indices = differences.index(min(differences))
    return period_indices[nearest_period_indices]

# %%
data_train = tokens_new[:nearest_period_indices(int(0.7*len(tokens_new)))]
data_val = tokens_new[nearest_period_indices(int(0.7*len(tokens_new))):nearest_period_indices(int(0.8*len(tokens_new)))]
data_test = tokens_new[nearest_period_indices(int(0.8*len(tokens_new))):]

print('Train:', len(data_train))
print('Val:', len(data_val))
print('Test:', len(data_test))
# Out:
# Train: 84910
# Val: 12127
# Test: 24260

# %% [markdown]
# # III. Building model:

# %% [markdown]
# ## 3.1 N-Gram model:

# %% [markdown]
# ### 3.1.1 N_gram Count:

# %%
data_train = [token for token in data_train if token != '.']

# %%
def n_gram_counts(tokens, n):
  n_tokens = len(tokens)
  result = dict()
  for i in range(n_tokens - n + 1):
    key = tuple(tokens[i:i+n])
    if key in result:
      result[key] += 1
    else:
      result[key] = 1
  return result

uni_counts = Counter(data_train).most_common()
uni_counts = dict(uni_counts)

bi_counts = n_gram_counts(data_train, 2)
tri_counts = n_gram_counts(data_train, 3)
four_counts = n_gram_counts(data_train, 4)

# %%
bi_counts
# Out:
# {('moby', 'dick'): 55,
#  ('dick', 'whale'): 5,
#  ('whale', 'herman'): 3,
#  ('herman', 'melville'): 4,
#  ('melville', 'project'): 1,
#  ('project', 'gutenberg'): 4,
#  ('gutenberg', 'ebook'): 2,
#  ('ebook', 'moby'): 2,
#  ('melville', 'thi'): 1,
#  ('thi', 'ebook'): 2,
#  ('ebook', 'use'): 1,
#  ('use', 'anyone'): 1,
#  ('anyone', 'anywhere'): 1,
#  ('anywhere', 'cost'): 1,
#  ('cost', 'almost'): 1,
#  ('almost', 'restriction'): 1,
#  ('restriction', 'whatsoever'): 1,
#  ('whatsoever', 'may'): 1,
#  ('may', 'copy'): 1,
#  ('copy', 'give'): 1,
#  ('give', 'away'): 1,
#  ('away', 'reuse'): 1,
#  ('reuse', 'term'): 1,
#  ('term', 'project'): 1,
#  ('gutenberg', 'license'): 1,
#  ('license', 'include'): 1,
#  ('include', 'thi'): 2,
#  ('ebook', 'online'): 1,
#  ('online', 'www.gutenberg.org'): 1,
#  ('www.gutenberg.org', 'title'): 1,
#  ('title', 'moby'): 1,
#  ('whale', 'author'): 2,
#  ('author', 'herman'): 1,
#  ('melville', 'UNK'): 1,
#  ('UNK', 'date'): 1,
#  ('date', 'december'): 1,
#  ('december', 'ebook'): 1,
#  ('ebook', 'last'): 1,
#  ('last', 'update'): 1,
#  ('update', 'december'): 1,
#  ('december', 'language'): 1,
#  ('language', 'english'): 1,
#  ('english', 'character'): 1,
#  ('character', 'set'): 1,
#  ('set', 'UNK'): 7,
#  ('UNK', 'UNK'): 556,
#  ('UNK', 'start'): 9,
#  ('start', 'thi'): 1,
#  ('thi', 'project'): 1,
#  ('whale', 'produce'): 1,
#  ('produce', 'daniel'): 1,
#  ('daniel', 'lazaru'): 1,
#  ('lazaru', 'jonesey'): 1,
#  ('jonesey', 'david'): 1,
#  ('david', 'widger'): 1,
#  ('widger', 'UNK'): 1,
#  ('UNK', 'whale'): 55,
#  ('melville', 'content'): 1,
#  ('content', 'etymology'): 1,
#  ('etymology', 'extract'): 1,
#  ('extract', 'supply'): 2,
#  ('supply', 'subsublibrarian'): 2,
#  ('subsublibrarian', 'chapter'): 1,
#  ('chapter', 'looming'): 2,
#  ('looming', 'chapter'): 1,
#  ('chapter', 'carpetbag'): 2,
#  ('carpetbag', 'chapter'): 1,
#  ('chapter', 'spouterinn'): 2,
#  ('spouterinn', 'chapter'): 1,
#  ('chapter', 'counterpane'): 2,
#  ('counterpane', 'chapter'): 1,
#  ('chapter', 'breakfast'): 2,
#  ('breakfast', 'chapter'): 1,
#  ('chapter', 'street'): 2,
#  ('street', 'chapter'): 1,
#  ('chapter', 'chapel'): 2,
#  ('chapel', 'chapter'): 1,
#  ('chapter', 'pulpit'): 2,
#  ('pulpit', 'chapter'): 1,
#  ('chapter', 'sermon'): 2,
#  ('sermon', 'chapter'): 1,
#  ('chapter', 'bosom'): 2,
#  ('bosom', 'friend'): 3,
#  ('friend', 'chapter'): 2,
#  ('chapter', 'nightgown'): 2,
#  ('nightgown', 'chapter'): 1,
#  ('chapter', 'biographical'): 2,
#  ('biographical', 'chapter'): 1,
#  ('chapter', 'wheelbarrow'): 2,
#  ('wheelbarrow', 'chapter'): 1,
#  ('chapter', 'nantucket'): 2,
#  ('nantucket', 'chapter'): 1,
#  ('chapter', 'chowder'): 2,
#  ('chowder', 'chapter'): 1,
#  ('chapter', 'ship'): 2,
#  ('ship', 'chapter'): 1,
#  ('chapter', 'ramadan'): 2,
#  ('ramadan', 'chapter'): 1,
#  ('chapter', 'hi'): 3,
#  ('hi', 'mark'): 6,
#  ('mark', 'chapter'): 1,
#  ('chapter', 'prophet'): 2,
#  ('prophet', 'chapter'): 1,
#  ('chapter', 'astir'): 2,
#  ('astir', 'chapter'): 1,
#  ('chapter', 'go'): 2,
#  ('go', 'aboard'): 4,
#  ('aboard', 'chapter'): 1,
#  ('chapter', 'merry'): 2,
#  ('merry', 'christma'): 2,
#  ('christma', 'chapter'): 1,
#  ('chapter', 'lee'): 2,
#  ('lee', 'shore'): 2,
#  ('shore', 'chapter'): 2,
#  ('chapter', 'advocate'): 2,
#  ('advocate', 'chapter'): 1,
#  ('chapter', 'postscript'): 2,
#  ('postscript', 'chapter'): 1,
#  ('chapter', 'knight'): 4,
#  ('knight', 'squire'): 4,
#  ('squire', 'chapter'): 2,
#  ('chapter', 'ahab'): 7,
#  ('ahab', 'chapter'): 1,
#  ('chapter', 'enter'): 2,
#  ('enter', 'ahab'): 3,
#  ('ahab', 'stubb'): 2,
#  ('stubb', 'chapter'): 1,
#  ('chapter', 'pipe'): 2,
#  ('pipe', 'chapter'): 1,
#  ('chapter', 'queen'): 2,
#  ('queen', 'mab'): 2,
#  ('mab', 'chapter'): 1,
#  ('chapter', 'cetology'): 2,
#  ('cetology', 'chapter'): 1,
#  ('chapter', 'specksnyder'): 2,
#  ('specksnyder', 'chapter'): 1,
#  ('chapter', 'cabintable'): 2,
#  ('cabintable', 'chapter'): 1,
#  ('chapter', 'masthead'): 2,
#  ('masthead', 'chapter'): 1,
#  ('chapter', 'quarterdeck'): 2,
#  ('quarterdeck', 'chapter'): 1,
#  ('chapter', 'sunset'): 2,
#  ('sunset', 'chapter'): 1,
#  ('chapter', 'dusk'): 2,
#  ('dusk', 'chapter'): 1,
#  ('chapter', 'first'): 4,
#  ('first', 'nightwatch'): 2,
#  ('nightwatch', 'chapter'): 1,
#  ('chapter', 'midnight'): 3,
#  ('midnight', 'forecastle'): 2,
#  ('forecastle', 'chapter'): 1,
#  ('chapter', 'moby'): 2,
#  ('dick', 'chapter'): 1,
#  ('chapter', 'whitenes'): 3,
#  ('whitenes', 'whale'): 3,
#  ('whale', 'chapter'): 9,
#  ('chapter', 'hark'): 2,
#  ('hark', 'chapter'): 1,
#  ('chapter', 'chart'): 2,
#  ('chart', 'chapter'): 1,
#  ('chapter', 'affidavit'): 2,
#  ('affidavit', 'chapter'): 1,
#  ('chapter', 'surmise'): 2,
#  ('surmise', 'chapter'): 1,
#  ('chapter', 'matmaker'): 2,
#  ('matmaker', 'chapter'): 1,
#  ('first', 'lower'): 2,
#  ('lower', 'chapter'): 1,
#  ('chapter', 'hyena'): 2,
#  ('hyena', 'chapter'): 1,
#  ('ahab', 'boat'): 4,
#  ('boat', 'crew'): 12,
#  ('crew', 'fedallah'): 2,
#  ('fedallah', 'chapter'): 1,
#  ('chapter', 'spiritspout'): 2,
#  ('spiritspout', 'chapter'): 1,
#  ('chapter', 'albatros'): 2,
#  ('albatros', 'chapter'): 1,
#  ('chapter', 'gam'): 2,
#  ('gam', 'chapter'): 1,
#  ('chapter', 'townho'): 2,
#  ('townho', 'story'): 3,
#  ('story', 'chapter'): 2,
#  ('chapter', 'monstrou'): 2,
#  ('monstrou', 'picture'): 3,
#  ('picture', 'whale'): 10,
#  ('chapter', 'les'): 2,
#  ('les', 'erroneou'): 2,
#  ('erroneou', 'picture'): 2,
#  ('whale', 'true'): 4,
#  ('true', 'picture'): 2,
#  ('whale', 'scene'): 7,
#  ('scene', 'chapter'): 1,
#  ('chapter', 'whale'): 8,
#  ('whale', 'paint'): 2,
#  ('paint', 'teeth'): 2,
#  ('teeth', 'wood'): 2,
#  ('wood', 'sheetiron'): 2,
#  ('sheetiron', 'stone'): 2,
#  ('stone', 'mountain'): 2,
#  ('mountain', 'star'): 2,
#  ('star', 'chapter'): 1,
#  ('chapter', 'brit'): 2,
#  ('brit', 'chapter'): 1,
#  ('chapter', 'squid'): 2,
#  ('squid', 'chapter'): 1,
#  ('chapter', 'line'): 2,
#  ('line', 'chapter'): 2,
#  ('chapter', 'stubb'): 6,
#  ('stubb', 'kill'): 2,
#  ('kill', 'whale'): 6,
#  ('chapter', 'dart'): 2,
#  ('dart', 'chapter'): 1,
#  ('chapter', 'crotch'): 3,
#  ('crotch', 'chapter'): 1,
#  ('stubb', 'supper'): 2,
#  ('supper', 'chapter'): 1,
#  ('whale', 'dish'): 2,
#  ('dish', 'chapter'): 1,
#  ('chapter', 'shark'): 2,
#  ('shark', 'massacre'): 2,
#  ('massacre', 'chapter'): 1,
#  ('chapter', 'cut'): 2,
#  ('cut', 'chapter'): 1,
#  ('chapter', 'blanket'): 2,
#  ('blanket', 'chapter'): 1,
#  ('chapter', 'funeral'): 2,
#  ('funeral', 'chapter'): 1,
#  ('chapter', 'sphynx'): 2,
#  ('sphynx', 'chapter'): 1,
#  ('chapter', 'jeroboam'): 2,
#  ('jeroboam', 'story'): 2,
#  ('chapter', 'monkeyrope'): 2,
#  ('monkeyrope', 'chapter'): 1,
#  ('stubb', 'flask'): 9,
#  ('flask', 'kill'): 3,
#  ('kill', 'right'): 2,
#  ('right', 'whale'): 55,
#  ('whale', 'talk'): 2,
#  ('talk', 'chapter'): 1,
#  ('chapter', 'sperm'): 2,
#  ('sperm', 'whale'): 170,
#  ('whale', 'headcontrast'): 4,
#  ('headcontrast', 'view'): 4,
#  ('view', 'chapter'): 2,
#  ('chapter', 'right'): 2,
#  ('chapter', 'batteringram'): 2,
#  ('batteringram', 'chapter'): 1,
#  ('chapter', 'great'): 2,
#  ('great', 'heidelburgh'): 4,
#  ('heidelburgh', 'tun'): 6,
#  ('tun', 'chapter'): 1,
#  ('chapter', 'cistern'): 2,
#  ('cistern', 'bucket'): 2,
#  ('bucket', 'chapter'): 2,
#  ('chapter', 'prairie'): 2,
#  ('prairie', 'chapter'): 1,
#  ('chapter', 'nut'): 2,
#  ('nut', 'chapter'): 1,
#  ('chapter', 'pequod'): 7,
#  ('pequod', 'meet'): 7,
#  ('meet', 'virgin'): 2,
#  ('virgin', 'chapter'): 1,
#  ('chapter', 'honor'): 2,
#  ('honor', 'glory'): 4,
#  ('glory', 'whale'): 3,
#  ('chapter', 'jonah'): 2,
#  ('jonah', 'historically'): 2,
#  ('historically', 'regard'): 2,
#  ('regard', 'chapter'): 1,
#  ('chapter', 'pitchpole'): 2,
#  ('pitchpole', 'chapter'): 1,
#  ('chapter', 'fountain'): 2,
#  ('fountain', 'chapter'): 1,
#  ('chapter', 'tail'): 2,
#  ('tail', 'chapter'): 3,
#  ('chapter', 'grand'): 2,
#  ('grand', 'armada'): 2,
#  ('armada', 'chapter'): 1,
#  ('chapter', 'school'): 2,
#  ('school', 'schoolmaster'): 2,
#  ('schoolmaster', 'chapter'): 1,
#  ('chapter', 'fastfish'): 2,
#  ('fastfish', 'loosefish'): 3,
#  ('loosefish', 'chapter'): 1,
#  ('chapter', 'head'): 2,
#  ('head', 'tail'): 2,
#  ('meet', 'rosebud'): 2,
#  ('rosebud', 'chapter'): 1,
#  ('chapter', 'ambergri'): 1,
#  ('ambergri', 'chapter'): 1,
#  ('chapter', 'castaway'): 1,
#  ('castaway', 'chapter'): 1,
#  ('chapter', 'squeeze'): 1,
#  ('squeeze', 'hand'): 1,
#  ('hand', 'chapter'): 1,
#  ('chapter', 'cassock'): 1,
#  ('cassock', 'chapter'): 1,
#  ('chapter', 'trywork'): 1,
#  ('trywork', 'chapter'): 1,
#  ('chapter', 'lamp'): 1,
#  ('lamp', 'chapter'): 1,
#  ('chapter', 'stow'): 1,
#  ('stow', 'clear'): 1,
#  ('clear', 'chapter'): 1,
#  ('chapter', 'doubloon'): 1,
#  ('doubloon', 'chapter'): 1,
#  ('chapter', 'leg'): 1,
#  ('leg', 'arm'): 1,
#  ('arm', 'chapter'): 1,
#  ('chapter', 'decanter'): 1,
#  ('decanter', 'chapter'): 1,
#  ('chapter', 'bower'): 1,
#  ('bower', 'arsacide'): 1,
#  ('arsacide', 'chapter'): 1,
#  ('chapter', 'measurement'): 1,
#  ('measurement', 'whale'): 1,
#  ('whale', 'skeleton'): 1,
#  ('skeleton', 'chapter'): 1,
#  ('chapter', 'fossil'): 1,
#  ('fossil', 'whale'): 1,
#  ('whale', 'magnitude'): 1,
#  ('magnitude', 'diminishwill'): 1,
#  ('diminishwill', 'perish'): 1,
#  ('perish', 'chapter'): 2,
#  ('ahab', 'leg'): 3,
#  ('leg', 'chapter'): 1,
#  ('chapter', 'carpenter'): 1,
#  ('carpenter', 'chapter'): 2,
#  ('ahab', 'carpenter'): 1,
#  ('ahab', 'starbuck'): 2,
#  ('starbuck', 'cabin'): 1,
#  ('cabin', 'chapter'): 4,
#  ('chapter', 'queequeg'): 1,
#  ('queequeg', 'hi'): 5,
#  ('hi', 'coffin'): 1,
#  ('coffin', 'chapter'): 1,
#  ('chapter', 'pacific'): 1,
#  ('pacific', 'chapter'): 1,
#  ('chapter', 'blacksmith'): 1,
#  ('blacksmith', 'chapter'): 1,
#  ('chapter', 'forge'): 1,
#  ('forge', 'chapter'): 1,
#  ('chapter', 'gilder'): 1,
#  ('gilder', 'chapter'): 1,
#  ('meet', 'bachelor'): 1,
#  ('bachelor', 'chapter'): 1,
#  ('chapter', 'die'): 1,
#  ('die', 'whale'): 2,
#  ('whale', 'watch'): 2,
#  ('watch', 'chapter'): 2,
#  ('chapter', 'quadrant'): 1,
#  ('quadrant', 'chapter'): 1,
#  ('chapter', 'candle'): 1,
#  ('candle', 'chapter'): 1,
#  ('chapter', 'deck'): 2,
#  ('deck', 'toward'): 1,
#  ('toward', 'end'): 2,
#  ('end', 'first'): 2,
#  ('first', 'night'): 1,
#  ('night', 'watch'): 3,
#  ('chapter', 'midnight.the'): 1,
#  ('midnight.the', 'forecastle'): 1,
#  ('forecastle', 'bulwark'): 1,
#  ('bulwark', 'chapter'): 1,
#  ('midnight', 'aloft.thunder'): 1,
#  ('aloft.thunder', 'lightn'): 1,
#  ('lightn', 'chapter'): 1,
#  ('chapter', 'musket'): 1,
#  ('musket', 'chapter'): 1,
#  ('chapter', 'needle'): 1,
#  ('needle', 'chapter'): 1,
#  ('chapter', 'log'): 1,
#  ('log', 'line'): 1,
#  ('chapter', 'lifebuoy'): 1,
#  ('lifebuoy', 'chapter'): 1,
#  ('deck', 'chapter'): 1,
#  ('meet', 'rachel'): 1,
#  ('rachel', 'chapter'): 1,
#  ('chapter', 'cabin'): 1,
#  ('chapter', 'hat'): 1,
#  ('hat', 'chapter'): 1,
#  ('meet', 'delight'): 1,
#  ('delight', 'chapter'): 1,
#  ('chapter', 'symphony'): 1,
#  ('symphony', 'chapter'): 1,
#  ('chapter', 'chasefirst'): 1,
#  ('chasefirst', 'day'): 1,
#  ('day', 'chapter'): 2,
#  ('chapter', 'chasesecond'): 1,
#  ('chasesecond', 'day'): 1,
#  ('chapter', 'chase.third'): 1,
#  ('chase.third', 'day'): 1,
#  ('day', 'epilogue'): 1,
#  ('epilogue', 'original'): 1,
#  ('original', 'UNK'): 4,
#  ('UNK', 'note'): 1,
#  ('note', 'thi'): 1,
#  ('thi', 'text'): 1,
#  ('text', 'combination'): 1,
#  ('combination', 'etext'): 1,
#  ('etext', 'one'): 1,
#  ('one', 'UNK'): 26,
#  ('UNK', 'project'): 2,
#  ('project', 'virginia'): 1,
#  ('virginia', 'tech'): 2,
#  ('tech', 'one'): 1,
#  ('one', 'project'): 1,
#  ('gutenberg', 'archive'): 1,
#  ('archive', 'UNK'): 1,
#  ('UNK', 'thi'): 74,
#  ('thi', 'version'): 1,
#  ('version', 'indebt'): 1,
#  ('indebt', 'UNK'): 1,
#  ('UNK', 'library'): 2,
#  ('library', 'preserve'): 1,
#  ('preserve', 'virginia'): 1,
#  ('tech', 'version'): 1,
#  ('version', 'result'): 1,
#  ('result', 'etext'): 1,
#  ('etext', 'compare'): 1,
#  ('compare', 'public'): 1,
#  ('public', 'domain'): 1,
#  ('domain', 'hard'): 1,
#  ('hard', 'copy'): 1,
#  ('copy', 'version'): 1,
#  ('version', 'text'): 1,
#  ('text', 'etymology'): 1,
#  ('etymology', 'supply'): 1,
#  ('supply', 'late'): 1,
#  ('late', 'UNK'): 1,
#  ('UNK', 'usher'): 1,
#  ('usher', 'grammar'): 1,
#  ('grammar', 'school'): 1,
#  ('school', 'pale'): 1,
#  ('pale', 'UNK'): 4,
#  ('UNK', 'coat'): 4,
#  ('coat', 'heart'): 1,
#  ('heart', 'body'): 1,
#  ('body', 'brain'): 1,
#  ('brain', 'see'): 2,
#  ('see', 'ever'): 1,
#  ('ever', 'dust'): 1,
#  ('dust', 'hi'): 3,
#  ('hi', 'old'): 11,
#  ('old', 'lexicon'): 1,
#  ('lexicon', 'grammar'): 1,
#  ('grammar', 'queer'): 1,
#  ('queer', 'handkerchief'): 1,
#  ('handkerchief', 'UNK'): 1,
#  ('UNK', 'embellish'): 1,
#  ('embellish', 'gay'): 1,
#  ('gay', 'flag'): 1,
#  ('flag', 'know'): 1,
#  ('know', 'nation'): 1,
#  ('nation', 'world'): 1,
#  ('world', 'love'): 1,
#  ('love', 'dust'): 1,
#  ('old', 'grammar'): 1,
#  ('grammar', 'somehow'): 1,
#  ('somehow', 'mildly'): 1,
#  ('mildly', 'remind'): 1,
#  ('remind', 'hi'): 1,
#  ('hi', 'mortality'): 1,
#  ('mortality', 'take'): 1,
#  ('take', 'hand'): 1,
#  ('hand', 'school'): 1,
#  ('school', 'teach'): 1,
#  ('teach', 'name'): 1,
#  ('name', 'UNK'): 6,
#  ('UNK', 'call'): 17,
#  ('call', 'tongue'): 1,
#  ('tongue', 'leave'): 1,
#  ('leave', 'ignorance'): 1,
#  ('ignorance', 'letter'): 1,
#  ('letter', 'UNK'): 3,
#  ('UNK', 'almost'): 5,
#  ('almost', 'alone'): 1,
#  ('alone', 'maketh'): 1,
#  ('maketh', 'UNK'): 1,
#  ('UNK', 'word'): 8,
#  ('word', 'deliver'): 1,
#  ('deliver', 'true'): 1,
#  ('true', 'hackluyt'): 1,
#  ('hackluyt', 'whale'): 1,
#  ('whale', 'UNK'): 63,
#  ('UNK', 'dan'): 2,
#  ('dan', 'UNK'): 1,
#  ('thi', 'animal'): 2,
#  ('animal', 'name'): 1,
#  ('UNK', 'roll'): 4,
#  ('roll', 'dan'): 1,
#  ('dan', 'hvalt'): 1,
#  ('hvalt', 'arch'): 1,
#  ('arch', 'vault'): 1,
#  ('vault', 'webster'): 1,
#  ('webster', 'dictionary'): 1,
#  ('dictionary', 'whale'): 1,
#  ('whale', 'immediately'): 3,
#  ('immediately', 'UNK'): 2,
#  ('roll', 'wallow'): 2,
#  ('wallow', 'UNK'): 1,
#  ('UNK', 'dictionary'): 1,
#  ('dictionary', 'hebrew'): 1,
#  ('hebrew', 'greek'): 1,
#  ('greek', 'cetu'): 1,
#  ('cetu', 'latin'): 1,
#  ('latin', 'UNK'): 2,
#  ('UNK', 'hvalt'): 1,
#  ('hvalt', 'danish'): 1,
#  ('danish', 'UNK'): 1,
#  ('UNK', 'dutch'): 1,
#  ('dutch', 'UNK'): 2,
#  ('whale', 'icelandic'): 1,
#  ('icelandic', 'whale'): 1,
#  ('whale', 'english'): 4,
#  ('english', 'baleine'): 1,
#  ('baleine', 'french'): 1,
#  ('french', 'UNK'): 3,
#  ('UNK', 'spanish'): 1,
#  ('spanish', 'UNK'): 1,
#  ('UNK', 'extract'): 1,
#  ('subsublibrarian', 'see'): 1,
#  ('see', 'thi'): 12,
#  ('thi', 'mere'): 2,
#  ('mere', 'UNK'): 6,
#  ('UNK', 'poor'): 6,
#  ('poor', 'devil'): 6,
#  ('devil', 'subsub'): 2,
#  ('subsub', 'appear'): 1,
#  ('appear', 'go'): 1,
#  ('go', 'long'): 1,
#  ('long', 'UNK'): 11,
#  ('UNK', 'earth'): 4,
#  ('earth', 'pick'): 1,
#  ('pick', 'whatever'): 1,
#  ('whatever', 'random'): 1,
#  ('random', 'allusion'): 1,
#  ('allusion', 'whale'): 1,
#  ('whale', 'anyway'): 1,
#  ('anyway', 'find'): 1,
#  ('find', 'book'): 2,
#  ('book', 'whatsoever'): 1,
#  ('whatsoever', 'sacre'): 1,
#  ('sacre', 'profane'): 1,
#  ('profane', 'therefore'): 1,
#  ('therefore', 'must'): 8,
#  ('must', 'every'): 1,
#  ('every', 'case'): 1,
#  ('case', 'least'): 1,
#  ('least', 'take'): 1,
#  ('take', 'UNK'): 12,
#  ('whale', 'statement'): 1,
#  ('statement', 'however'): 1,
#  ('however', 'authentic'): 1,
#  ('authentic', 'extract'): 1,
#  ('extract', 'veritable'): 1,
#  ('veritable', 'gospel'): 1,
#  ('gospel', 'cetology'): 1,
#  ('cetology', 'far'): 1,
#  ('far', 'touch'): 1,
#  ('touch', 'ancient'): 1,
#  ('ancient', 'author'): 1,
#  ('author', 'generally'): 1,
#  ('generally', 'well'): 2,
#  ('well', 'poet'): 1,
#  ('poet', 'appear'): 1,
#  ('appear', 'extract'): 1,
#  ('extract', 'solely'): 1,
#  ('solely', 'valuable'): 1,
#  ('valuable', 'entertain'): 1,
#  ('entertain', 'afford'): 1,
#  ('afford', 'glance'): 1,
#  ('glance', 'bird'): 1,
#  ('bird', 'eye'): 1,
#  ('eye', 'view'): 1,
#  ('view', 'UNK'): 1,
#  ('UNK', 'say'): 26,
#  ('say', 'think'): 6,
#  ('think', 'fancy'): 1,
#  ('fancy', 'sing'): 1,
#  ('sing', 'leviathan'): 1,
#  ('leviathan', 'many'): 1,
#  ('many', 'nation'): 1,
#  ('nation', 'generation'): 1,
#  ('generation', 'include'): 1,
#  ('include', 'fare'): 1,
#  ('fare', 'thee'): 1,
#  ('thee', 'well'): 1,
#  ('well', 'poor'): 1,
#  ('subsub', 'whose'): 1,
#  ('whose', 'commentator'): 1,
#  ('commentator', 'thou'): 1,
#  ('thou', 'UNK'): 17,
#  ('UNK', 'hopeles'): 2,
#  ('hopeles', 'UNK'): 2,
#  ('UNK', 'tribe'): 2,
#  ('tribe', 'wine'): 1,
#  ('wine', 'thi'): 1,
#  ('thi', 'world'): 15,
#  ('world', 'ever'): 1,
#  ('ever', 'warm'): 1,
#  ('warm', 'even'): 1,
#  ('even', 'pale'): 1,
#  ('UNK', 'would'): 20,
#  ('would', 'UNK'): 16,
#  ('UNK', 'one'): 39,
#  ('one', 'sometime'): 1,
#  ('sometime', 'love'): 1,
#  ('love', 'sit'): 1,
#  ('sit', 'feel'): 1,
#  ('feel', 'UNK'): 4,
#  ('UNK', 'grow'): 2,
#  ('grow', 'convivial'): 1,
#  ('convivial', 'upon'): 1,
#  ('upon', 'tear'): 1,
#  ('tear', 'say'): 1,
#  ('say', 'UNK'): 16,
#  ('UNK', 'full'): 5,
#  ('full', 'eye'): 1,
#  ('eye', 'empty'): 1,
#  ('empty', 'glass'): 2,
#  ('glass', 'altogether'): 1,
#  ('altogether', 'unpleasant'): 1,
#  ('unpleasant', 'UNK'): 1,
#  ('UNK', 'subsub'): 1,
#  ('subsub', 'much'): 1,
#  ('much', 'pain'): 1,
#  ('pain', 'ye'): 1,
#  ('ye', 'take'): 2,
#  ('take', 'please'): 1,
#  ('please', 'world'): 1,
#  ('world', 'much'): 2,
#  ('much', 'shall'): 1,
#  ('shall', 'ye'): 1,
#  ('ye', 'ever'): 1,
#  ('ever', 'go'): 4,
#  ('go', 'UNK'): 22,
#  ('would', 'clear'): 1,
#  ('clear', 'UNK'): 4,
#  ('UNK', 'court'): 1,
#  ('court', 'tuilery'): 1,
#  ('tuilery', 'ye'): 1,
#  ('ye', 'gulp'): 1,
#  ('gulp', 'tear'): 1,
#  ('tear', 'hie'): 1,
#  ('hie', 'aloft'): 1,
#  ('aloft', 'royalmast'): 1,
#  ('royalmast', 'heart'): 1,
#  ('heart', 'friend'): 1,
#  ('friend', 'go'): 1,
#  ('go', 'clear'): 1,
#  ('UNK', 'heaven'): 2,
#  ('heaven', 'make'): 1,
#  ('make', 'UNK'): 22,
#  ('UNK', 'gabriel'): 1,
#  ('gabriel', 'michael'): 1,
#  ('michael', 'UNK'): 1,
#  ('UNK', 'come'): 13,
#  ('come', 'ye'): 5,
#  ('ye', 'strike'): 1,
#  ('strike', 'splinter'): 1,
#  ('splinter', 'heart'): 2,
#  ('heart', 'UNK'): 7,
#  ('UNK', 'ye'): 28,
#  ('ye', 'shall'): 4,
#  ('shall', 'strike'): 1,
#  ('strike', 'UNK'): 5,
#  ('UNK', 'glass'): 3,
#  ('glass', 'extract'): 1,
#  ('extract', 'god'): 1,
#  ('god', 'create'): 1,
#  ('create', 'great'): 3,
#  ('great', 'whale'): 13,
#  ('whale', 'genesi'): 1,
#  ('genesi', 'leviathan'): 1,
#  ('leviathan', 'maketh'): 2,
#  ('maketh', 'path'): 1,
#  ('path', 'shine'): 1,
#  ('shine', 'one'): 1,
#  ('one', 'would'): 4,
#  ('would', 'think'): 17,
#  ('think', 'deep'): 2,
#  ('deep', 'hoary'): 1,
#  ('hoary', 'job'): 1,
#  ('job', 'lord'): 1,
#  ('lord', 'prepare'): 1,
#  ('prepare', 'great'): 2,
#  ('great', 'fish'): 3,
#  ('fish', 'swallow'): 2,
#  ('swallow', 'jonah'): 2,
#  ('jonah', 'jonah'): 1,
#  ('jonah', 'go'): 4,
#  ('go', 'ship'): 2,
#  ('ship', 'leviathan'): 1,
#  ('leviathan', 'thou'): 1,
#  ('thou', 'hast'): 6,
#  ('hast', 'make'): 1,
#  ('make', 'play'): 1,
#  ('play', 'therein'): 1,
#  ('therein', 'psalm'): 1,
#  ('psalm', 'day'): 1,
#  ('day', 'lord'): 1,
#  ('lord', 'hi'): 2,
#  ('hi', 'sore'): 1,
#  ('sore', 'great'): 1,
#  ('great', 'strong'): 1,
#  ('strong', 'sword'): 1,
#  ('sword', 'shall'): 1,
#  ('shall', 'UNK'): 3,
#  ('UNK', 'leviathan'): 6,
#  ('leviathan', 'pierce'): 1,
#  ('pierce', 'serpent'): 1,
#  ('serpent', 'even'): 1,
#  ('even', 'leviathan'): 1,
#  ('leviathan', 'crook'): 1,
#  ('crook', 'serpent'): 1,
#  ('serpent', 'shall'): 1,
#  ('shall', 'slay'): 1,
#  ('slay', 'dragon'): 1,
#  ('dragon', 'sea'): 2,
#  ('sea', 'isaiah'): 1,
#  ('isaiah', 'thing'): 1,
#  ('thing', 'UNK'): 13,
#  ('UNK', 'beside'): 4,
#  ('beside', 'UNK'): 5,
#  ('UNK', 'within'): 6,
#  ('within', 'chao'): 1,
#  ('chao', 'thi'): 1,
#  ('thi', 'monster'): 4,
#  ('monster', 'mouth'): 1,
#  ('mouth', 'beast'): 1,
#  ('beast', 'boat'): 1,
#  ('boat', 'stone'): 1,
#  ('stone', 'go'): 1,
#  ('UNK', 'foul'): 1,
#  ('foul', 'great'): 2,
#  ('great', 'swallow'): 1,
#  ('swallow', 'hi'): 1,
#  ('hi', 'UNK'): 109,
#  ('UNK', 'bottomles'): 1,
#  ('bottomles', 'gulf'): 1,
#  ('gulf', 'hi'): 1,
#  ('hi', 'paunch'): 1,
#  ('paunch', 'holland'): 1,
#  ('holland', 'UNK'): 1,
#  ('UNK', 'moral'): 2,
#  ('moral', 'indian'): 1,
#  ('indian', 'sea'): 1,
#  ('sea', 'UNK'): 24,
#  ('UNK', 'biggest'): 1,
#  ('biggest', 'fishes'): 1,
#  ('fishes', 'among'): 1,
#  ('among', 'whale'): 5,
#  ('call', 'UNK'): 15,
#  ('UNK', 'take'): 9,
#  ('take', 'much'): 2,
#  ('much', 'length'): 2,
#  ('length', 'four'): 1,
#  ('four', 'acre'): 1,
#  ('acre', 'UNK'): 1,
#  ('UNK', 'land'): 5,
#  ('land', 'holland'): 1,
#  ('holland', 'pliny'): 1,
#  ('pliny', 'scarcely'): 1,
#  ('scarcely', 'proceed'): 1,
#  ('proceed', 'two'): 2,
#  ('two', 'day'): 3,
#  ('day', 'sea'): 1,
#  ('sea', 'sunrise'): 1,
#  ('sunrise', 'great'): 1,
#  ('great', 'many'): 1,
#  ('many', 'whale'): 3,
#  ('whale', 'monster'): 2,
#  ('monster', 'sea'): 3,
#  ('sea', 'appear'): 1,
#  ('appear', 'among'): 2,
#  ('among', 'former'): 1,
#  ('former', 'one'): 2,
#  ('one', 'monstrou'): 1,
#  ('monstrou', 'size'): 1,
#  ('size', '....'): 1,
#  ('....', 'thi'): 1,
#  ('thi', 'come'): 2,
#  ('come', 'toward'): 1,
#  ('toward', 'u'): 4,
#  ('u', 'openmouthe'): 1,
#  ('openmouthe', 'raise'): 1,
#  ('raise', 'wave'): 1,
#  ('wave', 'side'): 1,
#  ('side', 'beat'): 1,
#  ('beat', 'sea'): 1,
#  ('sea', 'foam'): 1,
#  ('foam', 'UNK'): 2,
#  ('UNK', 'true'): 5,
#  ('true', 'history'): 3,
#  ('history', 'visit'): 1,
#  ('visit', 'thi'): 1,
#  ('thi', 'country'): 1,
#  ('country', 'also'): 1,
#  ('also', 'view'): 1,
#  ('view', 'catch'): 2,
#  ('catch', 'UNK'): 1,
#  ('UNK', 'bone'): 5,
#  ('bone', 'great'): 1,
#  ('great', 'value'): 1,
#  ('value', 'teeth'): 1,
#  ('teeth', 'bring'): 1,
#  ('bring', 'king'): 1,
#  ('king', '....'): 1,
#  ('....', 'best'): 1,
#  ('best', 'whale'): 1,
#  ('whale', 'catch'): 3,
#  ('catch', 'hi'): 2,
#  ('hi', 'country'): 2,
#  ('country', 'fortyeight'): 1,
#  ('fortyeight', 'fifty'): 1,
#  ('fifty', 'yard'): 3,
#  ('yard', 'long'): 1,
#  ('long', 'say'): 1,
#  ('say', 'one'): 4,
#  ('one', 'six'): 1,
#  ('six', 'kill'): 1,
#  ('kill', 'sixty'): 1,
#  ('sixty', 'two'): 1,
#  ('day', 'verbal'): 1,
#  ('verbal', 'narrative'): 1,
#  ('narrative', 'take'): 1,
#  ('take', 'hi'): 14,
#  ('hi', 'mouth'): 19,
#  ('mouth', 'king'): 1,
#  ('king', 'alfr'): 1,
#  ('alfr', 'a.d.'): 1,
#  ('a.d.', 'wherea'): 1,
#  ('wherea', 'thing'): 1,
#  ('thing', 'whether'): 1,
#  ('whether', 'beast'): 1,
#  ('beast', 'vessel'): 1,
#  ('vessel', 'enter'): 1,
#  ('enter', 'dreadful'): 1,
#  ('dreadful', 'gulf'): 1,
#  ('gulf', 'thi'): 1,
#  ('monster', 'whale'): 2,
#  ('whale', 'mouth'): 5,
#  ('mouth', 'immediately'): 1,
#  ('immediately', 'lose'): 1,
#  ('lose', 'swallow'): 1,
#  ('swallow', 'UNK'): 1,
#  ('UNK', 'retire'): 3,
#  ('retire', 'great'): 1,
#  ('great', 'security'): 1,
#  ('security', 'sleep'): 1,
#  ('sleep', 'UNK'): 3,
#  ('UNK', 'let'): 10,
#  ('let', 'u'): 25,
#  ('u', 'fly'): 2,
#  ('fly', 'let'): 1,
#  ('fly', 'old'): 1,
#  ('old', 'UNK'): 37,
#  ('take', 'leviathan'): 1,
#  ('leviathan', 'describe'): 1,
#  ('describe', 'noble'): 1,
#  ('noble', 'prophet'): 1,
#  ('prophet', 'mose'): 1,
#  ('mose', 'life'): 1,
#  ('life', 'patient'): 1,
#  ('patient', 'job'): 1,
#  ('job', 'rabelai'): 1,
#  ('rabelai', 'thi'): 1,
#  ('thi', 'whale'): 23,
#  ('whale', 'liver'): 1,
#  ('liver', 'two'): 1,
#  ('two', 'cartload'): 1,
#  ('cartload', 'UNK'): 1,
#  ('UNK', 'annal'): 1,
#  ('annal', 'great'): 1,
#  ('great', 'leviathan'): 7,
#  ('maketh', 'sea'): 1,
#  ('sea', 'seethe'): 1,
#  ('seethe', 'like'): 1,
#  ('like', 'boil'): 1,
#  ('boil', 'pan'): 1,
#  ('pan', 'lord'): 1,
#  ('lord', 'UNK'): 3,
#  ('UNK', 'version'): 1,
#  ('version', 'psalm'): 1,
#  ('psalm', 'touch'): 1,
#  ('touch', 'monstrou'): 1,
#  ('monstrou', 'bulk'): 1,
#  ('bulk', 'whale'): 2,
#  ('UNK', 'receive'): 5,
#  ('receive', 'nothe'): 1,
#  ('nothe', 'certain'): 1,
#  ('certain', 'grow'): 2,
#  ('grow', 'exceed'): 1,
#  ('exceed', 'fat'): 1,
#  ('fat', 'insomuch'): 1,
#  ('insomuch', 'incredible'): 1,
#  ('incredible', 'quantity'): 1,
#  ('quantity', 'oil'): 2,
#  ('oil', 'extract'): 1,
#  ('extract', 'one'): 1,
#  ('one', 'whale'): 5,
#  ('whale', 'ibid'): 1,
#  ('ibid', 'history'): 1,
#  ('history', 'life'): 1,
#  ('life', 'death'): 5,
#  ('death', 'UNK'): 2,
#  ('UNK', 'thing'): 22,
#  ('thing', 'earth'): 1,
#  ('earth', 'parmacetti'): 1,
#  ('parmacetti', 'inward'): 1,
#  ('inward', 'bruise'): 1,
#  ('bruise', 'king'): 1,
#  ('king', 'henry'): 1,
#  ('henry', 'like'): 1,
#  ('like', 'whale'): 3,
#  ('whale', 'hamlet'): 1,
#  ('hamlet', 'secure'): 1,
#  ('secure', 'skill'): 1,
#  ('skill', 'UNK'): 1,
#  ('UNK', 'art'): 1,
#  ('art', 'UNK'): 4,
#  ('UNK', 'hi'): 90,
#  ('hi', 'wound'): 1,
#  ('wound', 'worker'): 1,
#  ('worker', 'lowly'): 1,
#  ('lowly', 'dart'): 1,
#  ('dart', 'dint'): 1,
#  ('dint', 'hi'): 1,
#  ('hi', 'breast'): 1,
#  ('breast', 'breed'): 1,
#  ('breed', 'hi'): 2,
#  ('hi', 'restles'): 2,
#  ('restles', 'UNK'): 1,
#  ('UNK', 'like'): 27,
#  ('like', 'wound'): 1,
#  ('wound', 'whale'): 2,
#  ('whale', 'shore'): 1,
#  ('shore', 'fly'): 1,
#  ('fly', 'UNK'): 1,
#  ('UNK', 'queen'): 2,
#  ('queen', 'immense'): 1,
#  ('immense', 'whale'): 1,
#  ('whale', 'motion'): 1,
#  ('motion', 'whose'): 1,
#  ('whose', 'vast'): 1,
#  ('vast', 'body'): 1,
#  ('body', 'peaceful'): 1,
#  ('peaceful', 'calm'): 1,
#  ('calm', 'trouble'): 1,
#  ('trouble', 'ocean'): 1,
#  ('ocean', 'till'): 2,
#  ('till', 'boil'): 1,
#  ('boil', 'sir'): 1,
#  ('sir', 'william'): 2,
#  ('william', 'UNK'): 1,
#  ('UNK', 'spermacetti'): 1,
#  ('spermacetti', 'men'): 1,
#  ('men', 'might'): 1,
#  ('might', 'justly'): 1,
#  ('justly', 'doubt'): 1,
#  ('doubt', 'since'): 1,
#  ('since', 'learn'): 1,
#  ('learn', 'UNK'): 1,
#  ('hi', 'work'): 2,
#  ('work', 'thirty'): 1,
#  ('thirty', 'year'): 4,
#  ('year', 'saith'): 1,
#  ('saith', 'plainly'): 1,
#  ('plainly', 'UNK'): 1,
#  ('UNK', 'quid'): 1,
#  ('quid', 'sit'): 1,
#  ('sit', 'sir'): 1,
#  ('sir', 't.'): 3,
#  ('t.', 'browne'): 2,
#  ('browne', 'sperma'): 1,
#  ('sperma', 'ceti'): 2,
#  ('ceti', 'sperma'): 1,
#  ('ceti', 'whale'): 1,
#  ('hi', 'v.'): 1,
#  ('v.', 'e.'): 1,
#  ('e.', 'like'): 1,
#  ('like', 'UNK'): 52,
#  ('hi', 'modern'): 1,
#  ('modern', 'flail'): 1,
#  ('flail', 'threaten'): 1,
#  ('threaten', 'ruin'): 1,
#  ('ruin', 'hi'): 1,
#  ('hi', 'ponderou'): 1,
#  ('ponderou', 'tail'): 1,
#  ('tail', '...'): 1,
#  ('...', 'fix'): 1,
#  ('fix', 'UNK'): 2,
#  ('hi', 'side'): 6,
#  ('side', 'wear'): 1,
#  ('wear', 'hi'): 1,
#  ('hi', 'back'): 17,
#  ('back', 'grove'): 1,
#  ...}

# %%
sorted_bi_counts_values = dict(sorted(bi_counts.items(), key=lambda item: item[1], reverse=True))
sorted_bi_counts_values
# Out:
# {('UNK', 'UNK'): 556,
#  ('sperm', 'whale'): 170,
#  ('hi', 'UNK'): 109,
#  ('UNK', 'hi'): 90,
#  ('UNK', 'thi'): 74,
#  ('whale', 'UNK'): 63,
#  ('hi', 'head'): 57,
#  ('white', 'whale'): 56,
#  ('moby', 'dick'): 55,
#  ('UNK', 'whale'): 55,
#  ('right', 'whale'): 55,
#  ('like', 'UNK'): 52,
#  ('captain', 'ahab'): 47,
#  ('thi', 'UNK'): 45,
#  ('UNK', 'one'): 39,
#  ('old', 'UNK'): 37,
#  ('old', 'man'): 35,
#  ('hi', 'hand'): 34,
#  ('UNK', 'old'): 30,
#  ('hi', 'face'): 30,
#  ('captain', 'peleg'): 30,
#  ('UNK', 'ye'): 28,
#  ('hi', 'eye'): 28,
#  ('UNK', 'like'): 27,
#  ('one', 'UNK'): 26,
#  ('UNK', 'say'): 26,
#  ('let', 'u'): 25,
#  ('sea', 'UNK'): 24,
#  ('upon', 'hi'): 24,
#  ('ye', 'UNK'): 24,
#  ('thi', 'whale'): 23,
#  ('well', 'know'): 23,
#  ('UNK', 'upon'): 23,
#  ('ship', 'UNK'): 23,
#  ('sort', 'UNK'): 23,
#  ('seem', 'UNK'): 23,
#  ('go', 'UNK'): 22,
#  ('make', 'UNK'): 22,
#  ('UNK', 'thing'): 22,
#  ('one', 'hand'): 22,
#  ('UNK', 'though'): 21,
#  ('UNK', 'would'): 20,
#  ('UNK', 'man'): 20,
#  ('every', 'one'): 20,
#  ('yet', 'UNK'): 20,
#  ('hi', 'mouth'): 19,
#  ('upon', 'thi'): 19,
#  ('one', 'side'): 19,
#  ('UNK', 'sea'): 19,
#  ('UNK', 'seem'): 19,
#  ('hi', 'crew'): 19,
#  ('upon', 'UNK'): 18,
#  ('UNK', 'yet'): 18,
#  ('UNK', 'call'): 17,
#  ('thou', 'UNK'): 17,
#  ('would', 'think'): 17,
#  ('hi', 'back'): 17,
#  ('come', 'UNK'): 17,
#  ('look', 'UNK'): 17,
#  ('head', 'UNK'): 17,
#  ('whale', 'hi'): 17,
#  ('UNK', 'look'): 17,
#  ('hi', 'leg'): 17,
#  ('new', 'bedford'): 17,
#  ('great', 'UNK'): 17,
#  ('still', 'UNK'): 17,
#  ('whale', 'head'): 17,
#  ('man', 'UNK'): 17,
#  ('aye', 'aye'): 17,
#  ('ye', 'ye'): 17,
#  ('would', 'UNK'): 16,
#  ('say', 'UNK'): 16,
#  ('UNK', 'ship'): 16,
#  ('UNK', 'go'): 16,
#  ('UNK', 'see'): 16,
#  ('thi', 'matter'): 16,
#  ('young', 'man'): 16,
#  ('greenland', 'whale'): 16,
#  ('thi', 'world'): 15,
#  ('call', 'UNK'): 15,
#  ('hi', 'tail'): 15,
#  ('hi', 'feet'): 15,
#  ('UNK', 'think'): 15,
#  ('take', 'hi'): 14,
#  ('whale', 'fishery'): 14,
#  ('whale', 'thi'): 14,
#  ('cape', 'horn'): 14,
#  ('little', 'UNK'): 14,
#  ('stand', 'UNK'): 14,
#  ('even', 'UNK'): 14,
#  ('UNK', 'time'): 14,
#  ('chief', 'mate'): 14,
#  ('UNK', 'still'): 14,
#  ('UNK', 'come'): 13,
#  ('great', 'whale'): 13,
#  ('thing', 'UNK'): 13,
#  ('see', 'UNK'): 13,
#  ('UNK', 'sperm'): 13,
#  ('whale', 'voyage'): 13,
#  ('much', 'UNK'): 13,
#  ('turn', 'round'): 13,
#  ('three', 'year'): 13,
#  ('never', 'mind'): 13,
#  ('UNK', 'queequeg'): 13,
#  ('hi', 'pipe'): 13,
#  ('UNK', 'chapter'): 13,
#  ('would', 'seem'): 13,
#  ('look', 'like'): 13,
#  ('thi', 'way'): 13,
#  ('mrs.', 'hussey'): 13,
#  ('captain', 'bildad'): 13,
#  ('mr.', 'starbuck'): 13,
#  ('boat', 'crew'): 12,
#  ('see', 'thi'): 12,
#  ('take', 'UNK'): 12,
#  ('UNK', 'make'): 12,
#  ('one', 'know'): 12,
#  ('hand', 'UNK'): 12,
#  ('somethe', 'like'): 12,
#  ('UNK', 'sort'): 12,
#  ('though', 'UNK'): 12,
#  ('two', 'three'): 12,
#  ('mean', 'UNK'): 12,
#  ('UNK', 'long'): 12,
#  ('UNK', 'good'): 12,
#  ('hand', 'hi'): 12,
#  ('hi', 'harpoon'): 12,
#  ('ye', 'say'): 12,
#  ('ye', 'see'): 12,
#  ('UNK', 'even'): 12,
#  ('cry', 'stubb'): 12,
#  ('hi', 'old'): 11,
#  ('long', 'UNK'): 11,
#  ('UNK', 'water'): 11,
#  ('never', 'hear'): 11,
#  ('may', 'say'): 11,
#  ('UNK', 'great'): 11,
#  ('UNK', 'way'): 11,
#  ('UNK', 'may'): 11,
#  ('UNK', 'tell'): 11,
#  ('think', 'thi'): 11,
#  ('mind', 'UNK'): 11,
#  ('go', 'hi'): 11,
#  ('UNK', 'day'): 11,
#  ('UNK', 'last'): 11,
#  ('UNK', 'feel'): 11,
#  ('ever', 'since'): 11,
#  ('hi', 'boat'): 11,
#  ('two', 'UNK'): 11,
#  ('hi', 'ship'): 11,
#  ('lower', 'jaw'): 11,
#  ('queequeg', 'say'): 11,
#  ('round', 'hi'): 11,
#  ('remain', 'UNK'): 11,
#  ('ship', 'sail'): 11,
#  ('ahab', 'UNK'): 11,
#  ('whale', 'one'): 11,
#  ('UNK', 'men'): 11,
#  ('ere', 'long'): 11,
#  ('UNK', 'white'): 11,
#  ('picture', 'whale'): 10,
#  ('UNK', 'let'): 10,
#  ('man', 'hi'): 10,
#  ('captain', 'UNK'): 10,
#  ('know', 'UNK'): 10,
#  ('never', 'see'): 10,
#  ('turn', 'hi'): 10,
#  ('u', 'UNK'): 10,
#  ('last', 'come'): 10,
#  ('hi', 'forehead'): 10,
#  ('UNK', 'suppose'): 10,
#  ('one', 'two'): 10,
#  ('hi', 'arm'): 10,
#  ('think', 'UNK'): 10,
#  ('hi', 'great'): 10,
#  ('thi', 'day'): 10,
#  ('much', 'like'): 10,
#  ('UNK', 'first'): 10,
#  ('head', 'thi'): 10,
#  ('UNK', 'part'): 10,
#  ('say', 'queequeg'): 10,
#  ('side', 'side'): 10,
#  ('thi', 'old'): 10,
#  ('board', 'pequod'): 10,
#  ('UNK', 'cry'): 10,
#  ('time', 'UNK'): 10,
#  ('boat', 'UNK'): 10,
#  ('whale', 'would'): 10,
#  ('say', 'stubb'): 10,
#  ('cry', 'ahab'): 10,
#  ('hi', 'hammock'): 10,
#  ('give', 'way'): 10,
#  ('UNK', 'start'): 9,
#  ('whale', 'chapter'): 9,
#  ('stubb', 'flask'): 9,
#  ('UNK', 'take'): 9,
#  ('way', 'UNK'): 9,
#  ('feet', 'length'): 9,
#  ('UNK', 'world'): 9,
#  ('year', 'ago'): 9,
#  ('see', 'hi'): 9,
#  ('thi', 'one'): 9,
#  ('three', 'four'): 9,
#  ('UNK', 'far'): 9,
#  ('stand', 'hi'): 9,
#  ('go', 'sea'): 9,
#  ('UNK', 'eye'): 9,
#  ('thi', 'sort'): 9,
#  ('UNK', 'two'): 9,
#  ('like', 'thi'): 9,
#  ('part', 'UNK'): 9,
#  ('may', 'well'): 9,
#  ('UNK', 'might'): 9,
#  ('UNK', 'every'): 9,
#  ('one', 'end'): 9,
#  ('UNK', 'bear'): 9,
#  ('upon', 'whole'): 9,
#  ('turn', 'UNK'): 9,
#  ('ye', 'come'): 9,
#  ('show', 'hi'): 9,
#  ('UNK', 'run'): 9,
#  ('UNK', 'head'): 9,
#  ('three', 'day'): 9,
#  ('away', 'hi'): 9,
#  ('back', 'hi'): 9,
#  ('UNK', 'many'): 9,
#  ('round', 'UNK'): 9,
#  ('thou', 'art'): 9,
#  ('father', 'mapple'): 9,
#  ('certain', 'UNK'): 9,
#  ('whale', 'captain'): 9,
#  ('thu', 'far'): 9,
#  ('upon', 'whale'): 9,
#  ('one', 'hi'): 9,
#  ('say', 'peleg'): 9,
#  ('come', 'back'): 9,
#  ('make', 'one'): 9,
#  ('peleg', 'say'): 9,
#  ('say', 'bildad'): 9,
#  ('seven', 'hundr'): 9,
#  ('ship', 'would'): 9,
#  ('say', 'ye'): 9,
#  ('UNK', 'life'): 9,
#  ('stubb', 'UNK'): 9,
#  ('white', 'UNK'): 9,
#  ('great', 'sperm'): 9,
#  ('hi', 'body'): 9,
#  ('hi', 'one'): 9,
#  ('round', 'round'): 9,
#  ('cry', 'starbuck'): 9,
#  ('three', 'boat'): 9,
#  ('UNK', 'devil'): 9,
#  ('st.', 'george'): 9,
#  ('chapter', 'whale'): 8,
#  ('UNK', 'word'): 8,
#  ('therefore', 'must'): 8,
#  ('see', 'whale'): 8,
#  ('among', 'crew'): 8,
#  ('among', 'UNK'): 8,
#  ('almost', 'every'): 8,
#  ('must', 'need'): 8,
#  ('get', 'UNK'): 8,
#  ('UNK', 'never'): 8,
#  ('take', 'thi'): 8,
#  ('UNK', 'well'): 8,
#  ('give', 'chase'): 8,
#  ('UNK', 'thou'): 8,
#  ('every', 'way'): 8,
#  ('full', 'UNK'): 8,
#  ('side', 'UNK'): 8,
#  ('thi', 'harpooneer'): 8,
#  ('last', 'UNK'): 8,
#  ('yet', 'see'): 8,
#  ('UNK', 'new'): 8,
#  ('UNK', 'know'): 8,
#  ('would', 'come'): 8,
#  ('UNK', 'speak'): 8,
#  ('tell', 'ye'): 8,
#  ('thi', 'particular'): 8,
#  ('rest', 'hi'): 8,
#  ('bring', 'hi'): 8,
#  ('another', 'UNK'): 8,
#  ('draw', 'nigh'): 8,
#  ('UNK', 'form'): 8,
#  ('thi', 'busines'): 8,
#  ('hi', 'life'): 8,
#  ('hand', 'upon'): 8,
#  ('UNK', 'god'): 8,
#  ('UNK', 'oh'): 8,
#  ('yet', 'thi'): 8,
#  ('one', 'time'): 8,
#  ('sight', 'see'): 8,
#  ('queequeg', 'UNK'): 8,
#  ('king', 'UNK'): 8,
#  ('give', 'u'): 8,
#  ('look', 'ye'): 8,
#  ('though', 'hi'): 8,
#  ('old', 'bildad'): 8,
#  ('ship', 'company'): 8,
#  ('ahab', 'hi'): 8,
#  ('part', 'hi'): 8,
#  ('upon', 'one'): 8,
#  ('UNK', 'get'): 8,
#  ('hi', 'cabin'): 8,
#  ('hi', 'comrade'): 8,
#  ('mr.', 'stubb'): 8,
#  ('would', 'fain'): 8,
#  ('de', 'UNK'): 8,
#  ('whale', 'may'): 8,
#  ('present', 'day'): 8,
#  ('ahab', 'stand'): 8,
#  ('UNK', 'air'): 8,
#  ('thi', 'leviathan'): 8,
#  ('i.', 'folio'): 8,
#  ('ii', 'octavo'): 8,
#  ('may', 'possibly'): 8,
#  ('hi', 'spout'): 8,
#  ('back', 'UNK'): 8,
#  ('one', 'hundr'): 8,
#  ('UNK', 'boat'): 8,
#  ('whale', 'see'): 8,
#  ('beneath', 'surface'): 8,
#  ('four', 'boat'): 8,
#  ('set', 'UNK'): 7,
#  ('chapter', 'ahab'): 7,
#  ('whale', 'scene'): 7,
#  ('chapter', 'pequod'): 7,
#  ('pequod', 'meet'): 7,
#  ('heart', 'UNK'): 7,
#  ('great', 'leviathan'): 7,
#  ('whale', 'first'): 7,
#  ('find', 'UNK'): 7,
#  ('UNK', 'right'): 7,
#  ('whale', 'ship'): 7,
#  ('UNK', 'little'): 7,
#  ('high', 'time'): 7,
#  ('UNK', 'throw'): 7,
#  ('thousand', 'mile'): 7,
#  ('one', 'way'): 7,
#  ('long', 'time'): 7,
#  ('UNK', 'must'): 7,
#  ('look', 'see'): 7,
#  ('UNK', 'bed'): 7,
#  ('say', 'old'): 7,
#  ('new', 'england'): 7,
#  ('run', 'away'): 7,
#  ('old', 'time'): 7,
#  ('landlord', 'say'): 7,
#  ('say', 'i.'): 7,
#  ('UNK', 'round'): 7,
#  ('make', 'hi'): 7,
#  ('good', 'deal'): 7,
#  ('UNK', 'mean'): 7,
#  ('first', 'place'): 7,
#  ('new', 'zealand'): 7,
#  ('UNK', 'small'): 7,
#  ('hi', 'tomahawk'): 7,
#  ('think', 'ye'): 7,
#  ('UNK', 'turn'): 7,
#  ('keep', 'hi'): 7,
#  ('know', 'thi'): 7,
#  ('hi', 'way'): 7,
#  ('second', 'mate'): 7,
#  ('young', 'UNK'): 7,
#  ('indian', 'ocean'): 7,
#  ('bottom', 'sea'): 7,
#  ('must', 'go'): 7,
#  ('whose', 'UNK'): 7,
#  ('hi', 'name'): 7,
#  ('ship', 'boat'): 7,
#  ('cry', 'captain'): 7,
#  ('UNK', 'much'): 7,
#  ('hi', 'ivory'): 7,
#  ('may', 'seem'): 7,
#  ('man', 'would'): 7,
#  ('never', 'UNK'): 7,
#  ('hi', 'father'): 7,
#  ('poor', 'queequeg'): 7,
#  ('well', 'UNK'): 7,
#  ('UNK', 'captain'): 7,
#  ('good', 'time'): 7,
#  ('go', 'round'): 7,
#  ('UNK', 'sailor'): 7,
#  ('thi', 'whole'): 7,
#  ('whale', 'eye'): 7,
#  ('hi', 'whole'): 7,
#  ('say', 'thi'): 7,
#  ('UNK', 'stubb'): 7,
#  ('thi', 'seem'): 7,
#  ('three', 'UNK'): 7,
#  ('ivory', 'leg'): 7,
#  ('UNK', 'hold'): 7,
#  ('wise', 'stubb'): 7,
#  ('whale', 'say'): 7,
#  ('whale', 'great'): 7,
#  ('book', 'i.'): 7,
#  ('feet', 'long'): 7,
#  ('white', 'water'): 7,
#  ('book', 'ii'): 7,
#  ('upper', 'part'): 7,
#  ('starbuck', 'stubb'): 7,
#  ('specy', 'leviathan'): 7,
#  ('lower', 'boat'): 7,
#  ('hi', 'mark'): 6,
#  ('chapter', 'stubb'): 6,
#  ('kill', 'whale'): 6,
#  ('heidelburgh', 'tun'): 6,
#  ('name', 'UNK'): 6,
#  ('mere', 'UNK'): 6,
#  ('UNK', 'poor'): 6,
#  ('poor', 'devil'): 6,
#  ('say', 'think'): 6,
#  ('thou', 'hast'): 6,
#  ('UNK', 'leviathan'): 6,
#  ('UNK', 'within'): 6,
#  ('hi', 'side'): 6,
#  ('would', 'make'): 6,
#  ('like', 'great'): 6,
#  ('dead', 'whale'): 6,
#  ('whale', 'spout'): 6,
#  ('new', 'york'): 6,
#  ('point', 'view'): 6,
#  ('may', 'UNK'): 6,
#  ('whale', 'vessel'): 6,
#  ('UNK', 'live'): 6,
#  ('though', 'thi'): 6,
#  ('UNK', 'among'): 6,
#  ('upon', 'first'): 6,
#  ('far', 'UNK'): 6,
#  ('thing', 'would'): 6,
#  ('sail', 'nantucket'): 6,
#  ('busines', 'whale'): 6,
#  ('whale', 'though'): 6,
#  ('UNK', 'place'): 6,
#  ('american', 'whale'): 6,
#  ('still', 'another'): 6,
#  ('feet', 'UNK'): 6,
#  ('true', 'enough'): 6,
#  ('hi', 'teeth'): 6,
#  ('UNK', 'give'): 6,
#  ('almost', 'think'): 6,
#  ('would', 'almost'): 6,
#  ('green', 'UNK'): 6,
#  ('say', 'look'): 6,
#  ('go', 'back'): 6,
#  ('UNK', 'shall'): 6,
#  ('small', 'UNK'): 6,
#  ('next', 'morn'): 6,
#  ('think', 'might'): 6,
#  ('UNK', 'alway'): 6,
#  ('south', 'sea'): 6,
#  ('ye', 'think'): 6,
#  ('think', 'hi'): 6,
#  ('hi', 'chest'): 6,
#  ('strange', 'UNK'): 6,
#  ('light', 'hi'): 6,
#  ('thi', 'wild'): 6,
#  ('one', 'single'): 6,
#  ('hi', 'mind'): 6,
#  ('savage', 'UNK'): 6,
#  ('every', 'day'): 6,
#  ('used', 'UNK'): 6,
#  ('hi', 'proper'): 6,
#  ('see', 'world'): 6,
#  ('every', 'man'): 6,
#  ('much', 'hi'): 6,
#  ('whence', 'come'): 6,
#  ('poor', 'UNK'): 6,
#  ('perhap', 'UNK'): 6,
#  ('bow', 'hi'): 6,
#  ('UNK', 'line'): 6,
#  ('world', 'UNK'): 6,
#  ('hear', 'hi'): 6,
#  ('reason', 'thi'): 6,
#  ('thi', 'thing'): 6,
#  ('thi', 'book'): 6,
#  ('u', 'thi'): 6,
#  ('UNK', 'find'): 6,
#  ('god', 'UNK'): 6,
#  ('mark', 'UNK'): 6,
#  ('UNK', 'sail'): 6,
#  ('put', 'hi'): 6,
#  ('sir', 'say'): 6,
#  ('say', 'captain'): 6,
#  ('throw', 'hi'): 6,
#  ('upon', 'sea'): 6,
#  ('hi', 'soul'): 6,
#  ('thi', 'great'): 6,
#  ('like', 'many'): 6,
#  ('lift', 'hi'): 6,
#  ('thy', 'UNK'): 6,
#  ('UNK', 'left'): 6,
#  ('hi', 'nose'): 6,
#  ('time', 'say'): 6,
#  ('whether', 'thi'): 6,
#  ('follow', 'UNK'): 6,
#  ('wild', 'UNK'): 6,
#  ('UNK', 'used'): 6,
#  ('carry', 'hi'): 6,
#  ('say', 'say'): 6,
#  ('poor', 'fellow'): 6,
#  ('hi', 'long'): 6,
#  ('one', 'arm'): 6,
#  ('UNK', 'carve'): 6,
#  ('UNK', 'nothe'): 6,
#  ('though', 'indee'): 6,
#  ('dye', 'see'): 6,
#  ('see', 'well'): 6,
#  ('round', 'cape'): 6,
#  ('men', 'UNK'): 6,
#  ('UNK', 'rise'): 6,
#  ('hi', 'men'): 6,
#  ('bildad', 'say'): 6,
#  ('say', 'nothe'): 6,
#  ('hundr', 'seventyseventh'): 6,
#  ('ye', 'hear'): 6,
#  ('start', 'UNK'): 6,
#  ('tell', 'thee'): 6,
#  ('lose', 'hi'): 6,
#  ('might', 'UNK'): 6,
#  ('eight', 'ten'): 6,
#  ('thi', 'time'): 6,
#  ('ship', 'deck'): 6,
#  ('UNK', 'thy'): 6,
#  ('thrust', 'hi'): 6,
#  ('well', 'well'): 6,
#  ('morn', 'ye'): 6,
#  ('come', 'board'): 6,
#  ('UNK', 'pequod'): 6,
#  ('would', 'see'): 6,
#  ('UNK', 'lower'): 6,
#  ('hi', 'officer'): 6,
#  ('whale', 'much'): 6,
#  ('mr.', 'flask'): 6,
#  ('thi', 'head'): 6,
#  ('little', 'flask'): 6,
#  ('stand', 'upon'): 6,
#  ('side', 'hi'): 6,
#  ('might', 'well'): 6,
#  ('hi', 'broad'): 6,
#  ('whale', 'almost'): 6,
#  ('folio', 'chapter'): 6,
#  ('grind', 'UNK'): 6,
#  ('never', 'yet'): 6,
#  ('UNK', 'advance'): 6,
#  ('also', 'UNK'): 6,
#  ('thu', 'UNK'): 6,
#  ('end', 'UNK'): 6,
#  ('without', 'UNK'): 6,
#  ('UNK', 'stand'): 6,
#  ('captain', 'sleet'): 6,
#  ('many', 'UNK'): 6,
#  ('round', 'world'): 6,
#  ('start', 'hi'): 6,
#  ('good', 'hope'): 6,
#  ('hold', 'UNK'): 6,
#  ('UNK', 'wild'): 6,
#  ('latitude', 'longitude'): 6,
#  ('evince', 'hi'): 6,
#  ('bear', 'upon'): 6,
#  ('almost', 'seem'): 6,
#  ('whale', 'strike'): 6,
#  ('pull', 'UNK'): 6,
#  ('say', 'flask'): 6,
#  ('would', 'give'): 6,
#  ('time', 'thi'): 6,
#  ('ye', 'cry'): 6,
#  ('drop', 'astern'): 6,
#  ('body', 'whale'): 6,
#  ('leviathan', 'UNK'): 6,
#  ('hoist', 'deck'): 6,
#  ('lower', 'part'): 6,
#  ('twenty', 'feet'): 6,
#  ('strait', 'sunda'): 6,
#  ('dick', 'whale'): 5,
#  ('queequeg', 'hi'): 5,
#  ('UNK', 'almost'): 5,
#  ('UNK', 'full'): 5,
#  ('come', 'ye'): 5,
#  ('strike', 'UNK'): 5,
#  ('beside', 'UNK'): 5,
#  ('among', 'whale'): 5,
#  ('UNK', 'land'): 5,
#  ('UNK', 'true'): 5,
#  ('UNK', 'bone'): 5,
#  ('whale', 'mouth'): 5,
#  ('UNK', 'receive'): 5,
#  ('one', 'whale'): 5,
#  ('life', 'death'): 5,
#  ('UNK', 'mouth'): 5,
#  ('UNK', 'voyage'): 5,
#  ('set', 'sail'): 5,
#  ('sail', 'UNK'): 5,
#  ('UNK', 'wind'): 5,
#  ('wind', 'UNK'): 5,
#  ('say', 'whale'): 5,
#  ('see', 'whether'): 5,
#  ('whale', 'take'): 5,
#  ('whale', 'come'): 5,
#  ('spermaceti', 'whale'): 5,
#  ('round', 'globe'): 5,
#  ('high', 'UNK'): 5,
#  ('monster', 'UNK'): 5,
#  ('thi', 'vast'): 5,
#  ('pacific', 'ocean'): 5,
#  ('boat', 'hi'): 5,
#  ('every', 'time'): 5,
#  ('UNK', 'nantucket'): 5,
#  ('somethe', 'UNK'): 5,
#  ('UNK', 'rope'): 5,
#  ('instant', 'UNK'): 5,
#  ('right', 'left'): 5,
#  ('sight', 'land'): 5,
#  ('sleep', 'hi'): 5,
#  ('begin', 'grow'): 5,
#  ('sort', 'thing'): 5,
#  ('tell', 'thi'): 5,
#  ('think', 'see'): 5,
#  ('roll', 'hi'): 5,
#  ('saturday', 'night'): 5,
#  ('thi', 'new'): 5,
#  ('well', 'ye'): 5,
#  ('fiery', 'pit'): 5,
#  ('yet', 'come'): 5,
#  ('place', 'thi'): 5,
#  ('ever', 'anon'): 5,
#  ('UNK', 'idea'): 5,
#  ('bed', 'UNK'): 5,
#  ('harpooneer', 'UNK'): 5,
#  ('four', 'five'): 5,
#  ('monkey', 'jacket'): 5,
#  ('say', 'landlord'): 5,
#  ('begin', 'feel'): 5,
#  ('cry', 'UNK'): 5,
#  ('thi', 'man'): 5,
#  ('since', 'UNK'): 5,
#  ('case', 'might'): 5,
#  ('board', 'UNK'): 5,
#  ('go', 'bed'): 5,
#  ('thi', 'tell'): 5,
#  ('say', 'go'): 5,
#  ('tell', 'UNK'): 5,
#  ('one', 'one'): 5,
#  ('time', 'think'): 5,
#  ('come', 'near'): 5,
#  ('think', 'little'): 5,
#  ('wear', 'UNK'): 5,
#  ('say', 'word'): 5,
#  ('look', 'toward'): 5,
#  ('UNK', 'bag'): 5,
#  ('plainly', 'see'): 5,
#  ('soon', 'UNK'): 5,
#  ('UNK', 'truth'): 5,
#  ('white', 'man'): 5,
#  ('world', 'like'): 5,
#  ('completely', 'UNK'): 5,
#  ('might', 'take'): 5,
#  ('UNK', 'back'): 5,
#  ('next', 'moment'): 5,
#  ('UNK', 'help'): 5,
#  ('roll', 'away'): 5,
#  ('queequeg', 'look'): 5,
#  ('may', 'go'): 5,
#  ('take', 'away'): 5,
#  ('draw', 'back'): 5,
#  ('give', 'understand'): 5,
#  ('watch', 'hi'): 5,
#  ('top', 'hi'): 5,
#  ('hi', 'boot'): 5,
#  ('hard', 'work'): 5,
#  ('complete', 'UNK'): 5,
#  ('hi', 'hat'): 5,
#  ('thi', 'young'): 5,
#  ('UNK', 'whole'): 5,
#  ('say', 'much'): 5,
#  ('UNK', 'fellow'): 5,
#  ('gaze', 'upon'): 5,
#  ('atlantic', 'pacific'): 5,
#  ('fine', 'UNK'): 5,
#  ('high', 'air'): 5,
#  ('sailor', 'UNK'): 5,
#  ('one', 'boat'): 5,
#  ('UNK', 'heart'): 5,
#  ('century', 'ago'): 5,
#  ('many', 'year'): 5,
#  ('life', 'UNK'): 5,
#  ('old', 'age'): 5,
#  ('UNK', 'spring'): 5,
#  ('UNK', 'snow'): 5,
#  ('first', 'time'): 5,
#  ('come', 'hi'): 5,
#  ('like', 'old'): 5,
#  ('UNK', 'mere'): 5,
#  ('upon', 'ship'): 5,
#  ('close', 'eye'): 5,
#  ('hi', 'ear'): 5,
#  ('ye', 'shipmate'): 5,
#  ('hi', 'god'): 5,
#  ('UNK', 'break'): 5,
#  ('hi', 'berth'): 5,
#  ('whale', 'shall'): 5,
#  ('fore', 'aft'): 5,
#  ('know', 'hi'): 5,
#  ('feel', 'hi'): 5,
#  ('come', 'thi'): 5,
#  ('ten', 'thousand'): 5,
#  ('watery', 'world'): 5,
#  ('ship', 'thi'): 5,
#  ('UNK', 'thu'): 5,
#  ('feel', 'like'): 5,
#  ('speak', 'hi'): 5,
#  ('upon', 'deck'): 5,
#  ('let', 'go'): 5,
#  ('hi', 'wild'): 5,
#  ('four', 'ocean'): 5,
#  ('touch', 'hi'): 5,
#  ('ever', 'see'): 5,
#  ('UNK', 'common'): 5,
#  ('turn', 'say'): 5,
#  ('see', 'one'): 5,
#  ('queequeg', 'take'): 5,
#  ('boat', 'soon'): 5,
#  ('UNK', 'three'): 5,
#  ('first', 'man'): 5,
#  ('u', 'one'): 5,
#  ('come', 'forth'): 5,
#  ('one', 'morn'): 5,
#  ('four', 'year'): 5,
#  ('UNK', 'point'): 5,
#  ('ancient', 'UNK'): 5,
#  ('ahab', 'captain'): 5,
#  ('help', 'UNK'): 5,
#  ('UNK', 'creature'): 5,
#  ('nantucket', 'UNK'): 5,
#  ('yet', 'hi'): 5,
#  ('rather', 'UNK'): 5,
#  ('peleg', 'hi'): 5,
#  ('consider', 'UNK'): 5,
#  ('ever', 'sail'): 5,
#  ('ye', 'go'): 5,
#  ('UNK', 'ahab'): 5,
#  ('hi', 'lance'): 5,
#  ('pagan', 'UNK'): 5,
#  ('queequeg', 'harpoon'): 5,
#  ('open', 'UNK'): 5,
#  ('thi', 'strange'): 5,
#  ('hi', 'ramadan'): 5,
#  ('law', 'UNK'): 5,
#  ('toward', 'ship'): 5,
#  ('say', 'turn'): 5,
#  ('line', 'UNK'): 5,
#  ('eye', 'UNK'): 5,
#  ('hi', 'thought'): 5,
#  ('give', 'order'): 5,
#  ('tell', 'u'): 5,
#  ('UNK', 'u'): 5,
#  ('call', 'hi'): 5,
#  ('hi', 'foe'): 5,
#  ('ahab', 'hear'): 5,
#  ('within', 'hi'): 5,
#  ('blood', 'UNK'): 5,
#  ('spring', 'UNK'): 5,
#  ('sail', 'set'): 5,
#  ('mr.', 'UNK'): 5,
#  ('whale', 'hunter'): 5,
#  ('whale', 'famou'): 5,
#  ('way', 'whale'): 5,
#  ('hi', 'time'): 5,
#  ('say', 'starbuck'): 5,
#  ('UNK', 'ever'): 5,
#  ('whale', 'three'): 5,
#  ('old', 'ahab'): 5,
#  ('UNK', 'dart'): 5,
#  ('hi', 'brow'): 5,
#  ('stubb', 'say'): 5,
#  ('whale', 'many'): 5,
#  ('still', 'remain'): 5,
#  ('book', 'UNK'): 5,
#  ('iii', 'duodecimo'): 5,
#  ('hi', 'oil'): 5,
#  ('bestow', 'upon'): 5,
#  ('whale', 'right'): 5,
#  ('however', 'UNK'): 5,
#  ('octavo', 'chapter'): 5,
#  ('thi', 'fish'): 5,
#  ('UNK', 'shark'): 5,
#  ('hi', 'entire'): 5,
#  ('old', 'dutch'): 5,
#  ('UNK', 'general'): 5,
#  ('hi', 'brain'): 5,
#  ('another', 'thing'): 5,
#  ('UNK', 'keep'): 5,
#  ('often', 'happen'): 5,
#  ('concern', 'thi'): 5,
#  ('whale', 'must'): 5,
#  ('thousand', 'UNK'): 5,
#  ('ahab', 'must'): 5,
#  ('ahab', 'say'): 5,
#  ('ye', 'men'): 5,
#  ('water', 'UNK'): 5,
#  ('ha', 'ha'): 5,
#  ('nantucket', 'sailor'): 5,
#  ('dye', 'hear'): 5,
#  ('great', 'part'): 5,
#  ('whale', 'capture'): 5,
#  ('time', 'hi'): 5,
#  ('thi', 'may'): 5,
#  ('UNK', 'also'): 5,
#  ('time', 'place'): 5,
#  ('thi', 'whitenes'): 5,
#  ('UNK', 'middle'): 5,
#  ('give', 'UNK'): 5,
#  ('ever', 'find'): 5,
#  ('whale', 'case'): 5,
#  ('whale', 'body'): 5,
#  ('whale', 'might'): 5,
#  ('boat', 'still'): 5,
#  ('UNK', 'chance'): 5,
#  ('whale', 'go'): 5,
#  ('little', 'kingpost'): 5,
#  ('stubb', 'hi'): 5,
#  ('hi', 'seat'): 5,
#  ('boat', 'bow'): 5,
#  ('whale', 'seem'): 5,
#  ('half', 'UNK'): 5,
#  ('cape', 'good'): 5,
#  ('air', 'UNK'): 5,
#  ('jonah', 'whale'): 5,
#  ('full', 'grow'): 5,
#  ('however', 'much'): 5,
#  ('UNK', 'mass'): 5,
#  ('entire', 'length'): 5,
#  ('second', 'iron'): 5,
#  ('present', 'case'): 5,
#  ('herman', 'melville'): 4,
#  ('project', 'gutenberg'): 4,
#  ('go', 'aboard'): 4,
#  ('chapter', 'knight'): 4,
#  ('knight', 'squire'): 4,
#  ('chapter', 'first'): 4,
#  ('ahab', 'boat'): 4,
#  ('whale', 'true'): 4,
#  ('whale', 'headcontrast'): 4,
#  ('headcontrast', 'view'): 4,
#  ('great', 'heidelburgh'): 4,
#  ('honor', 'glory'): 4,
#  ('cabin', 'chapter'): 4,
#  ('original', 'UNK'): 4,
#  ('pale', 'UNK'): 4,
#  ('UNK', 'coat'): 4,
#  ('UNK', 'roll'): 4,
#  ('whale', 'english'): 4,
#  ('UNK', 'earth'): 4,
#  ('feel', 'UNK'): 4,
#  ('ever', 'go'): 4,
#  ('clear', 'UNK'): 4,
#  ('ye', 'shall'): 4,
#  ('one', 'would'): 4,
#  ('jonah', 'go'): 4,
#  ('UNK', 'beside'): 4,
#  ('thi', 'monster'): 4,
#  ('toward', 'u'): 4,
#  ('say', 'one'): 4,
#  ('art', 'UNK'): 4,
#  ('thirty', 'year'): 4,
#  ('UNK', 'swallow'): 4,
#  ('land', 'hi'): 4,
#  ('whale', 'swim'): 4,
#  ('sea', 'water'): 4,
#  ('see', 'many'): 4,
#  ('open', 'hi'): 4,
#  ('come', 'upon'): 4,
#  ('large', 'whale'): 4,
#  ('voyage', 'round'): 4,
#  ('UNK', 'smell'): 4,
#  ('carry', 'UNK'): 4,
#  ('whale', 'find'): 4,
#  ('UNK', 'green'): 4,
#  ('whale', 'jaw'): 4,
#  ('one', 'night'): 4,
#  ('whale', 'roll'): 4,
#  ('UNK', 'late'): 4,
#  ('greenland', 'right'): 4,
#  ('manner', 'UNK'): 4,
#  ('specy', 'whale'): 4,
#  ('island', 'nantucket'): 4,
#  ('new', 'UNK'): 4,
#  ('whale', 'white'): 4,
#  ('whaleship', 'UNK'): 4,
#  ('live', 'UNK'): 4,
#  ('rare', 'old'): 4,
#  ('old', 'whale'): 4,
#  ('sea', 'whale'): 4,
#  ('year', 'UNK'): 4,
#  ('UNK', 'mind'): 4,
#  ('think', 'would'): 4,
#  ('high', 'aloft'): 4,
#  ('UNK', 'drop'): 4,
#  ('story', 'UNK'): 4,
#  ('grow', 'UNK'): 4,
#  ('go', 'passenger'): 4,
#  ('general', 'UNK'): 4,
#  ('never', 'go'): 4,
#  ('UNK', 'somehow'): 4,
#  ('UNK', 'lord'): 4,
#  ('UNK', 'boy'): 4,
#  ('les', 'UNK'): 4,
#  ('alway', 'go'): 4,
#  ('ever', 'hear'): 4,
#  ('upon', 'u'): 4,
#  ('much', 'way'): 4,
#  ('many', 'thing'): 4,
#  ('go', 'whale'): 4,
#  ('one', 'else'): 4,
#  ('thi', 'part'): 4,
#  ('part', 'whale'): 4,
#  ('sea', 'land'): 4,
#  ('social', 'UNK'): 4,
#  ('make', 'sail'): 4,
#  ('UNK', 'put'): 4,
#  ('night', 'UNK'): 4,
#  ('know', 'one'): 4,
#  ('one', 'place'): 4,
#  ('ten', 'inch'): 4,
#  ('hard', 'UNK'): 4,
#  ('UNK', 'hard'): 4,
#  ('day', 'week'): 4,
#  ('UNK', 'open'): 4,
#  ('suppose', 'thi'): 4,
#  ('best', 'UNK'): 4,
#  ('UNK', 'whose'): 4,
#  ('stop', 'UNK'): 4,
#  ('hand', 'hold'): 4,
#  ('old', 'craft'): 4,
#  ('UNK', 'picture'): 4,
#  ('dart', 'UNK'): 4,
#  ('three', 'masthead'): 4,
#  ('round', 'like'): 4,
#  ('thi', 'long'): 4,
#  ('craft', 'UNK'): 4,
#  ('might', 'almost'): 4,
#  ('true', 'UNK'): 4,
#  ('sleep', 'two'): 4,
#  ('two', 'bed'): 4,
#  ('depend', 'upon'): 4,
#  ('UNK', 'want'): 4,
#  ('supper', 'UNK'): 4,
#  ('make', 'much'): 4,
#  ('year', 'voyage'): 4,
#  ('land', 'sea'): 4,
#  ('hi', 'voice'): 4,
#  ('think', 'must'): 4,
#  ('seem', 'almost'): 4,
#  ('almost', 'UNK'): 4,
#  ('together', 'one'): 4,
#  ('till', 'last'): 4,
#  ('middle', 'room'): 4,
#  ('hi', 'busines'): 4,
#  ('thi', 'plan'): 4,
#  ('would', 'never'): 4,
#  ('UNK', 'door'): 4,
#  ('hi', 'bed'): 4,
#  ('second', 'thought'): 4,
#  ('alway', 'keep'): 4,
#  ('hard', 'upon'): 4,
#  ('sell', 'hi'): 4,
#  ('UNK', 'story'): 4,
#  ('story', 'thi'): 4,
#  ('hear', 'UNK'): 4,
#  ('take', 'good'): 4,
#  ('dream', 'UNK'): 4,
#  ('say', 'would'): 4,
#  ('come', 'along'): 4,
#  ('UNK', 'along'): 4,
#  ('take', 'hold'): 4,
#  ('see', 'sight'): 4,
#  ('make', 'good'): 4,
#  ('heavy', 'UNK'): 4,
#  ('UNK', 'lay'): 4,
#  ('place', 'hi'): 4,
#  ('hi', 'cheek'): 4,
#  ('make', 'thi'): 4,
#  ('speak', 'UNK'): 4,
#  ('head', 'look'): 4,
#  ('UNK', 'square'): 4,
#  ('hi', 'heavy'): 4,
#  ('black', 'UNK'): 4,
#  ('move', 'hi'): 4,
#  ('hi', 'lip'): 4,
#  ('UNK', 'else'): 4,
#  ('conclude', 'hi'): 4,
#  ('time', 'never'): 4,
#  ('god', 'sake'): 4,
#  ('say', 'tell'): 4,
#  ('tomahawk', 'pipe'): 4,
#  ('tell', 'queequeg'): 4,
#  ('UNK', 'touch'): 4,
#  ('hi', 'wife'): 4,
#  ('UNK', 'arm'): 4,
#  ('UNK', 'feet'): 4,
#  ...}

# %%
four_counts
# Out:
# {('moby', 'dick', 'whale', 'herman'): 2,
#  ('dick', 'whale', 'herman', 'melville'): 2,
#  ('whale', 'herman', 'melville', 'project'): 1,
#  ('herman', 'melville', 'project', 'gutenberg'): 1,
#  ('melville', 'project', 'gutenberg', 'ebook'): 1,
#  ('project', 'gutenberg', 'ebook', 'moby'): 2,
#  ('gutenberg', 'ebook', 'moby', 'dick'): 2,
#  ('ebook', 'moby', 'dick', 'whale'): 2,
#  ('whale', 'herman', 'melville', 'thi'): 1,
#  ('herman', 'melville', 'thi', 'ebook'): 1,
#  ('melville', 'thi', 'ebook', 'use'): 1,
#  ('thi', 'ebook', 'use', 'anyone'): 1,
#  ('ebook', 'use', 'anyone', 'anywhere'): 1,
#  ('use', 'anyone', 'anywhere', 'cost'): 1,
#  ('anyone', 'anywhere', 'cost', 'almost'): 1,
#  ('anywhere', 'cost', 'almost', 'restriction'): 1,
#  ('cost', 'almost', 'restriction', 'whatsoever'): 1,
#  ('almost', 'restriction', 'whatsoever', 'may'): 1,
#  ('restriction', 'whatsoever', 'may', 'copy'): 1,
#  ('whatsoever', 'may', 'copy', 'give'): 1,
#  ('may', 'copy', 'give', 'away'): 1,
#  ('copy', 'give', 'away', 'reuse'): 1,
#  ('give', 'away', 'reuse', 'term'): 1,
#  ('away', 'reuse', 'term', 'project'): 1,
#  ('reuse', 'term', 'project', 'gutenberg'): 1,
#  ('term', 'project', 'gutenberg', 'license'): 1,
#  ('project', 'gutenberg', 'license', 'include'): 1,
#  ('gutenberg', 'license', 'include', 'thi'): 1,
#  ('license', 'include', 'thi', 'ebook'): 1,
#  ('include', 'thi', 'ebook', 'online'): 1,
#  ('thi', 'ebook', 'online', 'www.gutenberg.org'): 1,
#  ('ebook', 'online', 'www.gutenberg.org', 'title'): 1,
#  ('online', 'www.gutenberg.org', 'title', 'moby'): 1,
#  ('www.gutenberg.org', 'title', 'moby', 'dick'): 1,
#  ('title', 'moby', 'dick', 'whale'): 1,
#  ('moby', 'dick', 'whale', 'author'): 1,
#  ('dick', 'whale', 'author', 'herman'): 1,
#  ('whale', 'author', 'herman', 'melville'): 1,
#  ('author', 'herman', 'melville', 'UNK'): 1,
#  ('herman', 'melville', 'UNK', 'date'): 1,
#  ('melville', 'UNK', 'date', 'december'): 1,
#  ('UNK', 'date', 'december', 'ebook'): 1,
#  ('date', 'december', 'ebook', 'last'): 1,
#  ('december', 'ebook', 'last', 'update'): 1,
#  ('ebook', 'last', 'update', 'december'): 1,
#  ('last', 'update', 'december', 'language'): 1,
#  ('update', 'december', 'language', 'english'): 1,
#  ('december', 'language', 'english', 'character'): 1,
#  ('language', 'english', 'character', 'set'): 1,
#  ('english', 'character', 'set', 'UNK'): 1,
#  ('character', 'set', 'UNK', 'UNK'): 1,
#  ('set', 'UNK', 'UNK', 'start'): 1,
#  ('UNK', 'UNK', 'start', 'thi'): 1,
#  ('UNK', 'start', 'thi', 'project'): 1,
#  ('start', 'thi', 'project', 'gutenberg'): 1,
#  ('thi', 'project', 'gutenberg', 'ebook'): 1,
#  ('moby', 'dick', 'whale', 'produce'): 1,
#  ('dick', 'whale', 'produce', 'daniel'): 1,
#  ('whale', 'produce', 'daniel', 'lazaru'): 1,
#  ('produce', 'daniel', 'lazaru', 'jonesey'): 1,
#  ('daniel', 'lazaru', 'jonesey', 'david'): 1,
#  ('lazaru', 'jonesey', 'david', 'widger'): 1,
#  ('jonesey', 'david', 'widger', 'UNK'): 1,
#  ('david', 'widger', 'UNK', 'whale'): 1,
#  ('widger', 'UNK', 'whale', 'herman'): 1,
#  ('UNK', 'whale', 'herman', 'melville'): 1,
#  ('whale', 'herman', 'melville', 'content'): 1,
#  ('herman', 'melville', 'content', 'etymology'): 1,
#  ('melville', 'content', 'etymology', 'extract'): 1,
#  ('content', 'etymology', 'extract', 'supply'): 1,
#  ('etymology', 'extract', 'supply', 'subsublibrarian'): 1,
#  ('extract', 'supply', 'subsublibrarian', 'chapter'): 1,
#  ('supply', 'subsublibrarian', 'chapter', 'looming'): 1,
#  ('subsublibrarian', 'chapter', 'looming', 'chapter'): 1,
#  ('chapter', 'looming', 'chapter', 'carpetbag'): 1,
#  ('looming', 'chapter', 'carpetbag', 'chapter'): 1,
#  ('chapter', 'carpetbag', 'chapter', 'spouterinn'): 1,
#  ('carpetbag', 'chapter', 'spouterinn', 'chapter'): 1,
#  ('chapter', 'spouterinn', 'chapter', 'counterpane'): 1,
#  ('spouterinn', 'chapter', 'counterpane', 'chapter'): 1,
#  ('chapter', 'counterpane', 'chapter', 'breakfast'): 1,
#  ('counterpane', 'chapter', 'breakfast', 'chapter'): 1,
#  ('chapter', 'breakfast', 'chapter', 'street'): 1,
#  ('breakfast', 'chapter', 'street', 'chapter'): 1,
#  ('chapter', 'street', 'chapter', 'chapel'): 1,
#  ('street', 'chapter', 'chapel', 'chapter'): 1,
#  ('chapter', 'chapel', 'chapter', 'pulpit'): 1,
#  ('chapel', 'chapter', 'pulpit', 'chapter'): 1,
#  ('chapter', 'pulpit', 'chapter', 'sermon'): 1,
#  ('pulpit', 'chapter', 'sermon', 'chapter'): 1,
#  ('chapter', 'sermon', 'chapter', 'bosom'): 1,
#  ('sermon', 'chapter', 'bosom', 'friend'): 1,
#  ('chapter', 'bosom', 'friend', 'chapter'): 1,
#  ('bosom', 'friend', 'chapter', 'nightgown'): 1,
#  ('friend', 'chapter', 'nightgown', 'chapter'): 1,
#  ('chapter', 'nightgown', 'chapter', 'biographical'): 1,
#  ('nightgown', 'chapter', 'biographical', 'chapter'): 1,
#  ('chapter', 'biographical', 'chapter', 'wheelbarrow'): 1,
#  ('biographical', 'chapter', 'wheelbarrow', 'chapter'): 1,
#  ('chapter', 'wheelbarrow', 'chapter', 'nantucket'): 1,
#  ('wheelbarrow', 'chapter', 'nantucket', 'chapter'): 1,
#  ('chapter', 'nantucket', 'chapter', 'chowder'): 1,
#  ('nantucket', 'chapter', 'chowder', 'chapter'): 1,
#  ('chapter', 'chowder', 'chapter', 'ship'): 1,
#  ('chowder', 'chapter', 'ship', 'chapter'): 1,
#  ('chapter', 'ship', 'chapter', 'ramadan'): 1,
#  ('ship', 'chapter', 'ramadan', 'chapter'): 1,
#  ('chapter', 'ramadan', 'chapter', 'hi'): 1,
#  ('ramadan', 'chapter', 'hi', 'mark'): 1,
#  ('chapter', 'hi', 'mark', 'chapter'): 1,
#  ('hi', 'mark', 'chapter', 'prophet'): 1,
#  ('mark', 'chapter', 'prophet', 'chapter'): 1,
#  ('chapter', 'prophet', 'chapter', 'astir'): 1,
#  ('prophet', 'chapter', 'astir', 'chapter'): 1,
#  ('chapter', 'astir', 'chapter', 'go'): 1,
#  ('astir', 'chapter', 'go', 'aboard'): 1,
#  ('chapter', 'go', 'aboard', 'chapter'): 1,
#  ('go', 'aboard', 'chapter', 'merry'): 1,
#  ('aboard', 'chapter', 'merry', 'christma'): 1,
#  ('chapter', 'merry', 'christma', 'chapter'): 1,
#  ('merry', 'christma', 'chapter', 'lee'): 1,
#  ('christma', 'chapter', 'lee', 'shore'): 1,
#  ('chapter', 'lee', 'shore', 'chapter'): 2,
#  ('lee', 'shore', 'chapter', 'advocate'): 1,
#  ('shore', 'chapter', 'advocate', 'chapter'): 1,
#  ('chapter', 'advocate', 'chapter', 'postscript'): 1,
#  ('advocate', 'chapter', 'postscript', 'chapter'): 1,
#  ('chapter', 'postscript', 'chapter', 'knight'): 1,
#  ('postscript', 'chapter', 'knight', 'squire'): 1,
#  ('chapter', 'knight', 'squire', 'chapter'): 2,
#  ('knight', 'squire', 'chapter', 'knight'): 1,
#  ('squire', 'chapter', 'knight', 'squire'): 1,
#  ('knight', 'squire', 'chapter', 'ahab'): 1,
#  ('squire', 'chapter', 'ahab', 'chapter'): 1,
#  ('chapter', 'ahab', 'chapter', 'enter'): 1,
#  ('ahab', 'chapter', 'enter', 'ahab'): 1,
#  ('chapter', 'enter', 'ahab', 'stubb'): 2,
#  ('enter', 'ahab', 'stubb', 'chapter'): 1,
#  ('ahab', 'stubb', 'chapter', 'pipe'): 1,
#  ('stubb', 'chapter', 'pipe', 'chapter'): 1,
#  ('chapter', 'pipe', 'chapter', 'queen'): 1,
#  ('pipe', 'chapter', 'queen', 'mab'): 1,
#  ('chapter', 'queen', 'mab', 'chapter'): 1,
#  ('queen', 'mab', 'chapter', 'cetology'): 1,
#  ('mab', 'chapter', 'cetology', 'chapter'): 1,
#  ('chapter', 'cetology', 'chapter', 'specksnyder'): 1,
#  ('cetology', 'chapter', 'specksnyder', 'chapter'): 1,
#  ('chapter', 'specksnyder', 'chapter', 'cabintable'): 1,
#  ('specksnyder', 'chapter', 'cabintable', 'chapter'): 1,
#  ('chapter', 'cabintable', 'chapter', 'masthead'): 1,
#  ('cabintable', 'chapter', 'masthead', 'chapter'): 1,
#  ('chapter', 'masthead', 'chapter', 'quarterdeck'): 1,
#  ('masthead', 'chapter', 'quarterdeck', 'chapter'): 1,
#  ('chapter', 'quarterdeck', 'chapter', 'sunset'): 1,
#  ('quarterdeck', 'chapter', 'sunset', 'chapter'): 1,
#  ('chapter', 'sunset', 'chapter', 'dusk'): 1,
#  ('sunset', 'chapter', 'dusk', 'chapter'): 1,
#  ('chapter', 'dusk', 'chapter', 'first'): 1,
#  ('dusk', 'chapter', 'first', 'nightwatch'): 1,
#  ('chapter', 'first', 'nightwatch', 'chapter'): 1,
#  ('first', 'nightwatch', 'chapter', 'midnight'): 1,
#  ('nightwatch', 'chapter', 'midnight', 'forecastle'): 1,
#  ('chapter', 'midnight', 'forecastle', 'chapter'): 1,
#  ('midnight', 'forecastle', 'chapter', 'moby'): 1,
#  ('forecastle', 'chapter', 'moby', 'dick'): 1,
#  ('chapter', 'moby', 'dick', 'chapter'): 1,
#  ('moby', 'dick', 'chapter', 'whitenes'): 1,
#  ('dick', 'chapter', 'whitenes', 'whale'): 1,
#  ('chapter', 'whitenes', 'whale', 'chapter'): 1,
#  ('whitenes', 'whale', 'chapter', 'hark'): 1,
#  ('whale', 'chapter', 'hark', 'chapter'): 1,
#  ('chapter', 'hark', 'chapter', 'chart'): 1,
#  ('hark', 'chapter', 'chart', 'chapter'): 1,
#  ('chapter', 'chart', 'chapter', 'affidavit'): 1,
#  ('chart', 'chapter', 'affidavit', 'chapter'): 1,
#  ('chapter', 'affidavit', 'chapter', 'surmise'): 1,
#  ('affidavit', 'chapter', 'surmise', 'chapter'): 1,
#  ('chapter', 'surmise', 'chapter', 'matmaker'): 1,
#  ('surmise', 'chapter', 'matmaker', 'chapter'): 1,
#  ('chapter', 'matmaker', 'chapter', 'first'): 1,
#  ('matmaker', 'chapter', 'first', 'lower'): 1,
#  ('chapter', 'first', 'lower', 'chapter'): 1,
#  ('first', 'lower', 'chapter', 'hyena'): 1,
#  ('lower', 'chapter', 'hyena', 'chapter'): 1,
#  ('chapter', 'hyena', 'chapter', 'ahab'): 1,
#  ('hyena', 'chapter', 'ahab', 'boat'): 1,
#  ('chapter', 'ahab', 'boat', 'crew'): 2,
#  ('ahab', 'boat', 'crew', 'fedallah'): 2,
#  ('boat', 'crew', 'fedallah', 'chapter'): 1,
#  ('crew', 'fedallah', 'chapter', 'spiritspout'): 1,
#  ('fedallah', 'chapter', 'spiritspout', 'chapter'): 1,
#  ('chapter', 'spiritspout', 'chapter', 'albatros'): 1,
#  ('spiritspout', 'chapter', 'albatros', 'chapter'): 1,
#  ('chapter', 'albatros', 'chapter', 'gam'): 1,
#  ('albatros', 'chapter', 'gam', 'chapter'): 1,
#  ('chapter', 'gam', 'chapter', 'townho'): 1,
#  ('gam', 'chapter', 'townho', 'story'): 1,
#  ('chapter', 'townho', 'story', 'chapter'): 1,
#  ('townho', 'story', 'chapter', 'monstrou'): 1,
#  ('story', 'chapter', 'monstrou', 'picture'): 1,
#  ('chapter', 'monstrou', 'picture', 'whale'): 2,
#  ('monstrou', 'picture', 'whale', 'chapter'): 1,
#  ('picture', 'whale', 'chapter', 'les'): 1,
#  ('whale', 'chapter', 'les', 'erroneou'): 1,
#  ('chapter', 'les', 'erroneou', 'picture'): 2,
#  ('les', 'erroneou', 'picture', 'whale'): 2,
#  ('erroneou', 'picture', 'whale', 'true'): 2,
#  ('picture', 'whale', 'true', 'picture'): 2,
#  ('whale', 'true', 'picture', 'whale'): 2,
#  ('true', 'picture', 'whale', 'scene'): 2,
#  ('picture', 'whale', 'scene', 'chapter'): 1,
#  ('whale', 'scene', 'chapter', 'whale'): 1,
#  ('scene', 'chapter', 'whale', 'paint'): 1,
#  ('chapter', 'whale', 'paint', 'teeth'): 2,
#  ('whale', 'paint', 'teeth', 'wood'): 2,
#  ('paint', 'teeth', 'wood', 'sheetiron'): 2,
#  ('teeth', 'wood', 'sheetiron', 'stone'): 2,
#  ('wood', 'sheetiron', 'stone', 'mountain'): 2,
#  ('sheetiron', 'stone', 'mountain', 'star'): 2,
#  ('stone', 'mountain', 'star', 'chapter'): 1,
#  ('mountain', 'star', 'chapter', 'brit'): 1,
#  ('star', 'chapter', 'brit', 'chapter'): 1,
#  ('chapter', 'brit', 'chapter', 'squid'): 1,
#  ('brit', 'chapter', 'squid', 'chapter'): 1,
#  ('chapter', 'squid', 'chapter', 'line'): 1,
#  ('squid', 'chapter', 'line', 'chapter'): 1,
#  ('chapter', 'line', 'chapter', 'stubb'): 1,
#  ('line', 'chapter', 'stubb', 'kill'): 1,
#  ('chapter', 'stubb', 'kill', 'whale'): 2,
#  ('stubb', 'kill', 'whale', 'chapter'): 1,
#  ('kill', 'whale', 'chapter', 'dart'): 1,
#  ('whale', 'chapter', 'dart', 'chapter'): 1,
#  ('chapter', 'dart', 'chapter', 'crotch'): 1,
#  ('dart', 'chapter', 'crotch', 'chapter'): 1,
#  ('chapter', 'crotch', 'chapter', 'stubb'): 1,
#  ('crotch', 'chapter', 'stubb', 'supper'): 1,
#  ('chapter', 'stubb', 'supper', 'chapter'): 1,
#  ('stubb', 'supper', 'chapter', 'whale'): 1,
#  ('supper', 'chapter', 'whale', 'dish'): 1,
#  ('chapter', 'whale', 'dish', 'chapter'): 1,
#  ('whale', 'dish', 'chapter', 'shark'): 1,
#  ('dish', 'chapter', 'shark', 'massacre'): 1,
#  ('chapter', 'shark', 'massacre', 'chapter'): 1,
#  ('shark', 'massacre', 'chapter', 'cut'): 1,
#  ('massacre', 'chapter', 'cut', 'chapter'): 1,
#  ('chapter', 'cut', 'chapter', 'blanket'): 1,
#  ('cut', 'chapter', 'blanket', 'chapter'): 1,
#  ('chapter', 'blanket', 'chapter', 'funeral'): 1,
#  ('blanket', 'chapter', 'funeral', 'chapter'): 1,
#  ('chapter', 'funeral', 'chapter', 'sphynx'): 1,
#  ('funeral', 'chapter', 'sphynx', 'chapter'): 1,
#  ('chapter', 'sphynx', 'chapter', 'jeroboam'): 1,
#  ('sphynx', 'chapter', 'jeroboam', 'story'): 1,
#  ('chapter', 'jeroboam', 'story', 'chapter'): 1,
#  ('jeroboam', 'story', 'chapter', 'monkeyrope'): 1,
#  ('story', 'chapter', 'monkeyrope', 'chapter'): 1,
#  ('chapter', 'monkeyrope', 'chapter', 'stubb'): 1,
#  ('monkeyrope', 'chapter', 'stubb', 'flask'): 1,
#  ('chapter', 'stubb', 'flask', 'kill'): 2,
#  ('stubb', 'flask', 'kill', 'right'): 2,
#  ('flask', 'kill', 'right', 'whale'): 2,
#  ('kill', 'right', 'whale', 'talk'): 2,
#  ('right', 'whale', 'talk', 'chapter'): 1,
#  ('whale', 'talk', 'chapter', 'sperm'): 1,
#  ('talk', 'chapter', 'sperm', 'whale'): 1,
#  ('chapter', 'sperm', 'whale', 'headcontrast'): 2,
#  ('sperm', 'whale', 'headcontrast', 'view'): 2,
#  ('whale', 'headcontrast', 'view', 'chapter'): 2,
#  ('headcontrast', 'view', 'chapter', 'right'): 1,
#  ('view', 'chapter', 'right', 'whale'): 1,
#  ('chapter', 'right', 'whale', 'headcontrast'): 2,
#  ('right', 'whale', 'headcontrast', 'view'): 2,
#  ('headcontrast', 'view', 'chapter', 'batteringram'): 1,
#  ('view', 'chapter', 'batteringram', 'chapter'): 1,
#  ('chapter', 'batteringram', 'chapter', 'great'): 1,
#  ('batteringram', 'chapter', 'great', 'heidelburgh'): 1,
#  ('chapter', 'great', 'heidelburgh', 'tun'): 2,
#  ('great', 'heidelburgh', 'tun', 'chapter'): 1,
#  ('heidelburgh', 'tun', 'chapter', 'cistern'): 1,
#  ('tun', 'chapter', 'cistern', 'bucket'): 1,
#  ('chapter', 'cistern', 'bucket', 'chapter'): 1,
#  ('cistern', 'bucket', 'chapter', 'prairie'): 1,
#  ('bucket', 'chapter', 'prairie', 'chapter'): 1,
#  ('chapter', 'prairie', 'chapter', 'nut'): 1,
#  ('prairie', 'chapter', 'nut', 'chapter'): 1,
#  ('chapter', 'nut', 'chapter', 'pequod'): 1,
#  ('nut', 'chapter', 'pequod', 'meet'): 1,
#  ('chapter', 'pequod', 'meet', 'virgin'): 2,
#  ('pequod', 'meet', 'virgin', 'chapter'): 1,
#  ('meet', 'virgin', 'chapter', 'honor'): 1,
#  ('virgin', 'chapter', 'honor', 'glory'): 1,
#  ('chapter', 'honor', 'glory', 'whale'): 2,
#  ('honor', 'glory', 'whale', 'chapter'): 1,
#  ('glory', 'whale', 'chapter', 'jonah'): 1,
#  ('whale', 'chapter', 'jonah', 'historically'): 1,
#  ('chapter', 'jonah', 'historically', 'regard'): 2,
#  ('jonah', 'historically', 'regard', 'chapter'): 1,
#  ('historically', 'regard', 'chapter', 'pitchpole'): 1,
#  ('regard', 'chapter', 'pitchpole', 'chapter'): 1,
#  ('chapter', 'pitchpole', 'chapter', 'fountain'): 1,
#  ('pitchpole', 'chapter', 'fountain', 'chapter'): 1,
#  ('chapter', 'fountain', 'chapter', 'tail'): 1,
#  ('fountain', 'chapter', 'tail', 'chapter'): 1,
#  ('chapter', 'tail', 'chapter', 'grand'): 1,
#  ('tail', 'chapter', 'grand', 'armada'): 1,
#  ('chapter', 'grand', 'armada', 'chapter'): 1,
#  ('grand', 'armada', 'chapter', 'school'): 1,
#  ('armada', 'chapter', 'school', 'schoolmaster'): 1,
#  ('chapter', 'school', 'schoolmaster', 'chapter'): 1,
#  ('school', 'schoolmaster', 'chapter', 'fastfish'): 1,
#  ('schoolmaster', 'chapter', 'fastfish', 'loosefish'): 1,
#  ('chapter', 'fastfish', 'loosefish', 'chapter'): 1,
#  ('fastfish', 'loosefish', 'chapter', 'head'): 1,
#  ('loosefish', 'chapter', 'head', 'tail'): 1,
#  ('chapter', 'head', 'tail', 'chapter'): 1,
#  ('head', 'tail', 'chapter', 'pequod'): 1,
#  ('tail', 'chapter', 'pequod', 'meet'): 1,
#  ('chapter', 'pequod', 'meet', 'rosebud'): 2,
#  ('pequod', 'meet', 'rosebud', 'chapter'): 1,
#  ('meet', 'rosebud', 'chapter', 'ambergri'): 1,
#  ('rosebud', 'chapter', 'ambergri', 'chapter'): 1,
#  ('chapter', 'ambergri', 'chapter', 'castaway'): 1,
#  ('ambergri', 'chapter', 'castaway', 'chapter'): 1,
#  ('chapter', 'castaway', 'chapter', 'squeeze'): 1,
#  ('castaway', 'chapter', 'squeeze', 'hand'): 1,
#  ('chapter', 'squeeze', 'hand', 'chapter'): 1,
#  ('squeeze', 'hand', 'chapter', 'cassock'): 1,
#  ('hand', 'chapter', 'cassock', 'chapter'): 1,
#  ('chapter', 'cassock', 'chapter', 'trywork'): 1,
#  ('cassock', 'chapter', 'trywork', 'chapter'): 1,
#  ('chapter', 'trywork', 'chapter', 'lamp'): 1,
#  ('trywork', 'chapter', 'lamp', 'chapter'): 1,
#  ('chapter', 'lamp', 'chapter', 'stow'): 1,
#  ('lamp', 'chapter', 'stow', 'clear'): 1,
#  ('chapter', 'stow', 'clear', 'chapter'): 1,
#  ('stow', 'clear', 'chapter', 'doubloon'): 1,
#  ('clear', 'chapter', 'doubloon', 'chapter'): 1,
#  ('chapter', 'doubloon', 'chapter', 'leg'): 1,
#  ('doubloon', 'chapter', 'leg', 'arm'): 1,
#  ('chapter', 'leg', 'arm', 'chapter'): 1,
#  ('leg', 'arm', 'chapter', 'decanter'): 1,
#  ('arm', 'chapter', 'decanter', 'chapter'): 1,
#  ('chapter', 'decanter', 'chapter', 'bower'): 1,
#  ('decanter', 'chapter', 'bower', 'arsacide'): 1,
#  ('chapter', 'bower', 'arsacide', 'chapter'): 1,
#  ('bower', 'arsacide', 'chapter', 'measurement'): 1,
#  ('arsacide', 'chapter', 'measurement', 'whale'): 1,
#  ('chapter', 'measurement', 'whale', 'skeleton'): 1,
#  ('measurement', 'whale', 'skeleton', 'chapter'): 1,
#  ('whale', 'skeleton', 'chapter', 'fossil'): 1,
#  ('skeleton', 'chapter', 'fossil', 'whale'): 1,
#  ('chapter', 'fossil', 'whale', 'chapter'): 1,
#  ('fossil', 'whale', 'chapter', 'whale'): 1,
#  ('whale', 'chapter', 'whale', 'magnitude'): 1,
#  ('chapter', 'whale', 'magnitude', 'diminishwill'): 1,
#  ('whale', 'magnitude', 'diminishwill', 'perish'): 1,
#  ('magnitude', 'diminishwill', 'perish', 'chapter'): 1,
#  ('diminishwill', 'perish', 'chapter', 'ahab'): 1,
#  ('perish', 'chapter', 'ahab', 'leg'): 1,
#  ('chapter', 'ahab', 'leg', 'chapter'): 1,
#  ('ahab', 'leg', 'chapter', 'carpenter'): 1,
#  ('leg', 'chapter', 'carpenter', 'chapter'): 1,
#  ('chapter', 'carpenter', 'chapter', 'ahab'): 1,
#  ('carpenter', 'chapter', 'ahab', 'carpenter'): 1,
#  ('chapter', 'ahab', 'carpenter', 'chapter'): 1,
#  ('ahab', 'carpenter', 'chapter', 'ahab'): 1,
#  ('carpenter', 'chapter', 'ahab', 'starbuck'): 1,
#  ('chapter', 'ahab', 'starbuck', 'cabin'): 1,
#  ('ahab', 'starbuck', 'cabin', 'chapter'): 1,
#  ('starbuck', 'cabin', 'chapter', 'queequeg'): 1,
#  ('cabin', 'chapter', 'queequeg', 'hi'): 1,
#  ('chapter', 'queequeg', 'hi', 'coffin'): 1,
#  ('queequeg', 'hi', 'coffin', 'chapter'): 1,
#  ('hi', 'coffin', 'chapter', 'pacific'): 1,
#  ('coffin', 'chapter', 'pacific', 'chapter'): 1,
#  ('chapter', 'pacific', 'chapter', 'blacksmith'): 1,
#  ('pacific', 'chapter', 'blacksmith', 'chapter'): 1,
#  ('chapter', 'blacksmith', 'chapter', 'forge'): 1,
#  ('blacksmith', 'chapter', 'forge', 'chapter'): 1,
#  ('chapter', 'forge', 'chapter', 'gilder'): 1,
#  ('forge', 'chapter', 'gilder', 'chapter'): 1,
#  ('chapter', 'gilder', 'chapter', 'pequod'): 1,
#  ('gilder', 'chapter', 'pequod', 'meet'): 1,
#  ('chapter', 'pequod', 'meet', 'bachelor'): 1,
#  ('pequod', 'meet', 'bachelor', 'chapter'): 1,
#  ('meet', 'bachelor', 'chapter', 'die'): 1,
#  ('bachelor', 'chapter', 'die', 'whale'): 1,
#  ('chapter', 'die', 'whale', 'chapter'): 1,
#  ('die', 'whale', 'chapter', 'whale'): 1,
#  ('whale', 'chapter', 'whale', 'watch'): 1,
#  ('chapter', 'whale', 'watch', 'chapter'): 1,
#  ('whale', 'watch', 'chapter', 'quadrant'): 1,
#  ('watch', 'chapter', 'quadrant', 'chapter'): 1,
#  ('chapter', 'quadrant', 'chapter', 'candle'): 1,
#  ('quadrant', 'chapter', 'candle', 'chapter'): 1,
#  ('chapter', 'candle', 'chapter', 'deck'): 1,
#  ('candle', 'chapter', 'deck', 'toward'): 1,
#  ('chapter', 'deck', 'toward', 'end'): 1,
#  ('deck', 'toward', 'end', 'first'): 1,
#  ('toward', 'end', 'first', 'night'): 1,
#  ('end', 'first', 'night', 'watch'): 1,
#  ('first', 'night', 'watch', 'chapter'): 1,
#  ('night', 'watch', 'chapter', 'midnight.the'): 1,
#  ('watch', 'chapter', 'midnight.the', 'forecastle'): 1,
#  ('chapter', 'midnight.the', 'forecastle', 'bulwark'): 1,
#  ('midnight.the', 'forecastle', 'bulwark', 'chapter'): 1,
#  ('forecastle', 'bulwark', 'chapter', 'midnight'): 1,
#  ('bulwark', 'chapter', 'midnight', 'aloft.thunder'): 1,
#  ('chapter', 'midnight', 'aloft.thunder', 'lightn'): 1,
#  ('midnight', 'aloft.thunder', 'lightn', 'chapter'): 1,
#  ('aloft.thunder', 'lightn', 'chapter', 'musket'): 1,
#  ('lightn', 'chapter', 'musket', 'chapter'): 1,
#  ('chapter', 'musket', 'chapter', 'needle'): 1,
#  ('musket', 'chapter', 'needle', 'chapter'): 1,
#  ('chapter', 'needle', 'chapter', 'log'): 1,
#  ('needle', 'chapter', 'log', 'line'): 1,
#  ('chapter', 'log', 'line', 'chapter'): 1,
#  ('log', 'line', 'chapter', 'lifebuoy'): 1,
#  ('line', 'chapter', 'lifebuoy', 'chapter'): 1,
#  ('chapter', 'lifebuoy', 'chapter', 'deck'): 1,
#  ('lifebuoy', 'chapter', 'deck', 'chapter'): 1,
#  ('chapter', 'deck', 'chapter', 'pequod'): 1,
#  ('deck', 'chapter', 'pequod', 'meet'): 1,
#  ('chapter', 'pequod', 'meet', 'rachel'): 1,
#  ('pequod', 'meet', 'rachel', 'chapter'): 1,
#  ('meet', 'rachel', 'chapter', 'cabin'): 1,
#  ('rachel', 'chapter', 'cabin', 'chapter'): 1,
#  ('chapter', 'cabin', 'chapter', 'hat'): 1,
#  ('cabin', 'chapter', 'hat', 'chapter'): 1,
#  ('chapter', 'hat', 'chapter', 'pequod'): 1,
#  ('hat', 'chapter', 'pequod', 'meet'): 1,
#  ('chapter', 'pequod', 'meet', 'delight'): 1,
#  ('pequod', 'meet', 'delight', 'chapter'): 1,
#  ('meet', 'delight', 'chapter', 'symphony'): 1,
#  ('delight', 'chapter', 'symphony', 'chapter'): 1,
#  ('chapter', 'symphony', 'chapter', 'chasefirst'): 1,
#  ('symphony', 'chapter', 'chasefirst', 'day'): 1,
#  ('chapter', 'chasefirst', 'day', 'chapter'): 1,
#  ('chasefirst', 'day', 'chapter', 'chasesecond'): 1,
#  ('day', 'chapter', 'chasesecond', 'day'): 1,
#  ('chapter', 'chasesecond', 'day', 'chapter'): 1,
#  ('chasesecond', 'day', 'chapter', 'chase.third'): 1,
#  ('day', 'chapter', 'chase.third', 'day'): 1,
#  ('chapter', 'chase.third', 'day', 'epilogue'): 1,
#  ('chase.third', 'day', 'epilogue', 'original'): 1,
#  ('day', 'epilogue', 'original', 'UNK'): 1,
#  ('epilogue', 'original', 'UNK', 'note'): 1,
#  ('original', 'UNK', 'note', 'thi'): 1,
#  ('UNK', 'note', 'thi', 'text'): 1,
#  ('note', 'thi', 'text', 'combination'): 1,
#  ('thi', 'text', 'combination', 'etext'): 1,
#  ('text', 'combination', 'etext', 'one'): 1,
#  ('combination', 'etext', 'one', 'UNK'): 1,
#  ('etext', 'one', 'UNK', 'UNK'): 1,
#  ('one', 'UNK', 'UNK', 'project'): 1,
#  ('UNK', 'UNK', 'project', 'virginia'): 1,
#  ('UNK', 'project', 'virginia', 'tech'): 1,
#  ('project', 'virginia', 'tech', 'one'): 1,
#  ('virginia', 'tech', 'one', 'project'): 1,
#  ('tech', 'one', 'project', 'gutenberg'): 1,
#  ('one', 'project', 'gutenberg', 'archive'): 1,
#  ('project', 'gutenberg', 'archive', 'UNK'): 1,
#  ('gutenberg', 'archive', 'UNK', 'thi'): 1,
#  ('archive', 'UNK', 'thi', 'version'): 1,
#  ('UNK', 'thi', 'version', 'indebt'): 1,
#  ('thi', 'version', 'indebt', 'UNK'): 1,
#  ('version', 'indebt', 'UNK', 'UNK'): 1,
#  ('indebt', 'UNK', 'UNK', 'library'): 1,
#  ('UNK', 'UNK', 'library', 'preserve'): 1,
#  ('UNK', 'library', 'preserve', 'virginia'): 1,
#  ('library', 'preserve', 'virginia', 'tech'): 1,
#  ('preserve', 'virginia', 'tech', 'version'): 1,
#  ('virginia', 'tech', 'version', 'result'): 1,
#  ('tech', 'version', 'result', 'etext'): 1,
#  ('version', 'result', 'etext', 'compare'): 1,
#  ('result', 'etext', 'compare', 'public'): 1,
#  ('etext', 'compare', 'public', 'domain'): 1,
#  ('compare', 'public', 'domain', 'hard'): 1,
#  ('public', 'domain', 'hard', 'copy'): 1,
#  ('domain', 'hard', 'copy', 'version'): 1,
#  ('hard', 'copy', 'version', 'text'): 1,
#  ('copy', 'version', 'text', 'etymology'): 1,
#  ('version', 'text', 'etymology', 'supply'): 1,
#  ('text', 'etymology', 'supply', 'late'): 1,
#  ('etymology', 'supply', 'late', 'UNK'): 1,
#  ('supply', 'late', 'UNK', 'usher'): 1,
#  ('late', 'UNK', 'usher', 'grammar'): 1,
#  ('UNK', 'usher', 'grammar', 'school'): 1,
#  ('usher', 'grammar', 'school', 'pale'): 1,
#  ('grammar', 'school', 'pale', 'UNK'): 1,
#  ('school', 'pale', 'UNK', 'coat'): 1,
#  ('pale', 'UNK', 'coat', 'heart'): 1,
#  ('UNK', 'coat', 'heart', 'body'): 1,
#  ('coat', 'heart', 'body', 'brain'): 1,
#  ('heart', 'body', 'brain', 'see'): 1,
#  ('body', 'brain', 'see', 'ever'): 1,
#  ('brain', 'see', 'ever', 'dust'): 1,
#  ('see', 'ever', 'dust', 'hi'): 1,
#  ('ever', 'dust', 'hi', 'old'): 1,
#  ('dust', 'hi', 'old', 'lexicon'): 1,
#  ('hi', 'old', 'lexicon', 'grammar'): 1,
#  ('old', 'lexicon', 'grammar', 'queer'): 1,
#  ('lexicon', 'grammar', 'queer', 'handkerchief'): 1,
#  ('grammar', 'queer', 'handkerchief', 'UNK'): 1,
#  ('queer', 'handkerchief', 'UNK', 'embellish'): 1,
#  ('handkerchief', 'UNK', 'embellish', 'gay'): 1,
#  ('UNK', 'embellish', 'gay', 'flag'): 1,
#  ('embellish', 'gay', 'flag', 'know'): 1,
#  ('gay', 'flag', 'know', 'nation'): 1,
#  ('flag', 'know', 'nation', 'world'): 1,
#  ('know', 'nation', 'world', 'love'): 1,
#  ('nation', 'world', 'love', 'dust'): 1,
#  ('world', 'love', 'dust', 'hi'): 1,
#  ('love', 'dust', 'hi', 'old'): 1,
#  ('dust', 'hi', 'old', 'grammar'): 1,
#  ('hi', 'old', 'grammar', 'somehow'): 1,
#  ('old', 'grammar', 'somehow', 'mildly'): 1,
#  ('grammar', 'somehow', 'mildly', 'remind'): 1,
#  ('somehow', 'mildly', 'remind', 'hi'): 1,
#  ('mildly', 'remind', 'hi', 'mortality'): 1,
#  ('remind', 'hi', 'mortality', 'take'): 1,
#  ('hi', 'mortality', 'take', 'hand'): 1,
#  ('mortality', 'take', 'hand', 'school'): 1,
#  ('take', 'hand', 'school', 'teach'): 1,
#  ('hand', 'school', 'teach', 'name'): 1,
#  ('school', 'teach', 'name', 'UNK'): 1,
#  ('teach', 'name', 'UNK', 'call'): 1,
#  ('name', 'UNK', 'call', 'tongue'): 1,
#  ('UNK', 'call', 'tongue', 'leave'): 1,
#  ('call', 'tongue', 'leave', 'ignorance'): 1,
#  ('tongue', 'leave', 'ignorance', 'letter'): 1,
#  ('leave', 'ignorance', 'letter', 'UNK'): 1,
#  ('ignorance', 'letter', 'UNK', 'almost'): 1,
#  ('letter', 'UNK', 'almost', 'alone'): 1,
#  ('UNK', 'almost', 'alone', 'maketh'): 1,
#  ('almost', 'alone', 'maketh', 'UNK'): 1,
#  ('alone', 'maketh', 'UNK', 'word'): 1,
#  ('maketh', 'UNK', 'word', 'deliver'): 1,
#  ('UNK', 'word', 'deliver', 'true'): 1,
#  ('word', 'deliver', 'true', 'hackluyt'): 1,
#  ('deliver', 'true', 'hackluyt', 'whale'): 1,
#  ('true', 'hackluyt', 'whale', 'UNK'): 1,
#  ('hackluyt', 'whale', 'UNK', 'dan'): 1,
#  ('whale', 'UNK', 'dan', 'UNK'): 1,
#  ('UNK', 'dan', 'UNK', 'thi'): 1,
#  ('dan', 'UNK', 'thi', 'animal'): 1,
#  ('UNK', 'thi', 'animal', 'name'): 1,
#  ('thi', 'animal', 'name', 'UNK'): 1,
#  ('animal', 'name', 'UNK', 'roll'): 1,
#  ('name', 'UNK', 'roll', 'dan'): 1,
#  ('UNK', 'roll', 'dan', 'hvalt'): 1,
#  ('roll', 'dan', 'hvalt', 'arch'): 1,
#  ('dan', 'hvalt', 'arch', 'vault'): 1,
#  ('hvalt', 'arch', 'vault', 'webster'): 1,
#  ('arch', 'vault', 'webster', 'dictionary'): 1,
#  ('vault', 'webster', 'dictionary', 'whale'): 1,
#  ('webster', 'dictionary', 'whale', 'immediately'): 1,
#  ('dictionary', 'whale', 'immediately', 'UNK'): 1,
#  ('whale', 'immediately', 'UNK', 'UNK'): 1,
#  ('immediately', 'UNK', 'UNK', 'UNK'): 1,
#  ('UNK', 'UNK', 'UNK', 'UNK'): 23,
#  ('UNK', 'UNK', 'UNK', 'roll'): 1,
#  ('UNK', 'UNK', 'roll', 'wallow'): 1,
#  ('UNK', 'roll', 'wallow', 'UNK'): 1,
#  ('roll', 'wallow', 'UNK', 'dictionary'): 1,
#  ('wallow', 'UNK', 'dictionary', 'hebrew'): 1,
#  ('UNK', 'dictionary', 'hebrew', 'greek'): 1,
#  ('dictionary', 'hebrew', 'greek', 'cetu'): 1,
#  ('hebrew', 'greek', 'cetu', 'latin'): 1,
#  ('greek', 'cetu', 'latin', 'UNK'): 1,
#  ('cetu', 'latin', 'UNK', 'UNK'): 1,
#  ('latin', 'UNK', 'UNK', 'hvalt'): 1,
#  ('UNK', 'UNK', 'hvalt', 'danish'): 1,
#  ('UNK', 'hvalt', 'danish', 'UNK'): 1,
#  ('hvalt', 'danish', 'UNK', 'dutch'): 1,
#  ('danish', 'UNK', 'dutch', 'UNK'): 1,
#  ('UNK', 'dutch', 'UNK', 'UNK'): 1,
#  ('dutch', 'UNK', 'UNK', 'whale'): 1,
#  ('UNK', 'UNK', 'whale', 'icelandic'): 1,
#  ('UNK', 'whale', 'icelandic', 'whale'): 1,
#  ('whale', 'icelandic', 'whale', 'english'): 1,
#  ('icelandic', 'whale', 'english', 'baleine'): 1,
#  ('whale', 'english', 'baleine', 'french'): 1,
#  ('english', 'baleine', 'french', 'UNK'): 1,
#  ('baleine', 'french', 'UNK', 'spanish'): 1,
#  ('french', 'UNK', 'spanish', 'UNK'): 1,
#  ('UNK', 'spanish', 'UNK', 'UNK'): 1,
#  ('spanish', 'UNK', 'UNK', 'UNK'): 1,
#  ('UNK', 'UNK', 'UNK', 'extract'): 1,
#  ('UNK', 'UNK', 'extract', 'supply'): 1,
#  ('UNK', 'extract', 'supply', 'subsublibrarian'): 1,
#  ('extract', 'supply', 'subsublibrarian', 'see'): 1,
#  ('supply', 'subsublibrarian', 'see', 'thi'): 1,
#  ('subsublibrarian', 'see', 'thi', 'mere'): 1,
#  ('see', 'thi', 'mere', 'UNK'): 1,
#  ('thi', 'mere', 'UNK', 'UNK'): 1,
#  ('mere', 'UNK', 'UNK', 'UNK'): 1,
#  ('UNK', 'UNK', 'UNK', 'poor'): 1,
#  ('UNK', 'UNK', 'poor', 'devil'): 1,
#  ('UNK', 'poor', 'devil', 'subsub'): 1,
#  ('poor', 'devil', 'subsub', 'appear'): 1,
#  ('devil', 'subsub', 'appear', 'go'): 1,
#  ('subsub', 'appear', 'go', 'long'): 1,
#  ('appear', 'go', 'long', 'UNK'): 1,
#  ('go', 'long', 'UNK', 'UNK'): 1,
#  ('long', 'UNK', 'UNK', 'earth'): 1,
#  ('UNK', 'UNK', 'earth', 'pick'): 1,
#  ('UNK', 'earth', 'pick', 'whatever'): 1,
#  ('earth', 'pick', 'whatever', 'random'): 1,
#  ('pick', 'whatever', 'random', 'allusion'): 1,
#  ('whatever', 'random', 'allusion', 'whale'): 1,
#  ('random', 'allusion', 'whale', 'anyway'): 1,
#  ('allusion', 'whale', 'anyway', 'find'): 1,
#  ('whale', 'anyway', 'find', 'book'): 1,
#  ('anyway', 'find', 'book', 'whatsoever'): 1,
#  ('find', 'book', 'whatsoever', 'sacre'): 1,
#  ('book', 'whatsoever', 'sacre', 'profane'): 1,
#  ('whatsoever', 'sacre', 'profane', 'therefore'): 1,
#  ('sacre', 'profane', 'therefore', 'must'): 1,
#  ('profane', 'therefore', 'must', 'every'): 1,
#  ('therefore', 'must', 'every', 'case'): 1,
#  ('must', 'every', 'case', 'least'): 1,
#  ('every', 'case', 'least', 'take'): 1,
#  ('case', 'least', 'take', 'UNK'): 1,
#  ('least', 'take', 'UNK', 'whale'): 1,
#  ('take', 'UNK', 'whale', 'statement'): 1,
#  ('UNK', 'whale', 'statement', 'however'): 1,
#  ('whale', 'statement', 'however', 'authentic'): 1,
#  ('statement', 'however', 'authentic', 'extract'): 1,
#  ('however', 'authentic', 'extract', 'veritable'): 1,
#  ('authentic', 'extract', 'veritable', 'gospel'): 1,
#  ('extract', 'veritable', 'gospel', 'cetology'): 1,
#  ('veritable', 'gospel', 'cetology', 'far'): 1,
#  ('gospel', 'cetology', 'far', 'touch'): 1,
#  ('cetology', 'far', 'touch', 'ancient'): 1,
#  ('far', 'touch', 'ancient', 'author'): 1,
#  ('touch', 'ancient', 'author', 'generally'): 1,
#  ('ancient', 'author', 'generally', 'well'): 1,
#  ('author', 'generally', 'well', 'poet'): 1,
#  ('generally', 'well', 'poet', 'appear'): 1,
#  ('well', 'poet', 'appear', 'extract'): 1,
#  ('poet', 'appear', 'extract', 'solely'): 1,
#  ('appear', 'extract', 'solely', 'valuable'): 1,
#  ('extract', 'solely', 'valuable', 'entertain'): 1,
#  ('solely', 'valuable', 'entertain', 'afford'): 1,
#  ('valuable', 'entertain', 'afford', 'glance'): 1,
#  ('entertain', 'afford', 'glance', 'bird'): 1,
#  ('afford', 'glance', 'bird', 'eye'): 1,
#  ('glance', 'bird', 'eye', 'view'): 1,
#  ('bird', 'eye', 'view', 'UNK'): 1,
#  ('eye', 'view', 'UNK', 'say'): 1,
#  ('view', 'UNK', 'say', 'think'): 1,
#  ('UNK', 'say', 'think', 'fancy'): 1,
#  ('say', 'think', 'fancy', 'sing'): 1,
#  ('think', 'fancy', 'sing', 'leviathan'): 1,
#  ('fancy', 'sing', 'leviathan', 'many'): 1,
#  ('sing', 'leviathan', 'many', 'nation'): 1,
#  ('leviathan', 'many', 'nation', 'generation'): 1,
#  ('many', 'nation', 'generation', 'include'): 1,
#  ('nation', 'generation', 'include', 'fare'): 1,
#  ('generation', 'include', 'fare', 'thee'): 1,
#  ('include', 'fare', 'thee', 'well'): 1,
#  ('fare', 'thee', 'well', 'poor'): 1,
#  ('thee', 'well', 'poor', 'devil'): 1,
#  ('well', 'poor', 'devil', 'subsub'): 1,
#  ('poor', 'devil', 'subsub', 'whose'): 1,
#  ('devil', 'subsub', 'whose', 'commentator'): 1,
#  ('subsub', 'whose', 'commentator', 'thou'): 1,
#  ('whose', 'commentator', 'thou', 'UNK'): 1,
#  ('commentator', 'thou', 'UNK', 'hopeles'): 1,
#  ('thou', 'UNK', 'hopeles', 'UNK'): 1,
#  ('UNK', 'hopeles', 'UNK', 'tribe'): 1,
#  ('hopeles', 'UNK', 'tribe', 'wine'): 1,
#  ('UNK', 'tribe', 'wine', 'thi'): 1,
#  ('tribe', 'wine', 'thi', 'world'): 1,
#  ('wine', 'thi', 'world', 'ever'): 1,
#  ('thi', 'world', 'ever', 'warm'): 1,
#  ('world', 'ever', 'warm', 'even'): 1,
#  ('ever', 'warm', 'even', 'pale'): 1,
#  ('warm', 'even', 'pale', 'UNK'): 1,
#  ('even', 'pale', 'UNK', 'would'): 1,
#  ('pale', 'UNK', 'would', 'UNK'): 1,
#  ('UNK', 'would', 'UNK', 'one'): 1,
#  ('would', 'UNK', 'one', 'sometime'): 1,
#  ('UNK', 'one', 'sometime', 'love'): 1,
#  ('one', 'sometime', 'love', 'sit'): 1,
#  ('sometime', 'love', 'sit', 'feel'): 1,
#  ('love', 'sit', 'feel', 'UNK'): 1,
#  ('sit', 'feel', 'UNK', 'grow'): 1,
#  ('feel', 'UNK', 'grow', 'convivial'): 1,
#  ('UNK', 'grow', 'convivial', 'upon'): 1,
#  ('grow', 'convivial', 'upon', 'tear'): 1,
#  ('convivial', 'upon', 'tear', 'say'): 1,
#  ('upon', 'tear', 'say', 'UNK'): 1,
#  ('tear', 'say', 'UNK', 'full'): 1,
#  ('say', 'UNK', 'full', 'eye'): 1,
#  ('UNK', 'full', 'eye', 'empty'): 1,
#  ('full', 'eye', 'empty', 'glass'): 1,
#  ('eye', 'empty', 'glass', 'altogether'): 1,
#  ('empty', 'glass', 'altogether', 'unpleasant'): 1,
#  ('glass', 'altogether', 'unpleasant', 'UNK'): 1,
#  ('altogether', 'unpleasant', 'UNK', 'subsub'): 1,
#  ('unpleasant', 'UNK', 'subsub', 'much'): 1,
#  ('UNK', 'subsub', 'much', 'pain'): 1,
#  ('subsub', 'much', 'pain', 'ye'): 1,
#  ('much', 'pain', 'ye', 'take'): 1,
#  ('pain', 'ye', 'take', 'please'): 1,
#  ('ye', 'take', 'please', 'world'): 1,
#  ('take', 'please', 'world', 'much'): 1,
#  ('please', 'world', 'much', 'shall'): 1,
#  ('world', 'much', 'shall', 'ye'): 1,
#  ('much', 'shall', 'ye', 'ever'): 1,
#  ('shall', 'ye', 'ever', 'go'): 1,
#  ('ye', 'ever', 'go', 'UNK'): 1,
#  ('ever', 'go', 'UNK', 'would'): 1,
#  ('go', 'UNK', 'would', 'clear'): 1,
#  ('UNK', 'would', 'clear', 'UNK'): 1,
#  ('would', 'clear', 'UNK', 'court'): 1,
#  ('clear', 'UNK', 'court', 'tuilery'): 1,
#  ('UNK', 'court', 'tuilery', 'ye'): 1,
#  ('court', 'tuilery', 'ye', 'gulp'): 1,
#  ('tuilery', 'ye', 'gulp', 'tear'): 1,
#  ('ye', 'gulp', 'tear', 'hie'): 1,
#  ('gulp', 'tear', 'hie', 'aloft'): 1,
#  ('tear', 'hie', 'aloft', 'royalmast'): 1,
#  ('hie', 'aloft', 'royalmast', 'heart'): 1,
#  ('aloft', 'royalmast', 'heart', 'friend'): 1,
#  ('royalmast', 'heart', 'friend', 'go'): 1,
#  ('heart', 'friend', 'go', 'clear'): 1,
#  ('friend', 'go', 'clear', 'UNK'): 1,
#  ('go', 'clear', 'UNK', 'heaven'): 1,
#  ('clear', 'UNK', 'heaven', 'make'): 1,
#  ('UNK', 'heaven', 'make', 'UNK'): 1,
#  ('heaven', 'make', 'UNK', 'UNK'): 1,
#  ('make', 'UNK', 'UNK', 'gabriel'): 1,
#  ('UNK', 'UNK', 'gabriel', 'michael'): 1,
#  ('UNK', 'gabriel', 'michael', 'UNK'): 1,
#  ('gabriel', 'michael', 'UNK', 'come'): 1,
#  ('michael', 'UNK', 'come', 'ye'): 1,
#  ('UNK', 'come', 'ye', 'strike'): 1,
#  ('come', 'ye', 'strike', 'splinter'): 1,
#  ('ye', 'strike', 'splinter', 'heart'): 1,
#  ('strike', 'splinter', 'heart', 'UNK'): 1,
#  ('splinter', 'heart', 'UNK', 'ye'): 1,
#  ('heart', 'UNK', 'ye', 'shall'): 1,
#  ('UNK', 'ye', 'shall', 'strike'): 1,
#  ('ye', 'shall', 'strike', 'UNK'): 1,
#  ('shall', 'strike', 'UNK', 'glass'): 1,
#  ('strike', 'UNK', 'glass', 'extract'): 1,
#  ('UNK', 'glass', 'extract', 'god'): 1,
#  ('glass', 'extract', 'god', 'create'): 1,
#  ('extract', 'god', 'create', 'great'): 1,
#  ('god', 'create', 'great', 'whale'): 1,
#  ('create', 'great', 'whale', 'genesi'): 1,
#  ('great', 'whale', 'genesi', 'leviathan'): 1,
#  ('whale', 'genesi', 'leviathan', 'maketh'): 1,
#  ('genesi', 'leviathan', 'maketh', 'path'): 1,
#  ('leviathan', 'maketh', 'path', 'shine'): 1,
#  ('maketh', 'path', 'shine', 'one'): 1,
#  ('path', 'shine', 'one', 'would'): 1,
#  ('shine', 'one', 'would', 'think'): 1,
#  ('one', 'would', 'think', 'deep'): 1,
#  ('would', 'think', 'deep', 'hoary'): 1,
#  ('think', 'deep', 'hoary', 'job'): 1,
#  ('deep', 'hoary', 'job', 'lord'): 1,
#  ('hoary', 'job', 'lord', 'prepare'): 1,
#  ('job', 'lord', 'prepare', 'great'): 1,
#  ('lord', 'prepare', 'great', 'fish'): 1,
#  ('prepare', 'great', 'fish', 'swallow'): 2,
#  ('great', 'fish', 'swallow', 'jonah'): 2,
#  ('fish', 'swallow', 'jonah', 'jonah'): 1,
#  ('swallow', 'jonah', 'jonah', 'go'): 1,
#  ('jonah', 'jonah', 'go', 'ship'): 1,
#  ('jonah', 'go', 'ship', 'leviathan'): 1,
#  ('go', 'ship', 'leviathan', 'thou'): 1,
#  ('ship', 'leviathan', 'thou', 'hast'): 1,
#  ('leviathan', 'thou', 'hast', 'make'): 1,
#  ('thou', 'hast', 'make', 'play'): 1,
#  ('hast', 'make', 'play', 'therein'): 1,
#  ('make', 'play', 'therein', 'psalm'): 1,
#  ('play', 'therein', 'psalm', 'day'): 1,
#  ('therein', 'psalm', 'day', 'lord'): 1,
#  ('psalm', 'day', 'lord', 'hi'): 1,
#  ('day', 'lord', 'hi', 'sore'): 1,
#  ('lord', 'hi', 'sore', 'great'): 1,
#  ('hi', 'sore', 'great', 'strong'): 1,
#  ('sore', 'great', 'strong', 'sword'): 1,
#  ('great', 'strong', 'sword', 'shall'): 1,
#  ('strong', 'sword', 'shall', 'UNK'): 1,
#  ('sword', 'shall', 'UNK', 'leviathan'): 1,
#  ('shall', 'UNK', 'leviathan', 'pierce'): 1,
#  ('UNK', 'leviathan', 'pierce', 'serpent'): 1,
#  ('leviathan', 'pierce', 'serpent', 'even'): 1,
#  ('pierce', 'serpent', 'even', 'leviathan'): 1,
#  ('serpent', 'even', 'leviathan', 'crook'): 1,
#  ('even', 'leviathan', 'crook', 'serpent'): 1,
#  ('leviathan', 'crook', 'serpent', 'shall'): 1,
#  ('crook', 'serpent', 'shall', 'slay'): 1,
#  ('serpent', 'shall', 'slay', 'dragon'): 1,
#  ('shall', 'slay', 'dragon', 'sea'): 1,
#  ('slay', 'dragon', 'sea', 'isaiah'): 1,
#  ('dragon', 'sea', 'isaiah', 'thing'): 1,
#  ('sea', 'isaiah', 'thing', 'UNK'): 1,
#  ('isaiah', 'thing', 'UNK', 'beside'): 1,
#  ('thing', 'UNK', 'beside', 'UNK'): 1,
#  ('UNK', 'beside', 'UNK', 'within'): 1,
#  ('beside', 'UNK', 'within', 'chao'): 1,
#  ('UNK', 'within', 'chao', 'thi'): 1,
#  ('within', 'chao', 'thi', 'monster'): 1,
#  ('chao', 'thi', 'monster', 'mouth'): 1,
#  ('thi', 'monster', 'mouth', 'beast'): 1,
#  ('monster', 'mouth', 'beast', 'boat'): 1,
#  ('mouth', 'beast', 'boat', 'stone'): 1,
#  ('beast', 'boat', 'stone', 'go'): 1,
#  ('boat', 'stone', 'go', 'UNK'): 1,
#  ('stone', 'go', 'UNK', 'foul'): 1,
#  ('go', 'UNK', 'foul', 'great'): 1,
#  ('UNK', 'foul', 'great', 'swallow'): 1,
#  ('foul', 'great', 'swallow', 'hi'): 1,
#  ('great', 'swallow', 'hi', 'UNK'): 1,
#  ('swallow', 'hi', 'UNK', 'bottomles'): 1,
#  ('hi', 'UNK', 'bottomles', 'gulf'): 1,
#  ('UNK', 'bottomles', 'gulf', 'hi'): 1,
#  ('bottomles', 'gulf', 'hi', 'paunch'): 1,
#  ('gulf', 'hi', 'paunch', 'holland'): 1,
#  ('hi', 'paunch', 'holland', 'UNK'): 1,
#  ('paunch', 'holland', 'UNK', 'moral'): 1,
#  ('holland', 'UNK', 'moral', 'indian'): 1,
#  ('UNK', 'moral', 'indian', 'sea'): 1,
#  ('moral', 'indian', 'sea', 'UNK'): 1,
#  ('indian', 'sea', 'UNK', 'biggest'): 1,
#  ('sea', 'UNK', 'biggest', 'fishes'): 1,
#  ('UNK', 'biggest', 'fishes', 'among'): 1,
#  ('biggest', 'fishes', 'among', 'whale'): 1,
#  ('fishes', 'among', 'whale', 'UNK'): 1,
#  ('among', 'whale', 'UNK', 'call'): 1,
#  ('whale', 'UNK', 'call', 'UNK'): 1,
#  ('UNK', 'call', 'UNK', 'take'): 1,
#  ('call', 'UNK', 'take', 'much'): 1,
#  ('UNK', 'take', 'much', 'length'): 1,
#  ('take', 'much', 'length', 'four'): 1,
#  ('much', 'length', 'four', 'acre'): 1,
#  ('length', 'four', 'acre', 'UNK'): 1,
#  ('four', 'acre', 'UNK', 'land'): 1,
#  ('acre', 'UNK', 'land', 'holland'): 1,
#  ('UNK', 'land', 'holland', 'pliny'): 1,
#  ('land', 'holland', 'pliny', 'scarcely'): 1,
#  ('holland', 'pliny', 'scarcely', 'proceed'): 1,
#  ('pliny', 'scarcely', 'proceed', 'two'): 1,
#  ('scarcely', 'proceed', 'two', 'day'): 1,
#  ('proceed', 'two', 'day', 'sea'): 1,
#  ('two', 'day', 'sea', 'sunrise'): 1,
#  ('day', 'sea', 'sunrise', 'great'): 1,
#  ('sea', 'sunrise', 'great', 'many'): 1,
#  ('sunrise', 'great', 'many', 'whale'): 1,
#  ('great', 'many', 'whale', 'monster'): 1,
#  ('many', 'whale', 'monster', 'sea'): 1,
#  ('whale', 'monster', 'sea', 'appear'): 1,
#  ('monster', 'sea', 'appear', 'among'): 1,
#  ('sea', 'appear', 'among', 'former'): 1,
#  ('appear', 'among', 'former', 'one'): 1,
#  ('among', 'former', 'one', 'monstrou'): 1,
#  ('former', 'one', 'monstrou', 'size'): 1,
#  ('one', 'monstrou', 'size', '....'): 1,
#  ('monstrou', 'size', '....', 'thi'): 1,
#  ('size', '....', 'thi', 'come'): 1,
#  ('....', 'thi', 'come', 'toward'): 1,
#  ('thi', 'come', 'toward', 'u'): 1,
#  ('come', 'toward', 'u', 'openmouthe'): 1,
#  ('toward', 'u', 'openmouthe', 'raise'): 1,
#  ('u', 'openmouthe', 'raise', 'wave'): 1,
#  ('openmouthe', 'raise', 'wave', 'side'): 1,
#  ('raise', 'wave', 'side', 'beat'): 1,
#  ('wave', 'side', 'beat', 'sea'): 1,
#  ('side', 'beat', 'sea', 'foam'): 1,
#  ('beat', 'sea', 'foam', 'UNK'): 1,
#  ('sea', 'foam', 'UNK', 'UNK'): 1,
#  ('foam', 'UNK', 'UNK', 'true'): 1,
#  ('UNK', 'UNK', 'true', 'history'): 1,
#  ('UNK', 'true', 'history', 'visit'): 1,
#  ('true', 'history', 'visit', 'thi'): 1,
#  ('history', 'visit', 'thi', 'country'): 1,
#  ('visit', 'thi', 'country', 'also'): 1,
#  ('thi', 'country', 'also', 'view'): 1,
#  ('country', 'also', 'view', 'catch'): 1,
#  ('also', 'view', 'catch', 'UNK'): 1,
#  ('view', 'catch', 'UNK', 'bone'): 1,
#  ('catch', 'UNK', 'bone', 'great'): 1,
#  ('UNK', 'bone', 'great', 'value'): 1,
#  ('bone', 'great', 'value', 'teeth'): 1,
#  ('great', 'value', 'teeth', 'bring'): 1,
#  ('value', 'teeth', 'bring', 'king'): 1,
#  ('teeth', 'bring', 'king', '....'): 1,
#  ('bring', 'king', '....', 'best'): 1,
#  ('king', '....', 'best', 'whale'): 1,
#  ('....', 'best', 'whale', 'catch'): 1,
#  ('best', 'whale', 'catch', 'hi'): 1,
#  ('whale', 'catch', 'hi', 'country'): 1,
#  ('catch', 'hi', 'country', 'fortyeight'): 1,
#  ('hi', 'country', 'fortyeight', 'fifty'): 1,
#  ('country', 'fortyeight', 'fifty', 'yard'): 1,
#  ('fortyeight', 'fifty', 'yard', 'long'): 1,
#  ('fifty', 'yard', 'long', 'say'): 1,
#  ('yard', 'long', 'say', 'one'): 1,
#  ('long', 'say', 'one', 'six'): 1,
#  ('say', 'one', 'six', 'kill'): 1,
#  ('one', 'six', 'kill', 'sixty'): 1,
#  ('six', 'kill', 'sixty', 'two'): 1,
#  ('kill', 'sixty', 'two', 'day'): 1,
#  ('sixty', 'two', 'day', 'verbal'): 1,
#  ('two', 'day', 'verbal', 'narrative'): 1,
#  ('day', 'verbal', 'narrative', 'take'): 1,
#  ('verbal', 'narrative', 'take', 'hi'): 1,
#  ('narrative', 'take', 'hi', 'mouth'): 1,
#  ('take', 'hi', 'mouth', 'king'): 1,
#  ('hi', 'mouth', 'king', 'alfr'): 1,
#  ('mouth', 'king', 'alfr', 'a.d.'): 1,
#  ('king', 'alfr', 'a.d.', 'wherea'): 1,
#  ('alfr', 'a.d.', 'wherea', 'thing'): 1,
#  ('a.d.', 'wherea', 'thing', 'whether'): 1,
#  ('wherea', 'thing', 'whether', 'beast'): 1,
#  ('thing', 'whether', 'beast', 'vessel'): 1,
#  ('whether', 'beast', 'vessel', 'enter'): 1,
#  ('beast', 'vessel', 'enter', 'dreadful'): 1,
#  ('vessel', 'enter', 'dreadful', 'gulf'): 1,
#  ('enter', 'dreadful', 'gulf', 'thi'): 1,
#  ('dreadful', 'gulf', 'thi', 'monster'): 1,
#  ('gulf', 'thi', 'monster', 'whale'): 1,
#  ('thi', 'monster', 'whale', 'mouth'): 1,
#  ('monster', 'whale', 'mouth', 'immediately'): 1,
#  ('whale', 'mouth', 'immediately', 'lose'): 1,
#  ('mouth', 'immediately', 'lose', 'swallow'): 1,
#  ('immediately', 'lose', 'swallow', 'UNK'): 1,
#  ('lose', 'swallow', 'UNK', 'retire'): 1,
#  ('swallow', 'UNK', 'retire', 'great'): 1,
#  ('UNK', 'retire', 'great', 'security'): 1,
#  ('retire', 'great', 'security', 'sleep'): 1,
#  ('great', 'security', 'sleep', 'UNK'): 1,
#  ('security', 'sleep', 'UNK', 'UNK'): 1,
#  ('sleep', 'UNK', 'UNK', 'UNK'): 1,
#  ('UNK', 'UNK', 'UNK', 'let'): 1,
#  ('UNK', 'UNK', 'let', 'u'): 1,
#  ('UNK', 'let', 'u', 'fly'): 1,
#  ('let', 'u', 'fly', 'let'): 1,
#  ('u', 'fly', 'let', 'u'): 1,
#  ('fly', 'let', 'u', 'fly'): 1,
#  ('let', 'u', 'fly', 'old'): 1,
#  ('u', 'fly', 'old', 'UNK'): 1,
#  ('fly', 'old', 'UNK', 'take'): 1,
#  ('old', 'UNK', 'take', 'leviathan'): 1,
#  ('UNK', 'take', 'leviathan', 'describe'): 1,
#  ('take', 'leviathan', 'describe', 'noble'): 1,
#  ('leviathan', 'describe', 'noble', 'prophet'): 1,
#  ('describe', 'noble', 'prophet', 'mose'): 1,
#  ('noble', 'prophet', 'mose', 'life'): 1,
#  ('prophet', 'mose', 'life', 'patient'): 1,
#  ('mose', 'life', 'patient', 'job'): 1,
#  ('life', 'patient', 'job', 'rabelai'): 1,
#  ('patient', 'job', 'rabelai', 'thi'): 1,
#  ('job', 'rabelai', 'thi', 'whale'): 1,
#  ('rabelai', 'thi', 'whale', 'liver'): 1,
#  ('thi', 'whale', 'liver', 'two'): 1,
#  ('whale', 'liver', 'two', 'cartload'): 1,
#  ('liver', 'two', 'cartload', 'UNK'): 1,
#  ('two', 'cartload', 'UNK', 'annal'): 1,
#  ('cartload', 'UNK', 'annal', 'great'): 1,
#  ('UNK', 'annal', 'great', 'leviathan'): 1,
#  ('annal', 'great', 'leviathan', 'maketh'): 1,
#  ('great', 'leviathan', 'maketh', 'sea'): 1,
#  ('leviathan', 'maketh', 'sea', 'seethe'): 1,
#  ('maketh', 'sea', 'seethe', 'like'): 1,
#  ('sea', 'seethe', 'like', 'boil'): 1,
#  ('seethe', 'like', 'boil', 'pan'): 1,
#  ('like', 'boil', 'pan', 'lord'): 1,
#  ('boil', 'pan', 'lord', 'UNK'): 1,
#  ('pan', 'lord', 'UNK', 'version'): 1,
#  ('lord', 'UNK', 'version', 'psalm'): 1,
#  ('UNK', 'version', 'psalm', 'touch'): 1,
#  ('version', 'psalm', 'touch', 'monstrou'): 1,
#  ('psalm', 'touch', 'monstrou', 'bulk'): 1,
#  ('touch', 'monstrou', 'bulk', 'whale'): 1,
#  ('monstrou', 'bulk', 'whale', 'UNK'): 1,
#  ('bulk', 'whale', 'UNK', 'receive'): 1,
#  ('whale', 'UNK', 'receive', 'nothe'): 1,
#  ('UNK', 'receive', 'nothe', 'certain'): 1,
#  ('receive', 'nothe', 'certain', 'grow'): 1,
#  ('nothe', 'certain', 'grow', 'exceed'): 1,
#  ('certain', 'grow', 'exceed', 'fat'): 1,
#  ('grow', 'exceed', 'fat', 'insomuch'): 1,
#  ('exceed', 'fat', 'insomuch', 'incredible'): 1,
#  ('fat', 'insomuch', 'incredible', 'quantity'): 1,
#  ('insomuch', 'incredible', 'quantity', 'oil'): 1,
#  ('incredible', 'quantity', 'oil', 'extract'): 1,
#  ('quantity', 'oil', 'extract', 'one'): 1,
#  ('oil', 'extract', 'one', 'whale'): 1,
#  ('extract', 'one', 'whale', 'ibid'): 1,
#  ('one', 'whale', 'ibid', 'history'): 1,
#  ('whale', 'ibid', 'history', 'life'): 1,
#  ('ibid', 'history', 'life', 'death'): 1,
#  ('history', 'life', 'death', 'UNK'): 1,
#  ...}

# %%
sorted_4_counts_values = dict(sorted(four_counts.items(), key=lambda item: item[1], reverse=True))
sorted_4_counts_values
# Out:
# {('UNK', 'UNK', 'UNK', 'UNK'): 23,
#  ('book', 'i.', 'folio', 'chapter'): 6,
#  ('book', 'ii', 'octavo', 'chapter'): 5,
#  ('UNK', 'UNK', 'sperm', 'whale'): 4,
#  ('press', 'hi', 'forehead', 'mine'): 3,
#  ('morn', 'ye', 'shipmate', 'morn'): 3,
#  ('book', 'iii', 'duodecimo', 'chapter'): 3,
#  ('sperm', 'whale', 'sperm', 'whale'): 3,
#  ('sperm', 'whale', 'right', 'whale'): 3,
#  ('moby', 'dick', 'whale', 'herman'): 2,
#  ('dick', 'whale', 'herman', 'melville'): 2,
#  ('project', 'gutenberg', 'ebook', 'moby'): 2,
#  ('gutenberg', 'ebook', 'moby', 'dick'): 2,
#  ('ebook', 'moby', 'dick', 'whale'): 2,
#  ('chapter', 'lee', 'shore', 'chapter'): 2,
#  ('chapter', 'knight', 'squire', 'chapter'): 2,
#  ('chapter', 'enter', 'ahab', 'stubb'): 2,
#  ('chapter', 'ahab', 'boat', 'crew'): 2,
#  ('ahab', 'boat', 'crew', 'fedallah'): 2,
#  ('chapter', 'monstrou', 'picture', 'whale'): 2,
#  ('chapter', 'les', 'erroneou', 'picture'): 2,
#  ('les', 'erroneou', 'picture', 'whale'): 2,
#  ('erroneou', 'picture', 'whale', 'true'): 2,
#  ('picture', 'whale', 'true', 'picture'): 2,
#  ('whale', 'true', 'picture', 'whale'): 2,
#  ('true', 'picture', 'whale', 'scene'): 2,
#  ('chapter', 'whale', 'paint', 'teeth'): 2,
#  ('whale', 'paint', 'teeth', 'wood'): 2,
#  ('paint', 'teeth', 'wood', 'sheetiron'): 2,
#  ('teeth', 'wood', 'sheetiron', 'stone'): 2,
#  ('wood', 'sheetiron', 'stone', 'mountain'): 2,
#  ('sheetiron', 'stone', 'mountain', 'star'): 2,
#  ('chapter', 'stubb', 'kill', 'whale'): 2,
#  ('chapter', 'stubb', 'flask', 'kill'): 2,
#  ('stubb', 'flask', 'kill', 'right'): 2,
#  ('flask', 'kill', 'right', 'whale'): 2,
#  ('kill', 'right', 'whale', 'talk'): 2,
#  ('chapter', 'sperm', 'whale', 'headcontrast'): 2,
#  ('sperm', 'whale', 'headcontrast', 'view'): 2,
#  ('whale', 'headcontrast', 'view', 'chapter'): 2,
#  ('chapter', 'right', 'whale', 'headcontrast'): 2,
#  ('right', 'whale', 'headcontrast', 'view'): 2,
#  ('chapter', 'great', 'heidelburgh', 'tun'): 2,
#  ('chapter', 'pequod', 'meet', 'virgin'): 2,
#  ('chapter', 'honor', 'glory', 'whale'): 2,
#  ('chapter', 'jonah', 'historically', 'regard'): 2,
#  ('chapter', 'pequod', 'meet', 'rosebud'): 2,
#  ('prepare', 'great', 'fish', 'swallow'): 2,
#  ('great', 'fish', 'swallow', 'jonah'): 2,
#  ('UNK', 'UNK', 'UNK', 'hi'): 2,
#  ('way', 'UNK', 'UNK', 'UNK'): 2,
#  ('UNK', 'UNK', 'UNK', 'whale'): 2,
#  ('purpose', 'extend', 'spermaceti', 'whale'): 2,
#  ('extend', 'spermaceti', 'whale', 'fishery'): 2,
#  ('heart', 'never', 'fail', 'bold'): 2,
#  ('ye', 'every', 'one', 'know'): 2,
#  ('UNK', 'UNK', 'sleep', 'UNK'): 2,
#  ('alway', 'go', 'sea', 'sailor'): 2,
#  ('UNK', 'UNK', 'thou', 'UNK'): 2,
#  ('UNK', 'thou', 'UNK', 'well'): 2,
#  ('sailor', 'sleep', 'two', 'bed'): 2,
#  ('think', 'ye', 'UNK', 'UNK'): 2,
#  ('man', 'anythe', 'UNK', 'UNK'): 2,
#  ('atlantic', 'pacific', 'indian', 'ocean'): 2,
#  ('thi', 'tablet', 'erect', 'hi'): 2,
#  ('tablet', 'erect', 'hi', 'memory'): 2,
#  ('erect', 'hi', 'memory', 'hi'): 2,
#  ('thi', 'great', 'tempest', 'upon'): 2,
#  ('hint', 'queequeg', 'perhap', 'best'): 2,
#  ('light', 'hi', 'tomahawk', 'pipe'): 2,
#  ('smalle', 'fishe', 'queequeg', 'kille'): 2,
#  ('like', 'UNK', 'UNK', 'UNK'): 2,
#  ('dure', 'term', 'hi', 'UNK'): 2,
#  ('like', 'UNK', 'old', 'UNK'): 2,
#  ('UNK', 'old', 'UNK', 'UNK'): 2,
#  ('clap', 'eye', 'captain', 'ahab'): 2,
#  ('captain', 'peleg', 'captain', 'bildad'): 2,
#  ('seven', 'hundr', 'seventyseventh', 'lay'): 2,
#  ('lose', 'hi', 'leg', 'last'): 2,
#  ('hi', 'leg', 'last', 'voyage'): 2,
#  ('member', 'first', 'congregational', 'church'): 2,
#  ('UNK', 'every', 'one', 'know'): 2,
#  ('two', 'captain', 'peleg', 'bildad'): 2,
#  ('within', 'hi', 'cabin', 'chapter'): 2,
#  ('UNK', 'ye', 'mr.', 'UNK'): 2,
#  ('whale', 'famou', 'author', 'whale'): 2,
#  ('famou', 'author', 'whale', 'famou'): 2,
#  ('author', 'whale', 'famou', 'chronicler'): 2,
#  ('whale', 'never', 'figure', 'grand'): 2,
#  ('never', 'figure', 'grand', 'impose'): 2,
#  ('figure', 'grand', 'impose', 'way'): 2,
#  ('shall', 'ere', 'long', 'see'): 2,
#  ('within', 'easy', 'reach', 'hi'): 2,
#  ('easy', 'reach', 'hi', 'hand'): 2,
#  ('voyage', 'round', 'cape', 'horn'): 2,
#  ('american', 'whale', 'fishery', 'american'): 2,
#  ('even', 'UNK', 'UNK', 'UNK'): 2,
#  ('call', 'ten', 'time', 'donkey'): 2,
#  ('UNK', 'great', 'sperm', 'whale'): 2,
#  ('spout', 'fish', 'horizontal', 'tail'): 2,
#  ('whale', 'book', 'i.', 'folio'): 2,
#  ('UNK', 'thi', 'whale', 'little'): 2,
#  ('whosoever', 'ye', 'raise', 'whitehead'): 2,
#  ('ye', 'raise', 'whitehead', 'whale'): 2,
#  ('wrinkle', 'brow', 'crook', 'jaw'): 2,
#  ('moby', 'dick', 'moby', 'dick'): 2,
#  ('captain', 'ahab', 'say', 'starbuck'): 2,
#  ('UNK', 'little', 'lower', 'layer'): 2,
#  ('UNK', 'man', 'UNK', 'UNK'): 2,
#  ('UNK', 'la', 'lirra', 'skirra'): 2,
#  ('give', 'battle', 'moby', 'dick'): 2,
#  ('give', 'chase', 'moby', 'dick'): 2,
#  ('hist', 'hear', 'noise', 'cabaco'): 2,
#  ('particular', 'set', 'time', 'place'): 2,
#  ('UNK', 'whale', 'UNK', 'UNK'): 2,
#  ('pull', 'ye', 'pull', 'ye'): 2,
#  ('UNK', 'start', 'UNK', 'UNK'): 2,
#  ('UNK', 'stubb', 'hi', 'UNK'): 2,
#  ('never', 'mind', 'UNK', 'UNK'): 2,
#  ('rio', 'de', 'la', 'plata'): 2,
#  ('hammer', 'within', 'inch', 'hi'): 2,
#  ('full', 'grow', 'sperm', 'whale'): 2,
#  ('must', 'stop', 'dat', 'dam'): 2,
#  ('like', 'UNK', 'old', 'house'): 2,
#  ('nearly', 'one', 'third', 'hi'): 2,
#  ('one', 'third', 'hi', 'entire'): 2,
#  ('gabriel', 'start', 'hi', 'feet'): 2,
#  ('UNK', 'sperm', 'whale', 'right'): 2,
#  ('sperm', 'whale', 'head', 'may'): 2,
#  ('heidelburgh', 'tun', 'sperm', 'whale'): 2,
#  ('historical', 'story', 'jonah', 'whale'): 2,
#  ('hi', 'want', 'faith', 'thi'): 2,
#  ('none', 'young', 'vigorou', 'male'): 2,
#  ('whale', 'herman', 'melville', 'project'): 1,
#  ('herman', 'melville', 'project', 'gutenberg'): 1,
#  ('melville', 'project', 'gutenberg', 'ebook'): 1,
#  ('whale', 'herman', 'melville', 'thi'): 1,
#  ('herman', 'melville', 'thi', 'ebook'): 1,
#  ('melville', 'thi', 'ebook', 'use'): 1,
#  ('thi', 'ebook', 'use', 'anyone'): 1,
#  ('ebook', 'use', 'anyone', 'anywhere'): 1,
#  ('use', 'anyone', 'anywhere', 'cost'): 1,
#  ('anyone', 'anywhere', 'cost', 'almost'): 1,
#  ('anywhere', 'cost', 'almost', 'restriction'): 1,
#  ('cost', 'almost', 'restriction', 'whatsoever'): 1,
#  ('almost', 'restriction', 'whatsoever', 'may'): 1,
#  ('restriction', 'whatsoever', 'may', 'copy'): 1,
#  ('whatsoever', 'may', 'copy', 'give'): 1,
#  ('may', 'copy', 'give', 'away'): 1,
#  ('copy', 'give', 'away', 'reuse'): 1,
#  ('give', 'away', 'reuse', 'term'): 1,
#  ('away', 'reuse', 'term', 'project'): 1,
#  ('reuse', 'term', 'project', 'gutenberg'): 1,
#  ('term', 'project', 'gutenberg', 'license'): 1,
#  ('project', 'gutenberg', 'license', 'include'): 1,
#  ('gutenberg', 'license', 'include', 'thi'): 1,
#  ('license', 'include', 'thi', 'ebook'): 1,
#  ('include', 'thi', 'ebook', 'online'): 1,
#  ('thi', 'ebook', 'online', 'www.gutenberg.org'): 1,
#  ('ebook', 'online', 'www.gutenberg.org', 'title'): 1,
#  ('online', 'www.gutenberg.org', 'title', 'moby'): 1,
#  ('www.gutenberg.org', 'title', 'moby', 'dick'): 1,
#  ('title', 'moby', 'dick', 'whale'): 1,
#  ('moby', 'dick', 'whale', 'author'): 1,
#  ('dick', 'whale', 'author', 'herman'): 1,
#  ('whale', 'author', 'herman', 'melville'): 1,
#  ('author', 'herman', 'melville', 'UNK'): 1,
#  ('herman', 'melville', 'UNK', 'date'): 1,
#  ('melville', 'UNK', 'date', 'december'): 1,
#  ('UNK', 'date', 'december', 'ebook'): 1,
#  ('date', 'december', 'ebook', 'last'): 1,
#  ('december', 'ebook', 'last', 'update'): 1,
#  ('ebook', 'last', 'update', 'december'): 1,
#  ('last', 'update', 'december', 'language'): 1,
#  ('update', 'december', 'language', 'english'): 1,
#  ('december', 'language', 'english', 'character'): 1,
#  ('language', 'english', 'character', 'set'): 1,
#  ('english', 'character', 'set', 'UNK'): 1,
#  ('character', 'set', 'UNK', 'UNK'): 1,
#  ('set', 'UNK', 'UNK', 'start'): 1,
#  ('UNK', 'UNK', 'start', 'thi'): 1,
#  ('UNK', 'start', 'thi', 'project'): 1,
#  ('start', 'thi', 'project', 'gutenberg'): 1,
#  ('thi', 'project', 'gutenberg', 'ebook'): 1,
#  ('moby', 'dick', 'whale', 'produce'): 1,
#  ('dick', 'whale', 'produce', 'daniel'): 1,
#  ('whale', 'produce', 'daniel', 'lazaru'): 1,
#  ('produce', 'daniel', 'lazaru', 'jonesey'): 1,
#  ('daniel', 'lazaru', 'jonesey', 'david'): 1,
#  ('lazaru', 'jonesey', 'david', 'widger'): 1,
#  ('jonesey', 'david', 'widger', 'UNK'): 1,
#  ('david', 'widger', 'UNK', 'whale'): 1,
#  ('widger', 'UNK', 'whale', 'herman'): 1,
#  ('UNK', 'whale', 'herman', 'melville'): 1,
#  ('whale', 'herman', 'melville', 'content'): 1,
#  ('herman', 'melville', 'content', 'etymology'): 1,
#  ('melville', 'content', 'etymology', 'extract'): 1,
#  ('content', 'etymology', 'extract', 'supply'): 1,
#  ('etymology', 'extract', 'supply', 'subsublibrarian'): 1,
#  ('extract', 'supply', 'subsublibrarian', 'chapter'): 1,
#  ('supply', 'subsublibrarian', 'chapter', 'looming'): 1,
#  ('subsublibrarian', 'chapter', 'looming', 'chapter'): 1,
#  ('chapter', 'looming', 'chapter', 'carpetbag'): 1,
#  ('looming', 'chapter', 'carpetbag', 'chapter'): 1,
#  ('chapter', 'carpetbag', 'chapter', 'spouterinn'): 1,
#  ('carpetbag', 'chapter', 'spouterinn', 'chapter'): 1,
#  ('chapter', 'spouterinn', 'chapter', 'counterpane'): 1,
#  ('spouterinn', 'chapter', 'counterpane', 'chapter'): 1,
#  ('chapter', 'counterpane', 'chapter', 'breakfast'): 1,
#  ('counterpane', 'chapter', 'breakfast', 'chapter'): 1,
#  ('chapter', 'breakfast', 'chapter', 'street'): 1,
#  ('breakfast', 'chapter', 'street', 'chapter'): 1,
#  ('chapter', 'street', 'chapter', 'chapel'): 1,
#  ('street', 'chapter', 'chapel', 'chapter'): 1,
#  ('chapter', 'chapel', 'chapter', 'pulpit'): 1,
#  ('chapel', 'chapter', 'pulpit', 'chapter'): 1,
#  ('chapter', 'pulpit', 'chapter', 'sermon'): 1,
#  ('pulpit', 'chapter', 'sermon', 'chapter'): 1,
#  ('chapter', 'sermon', 'chapter', 'bosom'): 1,
#  ('sermon', 'chapter', 'bosom', 'friend'): 1,
#  ('chapter', 'bosom', 'friend', 'chapter'): 1,
#  ('bosom', 'friend', 'chapter', 'nightgown'): 1,
#  ('friend', 'chapter', 'nightgown', 'chapter'): 1,
#  ('chapter', 'nightgown', 'chapter', 'biographical'): 1,
#  ('nightgown', 'chapter', 'biographical', 'chapter'): 1,
#  ('chapter', 'biographical', 'chapter', 'wheelbarrow'): 1,
#  ('biographical', 'chapter', 'wheelbarrow', 'chapter'): 1,
#  ('chapter', 'wheelbarrow', 'chapter', 'nantucket'): 1,
#  ('wheelbarrow', 'chapter', 'nantucket', 'chapter'): 1,
#  ('chapter', 'nantucket', 'chapter', 'chowder'): 1,
#  ('nantucket', 'chapter', 'chowder', 'chapter'): 1,
#  ('chapter', 'chowder', 'chapter', 'ship'): 1,
#  ('chowder', 'chapter', 'ship', 'chapter'): 1,
#  ('chapter', 'ship', 'chapter', 'ramadan'): 1,
#  ('ship', 'chapter', 'ramadan', 'chapter'): 1,
#  ('chapter', 'ramadan', 'chapter', 'hi'): 1,
#  ('ramadan', 'chapter', 'hi', 'mark'): 1,
#  ('chapter', 'hi', 'mark', 'chapter'): 1,
#  ('hi', 'mark', 'chapter', 'prophet'): 1,
#  ('mark', 'chapter', 'prophet', 'chapter'): 1,
#  ('chapter', 'prophet', 'chapter', 'astir'): 1,
#  ('prophet', 'chapter', 'astir', 'chapter'): 1,
#  ('chapter', 'astir', 'chapter', 'go'): 1,
#  ('astir', 'chapter', 'go', 'aboard'): 1,
#  ('chapter', 'go', 'aboard', 'chapter'): 1,
#  ('go', 'aboard', 'chapter', 'merry'): 1,
#  ('aboard', 'chapter', 'merry', 'christma'): 1,
#  ('chapter', 'merry', 'christma', 'chapter'): 1,
#  ('merry', 'christma', 'chapter', 'lee'): 1,
#  ('christma', 'chapter', 'lee', 'shore'): 1,
#  ('lee', 'shore', 'chapter', 'advocate'): 1,
#  ('shore', 'chapter', 'advocate', 'chapter'): 1,
#  ('chapter', 'advocate', 'chapter', 'postscript'): 1,
#  ('advocate', 'chapter', 'postscript', 'chapter'): 1,
#  ('chapter', 'postscript', 'chapter', 'knight'): 1,
#  ('postscript', 'chapter', 'knight', 'squire'): 1,
#  ('knight', 'squire', 'chapter', 'knight'): 1,
#  ('squire', 'chapter', 'knight', 'squire'): 1,
#  ('knight', 'squire', 'chapter', 'ahab'): 1,
#  ('squire', 'chapter', 'ahab', 'chapter'): 1,
#  ('chapter', 'ahab', 'chapter', 'enter'): 1,
#  ('ahab', 'chapter', 'enter', 'ahab'): 1,
#  ('enter', 'ahab', 'stubb', 'chapter'): 1,
#  ('ahab', 'stubb', 'chapter', 'pipe'): 1,
#  ('stubb', 'chapter', 'pipe', 'chapter'): 1,
#  ('chapter', 'pipe', 'chapter', 'queen'): 1,
#  ('pipe', 'chapter', 'queen', 'mab'): 1,
#  ('chapter', 'queen', 'mab', 'chapter'): 1,
#  ('queen', 'mab', 'chapter', 'cetology'): 1,
#  ('mab', 'chapter', 'cetology', 'chapter'): 1,
#  ('chapter', 'cetology', 'chapter', 'specksnyder'): 1,
#  ('cetology', 'chapter', 'specksnyder', 'chapter'): 1,
#  ('chapter', 'specksnyder', 'chapter', 'cabintable'): 1,
#  ('specksnyder', 'chapter', 'cabintable', 'chapter'): 1,
#  ('chapter', 'cabintable', 'chapter', 'masthead'): 1,
#  ('cabintable', 'chapter', 'masthead', 'chapter'): 1,
#  ('chapter', 'masthead', 'chapter', 'quarterdeck'): 1,
#  ('masthead', 'chapter', 'quarterdeck', 'chapter'): 1,
#  ('chapter', 'quarterdeck', 'chapter', 'sunset'): 1,
#  ('quarterdeck', 'chapter', 'sunset', 'chapter'): 1,
#  ('chapter', 'sunset', 'chapter', 'dusk'): 1,
#  ('sunset', 'chapter', 'dusk', 'chapter'): 1,
#  ('chapter', 'dusk', 'chapter', 'first'): 1,
#  ('dusk', 'chapter', 'first', 'nightwatch'): 1,
#  ('chapter', 'first', 'nightwatch', 'chapter'): 1,
#  ('first', 'nightwatch', 'chapter', 'midnight'): 1,
#  ('nightwatch', 'chapter', 'midnight', 'forecastle'): 1,
#  ('chapter', 'midnight', 'forecastle', 'chapter'): 1,
#  ('midnight', 'forecastle', 'chapter', 'moby'): 1,
#  ('forecastle', 'chapter', 'moby', 'dick'): 1,
#  ('chapter', 'moby', 'dick', 'chapter'): 1,
#  ('moby', 'dick', 'chapter', 'whitenes'): 1,
#  ('dick', 'chapter', 'whitenes', 'whale'): 1,
#  ('chapter', 'whitenes', 'whale', 'chapter'): 1,
#  ('whitenes', 'whale', 'chapter', 'hark'): 1,
#  ('whale', 'chapter', 'hark', 'chapter'): 1,
#  ('chapter', 'hark', 'chapter', 'chart'): 1,
#  ('hark', 'chapter', 'chart', 'chapter'): 1,
#  ('chapter', 'chart', 'chapter', 'affidavit'): 1,
#  ('chart', 'chapter', 'affidavit', 'chapter'): 1,
#  ('chapter', 'affidavit', 'chapter', 'surmise'): 1,
#  ('affidavit', 'chapter', 'surmise', 'chapter'): 1,
#  ('chapter', 'surmise', 'chapter', 'matmaker'): 1,
#  ('surmise', 'chapter', 'matmaker', 'chapter'): 1,
#  ('chapter', 'matmaker', 'chapter', 'first'): 1,
#  ('matmaker', 'chapter', 'first', 'lower'): 1,
#  ('chapter', 'first', 'lower', 'chapter'): 1,
#  ('first', 'lower', 'chapter', 'hyena'): 1,
#  ('lower', 'chapter', 'hyena', 'chapter'): 1,
#  ('chapter', 'hyena', 'chapter', 'ahab'): 1,
#  ('hyena', 'chapter', 'ahab', 'boat'): 1,
#  ('boat', 'crew', 'fedallah', 'chapter'): 1,
#  ('crew', 'fedallah', 'chapter', 'spiritspout'): 1,
#  ('fedallah', 'chapter', 'spiritspout', 'chapter'): 1,
#  ('chapter', 'spiritspout', 'chapter', 'albatros'): 1,
#  ('spiritspout', 'chapter', 'albatros', 'chapter'): 1,
#  ('chapter', 'albatros', 'chapter', 'gam'): 1,
#  ('albatros', 'chapter', 'gam', 'chapter'): 1,
#  ('chapter', 'gam', 'chapter', 'townho'): 1,
#  ('gam', 'chapter', 'townho', 'story'): 1,
#  ('chapter', 'townho', 'story', 'chapter'): 1,
#  ('townho', 'story', 'chapter', 'monstrou'): 1,
#  ('story', 'chapter', 'monstrou', 'picture'): 1,
#  ('monstrou', 'picture', 'whale', 'chapter'): 1,
#  ('picture', 'whale', 'chapter', 'les'): 1,
#  ('whale', 'chapter', 'les', 'erroneou'): 1,
#  ('picture', 'whale', 'scene', 'chapter'): 1,
#  ('whale', 'scene', 'chapter', 'whale'): 1,
#  ('scene', 'chapter', 'whale', 'paint'): 1,
#  ('stone', 'mountain', 'star', 'chapter'): 1,
#  ('mountain', 'star', 'chapter', 'brit'): 1,
#  ('star', 'chapter', 'brit', 'chapter'): 1,
#  ('chapter', 'brit', 'chapter', 'squid'): 1,
#  ('brit', 'chapter', 'squid', 'chapter'): 1,
#  ('chapter', 'squid', 'chapter', 'line'): 1,
#  ('squid', 'chapter', 'line', 'chapter'): 1,
#  ('chapter', 'line', 'chapter', 'stubb'): 1,
#  ('line', 'chapter', 'stubb', 'kill'): 1,
#  ('stubb', 'kill', 'whale', 'chapter'): 1,
#  ('kill', 'whale', 'chapter', 'dart'): 1,
#  ('whale', 'chapter', 'dart', 'chapter'): 1,
#  ('chapter', 'dart', 'chapter', 'crotch'): 1,
#  ('dart', 'chapter', 'crotch', 'chapter'): 1,
#  ('chapter', 'crotch', 'chapter', 'stubb'): 1,
#  ('crotch', 'chapter', 'stubb', 'supper'): 1,
#  ('chapter', 'stubb', 'supper', 'chapter'): 1,
#  ('stubb', 'supper', 'chapter', 'whale'): 1,
#  ('supper', 'chapter', 'whale', 'dish'): 1,
#  ('chapter', 'whale', 'dish', 'chapter'): 1,
#  ('whale', 'dish', 'chapter', 'shark'): 1,
#  ('dish', 'chapter', 'shark', 'massacre'): 1,
#  ('chapter', 'shark', 'massacre', 'chapter'): 1,
#  ('shark', 'massacre', 'chapter', 'cut'): 1,
#  ('massacre', 'chapter', 'cut', 'chapter'): 1,
#  ('chapter', 'cut', 'chapter', 'blanket'): 1,
#  ('cut', 'chapter', 'blanket', 'chapter'): 1,
#  ('chapter', 'blanket', 'chapter', 'funeral'): 1,
#  ('blanket', 'chapter', 'funeral', 'chapter'): 1,
#  ('chapter', 'funeral', 'chapter', 'sphynx'): 1,
#  ('funeral', 'chapter', 'sphynx', 'chapter'): 1,
#  ('chapter', 'sphynx', 'chapter', 'jeroboam'): 1,
#  ('sphynx', 'chapter', 'jeroboam', 'story'): 1,
#  ('chapter', 'jeroboam', 'story', 'chapter'): 1,
#  ('jeroboam', 'story', 'chapter', 'monkeyrope'): 1,
#  ('story', 'chapter', 'monkeyrope', 'chapter'): 1,
#  ('chapter', 'monkeyrope', 'chapter', 'stubb'): 1,
#  ('monkeyrope', 'chapter', 'stubb', 'flask'): 1,
#  ('right', 'whale', 'talk', 'chapter'): 1,
#  ('whale', 'talk', 'chapter', 'sperm'): 1,
#  ('talk', 'chapter', 'sperm', 'whale'): 1,
#  ('headcontrast', 'view', 'chapter', 'right'): 1,
#  ('view', 'chapter', 'right', 'whale'): 1,
#  ('headcontrast', 'view', 'chapter', 'batteringram'): 1,
#  ('view', 'chapter', 'batteringram', 'chapter'): 1,
#  ('chapter', 'batteringram', 'chapter', 'great'): 1,
#  ('batteringram', 'chapter', 'great', 'heidelburgh'): 1,
#  ('great', 'heidelburgh', 'tun', 'chapter'): 1,
#  ('heidelburgh', 'tun', 'chapter', 'cistern'): 1,
#  ('tun', 'chapter', 'cistern', 'bucket'): 1,
#  ('chapter', 'cistern', 'bucket', 'chapter'): 1,
#  ('cistern', 'bucket', 'chapter', 'prairie'): 1,
#  ('bucket', 'chapter', 'prairie', 'chapter'): 1,
#  ('chapter', 'prairie', 'chapter', 'nut'): 1,
#  ('prairie', 'chapter', 'nut', 'chapter'): 1,
#  ('chapter', 'nut', 'chapter', 'pequod'): 1,
#  ('nut', 'chapter', 'pequod', 'meet'): 1,
#  ('pequod', 'meet', 'virgin', 'chapter'): 1,
#  ('meet', 'virgin', 'chapter', 'honor'): 1,
#  ('virgin', 'chapter', 'honor', 'glory'): 1,
#  ('honor', 'glory', 'whale', 'chapter'): 1,
#  ('glory', 'whale', 'chapter', 'jonah'): 1,
#  ('whale', 'chapter', 'jonah', 'historically'): 1,
#  ('jonah', 'historically', 'regard', 'chapter'): 1,
#  ('historically', 'regard', 'chapter', 'pitchpole'): 1,
#  ('regard', 'chapter', 'pitchpole', 'chapter'): 1,
#  ('chapter', 'pitchpole', 'chapter', 'fountain'): 1,
#  ('pitchpole', 'chapter', 'fountain', 'chapter'): 1,
#  ('chapter', 'fountain', 'chapter', 'tail'): 1,
#  ('fountain', 'chapter', 'tail', 'chapter'): 1,
#  ('chapter', 'tail', 'chapter', 'grand'): 1,
#  ('tail', 'chapter', 'grand', 'armada'): 1,
#  ('chapter', 'grand', 'armada', 'chapter'): 1,
#  ('grand', 'armada', 'chapter', 'school'): 1,
#  ('armada', 'chapter', 'school', 'schoolmaster'): 1,
#  ('chapter', 'school', 'schoolmaster', 'chapter'): 1,
#  ('school', 'schoolmaster', 'chapter', 'fastfish'): 1,
#  ('schoolmaster', 'chapter', 'fastfish', 'loosefish'): 1,
#  ('chapter', 'fastfish', 'loosefish', 'chapter'): 1,
#  ('fastfish', 'loosefish', 'chapter', 'head'): 1,
#  ('loosefish', 'chapter', 'head', 'tail'): 1,
#  ('chapter', 'head', 'tail', 'chapter'): 1,
#  ('head', 'tail', 'chapter', 'pequod'): 1,
#  ('tail', 'chapter', 'pequod', 'meet'): 1,
#  ('pequod', 'meet', 'rosebud', 'chapter'): 1,
#  ('meet', 'rosebud', 'chapter', 'ambergri'): 1,
#  ('rosebud', 'chapter', 'ambergri', 'chapter'): 1,
#  ('chapter', 'ambergri', 'chapter', 'castaway'): 1,
#  ('ambergri', 'chapter', 'castaway', 'chapter'): 1,
#  ('chapter', 'castaway', 'chapter', 'squeeze'): 1,
#  ('castaway', 'chapter', 'squeeze', 'hand'): 1,
#  ('chapter', 'squeeze', 'hand', 'chapter'): 1,
#  ('squeeze', 'hand', 'chapter', 'cassock'): 1,
#  ('hand', 'chapter', 'cassock', 'chapter'): 1,
#  ('chapter', 'cassock', 'chapter', 'trywork'): 1,
#  ('cassock', 'chapter', 'trywork', 'chapter'): 1,
#  ('chapter', 'trywork', 'chapter', 'lamp'): 1,
#  ('trywork', 'chapter', 'lamp', 'chapter'): 1,
#  ('chapter', 'lamp', 'chapter', 'stow'): 1,
#  ('lamp', 'chapter', 'stow', 'clear'): 1,
#  ('chapter', 'stow', 'clear', 'chapter'): 1,
#  ('stow', 'clear', 'chapter', 'doubloon'): 1,
#  ('clear', 'chapter', 'doubloon', 'chapter'): 1,
#  ('chapter', 'doubloon', 'chapter', 'leg'): 1,
#  ('doubloon', 'chapter', 'leg', 'arm'): 1,
#  ('chapter', 'leg', 'arm', 'chapter'): 1,
#  ('leg', 'arm', 'chapter', 'decanter'): 1,
#  ('arm', 'chapter', 'decanter', 'chapter'): 1,
#  ('chapter', 'decanter', 'chapter', 'bower'): 1,
#  ('decanter', 'chapter', 'bower', 'arsacide'): 1,
#  ('chapter', 'bower', 'arsacide', 'chapter'): 1,
#  ('bower', 'arsacide', 'chapter', 'measurement'): 1,
#  ('arsacide', 'chapter', 'measurement', 'whale'): 1,
#  ('chapter', 'measurement', 'whale', 'skeleton'): 1,
#  ('measurement', 'whale', 'skeleton', 'chapter'): 1,
#  ('whale', 'skeleton', 'chapter', 'fossil'): 1,
#  ('skeleton', 'chapter', 'fossil', 'whale'): 1,
#  ('chapter', 'fossil', 'whale', 'chapter'): 1,
#  ('fossil', 'whale', 'chapter', 'whale'): 1,
#  ('whale', 'chapter', 'whale', 'magnitude'): 1,
#  ('chapter', 'whale', 'magnitude', 'diminishwill'): 1,
#  ('whale', 'magnitude', 'diminishwill', 'perish'): 1,
#  ('magnitude', 'diminishwill', 'perish', 'chapter'): 1,
#  ('diminishwill', 'perish', 'chapter', 'ahab'): 1,
#  ('perish', 'chapter', 'ahab', 'leg'): 1,
#  ('chapter', 'ahab', 'leg', 'chapter'): 1,
#  ('ahab', 'leg', 'chapter', 'carpenter'): 1,
#  ('leg', 'chapter', 'carpenter', 'chapter'): 1,
#  ('chapter', 'carpenter', 'chapter', 'ahab'): 1,
#  ('carpenter', 'chapter', 'ahab', 'carpenter'): 1,
#  ('chapter', 'ahab', 'carpenter', 'chapter'): 1,
#  ('ahab', 'carpenter', 'chapter', 'ahab'): 1,
#  ('carpenter', 'chapter', 'ahab', 'starbuck'): 1,
#  ('chapter', 'ahab', 'starbuck', 'cabin'): 1,
#  ('ahab', 'starbuck', 'cabin', 'chapter'): 1,
#  ('starbuck', 'cabin', 'chapter', 'queequeg'): 1,
#  ('cabin', 'chapter', 'queequeg', 'hi'): 1,
#  ('chapter', 'queequeg', 'hi', 'coffin'): 1,
#  ('queequeg', 'hi', 'coffin', 'chapter'): 1,
#  ('hi', 'coffin', 'chapter', 'pacific'): 1,
#  ('coffin', 'chapter', 'pacific', 'chapter'): 1,
#  ('chapter', 'pacific', 'chapter', 'blacksmith'): 1,
#  ('pacific', 'chapter', 'blacksmith', 'chapter'): 1,
#  ('chapter', 'blacksmith', 'chapter', 'forge'): 1,
#  ('blacksmith', 'chapter', 'forge', 'chapter'): 1,
#  ('chapter', 'forge', 'chapter', 'gilder'): 1,
#  ('forge', 'chapter', 'gilder', 'chapter'): 1,
#  ('chapter', 'gilder', 'chapter', 'pequod'): 1,
#  ('gilder', 'chapter', 'pequod', 'meet'): 1,
#  ('chapter', 'pequod', 'meet', 'bachelor'): 1,
#  ('pequod', 'meet', 'bachelor', 'chapter'): 1,
#  ('meet', 'bachelor', 'chapter', 'die'): 1,
#  ('bachelor', 'chapter', 'die', 'whale'): 1,
#  ('chapter', 'die', 'whale', 'chapter'): 1,
#  ('die', 'whale', 'chapter', 'whale'): 1,
#  ('whale', 'chapter', 'whale', 'watch'): 1,
#  ('chapter', 'whale', 'watch', 'chapter'): 1,
#  ('whale', 'watch', 'chapter', 'quadrant'): 1,
#  ('watch', 'chapter', 'quadrant', 'chapter'): 1,
#  ('chapter', 'quadrant', 'chapter', 'candle'): 1,
#  ('quadrant', 'chapter', 'candle', 'chapter'): 1,
#  ('chapter', 'candle', 'chapter', 'deck'): 1,
#  ('candle', 'chapter', 'deck', 'toward'): 1,
#  ('chapter', 'deck', 'toward', 'end'): 1,
#  ('deck', 'toward', 'end', 'first'): 1,
#  ('toward', 'end', 'first', 'night'): 1,
#  ('end', 'first', 'night', 'watch'): 1,
#  ('first', 'night', 'watch', 'chapter'): 1,
#  ('night', 'watch', 'chapter', 'midnight.the'): 1,
#  ('watch', 'chapter', 'midnight.the', 'forecastle'): 1,
#  ('chapter', 'midnight.the', 'forecastle', 'bulwark'): 1,
#  ('midnight.the', 'forecastle', 'bulwark', 'chapter'): 1,
#  ('forecastle', 'bulwark', 'chapter', 'midnight'): 1,
#  ('bulwark', 'chapter', 'midnight', 'aloft.thunder'): 1,
#  ('chapter', 'midnight', 'aloft.thunder', 'lightn'): 1,
#  ('midnight', 'aloft.thunder', 'lightn', 'chapter'): 1,
#  ('aloft.thunder', 'lightn', 'chapter', 'musket'): 1,
#  ('lightn', 'chapter', 'musket', 'chapter'): 1,
#  ('chapter', 'musket', 'chapter', 'needle'): 1,
#  ('musket', 'chapter', 'needle', 'chapter'): 1,
#  ('chapter', 'needle', 'chapter', 'log'): 1,
#  ('needle', 'chapter', 'log', 'line'): 1,
#  ('chapter', 'log', 'line', 'chapter'): 1,
#  ('log', 'line', 'chapter', 'lifebuoy'): 1,
#  ('line', 'chapter', 'lifebuoy', 'chapter'): 1,
#  ('chapter', 'lifebuoy', 'chapter', 'deck'): 1,
#  ('lifebuoy', 'chapter', 'deck', 'chapter'): 1,
#  ('chapter', 'deck', 'chapter', 'pequod'): 1,
#  ('deck', 'chapter', 'pequod', 'meet'): 1,
#  ('chapter', 'pequod', 'meet', 'rachel'): 1,
#  ('pequod', 'meet', 'rachel', 'chapter'): 1,
#  ('meet', 'rachel', 'chapter', 'cabin'): 1,
#  ('rachel', 'chapter', 'cabin', 'chapter'): 1,
#  ('chapter', 'cabin', 'chapter', 'hat'): 1,
#  ('cabin', 'chapter', 'hat', 'chapter'): 1,
#  ('chapter', 'hat', 'chapter', 'pequod'): 1,
#  ('hat', 'chapter', 'pequod', 'meet'): 1,
#  ('chapter', 'pequod', 'meet', 'delight'): 1,
#  ('pequod', 'meet', 'delight', 'chapter'): 1,
#  ('meet', 'delight', 'chapter', 'symphony'): 1,
#  ('delight', 'chapter', 'symphony', 'chapter'): 1,
#  ('chapter', 'symphony', 'chapter', 'chasefirst'): 1,
#  ('symphony', 'chapter', 'chasefirst', 'day'): 1,
#  ('chapter', 'chasefirst', 'day', 'chapter'): 1,
#  ('chasefirst', 'day', 'chapter', 'chasesecond'): 1,
#  ('day', 'chapter', 'chasesecond', 'day'): 1,
#  ('chapter', 'chasesecond', 'day', 'chapter'): 1,
#  ('chasesecond', 'day', 'chapter', 'chase.third'): 1,
#  ('day', 'chapter', 'chase.third', 'day'): 1,
#  ('chapter', 'chase.third', 'day', 'epilogue'): 1,
#  ('chase.third', 'day', 'epilogue', 'original'): 1,
#  ('day', 'epilogue', 'original', 'UNK'): 1,
#  ('epilogue', 'original', 'UNK', 'note'): 1,
#  ('original', 'UNK', 'note', 'thi'): 1,
#  ('UNK', 'note', 'thi', 'text'): 1,
#  ('note', 'thi', 'text', 'combination'): 1,
#  ('thi', 'text', 'combination', 'etext'): 1,
#  ('text', 'combination', 'etext', 'one'): 1,
#  ('combination', 'etext', 'one', 'UNK'): 1,
#  ('etext', 'one', 'UNK', 'UNK'): 1,
#  ('one', 'UNK', 'UNK', 'project'): 1,
#  ('UNK', 'UNK', 'project', 'virginia'): 1,
#  ('UNK', 'project', 'virginia', 'tech'): 1,
#  ('project', 'virginia', 'tech', 'one'): 1,
#  ('virginia', 'tech', 'one', 'project'): 1,
#  ('tech', 'one', 'project', 'gutenberg'): 1,
#  ('one', 'project', 'gutenberg', 'archive'): 1,
#  ('project', 'gutenberg', 'archive', 'UNK'): 1,
#  ('gutenberg', 'archive', 'UNK', 'thi'): 1,
#  ('archive', 'UNK', 'thi', 'version'): 1,
#  ('UNK', 'thi', 'version', 'indebt'): 1,
#  ('thi', 'version', 'indebt', 'UNK'): 1,
#  ('version', 'indebt', 'UNK', 'UNK'): 1,
#  ('indebt', 'UNK', 'UNK', 'library'): 1,
#  ('UNK', 'UNK', 'library', 'preserve'): 1,
#  ('UNK', 'library', 'preserve', 'virginia'): 1,
#  ('library', 'preserve', 'virginia', 'tech'): 1,
#  ('preserve', 'virginia', 'tech', 'version'): 1,
#  ('virginia', 'tech', 'version', 'result'): 1,
#  ('tech', 'version', 'result', 'etext'): 1,
#  ('version', 'result', 'etext', 'compare'): 1,
#  ('result', 'etext', 'compare', 'public'): 1,
#  ('etext', 'compare', 'public', 'domain'): 1,
#  ('compare', 'public', 'domain', 'hard'): 1,
#  ('public', 'domain', 'hard', 'copy'): 1,
#  ('domain', 'hard', 'copy', 'version'): 1,
#  ('hard', 'copy', 'version', 'text'): 1,
#  ('copy', 'version', 'text', 'etymology'): 1,
#  ('version', 'text', 'etymology', 'supply'): 1,
#  ('text', 'etymology', 'supply', 'late'): 1,
#  ('etymology', 'supply', 'late', 'UNK'): 1,
#  ('supply', 'late', 'UNK', 'usher'): 1,
#  ('late', 'UNK', 'usher', 'grammar'): 1,
#  ('UNK', 'usher', 'grammar', 'school'): 1,
#  ('usher', 'grammar', 'school', 'pale'): 1,
#  ('grammar', 'school', 'pale', 'UNK'): 1,
#  ('school', 'pale', 'UNK', 'coat'): 1,
#  ('pale', 'UNK', 'coat', 'heart'): 1,
#  ('UNK', 'coat', 'heart', 'body'): 1,
#  ('coat', 'heart', 'body', 'brain'): 1,
#  ('heart', 'body', 'brain', 'see'): 1,
#  ('body', 'brain', 'see', 'ever'): 1,
#  ('brain', 'see', 'ever', 'dust'): 1,
#  ('see', 'ever', 'dust', 'hi'): 1,
#  ('ever', 'dust', 'hi', 'old'): 1,
#  ('dust', 'hi', 'old', 'lexicon'): 1,
#  ('hi', 'old', 'lexicon', 'grammar'): 1,
#  ('old', 'lexicon', 'grammar', 'queer'): 1,
#  ('lexicon', 'grammar', 'queer', 'handkerchief'): 1,
#  ('grammar', 'queer', 'handkerchief', 'UNK'): 1,
#  ('queer', 'handkerchief', 'UNK', 'embellish'): 1,
#  ('handkerchief', 'UNK', 'embellish', 'gay'): 1,
#  ('UNK', 'embellish', 'gay', 'flag'): 1,
#  ('embellish', 'gay', 'flag', 'know'): 1,
#  ('gay', 'flag', 'know', 'nation'): 1,
#  ('flag', 'know', 'nation', 'world'): 1,
#  ('know', 'nation', 'world', 'love'): 1,
#  ('nation', 'world', 'love', 'dust'): 1,
#  ('world', 'love', 'dust', 'hi'): 1,
#  ('love', 'dust', 'hi', 'old'): 1,
#  ('dust', 'hi', 'old', 'grammar'): 1,
#  ('hi', 'old', 'grammar', 'somehow'): 1,
#  ('old', 'grammar', 'somehow', 'mildly'): 1,
#  ('grammar', 'somehow', 'mildly', 'remind'): 1,
#  ('somehow', 'mildly', 'remind', 'hi'): 1,
#  ('mildly', 'remind', 'hi', 'mortality'): 1,
#  ('remind', 'hi', 'mortality', 'take'): 1,
#  ('hi', 'mortality', 'take', 'hand'): 1,
#  ('mortality', 'take', 'hand', 'school'): 1,
#  ('take', 'hand', 'school', 'teach'): 1,
#  ('hand', 'school', 'teach', 'name'): 1,
#  ('school', 'teach', 'name', 'UNK'): 1,
#  ('teach', 'name', 'UNK', 'call'): 1,
#  ('name', 'UNK', 'call', 'tongue'): 1,
#  ('UNK', 'call', 'tongue', 'leave'): 1,
#  ('call', 'tongue', 'leave', 'ignorance'): 1,
#  ('tongue', 'leave', 'ignorance', 'letter'): 1,
#  ('leave', 'ignorance', 'letter', 'UNK'): 1,
#  ('ignorance', 'letter', 'UNK', 'almost'): 1,
#  ('letter', 'UNK', 'almost', 'alone'): 1,
#  ('UNK', 'almost', 'alone', 'maketh'): 1,
#  ('almost', 'alone', 'maketh', 'UNK'): 1,
#  ('alone', 'maketh', 'UNK', 'word'): 1,
#  ('maketh', 'UNK', 'word', 'deliver'): 1,
#  ('UNK', 'word', 'deliver', 'true'): 1,
#  ('word', 'deliver', 'true', 'hackluyt'): 1,
#  ('deliver', 'true', 'hackluyt', 'whale'): 1,
#  ('true', 'hackluyt', 'whale', 'UNK'): 1,
#  ('hackluyt', 'whale', 'UNK', 'dan'): 1,
#  ('whale', 'UNK', 'dan', 'UNK'): 1,
#  ('UNK', 'dan', 'UNK', 'thi'): 1,
#  ('dan', 'UNK', 'thi', 'animal'): 1,
#  ('UNK', 'thi', 'animal', 'name'): 1,
#  ('thi', 'animal', 'name', 'UNK'): 1,
#  ('animal', 'name', 'UNK', 'roll'): 1,
#  ('name', 'UNK', 'roll', 'dan'): 1,
#  ('UNK', 'roll', 'dan', 'hvalt'): 1,
#  ('roll', 'dan', 'hvalt', 'arch'): 1,
#  ('dan', 'hvalt', 'arch', 'vault'): 1,
#  ('hvalt', 'arch', 'vault', 'webster'): 1,
#  ('arch', 'vault', 'webster', 'dictionary'): 1,
#  ('vault', 'webster', 'dictionary', 'whale'): 1,
#  ('webster', 'dictionary', 'whale', 'immediately'): 1,
#  ('dictionary', 'whale', 'immediately', 'UNK'): 1,
#  ('whale', 'immediately', 'UNK', 'UNK'): 1,
#  ('immediately', 'UNK', 'UNK', 'UNK'): 1,
#  ('UNK', 'UNK', 'UNK', 'roll'): 1,
#  ('UNK', 'UNK', 'roll', 'wallow'): 1,
#  ('UNK', 'roll', 'wallow', 'UNK'): 1,
#  ('roll', 'wallow', 'UNK', 'dictionary'): 1,
#  ('wallow', 'UNK', 'dictionary', 'hebrew'): 1,
#  ('UNK', 'dictionary', 'hebrew', 'greek'): 1,
#  ('dictionary', 'hebrew', 'greek', 'cetu'): 1,
#  ('hebrew', 'greek', 'cetu', 'latin'): 1,
#  ('greek', 'cetu', 'latin', 'UNK'): 1,
#  ('cetu', 'latin', 'UNK', 'UNK'): 1,
#  ('latin', 'UNK', 'UNK', 'hvalt'): 1,
#  ('UNK', 'UNK', 'hvalt', 'danish'): 1,
#  ('UNK', 'hvalt', 'danish', 'UNK'): 1,
#  ('hvalt', 'danish', 'UNK', 'dutch'): 1,
#  ('danish', 'UNK', 'dutch', 'UNK'): 1,
#  ('UNK', 'dutch', 'UNK', 'UNK'): 1,
#  ('dutch', 'UNK', 'UNK', 'whale'): 1,
#  ('UNK', 'UNK', 'whale', 'icelandic'): 1,
#  ('UNK', 'whale', 'icelandic', 'whale'): 1,
#  ('whale', 'icelandic', 'whale', 'english'): 1,
#  ('icelandic', 'whale', 'english', 'baleine'): 1,
#  ('whale', 'english', 'baleine', 'french'): 1,
#  ('english', 'baleine', 'french', 'UNK'): 1,
#  ('baleine', 'french', 'UNK', 'spanish'): 1,
#  ('french', 'UNK', 'spanish', 'UNK'): 1,
#  ('UNK', 'spanish', 'UNK', 'UNK'): 1,
#  ('spanish', 'UNK', 'UNK', 'UNK'): 1,
#  ('UNK', 'UNK', 'UNK', 'extract'): 1,
#  ('UNK', 'UNK', 'extract', 'supply'): 1,
#  ('UNK', 'extract', 'supply', 'subsublibrarian'): 1,
#  ('extract', 'supply', 'subsublibrarian', 'see'): 1,
#  ('supply', 'subsublibrarian', 'see', 'thi'): 1,
#  ('subsublibrarian', 'see', 'thi', 'mere'): 1,
#  ('see', 'thi', 'mere', 'UNK'): 1,
#  ('thi', 'mere', 'UNK', 'UNK'): 1,
#  ('mere', 'UNK', 'UNK', 'UNK'): 1,
#  ('UNK', 'UNK', 'UNK', 'poor'): 1,
#  ('UNK', 'UNK', 'poor', 'devil'): 1,
#  ('UNK', 'poor', 'devil', 'subsub'): 1,
#  ('poor', 'devil', 'subsub', 'appear'): 1,
#  ('devil', 'subsub', 'appear', 'go'): 1,
#  ('subsub', 'appear', 'go', 'long'): 1,
#  ('appear', 'go', 'long', 'UNK'): 1,
#  ('go', 'long', 'UNK', 'UNK'): 1,
#  ('long', 'UNK', 'UNK', 'earth'): 1,
#  ('UNK', 'UNK', 'earth', 'pick'): 1,
#  ('UNK', 'earth', 'pick', 'whatever'): 1,
#  ('earth', 'pick', 'whatever', 'random'): 1,
#  ('pick', 'whatever', 'random', 'allusion'): 1,
#  ('whatever', 'random', 'allusion', 'whale'): 1,
#  ('random', 'allusion', 'whale', 'anyway'): 1,
#  ('allusion', 'whale', 'anyway', 'find'): 1,
#  ('whale', 'anyway', 'find', 'book'): 1,
#  ('anyway', 'find', 'book', 'whatsoever'): 1,
#  ('find', 'book', 'whatsoever', 'sacre'): 1,
#  ('book', 'whatsoever', 'sacre', 'profane'): 1,
#  ('whatsoever', 'sacre', 'profane', 'therefore'): 1,
#  ('sacre', 'profane', 'therefore', 'must'): 1,
#  ('profane', 'therefore', 'must', 'every'): 1,
#  ('therefore', 'must', 'every', 'case'): 1,
#  ('must', 'every', 'case', 'least'): 1,
#  ('every', 'case', 'least', 'take'): 1,
#  ('case', 'least', 'take', 'UNK'): 1,
#  ('least', 'take', 'UNK', 'whale'): 1,
#  ('take', 'UNK', 'whale', 'statement'): 1,
#  ('UNK', 'whale', 'statement', 'however'): 1,
#  ('whale', 'statement', 'however', 'authentic'): 1,
#  ('statement', 'however', 'authentic', 'extract'): 1,
#  ('however', 'authentic', 'extract', 'veritable'): 1,
#  ('authentic', 'extract', 'veritable', 'gospel'): 1,
#  ('extract', 'veritable', 'gospel', 'cetology'): 1,
#  ('veritable', 'gospel', 'cetology', 'far'): 1,
#  ('gospel', 'cetology', 'far', 'touch'): 1,
#  ('cetology', 'far', 'touch', 'ancient'): 1,
#  ('far', 'touch', 'ancient', 'author'): 1,
#  ('touch', 'ancient', 'author', 'generally'): 1,
#  ('ancient', 'author', 'generally', 'well'): 1,
#  ('author', 'generally', 'well', 'poet'): 1,
#  ('generally', 'well', 'poet', 'appear'): 1,
#  ('well', 'poet', 'appear', 'extract'): 1,
#  ('poet', 'appear', 'extract', 'solely'): 1,
#  ('appear', 'extract', 'solely', 'valuable'): 1,
#  ('extract', 'solely', 'valuable', 'entertain'): 1,
#  ('solely', 'valuable', 'entertain', 'afford'): 1,
#  ('valuable', 'entertain', 'afford', 'glance'): 1,
#  ('entertain', 'afford', 'glance', 'bird'): 1,
#  ('afford', 'glance', 'bird', 'eye'): 1,
#  ('glance', 'bird', 'eye', 'view'): 1,
#  ('bird', 'eye', 'view', 'UNK'): 1,
#  ('eye', 'view', 'UNK', 'say'): 1,
#  ('view', 'UNK', 'say', 'think'): 1,
#  ('UNK', 'say', 'think', 'fancy'): 1,
#  ('say', 'think', 'fancy', 'sing'): 1,
#  ('think', 'fancy', 'sing', 'leviathan'): 1,
#  ('fancy', 'sing', 'leviathan', 'many'): 1,
#  ('sing', 'leviathan', 'many', 'nation'): 1,
#  ('leviathan', 'many', 'nation', 'generation'): 1,
#  ('many', 'nation', 'generation', 'include'): 1,
#  ('nation', 'generation', 'include', 'fare'): 1,
#  ('generation', 'include', 'fare', 'thee'): 1,
#  ('include', 'fare', 'thee', 'well'): 1,
#  ('fare', 'thee', 'well', 'poor'): 1,
#  ('thee', 'well', 'poor', 'devil'): 1,
#  ('well', 'poor', 'devil', 'subsub'): 1,
#  ('poor', 'devil', 'subsub', 'whose'): 1,
#  ('devil', 'subsub', 'whose', 'commentator'): 1,
#  ('subsub', 'whose', 'commentator', 'thou'): 1,
#  ('whose', 'commentator', 'thou', 'UNK'): 1,
#  ('commentator', 'thou', 'UNK', 'hopeles'): 1,
#  ('thou', 'UNK', 'hopeles', 'UNK'): 1,
#  ('UNK', 'hopeles', 'UNK', 'tribe'): 1,
#  ('hopeles', 'UNK', 'tribe', 'wine'): 1,
#  ('UNK', 'tribe', 'wine', 'thi'): 1,
#  ('tribe', 'wine', 'thi', 'world'): 1,
#  ('wine', 'thi', 'world', 'ever'): 1,
#  ('thi', 'world', 'ever', 'warm'): 1,
#  ('world', 'ever', 'warm', 'even'): 1,
#  ('ever', 'warm', 'even', 'pale'): 1,
#  ('warm', 'even', 'pale', 'UNK'): 1,
#  ('even', 'pale', 'UNK', 'would'): 1,
#  ('pale', 'UNK', 'would', 'UNK'): 1,
#  ('UNK', 'would', 'UNK', 'one'): 1,
#  ('would', 'UNK', 'one', 'sometime'): 1,
#  ('UNK', 'one', 'sometime', 'love'): 1,
#  ('one', 'sometime', 'love', 'sit'): 1,
#  ('sometime', 'love', 'sit', 'feel'): 1,
#  ('love', 'sit', 'feel', 'UNK'): 1,
#  ('sit', 'feel', 'UNK', 'grow'): 1,
#  ('feel', 'UNK', 'grow', 'convivial'): 1,
#  ('UNK', 'grow', 'convivial', 'upon'): 1,
#  ('grow', 'convivial', 'upon', 'tear'): 1,
#  ('convivial', 'upon', 'tear', 'say'): 1,
#  ('upon', 'tear', 'say', 'UNK'): 1,
#  ('tear', 'say', 'UNK', 'full'): 1,
#  ('say', 'UNK', 'full', 'eye'): 1,
#  ('UNK', 'full', 'eye', 'empty'): 1,
#  ('full', 'eye', 'empty', 'glass'): 1,
#  ('eye', 'empty', 'glass', 'altogether'): 1,
#  ('empty', 'glass', 'altogether', 'unpleasant'): 1,
#  ('glass', 'altogether', 'unpleasant', 'UNK'): 1,
#  ('altogether', 'unpleasant', 'UNK', 'subsub'): 1,
#  ('unpleasant', 'UNK', 'subsub', 'much'): 1,
#  ('UNK', 'subsub', 'much', 'pain'): 1,
#  ('subsub', 'much', 'pain', 'ye'): 1,
#  ('much', 'pain', 'ye', 'take'): 1,
#  ('pain', 'ye', 'take', 'please'): 1,
#  ('ye', 'take', 'please', 'world'): 1,
#  ('take', 'please', 'world', 'much'): 1,
#  ('please', 'world', 'much', 'shall'): 1,
#  ('world', 'much', 'shall', 'ye'): 1,
#  ('much', 'shall', 'ye', 'ever'): 1,
#  ('shall', 'ye', 'ever', 'go'): 1,
#  ('ye', 'ever', 'go', 'UNK'): 1,
#  ('ever', 'go', 'UNK', 'would'): 1,
#  ('go', 'UNK', 'would', 'clear'): 1,
#  ('UNK', 'would', 'clear', 'UNK'): 1,
#  ('would', 'clear', 'UNK', 'court'): 1,
#  ('clear', 'UNK', 'court', 'tuilery'): 1,
#  ('UNK', 'court', 'tuilery', 'ye'): 1,
#  ('court', 'tuilery', 'ye', 'gulp'): 1,
#  ('tuilery', 'ye', 'gulp', 'tear'): 1,
#  ('ye', 'gulp', 'tear', 'hie'): 1,
#  ('gulp', 'tear', 'hie', 'aloft'): 1,
#  ('tear', 'hie', 'aloft', 'royalmast'): 1,
#  ('hie', 'aloft', 'royalmast', 'heart'): 1,
#  ('aloft', 'royalmast', 'heart', 'friend'): 1,
#  ('royalmast', 'heart', 'friend', 'go'): 1,
#  ('heart', 'friend', 'go', 'clear'): 1,
#  ('friend', 'go', 'clear', 'UNK'): 1,
#  ('go', 'clear', 'UNK', 'heaven'): 1,
#  ('clear', 'UNK', 'heaven', 'make'): 1,
#  ('UNK', 'heaven', 'make', 'UNK'): 1,
#  ('heaven', 'make', 'UNK', 'UNK'): 1,
#  ('make', 'UNK', 'UNK', 'gabriel'): 1,
#  ('UNK', 'UNK', 'gabriel', 'michael'): 1,
#  ('UNK', 'gabriel', 'michael', 'UNK'): 1,
#  ('gabriel', 'michael', 'UNK', 'come'): 1,
#  ('michael', 'UNK', 'come', 'ye'): 1,
#  ('UNK', 'come', 'ye', 'strike'): 1,
#  ('come', 'ye', 'strike', 'splinter'): 1,
#  ('ye', 'strike', 'splinter', 'heart'): 1,
#  ('strike', 'splinter', 'heart', 'UNK'): 1,
#  ('splinter', 'heart', 'UNK', 'ye'): 1,
#  ('heart', 'UNK', 'ye', 'shall'): 1,
#  ('UNK', 'ye', 'shall', 'strike'): 1,
#  ('ye', 'shall', 'strike', 'UNK'): 1,
#  ('shall', 'strike', 'UNK', 'glass'): 1,
#  ('strike', 'UNK', 'glass', 'extract'): 1,
#  ('UNK', 'glass', 'extract', 'god'): 1,
#  ('glass', 'extract', 'god', 'create'): 1,
#  ('extract', 'god', 'create', 'great'): 1,
#  ('god', 'create', 'great', 'whale'): 1,
#  ('create', 'great', 'whale', 'genesi'): 1,
#  ('great', 'whale', 'genesi', 'leviathan'): 1,
#  ('whale', 'genesi', 'leviathan', 'maketh'): 1,
#  ('genesi', 'leviathan', 'maketh', 'path'): 1,
#  ('leviathan', 'maketh', 'path', 'shine'): 1,
#  ('maketh', 'path', 'shine', 'one'): 1,
#  ('path', 'shine', 'one', 'would'): 1,
#  ('shine', 'one', 'would', 'think'): 1,
#  ('one', 'would', 'think', 'deep'): 1,
#  ('would', 'think', 'deep', 'hoary'): 1,
#  ('think', 'deep', 'hoary', 'job'): 1,
#  ('deep', 'hoary', 'job', 'lord'): 1,
#  ('hoary', 'job', 'lord', 'prepare'): 1,
#  ('job', 'lord', 'prepare', 'great'): 1,
#  ('lord', 'prepare', 'great', 'fish'): 1,
#  ('fish', 'swallow', 'jonah', 'jonah'): 1,
#  ('swallow', 'jonah', 'jonah', 'go'): 1,
#  ('jonah', 'jonah', 'go', 'ship'): 1,
#  ('jonah', 'go', 'ship', 'leviathan'): 1,
#  ('go', 'ship', 'leviathan', 'thou'): 1,
#  ('ship', 'leviathan', 'thou', 'hast'): 1,
#  ('leviathan', 'thou', 'hast', 'make'): 1,
#  ('thou', 'hast', 'make', 'play'): 1,
#  ('hast', 'make', 'play', 'therein'): 1,
#  ('make', 'play', 'therein', 'psalm'): 1,
#  ('play', 'therein', 'psalm', 'day'): 1,
#  ('therein', 'psalm', 'day', 'lord'): 1,
#  ('psalm', 'day', 'lord', 'hi'): 1,
#  ('day', 'lord', 'hi', 'sore'): 1,
#  ('lord', 'hi', 'sore', 'great'): 1,
#  ('hi', 'sore', 'great', 'strong'): 1,
#  ('sore', 'great', 'strong', 'sword'): 1,
#  ('great', 'strong', 'sword', 'shall'): 1,
#  ('strong', 'sword', 'shall', 'UNK'): 1,
#  ('sword', 'shall', 'UNK', 'leviathan'): 1,
#  ('shall', 'UNK', 'leviathan', 'pierce'): 1,
#  ('UNK', 'leviathan', 'pierce', 'serpent'): 1,
#  ('leviathan', 'pierce', 'serpent', 'even'): 1,
#  ('pierce', 'serpent', 'even', 'leviathan'): 1,
#  ('serpent', 'even', 'leviathan', 'crook'): 1,
#  ('even', 'leviathan', 'crook', 'serpent'): 1,
#  ('leviathan', 'crook', 'serpent', 'shall'): 1,
#  ('crook', 'serpent', 'shall', 'slay'): 1,
#  ('serpent', 'shall', 'slay', 'dragon'): 1,
#  ('shall', 'slay', 'dragon', 'sea'): 1,
#  ('slay', 'dragon', 'sea', 'isaiah'): 1,
#  ('dragon', 'sea', 'isaiah', 'thing'): 1,
#  ('sea', 'isaiah', 'thing', 'UNK'): 1,
#  ('isaiah', 'thing', 'UNK', 'beside'): 1,
#  ('thing', 'UNK', 'beside', 'UNK'): 1,
#  ('UNK', 'beside', 'UNK', 'within'): 1,
#  ('beside', 'UNK', 'within', 'chao'): 1,
#  ('UNK', 'within', 'chao', 'thi'): 1,
#  ('within', 'chao', 'thi', 'monster'): 1,
#  ('chao', 'thi', 'monster', 'mouth'): 1,
#  ('thi', 'monster', 'mouth', 'beast'): 1,
#  ('monster', 'mouth', 'beast', 'boat'): 1,
#  ('mouth', 'beast', 'boat', 'stone'): 1,
#  ('beast', 'boat', 'stone', 'go'): 1,
#  ('boat', 'stone', 'go', 'UNK'): 1,
#  ('stone', 'go', 'UNK', 'foul'): 1,
#  ('go', 'UNK', 'foul', 'great'): 1,
#  ('UNK', 'foul', 'great', 'swallow'): 1,
#  ('foul', 'great', 'swallow', 'hi'): 1,
#  ('great', 'swallow', 'hi', 'UNK'): 1,
#  ('swallow', 'hi', 'UNK', 'bottomles'): 1,
#  ('hi', 'UNK', 'bottomles', 'gulf'): 1,
#  ('UNK', 'bottomles', 'gulf', 'hi'): 1,
#  ('bottomles', 'gulf', 'hi', 'paunch'): 1,
#  ('gulf', 'hi', 'paunch', 'holland'): 1,
#  ('hi', 'paunch', 'holland', 'UNK'): 1,
#  ('paunch', 'holland', 'UNK', 'moral'): 1,
#  ('holland', 'UNK', 'moral', 'indian'): 1,
#  ('UNK', 'moral', 'indian', 'sea'): 1,
#  ('moral', 'indian', 'sea', 'UNK'): 1,
#  ('indian', 'sea', 'UNK', 'biggest'): 1,
#  ('sea', 'UNK', 'biggest', 'fishes'): 1,
#  ('UNK', 'biggest', 'fishes', 'among'): 1,
#  ('biggest', 'fishes', 'among', 'whale'): 1,
#  ('fishes', 'among', 'whale', 'UNK'): 1,
#  ('among', 'whale', 'UNK', 'call'): 1,
#  ('whale', 'UNK', 'call', 'UNK'): 1,
#  ('UNK', 'call', 'UNK', 'take'): 1,
#  ('call', 'UNK', 'take', 'much'): 1,
#  ('UNK', 'take', 'much', 'length'): 1,
#  ('take', 'much', 'length', 'four'): 1,
#  ('much', 'length', 'four', 'acre'): 1,
#  ('length', 'four', 'acre', 'UNK'): 1,
#  ('four', 'acre', 'UNK', 'land'): 1,
#  ('acre', 'UNK', 'land', 'holland'): 1,
#  ('UNK', 'land', 'holland', 'pliny'): 1,
#  ('land', 'holland', 'pliny', 'scarcely'): 1,
#  ('holland', 'pliny', 'scarcely', 'proceed'): 1,
#  ('pliny', 'scarcely', 'proceed', 'two'): 1,
#  ('scarcely', 'proceed', 'two', 'day'): 1,
#  ('proceed', 'two', 'day', 'sea'): 1,
#  ('two', 'day', 'sea', 'sunrise'): 1,
#  ('day', 'sea', 'sunrise', 'great'): 1,
#  ('sea', 'sunrise', 'great', 'many'): 1,
#  ('sunrise', 'great', 'many', 'whale'): 1,
#  ('great', 'many', 'whale', 'monster'): 1,
#  ('many', 'whale', 'monster', 'sea'): 1,
#  ('whale', 'monster', 'sea', 'appear'): 1,
#  ('monster', 'sea', 'appear', 'among'): 1,
#  ('sea', 'appear', 'among', 'former'): 1,
#  ('appear', 'among', 'former', 'one'): 1,
#  ('among', 'former', 'one', 'monstrou'): 1,
#  ('former', 'one', 'monstrou', 'size'): 1,
#  ('one', 'monstrou', 'size', '....'): 1,
#  ('monstrou', 'size', '....', 'thi'): 1,
#  ('size', '....', 'thi', 'come'): 1,
#  ('....', 'thi', 'come', 'toward'): 1,
#  ('thi', 'come', 'toward', 'u'): 1,
#  ('come', 'toward', 'u', 'openmouthe'): 1,
#  ('toward', 'u', 'openmouthe', 'raise'): 1,
#  ('u', 'openmouthe', 'raise', 'wave'): 1,
#  ('openmouthe', 'raise', 'wave', 'side'): 1,
#  ('raise', 'wave', 'side', 'beat'): 1,
#  ('wave', 'side', 'beat', 'sea'): 1,
#  ('side', 'beat', 'sea', 'foam'): 1,
#  ('beat', 'sea', 'foam', 'UNK'): 1,
#  ('sea', 'foam', 'UNK', 'UNK'): 1,
#  ('foam', 'UNK', 'UNK', 'true'): 1,
#  ('UNK', 'UNK', 'true', 'history'): 1,
#  ('UNK', 'true', 'history', 'visit'): 1,
#  ('true', 'history', 'visit', 'thi'): 1,
#  ('history', 'visit', 'thi', 'country'): 1,
#  ('visit', 'thi', 'country', 'also'): 1,
#  ('thi', 'country', 'also', 'view'): 1,
#  ('country', 'also', 'view', 'catch'): 1,
#  ('also', 'view', 'catch', 'UNK'): 1,
#  ('view', 'catch', 'UNK', 'bone'): 1,
#  ('catch', 'UNK', 'bone', 'great'): 1,
#  ('UNK', 'bone', 'great', 'value'): 1,
#  ('bone', 'great', 'value', 'teeth'): 1,
#  ('great', 'value', 'teeth', 'bring'): 1,
#  ('value', 'teeth', 'bring', 'king'): 1,
#  ('teeth', 'bring', 'king', '....'): 1,
#  ('bring', 'king', '....', 'best'): 1,
#  ('king', '....', 'best', 'whale'): 1,
#  ('....', 'best', 'whale', 'catch'): 1,
#  ('best', 'whale', 'catch', 'hi'): 1,
#  ('whale', 'catch', 'hi', 'country'): 1,
#  ('catch', 'hi', 'country', 'fortyeight'): 1,
#  ('hi', 'country', 'fortyeight', 'fifty'): 1,
#  ('country', 'fortyeight', 'fifty', 'yard'): 1,
#  ('fortyeight', 'fifty', 'yard', 'long'): 1,
#  ('fifty', 'yard', 'long', 'say'): 1,
#  ('yard', 'long', 'say', 'one'): 1,
#  ('long', 'say', 'one', 'six'): 1,
#  ('say', 'one', 'six', 'kill'): 1,
#  ('one', 'six', 'kill', 'sixty'): 1,
#  ('six', 'kill', 'sixty', 'two'): 1,
#  ...}

# %% [markdown]
# ### 3.1.2 Model:

# %%
# import random

# class NGramModelWithBackoff:
#     def __init__(self, uni_counts, bi_counts, tri_counts, four_counts):
#         self.uni_counts = uni_counts
#         self.bi_counts = bi_counts
#         self.tri_counts = tri_counts
#         self.four_counts = four_counts
#         self.total_count = sum(uni_counts.values())
#         self.vocab_size = len(uni_counts)

#     def _get_probability(self, ngram):
#         if len(ngram) == 1:
#             return self.uni_counts.get(ngram[0], 0) / self.total_count
#         elif len(ngram) == 2:
#             return self.bi_counts.get(ngram, 0) / self.uni_counts.get(ngram[0], 1)
#         elif len(ngram) == 3:
#             return self.tri_counts.get(ngram, 0) / self.bi_counts.get(ngram[:2], 1)
#         elif len(ngram) == 4:
#             return self.four_counts.get(ngram, 0) / self.tri_counts.get(ngram[:3], 1)
#         else:
#             return 0

#     def generate_text(self, length):
#         generated_text = []
#         start_word = random.choice(list(self.uni_counts.keys()))
#         generated_text.append(start_word)

#         for i in range(length-1):
#             current_word = generated_text[-1]
#             if len(generated_text) >= 4 and (generated_text[-4], generated_text[-3], generated_text[-2], current_word) in self.four_counts:
#                 ngram = (generated_text[-4], generated_text[-3], generated_text[-2], current_word)
#             elif len(generated_text) >= 3 and (generated_text[-3], generated_text[-2], current_word) in self.tri_counts:
#                 ngram = (generated_text[-3], generated_text[-2], current_word)
#             elif len(generated_text) >= 2 and (generated_text[-2], current_word) in self.bi_counts:
#                 ngram = (generated_text[-2], current_word)
#             else:
#                 ngram = (current_word,)

#             next_word = self._sample_next_word(ngram)
#             generated_text.append(next_word)

#         return ' '.join(generated_text)

#     def _sample_next_word(self, ngram):
#         next_word_probs = {}
#         for word in self.uni_counts.keys():
#             next_ngram = ngram + (word,)
#             next_word_probs[word] = self._get_probability(next_ngram)
#         return random.choices(list(next_word_probs.keys()), list(next_word_probs.values()))[0]

# # Example usage:
# uni_counts = {'This': 1, 'is': 2, 'a': 1, 'sample': 1, 'text': 1, 'for': 1, 'building': 1, '4-gram': 1, 'model': 1, 'with': 1, 'back-off.': 1}
# bi_counts = {('This', 'is'): 1, ('is', 'a'): 1, ('a', 'sample'): 1, ('sample', 'text'): 1, ('text', 'for'): 1, ('for', 'building'): 1, ('building', 'a'): 1, ('a', '4-gram'): 1, ('4-gram', 'model'): 1, ('model', 'with'): 1, ('with', 'back-off.'): 1}
# tri_counts = {('This', 'is', 'a'): 1, ('is', 'a', 'sample'): 1, ('a', 'sample', 'text'): 1, ('sample', 'text', 'for'): 1, ('text', 'for', 'building'): 1, ('for', 'building', 'a'): 1, ('building', 'a', '4-gram'): 1, ('a', '4-gram', 'model'): 1, ('4-gram', 'model', 'with'): 1, ('model', 'with', 'back-off.'): 1}
# four_counts = {('This', 'is', 'a', 'sample'): 1, ('is', 'a', 'sample', 'text'): 1, ('a', 'sample', 'text', 'for'): 1, ('sample', 'text', 'for', 'building'): 1, ('text', 'for', 'building', 'a'): 1, ('for', 'building', 'a', '4-gram'): 1, ('building', 'a', '4-gram', 'model'): 1, ('a', '4-gram', 'model', 'with'): 1, ('4-gram', 'model', 'with', 'back-off.'): 1}

# model = NGramModelWithBackoff(uni_counts, bi_counts, tri_counts, four_counts)

# generated_text = model.generate_text(20)
# print(generated_text)

# %%
# import random

# class NGramModelWithBackoff:
#     def __init__(self, uni_counts, bi_counts, tri_counts, four_counts):
#         self.uni_counts = uni_counts
#         self.bi_counts = bi_counts
#         self.tri_counts = tri_counts
#         self.four_counts = four_counts
#         self.total_count = sum(uni_counts.values())
#         self.vocab_size = len(uni_counts)

#     def _get_probability(self, ngram):
#         if len(ngram) == 1:
#             return self.uni_counts.get(ngram[0], 0) / self.total_count
#         elif len(ngram) == 2:
#             return self.bi_counts.get(ngram, 0) / self.uni_counts.get(ngram[0], 1)
#         elif len(ngram) == 3:
#             return self.tri_counts.get(ngram, 0) / self.bi_counts.get(ngram[:2], 1)
#         elif len(ngram) == 4:
#             return self.four_counts.get(ngram, 0) / self.tri_counts.get(ngram[:3], 1)
#         else:
#             return 0

#     def generate_text(self, length):
#         generated_text = []
#         start_word = random.choice(list(self.uni_counts.keys()))
#         generated_text.append(start_word)

#         for i in range(length-1):
#             current_word = generated_text[-1]
#             if len(generated_text) >= 4 and (generated_text[-4], generated_text[-3], generated_text[-2], current_word) in self.four_counts:
#                 ngram = (generated_text[-4], generated_text[-3], generated_text[-2], current_word)
#             elif len(generated_text) >= 3 and (generated_text[-3], generated_text[-2], current_word) in self.tri_counts:
#                 ngram = (generated_text[-3], generated_text[-2], current_word)
#             elif len(generated_text) >= 2 and (generated_text[-2], current_word) in self.bi_counts:
#                 ngram = (generated_text[-2], current_word)
#             else:
#                 ngram = (current_word,)

#             next_word = self._sample_next_word(ngram)
#             generated_text.append(next_word)

#         return ' '.join(generated_text)

#     def _sample_next_word(self, ngram):
#         next_word_probs = {}
#         total_prob = 0
#         for word in self.uni_counts.keys():
#             next_ngram = ngram + (word,)
#             prob = self._get_probability(next_ngram)
#             next_word_probs[word] = prob
#             total_prob += prob

#         if total_prob == 0:
#             return random.choice(list(self.uni_counts.keys()))

#         return random.choices(list(next_word_probs.keys()), list(next_word_probs.values()))[0]

# # Example usage:
# uni_counts = {'This': 1, 'is': 2, 'a': 1, 'sample': 1, 'text': 1, 'for': 1, 'building': 1, '4-gram': 1, 'model': 1, 'with': 1, 'back-off.': 1}
# bi_counts = {('This', 'is'): 1, ('is', 'a'): 1, ('a', 'sample'): 1, ('sample', 'text'): 1, ('text', 'for'): 1, ('for', 'building'): 1, ('building', 'a'): 1, ('a', '4-gram'): 1, ('4-gram', 'model'): 1, ('model', 'with'): 1, ('with', 'back-off.'): 1}
# tri_counts = {('This', 'is', 'a'): 1, ('is', 'a', 'sample'): 1, ('a', 'sample', 'text'): 1, ('sample', 'text', 'for'): 1, ('text', 'for', 'building'): 1, ('for', 'building', 'a'): 1, ('building', 'a', '4-gram'): 1, ('a', '4-gram', 'model'): 1, ('4-gram', 'model', 'with'): 1, ('model', 'with', 'back-off.'): 1}
# four_counts = {('This', 'is', 'a', 'sample'): 1, ('is', 'a', 'sample', 'text'): 1, ('a', 'sample', 'text', 'for'): 1, ('sample', 'text', 'for', 'building'): 1, ('text', 'for', 'building', 'a'): 1, ('for', 'building', 'a', '4-gram'): 1, ('building', 'a', '4-gram', 'model'): 1, ('a', '4-gram', 'model', 'with'): 1, ('4-gram', 'model', 'with', 'back-off.'): 1}

# model = NGramModelWithBackoff(uni_counts, bi_counts, tri_counts, four_counts)

# generated_text = model.generate_text(20)
# print(generated_text)

# %%
# def _get_probability(self, ngram):
#         if len(ngram) == 1:
#             return self.uni_counts.get(ngram[0], 0) / self.total_count
#         elif len(ngram) == 2:
#             return self.bi_counts.get(ngram, 0) / self.uni_counts.get(ngram[0], 1)
#         elif len(ngram) == 3:
#             return self.tri_counts.get(ngram, 0) / self.bi_counts.get(ngram[:2], 1)
#         elif len(ngram) == 4:
#             return self.four_counts.get(ngram, 0) / self.tri_counts.get(ngram[:3], 1)
#         else:
#             return 0

# %%
# #GPT_new_new
# import random

# class NGramModelWithBackoff:
    
#     @staticmethod
#     def n_gram_counts(tokens, n):
#         n_tokens = len(tokens)
#         result = {}
#         for i in range(n_tokens - n + 1):
#             key = tuple(tokens[i:i+n])
#             if key in result:
#                 result[key] += 1
#             else:
#                 result[key] = 1
#         return result
    
#     def __init__(self, tokens):
#         # Initialize n-gram counts
#         self.uni_counts = self.n_gram_counts(tokens, 1)
#         self.bi_counts = self.n_gram_counts(tokens, 2)
#         self.tri_counts = self.n_gram_counts(tokens, 3)
#         self.four_counts = self.n_gram_counts(tokens, 4)
        
#         # Total count of tokens
#         self.total_count = len(tokens)
        
#         # Vocabulary size
#         self.vocab = len(set(tokens))  # Using set to get unique tokens
    
#     # def _sample_next_word(self, ngram):
#     #     next_word_probs = {}
#     #     total_prob = 0
#     #     for word in self.uni_counts.keys():
#     #         next_ngram = ngram + (word,)
#     #         prob = self._get_probability(next_ngram)
#     #         next_word_probs[word] = prob
#     #         total_prob += prob

#     #     if total_prob == 0:
#     #         return random.choice(list(self.uni_counts.keys()))

#     #     return random.choices(list(next_word_probs.keys()), list(next_word_probs.values()))[0]

            
    
# ngram_model = NGramModelWithBackoff(data_train)

# %%
# def next_word(given_ngram, four_counts=four_counts):
#     max_count = 0
#     most_common_4gram = None
    
#     for four_gram, count in four_counts.items():
#         if four_gram[:3] == given_ngram and count > max_count:
#             max_count = count
#             most_common_4gram = four_gram
    
#     return most_common_4gram[-1] if most_common_4gram else "None"

# %%
# def next_word(given_ngram):
#     max_count = 0
#     most_common_ngram = None
    
#     # Check 4-gram
#     if len(given_ngram) == 3:
#         for four_gram, count in four_counts.items():
#             if four_gram[:3] == given_ngram and count > max_count:
#                 max_count = count
#                 most_common_ngram = four_gram
#         if most_common_ngram:
#             return most_common_ngram[-1]
    
#     # Check trigram if 4-gram not found
#     if len(given_ngram) >= 2:
#         for tri_gram, count in tri_counts.items():
#             if tri_gram[:2] == given_ngram and count > max_count:
#                 max_count = count
#                 most_common_ngram = tri_gram
#         if most_common_ngram:
#             return most_common_ngram[-1]
    
#     # Check bigram if trigram or 4-gram not found
#     if len(given_ngram) >= 1:
#         for bi_gram, count in bi_counts.items():
#             if bi_gram[:1] == given_ngram and count > max_count:
#                 max_count = count
#                 most_common_ngram = bi_gram
#         if most_common_ngram:
#             return most_common_ngram[-1]
    
#     # Check unigram if no match found
#     for uni_gram, count in uni_counts.items():
#         if count > max_count:
#             max_count = count
#             most_common_ngram = uni_gram
    
#     return most_common_ngram if most_common_ngram else "None"

# %%
# def next_word(given_ngram):
#     max_count = 0
#     most_common_ngram = None
    
#     # Check 4-gram
#     if len(given_ngram) == 3:
#         for four_gram, count in four_counts.items():
#             if four_gram[:3] == given_ngram and count > max_count:
#                 max_count = count
#                 most_common_ngram = four_gram
#         if most_common_ngram:
#             return most_common_ngram[-1]

# %%
# def next_word(given_ngram, ngram_counts=n_gram_counts):
#     max_count = 0
#     most_common_ngram = None
    
#     for n in range(4, 0, -1):  # Iterate from 4-gram down to unigram
#         ngram_counts=n_gram_counts(data_train,n)
#         for ngram, count in ngram_counts.items():
#             if ngram[:n-1] == given_ngram[-(n-1):] and count > max_count:
#                 max_count = count
#                 most_common_ngram = ngram
#         if most_common_ngram:
#             return (most_common_ngram[-1],)
    
#     return most_common_ngram[-1] if most_common_ngram else None

# %%
bi_counts
# Out:
# {('moby', 'dick'): 55,
#  ('dick', 'whale'): 5,
#  ('whale', 'herman'): 3,
#  ('herman', 'melville'): 4,
#  ('melville', 'project'): 1,
#  ('project', 'gutenberg'): 4,
#  ('gutenberg', 'ebook'): 2,
#  ('ebook', 'moby'): 2,
#  ('melville', 'thi'): 1,
#  ('thi', 'ebook'): 2,
#  ('ebook', 'use'): 1,
#  ('use', 'anyone'): 1,
#  ('anyone', 'anywhere'): 1,
#  ('anywhere', 'cost'): 1,
#  ('cost', 'almost'): 1,
#  ('almost', 'restriction'): 1,
#  ('restriction', 'whatsoever'): 1,
#  ('whatsoever', 'may'): 1,
#  ('may', 'copy'): 1,
#  ('copy', 'give'): 1,
#  ('give', 'away'): 1,
#  ('away', 'reuse'): 1,
#  ('reuse', 'term'): 1,
#  ('term', 'project'): 1,
#  ('gutenberg', 'license'): 1,
#  ('license', 'include'): 1,
#  ('include', 'thi'): 2,
#  ('ebook', 'online'): 1,
#  ('online', 'www.gutenberg.org'): 1,
#  ('www.gutenberg.org', 'title'): 1,
#  ('title', 'moby'): 1,
#  ('whale', 'author'): 2,
#  ('author', 'herman'): 1,
#  ('melville', 'UNK'): 1,
#  ('UNK', 'date'): 1,
#  ('date', 'december'): 1,
#  ('december', 'ebook'): 1,
#  ('ebook', 'last'): 1,
#  ('last', 'update'): 1,
#  ('update', 'december'): 1,
#  ('december', 'language'): 1,
#  ('language', 'english'): 1,
#  ('english', 'character'): 1,
#  ('character', 'set'): 1,
#  ('set', 'UNK'): 7,
#  ('UNK', 'UNK'): 556,
#  ('UNK', 'start'): 9,
#  ('start', 'thi'): 1,
#  ('thi', 'project'): 1,
#  ('whale', 'produce'): 1,
#  ('produce', 'daniel'): 1,
#  ('daniel', 'lazaru'): 1,
#  ('lazaru', 'jonesey'): 1,
#  ('jonesey', 'david'): 1,
#  ('david', 'widger'): 1,
#  ('widger', 'UNK'): 1,
#  ('UNK', 'whale'): 55,
#  ('melville', 'content'): 1,
#  ('content', 'etymology'): 1,
#  ('etymology', 'extract'): 1,
#  ('extract', 'supply'): 2,
#  ('supply', 'subsublibrarian'): 2,
#  ('subsublibrarian', 'chapter'): 1,
#  ('chapter', 'looming'): 2,
#  ('looming', 'chapter'): 1,
#  ('chapter', 'carpetbag'): 2,
#  ('carpetbag', 'chapter'): 1,
#  ('chapter', 'spouterinn'): 2,
#  ('spouterinn', 'chapter'): 1,
#  ('chapter', 'counterpane'): 2,
#  ('counterpane', 'chapter'): 1,
#  ('chapter', 'breakfast'): 2,
#  ('breakfast', 'chapter'): 1,
#  ('chapter', 'street'): 2,
#  ('street', 'chapter'): 1,
#  ('chapter', 'chapel'): 2,
#  ('chapel', 'chapter'): 1,
#  ('chapter', 'pulpit'): 2,
#  ('pulpit', 'chapter'): 1,
#  ('chapter', 'sermon'): 2,
#  ('sermon', 'chapter'): 1,
#  ('chapter', 'bosom'): 2,
#  ('bosom', 'friend'): 3,
#  ('friend', 'chapter'): 2,
#  ('chapter', 'nightgown'): 2,
#  ('nightgown', 'chapter'): 1,
#  ('chapter', 'biographical'): 2,
#  ('biographical', 'chapter'): 1,
#  ('chapter', 'wheelbarrow'): 2,
#  ('wheelbarrow', 'chapter'): 1,
#  ('chapter', 'nantucket'): 2,
#  ('nantucket', 'chapter'): 1,
#  ('chapter', 'chowder'): 2,
#  ('chowder', 'chapter'): 1,
#  ('chapter', 'ship'): 2,
#  ('ship', 'chapter'): 1,
#  ('chapter', 'ramadan'): 2,
#  ('ramadan', 'chapter'): 1,
#  ('chapter', 'hi'): 3,
#  ('hi', 'mark'): 6,
#  ('mark', 'chapter'): 1,
#  ('chapter', 'prophet'): 2,
#  ('prophet', 'chapter'): 1,
#  ('chapter', 'astir'): 2,
#  ('astir', 'chapter'): 1,
#  ('chapter', 'go'): 2,
#  ('go', 'aboard'): 4,
#  ('aboard', 'chapter'): 1,
#  ('chapter', 'merry'): 2,
#  ('merry', 'christma'): 2,
#  ('christma', 'chapter'): 1,
#  ('chapter', 'lee'): 2,
#  ('lee', 'shore'): 2,
#  ('shore', 'chapter'): 2,
#  ('chapter', 'advocate'): 2,
#  ('advocate', 'chapter'): 1,
#  ('chapter', 'postscript'): 2,
#  ('postscript', 'chapter'): 1,
#  ('chapter', 'knight'): 4,
#  ('knight', 'squire'): 4,
#  ('squire', 'chapter'): 2,
#  ('chapter', 'ahab'): 7,
#  ('ahab', 'chapter'): 1,
#  ('chapter', 'enter'): 2,
#  ('enter', 'ahab'): 3,
#  ('ahab', 'stubb'): 2,
#  ('stubb', 'chapter'): 1,
#  ('chapter', 'pipe'): 2,
#  ('pipe', 'chapter'): 1,
#  ('chapter', 'queen'): 2,
#  ('queen', 'mab'): 2,
#  ('mab', 'chapter'): 1,
#  ('chapter', 'cetology'): 2,
#  ('cetology', 'chapter'): 1,
#  ('chapter', 'specksnyder'): 2,
#  ('specksnyder', 'chapter'): 1,
#  ('chapter', 'cabintable'): 2,
#  ('cabintable', 'chapter'): 1,
#  ('chapter', 'masthead'): 2,
#  ('masthead', 'chapter'): 1,
#  ('chapter', 'quarterdeck'): 2,
#  ('quarterdeck', 'chapter'): 1,
#  ('chapter', 'sunset'): 2,
#  ('sunset', 'chapter'): 1,
#  ('chapter', 'dusk'): 2,
#  ('dusk', 'chapter'): 1,
#  ('chapter', 'first'): 4,
#  ('first', 'nightwatch'): 2,
#  ('nightwatch', 'chapter'): 1,
#  ('chapter', 'midnight'): 3,
#  ('midnight', 'forecastle'): 2,
#  ('forecastle', 'chapter'): 1,
#  ('chapter', 'moby'): 2,
#  ('dick', 'chapter'): 1,
#  ('chapter', 'whitenes'): 3,
#  ('whitenes', 'whale'): 3,
#  ('whale', 'chapter'): 9,
#  ('chapter', 'hark'): 2,
#  ('hark', 'chapter'): 1,
#  ('chapter', 'chart'): 2,
#  ('chart', 'chapter'): 1,
#  ('chapter', 'affidavit'): 2,
#  ('affidavit', 'chapter'): 1,
#  ('chapter', 'surmise'): 2,
#  ('surmise', 'chapter'): 1,
#  ('chapter', 'matmaker'): 2,
#  ('matmaker', 'chapter'): 1,
#  ('first', 'lower'): 2,
#  ('lower', 'chapter'): 1,
#  ('chapter', 'hyena'): 2,
#  ('hyena', 'chapter'): 1,
#  ('ahab', 'boat'): 4,
#  ('boat', 'crew'): 12,
#  ('crew', 'fedallah'): 2,
#  ('fedallah', 'chapter'): 1,
#  ('chapter', 'spiritspout'): 2,
#  ('spiritspout', 'chapter'): 1,
#  ('chapter', 'albatros'): 2,
#  ('albatros', 'chapter'): 1,
#  ('chapter', 'gam'): 2,
#  ('gam', 'chapter'): 1,
#  ('chapter', 'townho'): 2,
#  ('townho', 'story'): 3,
#  ('story', 'chapter'): 2,
#  ('chapter', 'monstrou'): 2,
#  ('monstrou', 'picture'): 3,
#  ('picture', 'whale'): 10,
#  ('chapter', 'les'): 2,
#  ('les', 'erroneou'): 2,
#  ('erroneou', 'picture'): 2,
#  ('whale', 'true'): 4,
#  ('true', 'picture'): 2,
#  ('whale', 'scene'): 7,
#  ('scene', 'chapter'): 1,
#  ('chapter', 'whale'): 8,
#  ('whale', 'paint'): 2,
#  ('paint', 'teeth'): 2,
#  ('teeth', 'wood'): 2,
#  ('wood', 'sheetiron'): 2,
#  ('sheetiron', 'stone'): 2,
#  ('stone', 'mountain'): 2,
#  ('mountain', 'star'): 2,
#  ('star', 'chapter'): 1,
#  ('chapter', 'brit'): 2,
#  ('brit', 'chapter'): 1,
#  ('chapter', 'squid'): 2,
#  ('squid', 'chapter'): 1,
#  ('chapter', 'line'): 2,
#  ('line', 'chapter'): 2,
#  ('chapter', 'stubb'): 6,
#  ('stubb', 'kill'): 2,
#  ('kill', 'whale'): 6,
#  ('chapter', 'dart'): 2,
#  ('dart', 'chapter'): 1,
#  ('chapter', 'crotch'): 3,
#  ('crotch', 'chapter'): 1,
#  ('stubb', 'supper'): 2,
#  ('supper', 'chapter'): 1,
#  ('whale', 'dish'): 2,
#  ('dish', 'chapter'): 1,
#  ('chapter', 'shark'): 2,
#  ('shark', 'massacre'): 2,
#  ('massacre', 'chapter'): 1,
#  ('chapter', 'cut'): 2,
#  ('cut', 'chapter'): 1,
#  ('chapter', 'blanket'): 2,
#  ('blanket', 'chapter'): 1,
#  ('chapter', 'funeral'): 2,
#  ('funeral', 'chapter'): 1,
#  ('chapter', 'sphynx'): 2,
#  ('sphynx', 'chapter'): 1,
#  ('chapter', 'jeroboam'): 2,
#  ('jeroboam', 'story'): 2,
#  ('chapter', 'monkeyrope'): 2,
#  ('monkeyrope', 'chapter'): 1,
#  ('stubb', 'flask'): 9,
#  ('flask', 'kill'): 3,
#  ('kill', 'right'): 2,
#  ('right', 'whale'): 55,
#  ('whale', 'talk'): 2,
#  ('talk', 'chapter'): 1,
#  ('chapter', 'sperm'): 2,
#  ('sperm', 'whale'): 170,
#  ('whale', 'headcontrast'): 4,
#  ('headcontrast', 'view'): 4,
#  ('view', 'chapter'): 2,
#  ('chapter', 'right'): 2,
#  ('chapter', 'batteringram'): 2,
#  ('batteringram', 'chapter'): 1,
#  ('chapter', 'great'): 2,
#  ('great', 'heidelburgh'): 4,
#  ('heidelburgh', 'tun'): 6,
#  ('tun', 'chapter'): 1,
#  ('chapter', 'cistern'): 2,
#  ('cistern', 'bucket'): 2,
#  ('bucket', 'chapter'): 2,
#  ('chapter', 'prairie'): 2,
#  ('prairie', 'chapter'): 1,
#  ('chapter', 'nut'): 2,
#  ('nut', 'chapter'): 1,
#  ('chapter', 'pequod'): 7,
#  ('pequod', 'meet'): 7,
#  ('meet', 'virgin'): 2,
#  ('virgin', 'chapter'): 1,
#  ('chapter', 'honor'): 2,
#  ('honor', 'glory'): 4,
#  ('glory', 'whale'): 3,
#  ('chapter', 'jonah'): 2,
#  ('jonah', 'historically'): 2,
#  ('historically', 'regard'): 2,
#  ('regard', 'chapter'): 1,
#  ('chapter', 'pitchpole'): 2,
#  ('pitchpole', 'chapter'): 1,
#  ('chapter', 'fountain'): 2,
#  ('fountain', 'chapter'): 1,
#  ('chapter', 'tail'): 2,
#  ('tail', 'chapter'): 3,
#  ('chapter', 'grand'): 2,
#  ('grand', 'armada'): 2,
#  ('armada', 'chapter'): 1,
#  ('chapter', 'school'): 2,
#  ('school', 'schoolmaster'): 2,
#  ('schoolmaster', 'chapter'): 1,
#  ('chapter', 'fastfish'): 2,
#  ('fastfish', 'loosefish'): 3,
#  ('loosefish', 'chapter'): 1,
#  ('chapter', 'head'): 2,
#  ('head', 'tail'): 2,
#  ('meet', 'rosebud'): 2,
#  ('rosebud', 'chapter'): 1,
#  ('chapter', 'ambergri'): 1,
#  ('ambergri', 'chapter'): 1,
#  ('chapter', 'castaway'): 1,
#  ('castaway', 'chapter'): 1,
#  ('chapter', 'squeeze'): 1,
#  ('squeeze', 'hand'): 1,
#  ('hand', 'chapter'): 1,
#  ('chapter', 'cassock'): 1,
#  ('cassock', 'chapter'): 1,
#  ('chapter', 'trywork'): 1,
#  ('trywork', 'chapter'): 1,
#  ('chapter', 'lamp'): 1,
#  ('lamp', 'chapter'): 1,
#  ('chapter', 'stow'): 1,
#  ('stow', 'clear'): 1,
#  ('clear', 'chapter'): 1,
#  ('chapter', 'doubloon'): 1,
#  ('doubloon', 'chapter'): 1,
#  ('chapter', 'leg'): 1,
#  ('leg', 'arm'): 1,
#  ('arm', 'chapter'): 1,
#  ('chapter', 'decanter'): 1,
#  ('decanter', 'chapter'): 1,
#  ('chapter', 'bower'): 1,
#  ('bower', 'arsacide'): 1,
#  ('arsacide', 'chapter'): 1,
#  ('chapter', 'measurement'): 1,
#  ('measurement', 'whale'): 1,
#  ('whale', 'skeleton'): 1,
#  ('skeleton', 'chapter'): 1,
#  ('chapter', 'fossil'): 1,
#  ('fossil', 'whale'): 1,
#  ('whale', 'magnitude'): 1,
#  ('magnitude', 'diminishwill'): 1,
#  ('diminishwill', 'perish'): 1,
#  ('perish', 'chapter'): 2,
#  ('ahab', 'leg'): 3,
#  ('leg', 'chapter'): 1,
#  ('chapter', 'carpenter'): 1,
#  ('carpenter', 'chapter'): 2,
#  ('ahab', 'carpenter'): 1,
#  ('ahab', 'starbuck'): 2,
#  ('starbuck', 'cabin'): 1,
#  ('cabin', 'chapter'): 4,
#  ('chapter', 'queequeg'): 1,
#  ('queequeg', 'hi'): 5,
#  ('hi', 'coffin'): 1,
#  ('coffin', 'chapter'): 1,
#  ('chapter', 'pacific'): 1,
#  ('pacific', 'chapter'): 1,
#  ('chapter', 'blacksmith'): 1,
#  ('blacksmith', 'chapter'): 1,
#  ('chapter', 'forge'): 1,
#  ('forge', 'chapter'): 1,
#  ('chapter', 'gilder'): 1,
#  ('gilder', 'chapter'): 1,
#  ('meet', 'bachelor'): 1,
#  ('bachelor', 'chapter'): 1,
#  ('chapter', 'die'): 1,
#  ('die', 'whale'): 2,
#  ('whale', 'watch'): 2,
#  ('watch', 'chapter'): 2,
#  ('chapter', 'quadrant'): 1,
#  ('quadrant', 'chapter'): 1,
#  ('chapter', 'candle'): 1,
#  ('candle', 'chapter'): 1,
#  ('chapter', 'deck'): 2,
#  ('deck', 'toward'): 1,
#  ('toward', 'end'): 2,
#  ('end', 'first'): 2,
#  ('first', 'night'): 1,
#  ('night', 'watch'): 3,
#  ('chapter', 'midnight.the'): 1,
#  ('midnight.the', 'forecastle'): 1,
#  ('forecastle', 'bulwark'): 1,
#  ('bulwark', 'chapter'): 1,
#  ('midnight', 'aloft.thunder'): 1,
#  ('aloft.thunder', 'lightn'): 1,
#  ('lightn', 'chapter'): 1,
#  ('chapter', 'musket'): 1,
#  ('musket', 'chapter'): 1,
#  ('chapter', 'needle'): 1,
#  ('needle', 'chapter'): 1,
#  ('chapter', 'log'): 1,
#  ('log', 'line'): 1,
#  ('chapter', 'lifebuoy'): 1,
#  ('lifebuoy', 'chapter'): 1,
#  ('deck', 'chapter'): 1,
#  ('meet', 'rachel'): 1,
#  ('rachel', 'chapter'): 1,
#  ('chapter', 'cabin'): 1,
#  ('chapter', 'hat'): 1,
#  ('hat', 'chapter'): 1,
#  ('meet', 'delight'): 1,
#  ('delight', 'chapter'): 1,
#  ('chapter', 'symphony'): 1,
#  ('symphony', 'chapter'): 1,
#  ('chapter', 'chasefirst'): 1,
#  ('chasefirst', 'day'): 1,
#  ('day', 'chapter'): 2,
#  ('chapter', 'chasesecond'): 1,
#  ('chasesecond', 'day'): 1,
#  ('chapter', 'chase.third'): 1,
#  ('chase.third', 'day'): 1,
#  ('day', 'epilogue'): 1,
#  ('epilogue', 'original'): 1,
#  ('original', 'UNK'): 4,
#  ('UNK', 'note'): 1,
#  ('note', 'thi'): 1,
#  ('thi', 'text'): 1,
#  ('text', 'combination'): 1,
#  ('combination', 'etext'): 1,
#  ('etext', 'one'): 1,
#  ('one', 'UNK'): 26,
#  ('UNK', 'project'): 2,
#  ('project', 'virginia'): 1,
#  ('virginia', 'tech'): 2,
#  ('tech', 'one'): 1,
#  ('one', 'project'): 1,
#  ('gutenberg', 'archive'): 1,
#  ('archive', 'UNK'): 1,
#  ('UNK', 'thi'): 74,
#  ('thi', 'version'): 1,
#  ('version', 'indebt'): 1,
#  ('indebt', 'UNK'): 1,
#  ('UNK', 'library'): 2,
#  ('library', 'preserve'): 1,
#  ('preserve', 'virginia'): 1,
#  ('tech', 'version'): 1,
#  ('version', 'result'): 1,
#  ('result', 'etext'): 1,
#  ('etext', 'compare'): 1,
#  ('compare', 'public'): 1,
#  ('public', 'domain'): 1,
#  ('domain', 'hard'): 1,
#  ('hard', 'copy'): 1,
#  ('copy', 'version'): 1,
#  ('version', 'text'): 1,
#  ('text', 'etymology'): 1,
#  ('etymology', 'supply'): 1,
#  ('supply', 'late'): 1,
#  ('late', 'UNK'): 1,
#  ('UNK', 'usher'): 1,
#  ('usher', 'grammar'): 1,
#  ('grammar', 'school'): 1,
#  ('school', 'pale'): 1,
#  ('pale', 'UNK'): 4,
#  ('UNK', 'coat'): 4,
#  ('coat', 'heart'): 1,
#  ('heart', 'body'): 1,
#  ('body', 'brain'): 1,
#  ('brain', 'see'): 2,
#  ('see', 'ever'): 1,
#  ('ever', 'dust'): 1,
#  ('dust', 'hi'): 3,
#  ('hi', 'old'): 11,
#  ('old', 'lexicon'): 1,
#  ('lexicon', 'grammar'): 1,
#  ('grammar', 'queer'): 1,
#  ('queer', 'handkerchief'): 1,
#  ('handkerchief', 'UNK'): 1,
#  ('UNK', 'embellish'): 1,
#  ('embellish', 'gay'): 1,
#  ('gay', 'flag'): 1,
#  ('flag', 'know'): 1,
#  ('know', 'nation'): 1,
#  ('nation', 'world'): 1,
#  ('world', 'love'): 1,
#  ('love', 'dust'): 1,
#  ('old', 'grammar'): 1,
#  ('grammar', 'somehow'): 1,
#  ('somehow', 'mildly'): 1,
#  ('mildly', 'remind'): 1,
#  ('remind', 'hi'): 1,
#  ('hi', 'mortality'): 1,
#  ('mortality', 'take'): 1,
#  ('take', 'hand'): 1,
#  ('hand', 'school'): 1,
#  ('school', 'teach'): 1,
#  ('teach', 'name'): 1,
#  ('name', 'UNK'): 6,
#  ('UNK', 'call'): 17,
#  ('call', 'tongue'): 1,
#  ('tongue', 'leave'): 1,
#  ('leave', 'ignorance'): 1,
#  ('ignorance', 'letter'): 1,
#  ('letter', 'UNK'): 3,
#  ('UNK', 'almost'): 5,
#  ('almost', 'alone'): 1,
#  ('alone', 'maketh'): 1,
#  ('maketh', 'UNK'): 1,
#  ('UNK', 'word'): 8,
#  ('word', 'deliver'): 1,
#  ('deliver', 'true'): 1,
#  ('true', 'hackluyt'): 1,
#  ('hackluyt', 'whale'): 1,
#  ('whale', 'UNK'): 63,
#  ('UNK', 'dan'): 2,
#  ('dan', 'UNK'): 1,
#  ('thi', 'animal'): 2,
#  ('animal', 'name'): 1,
#  ('UNK', 'roll'): 4,
#  ('roll', 'dan'): 1,
#  ('dan', 'hvalt'): 1,
#  ('hvalt', 'arch'): 1,
#  ('arch', 'vault'): 1,
#  ('vault', 'webster'): 1,
#  ('webster', 'dictionary'): 1,
#  ('dictionary', 'whale'): 1,
#  ('whale', 'immediately'): 3,
#  ('immediately', 'UNK'): 2,
#  ('roll', 'wallow'): 2,
#  ('wallow', 'UNK'): 1,
#  ('UNK', 'dictionary'): 1,
#  ('dictionary', 'hebrew'): 1,
#  ('hebrew', 'greek'): 1,
#  ('greek', 'cetu'): 1,
#  ('cetu', 'latin'): 1,
#  ('latin', 'UNK'): 2,
#  ('UNK', 'hvalt'): 1,
#  ('hvalt', 'danish'): 1,
#  ('danish', 'UNK'): 1,
#  ('UNK', 'dutch'): 1,
#  ('dutch', 'UNK'): 2,
#  ('whale', 'icelandic'): 1,
#  ('icelandic', 'whale'): 1,
#  ('whale', 'english'): 4,
#  ('english', 'baleine'): 1,
#  ('baleine', 'french'): 1,
#  ('french', 'UNK'): 3,
#  ('UNK', 'spanish'): 1,
#  ('spanish', 'UNK'): 1,
#  ('UNK', 'extract'): 1,
#  ('subsublibrarian', 'see'): 1,
#  ('see', 'thi'): 12,
#  ('thi', 'mere'): 2,
#  ('mere', 'UNK'): 6,
#  ('UNK', 'poor'): 6,
#  ('poor', 'devil'): 6,
#  ('devil', 'subsub'): 2,
#  ('subsub', 'appear'): 1,
#  ('appear', 'go'): 1,
#  ('go', 'long'): 1,
#  ('long', 'UNK'): 11,
#  ('UNK', 'earth'): 4,
#  ('earth', 'pick'): 1,
#  ('pick', 'whatever'): 1,
#  ('whatever', 'random'): 1,
#  ('random', 'allusion'): 1,
#  ('allusion', 'whale'): 1,
#  ('whale', 'anyway'): 1,
#  ('anyway', 'find'): 1,
#  ('find', 'book'): 2,
#  ('book', 'whatsoever'): 1,
#  ('whatsoever', 'sacre'): 1,
#  ('sacre', 'profane'): 1,
#  ('profane', 'therefore'): 1,
#  ('therefore', 'must'): 8,
#  ('must', 'every'): 1,
#  ('every', 'case'): 1,
#  ('case', 'least'): 1,
#  ('least', 'take'): 1,
#  ('take', 'UNK'): 12,
#  ('whale', 'statement'): 1,
#  ('statement', 'however'): 1,
#  ('however', 'authentic'): 1,
#  ('authentic', 'extract'): 1,
#  ('extract', 'veritable'): 1,
#  ('veritable', 'gospel'): 1,
#  ('gospel', 'cetology'): 1,
#  ('cetology', 'far'): 1,
#  ('far', 'touch'): 1,
#  ('touch', 'ancient'): 1,
#  ('ancient', 'author'): 1,
#  ('author', 'generally'): 1,
#  ('generally', 'well'): 2,
#  ('well', 'poet'): 1,
#  ('poet', 'appear'): 1,
#  ('appear', 'extract'): 1,
#  ('extract', 'solely'): 1,
#  ('solely', 'valuable'): 1,
#  ('valuable', 'entertain'): 1,
#  ('entertain', 'afford'): 1,
#  ('afford', 'glance'): 1,
#  ('glance', 'bird'): 1,
#  ('bird', 'eye'): 1,
#  ('eye', 'view'): 1,
#  ('view', 'UNK'): 1,
#  ('UNK', 'say'): 26,
#  ('say', 'think'): 6,
#  ('think', 'fancy'): 1,
#  ('fancy', 'sing'): 1,
#  ('sing', 'leviathan'): 1,
#  ('leviathan', 'many'): 1,
#  ('many', 'nation'): 1,
#  ('nation', 'generation'): 1,
#  ('generation', 'include'): 1,
#  ('include', 'fare'): 1,
#  ('fare', 'thee'): 1,
#  ('thee', 'well'): 1,
#  ('well', 'poor'): 1,
#  ('subsub', 'whose'): 1,
#  ('whose', 'commentator'): 1,
#  ('commentator', 'thou'): 1,
#  ('thou', 'UNK'): 17,
#  ('UNK', 'hopeles'): 2,
#  ('hopeles', 'UNK'): 2,
#  ('UNK', 'tribe'): 2,
#  ('tribe', 'wine'): 1,
#  ('wine', 'thi'): 1,
#  ('thi', 'world'): 15,
#  ('world', 'ever'): 1,
#  ('ever', 'warm'): 1,
#  ('warm', 'even'): 1,
#  ('even', 'pale'): 1,
#  ('UNK', 'would'): 20,
#  ('would', 'UNK'): 16,
#  ('UNK', 'one'): 39,
#  ('one', 'sometime'): 1,
#  ('sometime', 'love'): 1,
#  ('love', 'sit'): 1,
#  ('sit', 'feel'): 1,
#  ('feel', 'UNK'): 4,
#  ('UNK', 'grow'): 2,
#  ('grow', 'convivial'): 1,
#  ('convivial', 'upon'): 1,
#  ('upon', 'tear'): 1,
#  ('tear', 'say'): 1,
#  ('say', 'UNK'): 16,
#  ('UNK', 'full'): 5,
#  ('full', 'eye'): 1,
#  ('eye', 'empty'): 1,
#  ('empty', 'glass'): 2,
#  ('glass', 'altogether'): 1,
#  ('altogether', 'unpleasant'): 1,
#  ('unpleasant', 'UNK'): 1,
#  ('UNK', 'subsub'): 1,
#  ('subsub', 'much'): 1,
#  ('much', 'pain'): 1,
#  ('pain', 'ye'): 1,
#  ('ye', 'take'): 2,
#  ('take', 'please'): 1,
#  ('please', 'world'): 1,
#  ('world', 'much'): 2,
#  ('much', 'shall'): 1,
#  ('shall', 'ye'): 1,
#  ('ye', 'ever'): 1,
#  ('ever', 'go'): 4,
#  ('go', 'UNK'): 22,
#  ('would', 'clear'): 1,
#  ('clear', 'UNK'): 4,
#  ('UNK', 'court'): 1,
#  ('court', 'tuilery'): 1,
#  ('tuilery', 'ye'): 1,
#  ('ye', 'gulp'): 1,
#  ('gulp', 'tear'): 1,
#  ('tear', 'hie'): 1,
#  ('hie', 'aloft'): 1,
#  ('aloft', 'royalmast'): 1,
#  ('royalmast', 'heart'): 1,
#  ('heart', 'friend'): 1,
#  ('friend', 'go'): 1,
#  ('go', 'clear'): 1,
#  ('UNK', 'heaven'): 2,
#  ('heaven', 'make'): 1,
#  ('make', 'UNK'): 22,
#  ('UNK', 'gabriel'): 1,
#  ('gabriel', 'michael'): 1,
#  ('michael', 'UNK'): 1,
#  ('UNK', 'come'): 13,
#  ('come', 'ye'): 5,
#  ('ye', 'strike'): 1,
#  ('strike', 'splinter'): 1,
#  ('splinter', 'heart'): 2,
#  ('heart', 'UNK'): 7,
#  ('UNK', 'ye'): 28,
#  ('ye', 'shall'): 4,
#  ('shall', 'strike'): 1,
#  ('strike', 'UNK'): 5,
#  ('UNK', 'glass'): 3,
#  ('glass', 'extract'): 1,
#  ('extract', 'god'): 1,
#  ('god', 'create'): 1,
#  ('create', 'great'): 3,
#  ('great', 'whale'): 13,
#  ('whale', 'genesi'): 1,
#  ('genesi', 'leviathan'): 1,
#  ('leviathan', 'maketh'): 2,
#  ('maketh', 'path'): 1,
#  ('path', 'shine'): 1,
#  ('shine', 'one'): 1,
#  ('one', 'would'): 4,
#  ('would', 'think'): 17,
#  ('think', 'deep'): 2,
#  ('deep', 'hoary'): 1,
#  ('hoary', 'job'): 1,
#  ('job', 'lord'): 1,
#  ('lord', 'prepare'): 1,
#  ('prepare', 'great'): 2,
#  ('great', 'fish'): 3,
#  ('fish', 'swallow'): 2,
#  ('swallow', 'jonah'): 2,
#  ('jonah', 'jonah'): 1,
#  ('jonah', 'go'): 4,
#  ('go', 'ship'): 2,
#  ('ship', 'leviathan'): 1,
#  ('leviathan', 'thou'): 1,
#  ('thou', 'hast'): 6,
#  ('hast', 'make'): 1,
#  ('make', 'play'): 1,
#  ('play', 'therein'): 1,
#  ('therein', 'psalm'): 1,
#  ('psalm', 'day'): 1,
#  ('day', 'lord'): 1,
#  ('lord', 'hi'): 2,
#  ('hi', 'sore'): 1,
#  ('sore', 'great'): 1,
#  ('great', 'strong'): 1,
#  ('strong', 'sword'): 1,
#  ('sword', 'shall'): 1,
#  ('shall', 'UNK'): 3,
#  ('UNK', 'leviathan'): 6,
#  ('leviathan', 'pierce'): 1,
#  ('pierce', 'serpent'): 1,
#  ('serpent', 'even'): 1,
#  ('even', 'leviathan'): 1,
#  ('leviathan', 'crook'): 1,
#  ('crook', 'serpent'): 1,
#  ('serpent', 'shall'): 1,
#  ('shall', 'slay'): 1,
#  ('slay', 'dragon'): 1,
#  ('dragon', 'sea'): 2,
#  ('sea', 'isaiah'): 1,
#  ('isaiah', 'thing'): 1,
#  ('thing', 'UNK'): 13,
#  ('UNK', 'beside'): 4,
#  ('beside', 'UNK'): 5,
#  ('UNK', 'within'): 6,
#  ('within', 'chao'): 1,
#  ('chao', 'thi'): 1,
#  ('thi', 'monster'): 4,
#  ('monster', 'mouth'): 1,
#  ('mouth', 'beast'): 1,
#  ('beast', 'boat'): 1,
#  ('boat', 'stone'): 1,
#  ('stone', 'go'): 1,
#  ('UNK', 'foul'): 1,
#  ('foul', 'great'): 2,
#  ('great', 'swallow'): 1,
#  ('swallow', 'hi'): 1,
#  ('hi', 'UNK'): 109,
#  ('UNK', 'bottomles'): 1,
#  ('bottomles', 'gulf'): 1,
#  ('gulf', 'hi'): 1,
#  ('hi', 'paunch'): 1,
#  ('paunch', 'holland'): 1,
#  ('holland', 'UNK'): 1,
#  ('UNK', 'moral'): 2,
#  ('moral', 'indian'): 1,
#  ('indian', 'sea'): 1,
#  ('sea', 'UNK'): 24,
#  ('UNK', 'biggest'): 1,
#  ('biggest', 'fishes'): 1,
#  ('fishes', 'among'): 1,
#  ('among', 'whale'): 5,
#  ('call', 'UNK'): 15,
#  ('UNK', 'take'): 9,
#  ('take', 'much'): 2,
#  ('much', 'length'): 2,
#  ('length', 'four'): 1,
#  ('four', 'acre'): 1,
#  ('acre', 'UNK'): 1,
#  ('UNK', 'land'): 5,
#  ('land', 'holland'): 1,
#  ('holland', 'pliny'): 1,
#  ('pliny', 'scarcely'): 1,
#  ('scarcely', 'proceed'): 1,
#  ('proceed', 'two'): 2,
#  ('two', 'day'): 3,
#  ('day', 'sea'): 1,
#  ('sea', 'sunrise'): 1,
#  ('sunrise', 'great'): 1,
#  ('great', 'many'): 1,
#  ('many', 'whale'): 3,
#  ('whale', 'monster'): 2,
#  ('monster', 'sea'): 3,
#  ('sea', 'appear'): 1,
#  ('appear', 'among'): 2,
#  ('among', 'former'): 1,
#  ('former', 'one'): 2,
#  ('one', 'monstrou'): 1,
#  ('monstrou', 'size'): 1,
#  ('size', '....'): 1,
#  ('....', 'thi'): 1,
#  ('thi', 'come'): 2,
#  ('come', 'toward'): 1,
#  ('toward', 'u'): 4,
#  ('u', 'openmouthe'): 1,
#  ('openmouthe', 'raise'): 1,
#  ('raise', 'wave'): 1,
#  ('wave', 'side'): 1,
#  ('side', 'beat'): 1,
#  ('beat', 'sea'): 1,
#  ('sea', 'foam'): 1,
#  ('foam', 'UNK'): 2,
#  ('UNK', 'true'): 5,
#  ('true', 'history'): 3,
#  ('history', 'visit'): 1,
#  ('visit', 'thi'): 1,
#  ('thi', 'country'): 1,
#  ('country', 'also'): 1,
#  ('also', 'view'): 1,
#  ('view', 'catch'): 2,
#  ('catch', 'UNK'): 1,
#  ('UNK', 'bone'): 5,
#  ('bone', 'great'): 1,
#  ('great', 'value'): 1,
#  ('value', 'teeth'): 1,
#  ('teeth', 'bring'): 1,
#  ('bring', 'king'): 1,
#  ('king', '....'): 1,
#  ('....', 'best'): 1,
#  ('best', 'whale'): 1,
#  ('whale', 'catch'): 3,
#  ('catch', 'hi'): 2,
#  ('hi', 'country'): 2,
#  ('country', 'fortyeight'): 1,
#  ('fortyeight', 'fifty'): 1,
#  ('fifty', 'yard'): 3,
#  ('yard', 'long'): 1,
#  ('long', 'say'): 1,
#  ('say', 'one'): 4,
#  ('one', 'six'): 1,
#  ('six', 'kill'): 1,
#  ('kill', 'sixty'): 1,
#  ('sixty', 'two'): 1,
#  ('day', 'verbal'): 1,
#  ('verbal', 'narrative'): 1,
#  ('narrative', 'take'): 1,
#  ('take', 'hi'): 14,
#  ('hi', 'mouth'): 19,
#  ('mouth', 'king'): 1,
#  ('king', 'alfr'): 1,
#  ('alfr', 'a.d.'): 1,
#  ('a.d.', 'wherea'): 1,
#  ('wherea', 'thing'): 1,
#  ('thing', 'whether'): 1,
#  ('whether', 'beast'): 1,
#  ('beast', 'vessel'): 1,
#  ('vessel', 'enter'): 1,
#  ('enter', 'dreadful'): 1,
#  ('dreadful', 'gulf'): 1,
#  ('gulf', 'thi'): 1,
#  ('monster', 'whale'): 2,
#  ('whale', 'mouth'): 5,
#  ('mouth', 'immediately'): 1,
#  ('immediately', 'lose'): 1,
#  ('lose', 'swallow'): 1,
#  ('swallow', 'UNK'): 1,
#  ('UNK', 'retire'): 3,
#  ('retire', 'great'): 1,
#  ('great', 'security'): 1,
#  ('security', 'sleep'): 1,
#  ('sleep', 'UNK'): 3,
#  ('UNK', 'let'): 10,
#  ('let', 'u'): 25,
#  ('u', 'fly'): 2,
#  ('fly', 'let'): 1,
#  ('fly', 'old'): 1,
#  ('old', 'UNK'): 37,
#  ('take', 'leviathan'): 1,
#  ('leviathan', 'describe'): 1,
#  ('describe', 'noble'): 1,
#  ('noble', 'prophet'): 1,
#  ('prophet', 'mose'): 1,
#  ('mose', 'life'): 1,
#  ('life', 'patient'): 1,
#  ('patient', 'job'): 1,
#  ('job', 'rabelai'): 1,
#  ('rabelai', 'thi'): 1,
#  ('thi', 'whale'): 23,
#  ('whale', 'liver'): 1,
#  ('liver', 'two'): 1,
#  ('two', 'cartload'): 1,
#  ('cartload', 'UNK'): 1,
#  ('UNK', 'annal'): 1,
#  ('annal', 'great'): 1,
#  ('great', 'leviathan'): 7,
#  ('maketh', 'sea'): 1,
#  ('sea', 'seethe'): 1,
#  ('seethe', 'like'): 1,
#  ('like', 'boil'): 1,
#  ('boil', 'pan'): 1,
#  ('pan', 'lord'): 1,
#  ('lord', 'UNK'): 3,
#  ('UNK', 'version'): 1,
#  ('version', 'psalm'): 1,
#  ('psalm', 'touch'): 1,
#  ('touch', 'monstrou'): 1,
#  ('monstrou', 'bulk'): 1,
#  ('bulk', 'whale'): 2,
#  ('UNK', 'receive'): 5,
#  ('receive', 'nothe'): 1,
#  ('nothe', 'certain'): 1,
#  ('certain', 'grow'): 2,
#  ('grow', 'exceed'): 1,
#  ('exceed', 'fat'): 1,
#  ('fat', 'insomuch'): 1,
#  ('insomuch', 'incredible'): 1,
#  ('incredible', 'quantity'): 1,
#  ('quantity', 'oil'): 2,
#  ('oil', 'extract'): 1,
#  ('extract', 'one'): 1,
#  ('one', 'whale'): 5,
#  ('whale', 'ibid'): 1,
#  ('ibid', 'history'): 1,
#  ('history', 'life'): 1,
#  ('life', 'death'): 5,
#  ('death', 'UNK'): 2,
#  ('UNK', 'thing'): 22,
#  ('thing', 'earth'): 1,
#  ('earth', 'parmacetti'): 1,
#  ('parmacetti', 'inward'): 1,
#  ('inward', 'bruise'): 1,
#  ('bruise', 'king'): 1,
#  ('king', 'henry'): 1,
#  ('henry', 'like'): 1,
#  ('like', 'whale'): 3,
#  ('whale', 'hamlet'): 1,
#  ('hamlet', 'secure'): 1,
#  ('secure', 'skill'): 1,
#  ('skill', 'UNK'): 1,
#  ('UNK', 'art'): 1,
#  ('art', 'UNK'): 4,
#  ('UNK', 'hi'): 90,
#  ('hi', 'wound'): 1,
#  ('wound', 'worker'): 1,
#  ('worker', 'lowly'): 1,
#  ('lowly', 'dart'): 1,
#  ('dart', 'dint'): 1,
#  ('dint', 'hi'): 1,
#  ('hi', 'breast'): 1,
#  ('breast', 'breed'): 1,
#  ('breed', 'hi'): 2,
#  ('hi', 'restles'): 2,
#  ('restles', 'UNK'): 1,
#  ('UNK', 'like'): 27,
#  ('like', 'wound'): 1,
#  ('wound', 'whale'): 2,
#  ('whale', 'shore'): 1,
#  ('shore', 'fly'): 1,
#  ('fly', 'UNK'): 1,
#  ('UNK', 'queen'): 2,
#  ('queen', 'immense'): 1,
#  ('immense', 'whale'): 1,
#  ('whale', 'motion'): 1,
#  ('motion', 'whose'): 1,
#  ('whose', 'vast'): 1,
#  ('vast', 'body'): 1,
#  ('body', 'peaceful'): 1,
#  ('peaceful', 'calm'): 1,
#  ('calm', 'trouble'): 1,
#  ('trouble', 'ocean'): 1,
#  ('ocean', 'till'): 2,
#  ('till', 'boil'): 1,
#  ('boil', 'sir'): 1,
#  ('sir', 'william'): 2,
#  ('william', 'UNK'): 1,
#  ('UNK', 'spermacetti'): 1,
#  ('spermacetti', 'men'): 1,
#  ('men', 'might'): 1,
#  ('might', 'justly'): 1,
#  ('justly', 'doubt'): 1,
#  ('doubt', 'since'): 1,
#  ('since', 'learn'): 1,
#  ('learn', 'UNK'): 1,
#  ('hi', 'work'): 2,
#  ('work', 'thirty'): 1,
#  ('thirty', 'year'): 4,
#  ('year', 'saith'): 1,
#  ('saith', 'plainly'): 1,
#  ('plainly', 'UNK'): 1,
#  ('UNK', 'quid'): 1,
#  ('quid', 'sit'): 1,
#  ('sit', 'sir'): 1,
#  ('sir', 't.'): 3,
#  ('t.', 'browne'): 2,
#  ('browne', 'sperma'): 1,
#  ('sperma', 'ceti'): 2,
#  ('ceti', 'sperma'): 1,
#  ('ceti', 'whale'): 1,
#  ('hi', 'v.'): 1,
#  ('v.', 'e.'): 1,
#  ('e.', 'like'): 1,
#  ('like', 'UNK'): 52,
#  ('hi', 'modern'): 1,
#  ('modern', 'flail'): 1,
#  ('flail', 'threaten'): 1,
#  ('threaten', 'ruin'): 1,
#  ('ruin', 'hi'): 1,
#  ('hi', 'ponderou'): 1,
#  ('ponderou', 'tail'): 1,
#  ('tail', '...'): 1,
#  ('...', 'fix'): 1,
#  ('fix', 'UNK'): 2,
#  ('hi', 'side'): 6,
#  ('side', 'wear'): 1,
#  ('wear', 'hi'): 1,
#  ('hi', 'back'): 17,
#  ('back', 'grove'): 1,
#  ...}

# %%
four_counts
# Out:
# {('moby', 'dick', 'whale', 'herman'): 2,
#  ('dick', 'whale', 'herman', 'melville'): 2,
#  ('whale', 'herman', 'melville', 'project'): 1,
#  ('herman', 'melville', 'project', 'gutenberg'): 1,
#  ('melville', 'project', 'gutenberg', 'ebook'): 1,
#  ('project', 'gutenberg', 'ebook', 'moby'): 2,
#  ('gutenberg', 'ebook', 'moby', 'dick'): 2,
#  ('ebook', 'moby', 'dick', 'whale'): 2,
#  ('whale', 'herman', 'melville', 'thi'): 1,
#  ('herman', 'melville', 'thi', 'ebook'): 1,
#  ('melville', 'thi', 'ebook', 'use'): 1,
#  ('thi', 'ebook', 'use', 'anyone'): 1,
#  ('ebook', 'use', 'anyone', 'anywhere'): 1,
#  ('use', 'anyone', 'anywhere', 'cost'): 1,
#  ('anyone', 'anywhere', 'cost', 'almost'): 1,
#  ('anywhere', 'cost', 'almost', 'restriction'): 1,
#  ('cost', 'almost', 'restriction', 'whatsoever'): 1,
#  ('almost', 'restriction', 'whatsoever', 'may'): 1,
#  ('restriction', 'whatsoever', 'may', 'copy'): 1,
#  ('whatsoever', 'may', 'copy', 'give'): 1,
#  ('may', 'copy', 'give', 'away'): 1,
#  ('copy', 'give', 'away', 'reuse'): 1,
#  ('give', 'away', 'reuse', 'term'): 1,
#  ('away', 'reuse', 'term', 'project'): 1,
#  ('reuse', 'term', 'project', 'gutenberg'): 1,
#  ('term', 'project', 'gutenberg', 'license'): 1,
#  ('project', 'gutenberg', 'license', 'include'): 1,
#  ('gutenberg', 'license', 'include', 'thi'): 1,
#  ('license', 'include', 'thi', 'ebook'): 1,
#  ('include', 'thi', 'ebook', 'online'): 1,
#  ('thi', 'ebook', 'online', 'www.gutenberg.org'): 1,
#  ('ebook', 'online', 'www.gutenberg.org', 'title'): 1,
#  ('online', 'www.gutenberg.org', 'title', 'moby'): 1,
#  ('www.gutenberg.org', 'title', 'moby', 'dick'): 1,
#  ('title', 'moby', 'dick', 'whale'): 1,
#  ('moby', 'dick', 'whale', 'author'): 1,
#  ('dick', 'whale', 'author', 'herman'): 1,
#  ('whale', 'author', 'herman', 'melville'): 1,
#  ('author', 'herman', 'melville', 'UNK'): 1,
#  ('herman', 'melville', 'UNK', 'date'): 1,
#  ('melville', 'UNK', 'date', 'december'): 1,
#  ('UNK', 'date', 'december', 'ebook'): 1,
#  ('date', 'december', 'ebook', 'last'): 1,
#  ('december', 'ebook', 'last', 'update'): 1,
#  ('ebook', 'last', 'update', 'december'): 1,
#  ('last', 'update', 'december', 'language'): 1,
#  ('update', 'december', 'language', 'english'): 1,
#  ('december', 'language', 'english', 'character'): 1,
#  ('language', 'english', 'character', 'set'): 1,
#  ('english', 'character', 'set', 'UNK'): 1,
#  ('character', 'set', 'UNK', 'UNK'): 1,
#  ('set', 'UNK', 'UNK', 'start'): 1,
#  ('UNK', 'UNK', 'start', 'thi'): 1,
#  ('UNK', 'start', 'thi', 'project'): 1,
#  ('start', 'thi', 'project', 'gutenberg'): 1,
#  ('thi', 'project', 'gutenberg', 'ebook'): 1,
#  ('moby', 'dick', 'whale', 'produce'): 1,
#  ('dick', 'whale', 'produce', 'daniel'): 1,
#  ('whale', 'produce', 'daniel', 'lazaru'): 1,
#  ('produce', 'daniel', 'lazaru', 'jonesey'): 1,
#  ('daniel', 'lazaru', 'jonesey', 'david'): 1,
#  ('lazaru', 'jonesey', 'david', 'widger'): 1,
#  ('jonesey', 'david', 'widger', 'UNK'): 1,
#  ('david', 'widger', 'UNK', 'whale'): 1,
#  ('widger', 'UNK', 'whale', 'herman'): 1,
#  ('UNK', 'whale', 'herman', 'melville'): 1,
#  ('whale', 'herman', 'melville', 'content'): 1,
#  ('herman', 'melville', 'content', 'etymology'): 1,
#  ('melville', 'content', 'etymology', 'extract'): 1,
#  ('content', 'etymology', 'extract', 'supply'): 1,
#  ('etymology', 'extract', 'supply', 'subsublibrarian'): 1,
#  ('extract', 'supply', 'subsublibrarian', 'chapter'): 1,
#  ('supply', 'subsublibrarian', 'chapter', 'looming'): 1,
#  ('subsublibrarian', 'chapter', 'looming', 'chapter'): 1,
#  ('chapter', 'looming', 'chapter', 'carpetbag'): 1,
#  ('looming', 'chapter', 'carpetbag', 'chapter'): 1,
#  ('chapter', 'carpetbag', 'chapter', 'spouterinn'): 1,
#  ('carpetbag', 'chapter', 'spouterinn', 'chapter'): 1,
#  ('chapter', 'spouterinn', 'chapter', 'counterpane'): 1,
#  ('spouterinn', 'chapter', 'counterpane', 'chapter'): 1,
#  ('chapter', 'counterpane', 'chapter', 'breakfast'): 1,
#  ('counterpane', 'chapter', 'breakfast', 'chapter'): 1,
#  ('chapter', 'breakfast', 'chapter', 'street'): 1,
#  ('breakfast', 'chapter', 'street', 'chapter'): 1,
#  ('chapter', 'street', 'chapter', 'chapel'): 1,
#  ('street', 'chapter', 'chapel', 'chapter'): 1,
#  ('chapter', 'chapel', 'chapter', 'pulpit'): 1,
#  ('chapel', 'chapter', 'pulpit', 'chapter'): 1,
#  ('chapter', 'pulpit', 'chapter', 'sermon'): 1,
#  ('pulpit', 'chapter', 'sermon', 'chapter'): 1,
#  ('chapter', 'sermon', 'chapter', 'bosom'): 1,
#  ('sermon', 'chapter', 'bosom', 'friend'): 1,
#  ('chapter', 'bosom', 'friend', 'chapter'): 1,
#  ('bosom', 'friend', 'chapter', 'nightgown'): 1,
#  ('friend', 'chapter', 'nightgown', 'chapter'): 1,
#  ('chapter', 'nightgown', 'chapter', 'biographical'): 1,
#  ('nightgown', 'chapter', 'biographical', 'chapter'): 1,
#  ('chapter', 'biographical', 'chapter', 'wheelbarrow'): 1,
#  ('biographical', 'chapter', 'wheelbarrow', 'chapter'): 1,
#  ('chapter', 'wheelbarrow', 'chapter', 'nantucket'): 1,
#  ('wheelbarrow', 'chapter', 'nantucket', 'chapter'): 1,
#  ('chapter', 'nantucket', 'chapter', 'chowder'): 1,
#  ('nantucket', 'chapter', 'chowder', 'chapter'): 1,
#  ('chapter', 'chowder', 'chapter', 'ship'): 1,
#  ('chowder', 'chapter', 'ship', 'chapter'): 1,
#  ('chapter', 'ship', 'chapter', 'ramadan'): 1,
#  ('ship', 'chapter', 'ramadan', 'chapter'): 1,
#  ('chapter', 'ramadan', 'chapter', 'hi'): 1,
#  ('ramadan', 'chapter', 'hi', 'mark'): 1,
#  ('chapter', 'hi', 'mark', 'chapter'): 1,
#  ('hi', 'mark', 'chapter', 'prophet'): 1,
#  ('mark', 'chapter', 'prophet', 'chapter'): 1,
#  ('chapter', 'prophet', 'chapter', 'astir'): 1,
#  ('prophet', 'chapter', 'astir', 'chapter'): 1,
#  ('chapter', 'astir', 'chapter', 'go'): 1,
#  ('astir', 'chapter', 'go', 'aboard'): 1,
#  ('chapter', 'go', 'aboard', 'chapter'): 1,
#  ('go', 'aboard', 'chapter', 'merry'): 1,
#  ('aboard', 'chapter', 'merry', 'christma'): 1,
#  ('chapter', 'merry', 'christma', 'chapter'): 1,
#  ('merry', 'christma', 'chapter', 'lee'): 1,
#  ('christma', 'chapter', 'lee', 'shore'): 1,
#  ('chapter', 'lee', 'shore', 'chapter'): 2,
#  ('lee', 'shore', 'chapter', 'advocate'): 1,
#  ('shore', 'chapter', 'advocate', 'chapter'): 1,
#  ('chapter', 'advocate', 'chapter', 'postscript'): 1,
#  ('advocate', 'chapter', 'postscript', 'chapter'): 1,
#  ('chapter', 'postscript', 'chapter', 'knight'): 1,
#  ('postscript', 'chapter', 'knight', 'squire'): 1,
#  ('chapter', 'knight', 'squire', 'chapter'): 2,
#  ('knight', 'squire', 'chapter', 'knight'): 1,
#  ('squire', 'chapter', 'knight', 'squire'): 1,
#  ('knight', 'squire', 'chapter', 'ahab'): 1,
#  ('squire', 'chapter', 'ahab', 'chapter'): 1,
#  ('chapter', 'ahab', 'chapter', 'enter'): 1,
#  ('ahab', 'chapter', 'enter', 'ahab'): 1,
#  ('chapter', 'enter', 'ahab', 'stubb'): 2,
#  ('enter', 'ahab', 'stubb', 'chapter'): 1,
#  ('ahab', 'stubb', 'chapter', 'pipe'): 1,
#  ('stubb', 'chapter', 'pipe', 'chapter'): 1,
#  ('chapter', 'pipe', 'chapter', 'queen'): 1,
#  ('pipe', 'chapter', 'queen', 'mab'): 1,
#  ('chapter', 'queen', 'mab', 'chapter'): 1,
#  ('queen', 'mab', 'chapter', 'cetology'): 1,
#  ('mab', 'chapter', 'cetology', 'chapter'): 1,
#  ('chapter', 'cetology', 'chapter', 'specksnyder'): 1,
#  ('cetology', 'chapter', 'specksnyder', 'chapter'): 1,
#  ('chapter', 'specksnyder', 'chapter', 'cabintable'): 1,
#  ('specksnyder', 'chapter', 'cabintable', 'chapter'): 1,
#  ('chapter', 'cabintable', 'chapter', 'masthead'): 1,
#  ('cabintable', 'chapter', 'masthead', 'chapter'): 1,
#  ('chapter', 'masthead', 'chapter', 'quarterdeck'): 1,
#  ('masthead', 'chapter', 'quarterdeck', 'chapter'): 1,
#  ('chapter', 'quarterdeck', 'chapter', 'sunset'): 1,
#  ('quarterdeck', 'chapter', 'sunset', 'chapter'): 1,
#  ('chapter', 'sunset', 'chapter', 'dusk'): 1,
#  ('sunset', 'chapter', 'dusk', 'chapter'): 1,
#  ('chapter', 'dusk', 'chapter', 'first'): 1,
#  ('dusk', 'chapter', 'first', 'nightwatch'): 1,
#  ('chapter', 'first', 'nightwatch', 'chapter'): 1,
#  ('first', 'nightwatch', 'chapter', 'midnight'): 1,
#  ('nightwatch', 'chapter', 'midnight', 'forecastle'): 1,
#  ('chapter', 'midnight', 'forecastle', 'chapter'): 1,
#  ('midnight', 'forecastle', 'chapter', 'moby'): 1,
#  ('forecastle', 'chapter', 'moby', 'dick'): 1,
#  ('chapter', 'moby', 'dick', 'chapter'): 1,
#  ('moby', 'dick', 'chapter', 'whitenes'): 1,
#  ('dick', 'chapter', 'whitenes', 'whale'): 1,
#  ('chapter', 'whitenes', 'whale', 'chapter'): 1,
#  ('whitenes', 'whale', 'chapter', 'hark'): 1,
#  ('whale', 'chapter', 'hark', 'chapter'): 1,
#  ('chapter', 'hark', 'chapter', 'chart'): 1,
#  ('hark', 'chapter', 'chart', 'chapter'): 1,
#  ('chapter', 'chart', 'chapter', 'affidavit'): 1,
#  ('chart', 'chapter', 'affidavit', 'chapter'): 1,
#  ('chapter', 'affidavit', 'chapter', 'surmise'): 1,
#  ('affidavit', 'chapter', 'surmise', 'chapter'): 1,
#  ('chapter', 'surmise', 'chapter', 'matmaker'): 1,
#  ('surmise', 'chapter', 'matmaker', 'chapter'): 1,
#  ('chapter', 'matmaker', 'chapter', 'first'): 1,
#  ('matmaker', 'chapter', 'first', 'lower'): 1,
#  ('chapter', 'first', 'lower', 'chapter'): 1,
#  ('first', 'lower', 'chapter', 'hyena'): 1,
#  ('lower', 'chapter', 'hyena', 'chapter'): 1,
#  ('chapter', 'hyena', 'chapter', 'ahab'): 1,
#  ('hyena', 'chapter', 'ahab', 'boat'): 1,
#  ('chapter', 'ahab', 'boat', 'crew'): 2,
#  ('ahab', 'boat', 'crew', 'fedallah'): 2,
#  ('boat', 'crew', 'fedallah', 'chapter'): 1,
#  ('crew', 'fedallah', 'chapter', 'spiritspout'): 1,
#  ('fedallah', 'chapter', 'spiritspout', 'chapter'): 1,
#  ('chapter', 'spiritspout', 'chapter', 'albatros'): 1,
#  ('spiritspout', 'chapter', 'albatros', 'chapter'): 1,
#  ('chapter', 'albatros', 'chapter', 'gam'): 1,
#  ('albatros', 'chapter', 'gam', 'chapter'): 1,
#  ('chapter', 'gam', 'chapter', 'townho'): 1,
#  ('gam', 'chapter', 'townho', 'story'): 1,
#  ('chapter', 'townho', 'story', 'chapter'): 1,
#  ('townho', 'story', 'chapter', 'monstrou'): 1,
#  ('story', 'chapter', 'monstrou', 'picture'): 1,
#  ('chapter', 'monstrou', 'picture', 'whale'): 2,
#  ('monstrou', 'picture', 'whale', 'chapter'): 1,
#  ('picture', 'whale', 'chapter', 'les'): 1,
#  ('whale', 'chapter', 'les', 'erroneou'): 1,
#  ('chapter', 'les', 'erroneou', 'picture'): 2,
#  ('les', 'erroneou', 'picture', 'whale'): 2,
#  ('erroneou', 'picture', 'whale', 'true'): 2,
#  ('picture', 'whale', 'true', 'picture'): 2,
#  ('whale', 'true', 'picture', 'whale'): 2,
#  ('true', 'picture', 'whale', 'scene'): 2,
#  ('picture', 'whale', 'scene', 'chapter'): 1,
#  ('whale', 'scene', 'chapter', 'whale'): 1,
#  ('scene', 'chapter', 'whale', 'paint'): 1,
#  ('chapter', 'whale', 'paint', 'teeth'): 2,
#  ('whale', 'paint', 'teeth', 'wood'): 2,
#  ('paint', 'teeth', 'wood', 'sheetiron'): 2,
#  ('teeth', 'wood', 'sheetiron', 'stone'): 2,
#  ('wood', 'sheetiron', 'stone', 'mountain'): 2,
#  ('sheetiron', 'stone', 'mountain', 'star'): 2,
#  ('stone', 'mountain', 'star', 'chapter'): 1,
#  ('mountain', 'star', 'chapter', 'brit'): 1,
#  ('star', 'chapter', 'brit', 'chapter'): 1,
#  ('chapter', 'brit', 'chapter', 'squid'): 1,
#  ('brit', 'chapter', 'squid', 'chapter'): 1,
#  ('chapter', 'squid', 'chapter', 'line'): 1,
#  ('squid', 'chapter', 'line', 'chapter'): 1,
#  ('chapter', 'line', 'chapter', 'stubb'): 1,
#  ('line', 'chapter', 'stubb', 'kill'): 1,
#  ('chapter', 'stubb', 'kill', 'whale'): 2,
#  ('stubb', 'kill', 'whale', 'chapter'): 1,
#  ('kill', 'whale', 'chapter', 'dart'): 1,
#  ('whale', 'chapter', 'dart', 'chapter'): 1,
#  ('chapter', 'dart', 'chapter', 'crotch'): 1,
#  ('dart', 'chapter', 'crotch', 'chapter'): 1,
#  ('chapter', 'crotch', 'chapter', 'stubb'): 1,
#  ('crotch', 'chapter', 'stubb', 'supper'): 1,
#  ('chapter', 'stubb', 'supper', 'chapter'): 1,
#  ('stubb', 'supper', 'chapter', 'whale'): 1,
#  ('supper', 'chapter', 'whale', 'dish'): 1,
#  ('chapter', 'whale', 'dish', 'chapter'): 1,
#  ('whale', 'dish', 'chapter', 'shark'): 1,
#  ('dish', 'chapter', 'shark', 'massacre'): 1,
#  ('chapter', 'shark', 'massacre', 'chapter'): 1,
#  ('shark', 'massacre', 'chapter', 'cut'): 1,
#  ('massacre', 'chapter', 'cut', 'chapter'): 1,
#  ('chapter', 'cut', 'chapter', 'blanket'): 1,
#  ('cut', 'chapter', 'blanket', 'chapter'): 1,
#  ('chapter', 'blanket', 'chapter', 'funeral'): 1,
#  ('blanket', 'chapter', 'funeral', 'chapter'): 1,
#  ('chapter', 'funeral', 'chapter', 'sphynx'): 1,
#  ('funeral', 'chapter', 'sphynx', 'chapter'): 1,
#  ('chapter', 'sphynx', 'chapter', 'jeroboam'): 1,
#  ('sphynx', 'chapter', 'jeroboam', 'story'): 1,
#  ('chapter', 'jeroboam', 'story', 'chapter'): 1,
#  ('jeroboam', 'story', 'chapter', 'monkeyrope'): 1,
#  ('story', 'chapter', 'monkeyrope', 'chapter'): 1,
#  ('chapter', 'monkeyrope', 'chapter', 'stubb'): 1,
#  ('monkeyrope', 'chapter', 'stubb', 'flask'): 1,
#  ('chapter', 'stubb', 'flask', 'kill'): 2,
#  ('stubb', 'flask', 'kill', 'right'): 2,
#  ('flask', 'kill', 'right', 'whale'): 2,
#  ('kill', 'right', 'whale', 'talk'): 2,
#  ('right', 'whale', 'talk', 'chapter'): 1,
#  ('whale', 'talk', 'chapter', 'sperm'): 1,
#  ('talk', 'chapter', 'sperm', 'whale'): 1,
#  ('chapter', 'sperm', 'whale', 'headcontrast'): 2,
#  ('sperm', 'whale', 'headcontrast', 'view'): 2,
#  ('whale', 'headcontrast', 'view', 'chapter'): 2,
#  ('headcontrast', 'view', 'chapter', 'right'): 1,
#  ('view', 'chapter', 'right', 'whale'): 1,
#  ('chapter', 'right', 'whale', 'headcontrast'): 2,
#  ('right', 'whale', 'headcontrast', 'view'): 2,
#  ('headcontrast', 'view', 'chapter', 'batteringram'): 1,
#  ('view', 'chapter', 'batteringram', 'chapter'): 1,
#  ('chapter', 'batteringram', 'chapter', 'great'): 1,
#  ('batteringram', 'chapter', 'great', 'heidelburgh'): 1,
#  ('chapter', 'great', 'heidelburgh', 'tun'): 2,
#  ('great', 'heidelburgh', 'tun', 'chapter'): 1,
#  ('heidelburgh', 'tun', 'chapter', 'cistern'): 1,
#  ('tun', 'chapter', 'cistern', 'bucket'): 1,
#  ('chapter', 'cistern', 'bucket', 'chapter'): 1,
#  ('cistern', 'bucket', 'chapter', 'prairie'): 1,
#  ('bucket', 'chapter', 'prairie', 'chapter'): 1,
#  ('chapter', 'prairie', 'chapter', 'nut'): 1,
#  ('prairie', 'chapter', 'nut', 'chapter'): 1,
#  ('chapter', 'nut', 'chapter', 'pequod'): 1,
#  ('nut', 'chapter', 'pequod', 'meet'): 1,
#  ('chapter', 'pequod', 'meet', 'virgin'): 2,
#  ('pequod', 'meet', 'virgin', 'chapter'): 1,
#  ('meet', 'virgin', 'chapter', 'honor'): 1,
#  ('virgin', 'chapter', 'honor', 'glory'): 1,
#  ('chapter', 'honor', 'glory', 'whale'): 2,
#  ('honor', 'glory', 'whale', 'chapter'): 1,
#  ('glory', 'whale', 'chapter', 'jonah'): 1,
#  ('whale', 'chapter', 'jonah', 'historically'): 1,
#  ('chapter', 'jonah', 'historically', 'regard'): 2,
#  ('jonah', 'historically', 'regard', 'chapter'): 1,
#  ('historically', 'regard', 'chapter', 'pitchpole'): 1,
#  ('regard', 'chapter', 'pitchpole', 'chapter'): 1,
#  ('chapter', 'pitchpole', 'chapter', 'fountain'): 1,
#  ('pitchpole', 'chapter', 'fountain', 'chapter'): 1,
#  ('chapter', 'fountain', 'chapter', 'tail'): 1,
#  ('fountain', 'chapter', 'tail', 'chapter'): 1,
#  ('chapter', 'tail', 'chapter', 'grand'): 1,
#  ('tail', 'chapter', 'grand', 'armada'): 1,
#  ('chapter', 'grand', 'armada', 'chapter'): 1,
#  ('grand', 'armada', 'chapter', 'school'): 1,
#  ('armada', 'chapter', 'school', 'schoolmaster'): 1,
#  ('chapter', 'school', 'schoolmaster', 'chapter'): 1,
#  ('school', 'schoolmaster', 'chapter', 'fastfish'): 1,
#  ('schoolmaster', 'chapter', 'fastfish', 'loosefish'): 1,
#  ('chapter', 'fastfish', 'loosefish', 'chapter'): 1,
#  ('fastfish', 'loosefish', 'chapter', 'head'): 1,
#  ('loosefish', 'chapter', 'head', 'tail'): 1,
#  ('chapter', 'head', 'tail', 'chapter'): 1,
#  ('head', 'tail', 'chapter', 'pequod'): 1,
#  ('tail', 'chapter', 'pequod', 'meet'): 1,
#  ('chapter', 'pequod', 'meet', 'rosebud'): 2,
#  ('pequod', 'meet', 'rosebud', 'chapter'): 1,
#  ('meet', 'rosebud', 'chapter', 'ambergri'): 1,
#  ('rosebud', 'chapter', 'ambergri', 'chapter'): 1,
#  ('chapter', 'ambergri', 'chapter', 'castaway'): 1,
#  ('ambergri', 'chapter', 'castaway', 'chapter'): 1,
#  ('chapter', 'castaway', 'chapter', 'squeeze'): 1,
#  ('castaway', 'chapter', 'squeeze', 'hand'): 1,
#  ('chapter', 'squeeze', 'hand', 'chapter'): 1,
#  ('squeeze', 'hand', 'chapter', 'cassock'): 1,
#  ('hand', 'chapter', 'cassock', 'chapter'): 1,
#  ('chapter', 'cassock', 'chapter', 'trywork'): 1,
#  ('cassock', 'chapter', 'trywork', 'chapter'): 1,
#  ('chapter', 'trywork', 'chapter', 'lamp'): 1,
#  ('trywork', 'chapter', 'lamp', 'chapter'): 1,
#  ('chapter', 'lamp', 'chapter', 'stow'): 1,
#  ('lamp', 'chapter', 'stow', 'clear'): 1,
#  ('chapter', 'stow', 'clear', 'chapter'): 1,
#  ('stow', 'clear', 'chapter', 'doubloon'): 1,
#  ('clear', 'chapter', 'doubloon', 'chapter'): 1,
#  ('chapter', 'doubloon', 'chapter', 'leg'): 1,
#  ('doubloon', 'chapter', 'leg', 'arm'): 1,
#  ('chapter', 'leg', 'arm', 'chapter'): 1,
#  ('leg', 'arm', 'chapter', 'decanter'): 1,
#  ('arm', 'chapter', 'decanter', 'chapter'): 1,
#  ('chapter', 'decanter', 'chapter', 'bower'): 1,
#  ('decanter', 'chapter', 'bower', 'arsacide'): 1,
#  ('chapter', 'bower', 'arsacide', 'chapter'): 1,
#  ('bower', 'arsacide', 'chapter', 'measurement'): 1,
#  ('arsacide', 'chapter', 'measurement', 'whale'): 1,
#  ('chapter', 'measurement', 'whale', 'skeleton'): 1,
#  ('measurement', 'whale', 'skeleton', 'chapter'): 1,
#  ('whale', 'skeleton', 'chapter', 'fossil'): 1,
#  ('skeleton', 'chapter', 'fossil', 'whale'): 1,
#  ('chapter', 'fossil', 'whale', 'chapter'): 1,
#  ('fossil', 'whale', 'chapter', 'whale'): 1,
#  ('whale', 'chapter', 'whale', 'magnitude'): 1,
#  ('chapter', 'whale', 'magnitude', 'diminishwill'): 1,
#  ('whale', 'magnitude', 'diminishwill', 'perish'): 1,
#  ('magnitude', 'diminishwill', 'perish', 'chapter'): 1,
#  ('diminishwill', 'perish', 'chapter', 'ahab'): 1,
#  ('perish', 'chapter', 'ahab', 'leg'): 1,
#  ('chapter', 'ahab', 'leg', 'chapter'): 1,
#  ('ahab', 'leg', 'chapter', 'carpenter'): 1,
#  ('leg', 'chapter', 'carpenter', 'chapter'): 1,
#  ('chapter', 'carpenter', 'chapter', 'ahab'): 1,
#  ('carpenter', 'chapter', 'ahab', 'carpenter'): 1,
#  ('chapter', 'ahab', 'carpenter', 'chapter'): 1,
#  ('ahab', 'carpenter', 'chapter', 'ahab'): 1,
#  ('carpenter', 'chapter', 'ahab', 'starbuck'): 1,
#  ('chapter', 'ahab', 'starbuck', 'cabin'): 1,
#  ('ahab', 'starbuck', 'cabin', 'chapter'): 1,
#  ('starbuck', 'cabin', 'chapter', 'queequeg'): 1,
#  ('cabin', 'chapter', 'queequeg', 'hi'): 1,
#  ('chapter', 'queequeg', 'hi', 'coffin'): 1,
#  ('queequeg', 'hi', 'coffin', 'chapter'): 1,
#  ('hi', 'coffin', 'chapter', 'pacific'): 1,
#  ('coffin', 'chapter', 'pacific', 'chapter'): 1,
#  ('chapter', 'pacific', 'chapter', 'blacksmith'): 1,
#  ('pacific', 'chapter', 'blacksmith', 'chapter'): 1,
#  ('chapter', 'blacksmith', 'chapter', 'forge'): 1,
#  ('blacksmith', 'chapter', 'forge', 'chapter'): 1,
#  ('chapter', 'forge', 'chapter', 'gilder'): 1,
#  ('forge', 'chapter', 'gilder', 'chapter'): 1,
#  ('chapter', 'gilder', 'chapter', 'pequod'): 1,
#  ('gilder', 'chapter', 'pequod', 'meet'): 1,
#  ('chapter', 'pequod', 'meet', 'bachelor'): 1,
#  ('pequod', 'meet', 'bachelor', 'chapter'): 1,
#  ('meet', 'bachelor', 'chapter', 'die'): 1,
#  ('bachelor', 'chapter', 'die', 'whale'): 1,
#  ('chapter', 'die', 'whale', 'chapter'): 1,
#  ('die', 'whale', 'chapter', 'whale'): 1,
#  ('whale', 'chapter', 'whale', 'watch'): 1,
#  ('chapter', 'whale', 'watch', 'chapter'): 1,
#  ('whale', 'watch', 'chapter', 'quadrant'): 1,
#  ('watch', 'chapter', 'quadrant', 'chapter'): 1,
#  ('chapter', 'quadrant', 'chapter', 'candle'): 1,
#  ('quadrant', 'chapter', 'candle', 'chapter'): 1,
#  ('chapter', 'candle', 'chapter', 'deck'): 1,
#  ('candle', 'chapter', 'deck', 'toward'): 1,
#  ('chapter', 'deck', 'toward', 'end'): 1,
#  ('deck', 'toward', 'end', 'first'): 1,
#  ('toward', 'end', 'first', 'night'): 1,
#  ('end', 'first', 'night', 'watch'): 1,
#  ('first', 'night', 'watch', 'chapter'): 1,
#  ('night', 'watch', 'chapter', 'midnight.the'): 1,
#  ('watch', 'chapter', 'midnight.the', 'forecastle'): 1,
#  ('chapter', 'midnight.the', 'forecastle', 'bulwark'): 1,
#  ('midnight.the', 'forecastle', 'bulwark', 'chapter'): 1,
#  ('forecastle', 'bulwark', 'chapter', 'midnight'): 1,
#  ('bulwark', 'chapter', 'midnight', 'aloft.thunder'): 1,
#  ('chapter', 'midnight', 'aloft.thunder', 'lightn'): 1,
#  ('midnight', 'aloft.thunder', 'lightn', 'chapter'): 1,
#  ('aloft.thunder', 'lightn', 'chapter', 'musket'): 1,
#  ('lightn', 'chapter', 'musket', 'chapter'): 1,
#  ('chapter', 'musket', 'chapter', 'needle'): 1,
#  ('musket', 'chapter', 'needle', 'chapter'): 1,
#  ('chapter', 'needle', 'chapter', 'log'): 1,
#  ('needle', 'chapter', 'log', 'line'): 1,
#  ('chapter', 'log', 'line', 'chapter'): 1,
#  ('log', 'line', 'chapter', 'lifebuoy'): 1,
#  ('line', 'chapter', 'lifebuoy', 'chapter'): 1,
#  ('chapter', 'lifebuoy', 'chapter', 'deck'): 1,
#  ('lifebuoy', 'chapter', 'deck', 'chapter'): 1,
#  ('chapter', 'deck', 'chapter', 'pequod'): 1,
#  ('deck', 'chapter', 'pequod', 'meet'): 1,
#  ('chapter', 'pequod', 'meet', 'rachel'): 1,
#  ('pequod', 'meet', 'rachel', 'chapter'): 1,
#  ('meet', 'rachel', 'chapter', 'cabin'): 1,
#  ('rachel', 'chapter', 'cabin', 'chapter'): 1,
#  ('chapter', 'cabin', 'chapter', 'hat'): 1,
#  ('cabin', 'chapter', 'hat', 'chapter'): 1,
#  ('chapter', 'hat', 'chapter', 'pequod'): 1,
#  ('hat', 'chapter', 'pequod', 'meet'): 1,
#  ('chapter', 'pequod', 'meet', 'delight'): 1,
#  ('pequod', 'meet', 'delight', 'chapter'): 1,
#  ('meet', 'delight', 'chapter', 'symphony'): 1,
#  ('delight', 'chapter', 'symphony', 'chapter'): 1,
#  ('chapter', 'symphony', 'chapter', 'chasefirst'): 1,
#  ('symphony', 'chapter', 'chasefirst', 'day'): 1,
#  ('chapter', 'chasefirst', 'day', 'chapter'): 1,
#  ('chasefirst', 'day', 'chapter', 'chasesecond'): 1,
#  ('day', 'chapter', 'chasesecond', 'day'): 1,
#  ('chapter', 'chasesecond', 'day', 'chapter'): 1,
#  ('chasesecond', 'day', 'chapter', 'chase.third'): 1,
#  ('day', 'chapter', 'chase.third', 'day'): 1,
#  ('chapter', 'chase.third', 'day', 'epilogue'): 1,
#  ('chase.third', 'day', 'epilogue', 'original'): 1,
#  ('day', 'epilogue', 'original', 'UNK'): 1,
#  ('epilogue', 'original', 'UNK', 'note'): 1,
#  ('original', 'UNK', 'note', 'thi'): 1,
#  ('UNK', 'note', 'thi', 'text'): 1,
#  ('note', 'thi', 'text', 'combination'): 1,
#  ('thi', 'text', 'combination', 'etext'): 1,
#  ('text', 'combination', 'etext', 'one'): 1,
#  ('combination', 'etext', 'one', 'UNK'): 1,
#  ('etext', 'one', 'UNK', 'UNK'): 1,
#  ('one', 'UNK', 'UNK', 'project'): 1,
#  ('UNK', 'UNK', 'project', 'virginia'): 1,
#  ('UNK', 'project', 'virginia', 'tech'): 1,
#  ('project', 'virginia', 'tech', 'one'): 1,
#  ('virginia', 'tech', 'one', 'project'): 1,
#  ('tech', 'one', 'project', 'gutenberg'): 1,
#  ('one', 'project', 'gutenberg', 'archive'): 1,
#  ('project', 'gutenberg', 'archive', 'UNK'): 1,
#  ('gutenberg', 'archive', 'UNK', 'thi'): 1,
#  ('archive', 'UNK', 'thi', 'version'): 1,
#  ('UNK', 'thi', 'version', 'indebt'): 1,
#  ('thi', 'version', 'indebt', 'UNK'): 1,
#  ('version', 'indebt', 'UNK', 'UNK'): 1,
#  ('indebt', 'UNK', 'UNK', 'library'): 1,
#  ('UNK', 'UNK', 'library', 'preserve'): 1,
#  ('UNK', 'library', 'preserve', 'virginia'): 1,
#  ('library', 'preserve', 'virginia', 'tech'): 1,
#  ('preserve', 'virginia', 'tech', 'version'): 1,
#  ('virginia', 'tech', 'version', 'result'): 1,
#  ('tech', 'version', 'result', 'etext'): 1,
#  ('version', 'result', 'etext', 'compare'): 1,
#  ('result', 'etext', 'compare', 'public'): 1,
#  ('etext', 'compare', 'public', 'domain'): 1,
#  ('compare', 'public', 'domain', 'hard'): 1,
#  ('public', 'domain', 'hard', 'copy'): 1,
#  ('domain', 'hard', 'copy', 'version'): 1,
#  ('hard', 'copy', 'version', 'text'): 1,
#  ('copy', 'version', 'text', 'etymology'): 1,
#  ('version', 'text', 'etymology', 'supply'): 1,
#  ('text', 'etymology', 'supply', 'late'): 1,
#  ('etymology', 'supply', 'late', 'UNK'): 1,
#  ('supply', 'late', 'UNK', 'usher'): 1,
#  ('late', 'UNK', 'usher', 'grammar'): 1,
#  ('UNK', 'usher', 'grammar', 'school'): 1,
#  ('usher', 'grammar', 'school', 'pale'): 1,
#  ('grammar', 'school', 'pale', 'UNK'): 1,
#  ('school', 'pale', 'UNK', 'coat'): 1,
#  ('pale', 'UNK', 'coat', 'heart'): 1,
#  ('UNK', 'coat', 'heart', 'body'): 1,
#  ('coat', 'heart', 'body', 'brain'): 1,
#  ('heart', 'body', 'brain', 'see'): 1,
#  ('body', 'brain', 'see', 'ever'): 1,
#  ('brain', 'see', 'ever', 'dust'): 1,
#  ('see', 'ever', 'dust', 'hi'): 1,
#  ('ever', 'dust', 'hi', 'old'): 1,
#  ('dust', 'hi', 'old', 'lexicon'): 1,
#  ('hi', 'old', 'lexicon', 'grammar'): 1,
#  ('old', 'lexicon', 'grammar', 'queer'): 1,
#  ('lexicon', 'grammar', 'queer', 'handkerchief'): 1,
#  ('grammar', 'queer', 'handkerchief', 'UNK'): 1,
#  ('queer', 'handkerchief', 'UNK', 'embellish'): 1,
#  ('handkerchief', 'UNK', 'embellish', 'gay'): 1,
#  ('UNK', 'embellish', 'gay', 'flag'): 1,
#  ('embellish', 'gay', 'flag', 'know'): 1,
#  ('gay', 'flag', 'know', 'nation'): 1,
#  ('flag', 'know', 'nation', 'world'): 1,
#  ('know', 'nation', 'world', 'love'): 1,
#  ('nation', 'world', 'love', 'dust'): 1,
#  ('world', 'love', 'dust', 'hi'): 1,
#  ('love', 'dust', 'hi', 'old'): 1,
#  ('dust', 'hi', 'old', 'grammar'): 1,
#  ('hi', 'old', 'grammar', 'somehow'): 1,
#  ('old', 'grammar', 'somehow', 'mildly'): 1,
#  ('grammar', 'somehow', 'mildly', 'remind'): 1,
#  ('somehow', 'mildly', 'remind', 'hi'): 1,
#  ('mildly', 'remind', 'hi', 'mortality'): 1,
#  ('remind', 'hi', 'mortality', 'take'): 1,
#  ('hi', 'mortality', 'take', 'hand'): 1,
#  ('mortality', 'take', 'hand', 'school'): 1,
#  ('take', 'hand', 'school', 'teach'): 1,
#  ('hand', 'school', 'teach', 'name'): 1,
#  ('school', 'teach', 'name', 'UNK'): 1,
#  ('teach', 'name', 'UNK', 'call'): 1,
#  ('name', 'UNK', 'call', 'tongue'): 1,
#  ('UNK', 'call', 'tongue', 'leave'): 1,
#  ('call', 'tongue', 'leave', 'ignorance'): 1,
#  ('tongue', 'leave', 'ignorance', 'letter'): 1,
#  ('leave', 'ignorance', 'letter', 'UNK'): 1,
#  ('ignorance', 'letter', 'UNK', 'almost'): 1,
#  ('letter', 'UNK', 'almost', 'alone'): 1,
#  ('UNK', 'almost', 'alone', 'maketh'): 1,
#  ('almost', 'alone', 'maketh', 'UNK'): 1,
#  ('alone', 'maketh', 'UNK', 'word'): 1,
#  ('maketh', 'UNK', 'word', 'deliver'): 1,
#  ('UNK', 'word', 'deliver', 'true'): 1,
#  ('word', 'deliver', 'true', 'hackluyt'): 1,
#  ('deliver', 'true', 'hackluyt', 'whale'): 1,
#  ('true', 'hackluyt', 'whale', 'UNK'): 1,
#  ('hackluyt', 'whale', 'UNK', 'dan'): 1,
#  ('whale', 'UNK', 'dan', 'UNK'): 1,
#  ('UNK', 'dan', 'UNK', 'thi'): 1,
#  ('dan', 'UNK', 'thi', 'animal'): 1,
#  ('UNK', 'thi', 'animal', 'name'): 1,
#  ('thi', 'animal', 'name', 'UNK'): 1,
#  ('animal', 'name', 'UNK', 'roll'): 1,
#  ('name', 'UNK', 'roll', 'dan'): 1,
#  ('UNK', 'roll', 'dan', 'hvalt'): 1,
#  ('roll', 'dan', 'hvalt', 'arch'): 1,
#  ('dan', 'hvalt', 'arch', 'vault'): 1,
#  ('hvalt', 'arch', 'vault', 'webster'): 1,
#  ('arch', 'vault', 'webster', 'dictionary'): 1,
#  ('vault', 'webster', 'dictionary', 'whale'): 1,
#  ('webster', 'dictionary', 'whale', 'immediately'): 1,
#  ('dictionary', 'whale', 'immediately', 'UNK'): 1,
#  ('whale', 'immediately', 'UNK', 'UNK'): 1,
#  ('immediately', 'UNK', 'UNK', 'UNK'): 1,
#  ('UNK', 'UNK', 'UNK', 'UNK'): 23,
#  ('UNK', 'UNK', 'UNK', 'roll'): 1,
#  ('UNK', 'UNK', 'roll', 'wallow'): 1,
#  ('UNK', 'roll', 'wallow', 'UNK'): 1,
#  ('roll', 'wallow', 'UNK', 'dictionary'): 1,
#  ('wallow', 'UNK', 'dictionary', 'hebrew'): 1,
#  ('UNK', 'dictionary', 'hebrew', 'greek'): 1,
#  ('dictionary', 'hebrew', 'greek', 'cetu'): 1,
#  ('hebrew', 'greek', 'cetu', 'latin'): 1,
#  ('greek', 'cetu', 'latin', 'UNK'): 1,
#  ('cetu', 'latin', 'UNK', 'UNK'): 1,
#  ('latin', 'UNK', 'UNK', 'hvalt'): 1,
#  ('UNK', 'UNK', 'hvalt', 'danish'): 1,
#  ('UNK', 'hvalt', 'danish', 'UNK'): 1,
#  ('hvalt', 'danish', 'UNK', 'dutch'): 1,
#  ('danish', 'UNK', 'dutch', 'UNK'): 1,
#  ('UNK', 'dutch', 'UNK', 'UNK'): 1,
#  ('dutch', 'UNK', 'UNK', 'whale'): 1,
#  ('UNK', 'UNK', 'whale', 'icelandic'): 1,
#  ('UNK', 'whale', 'icelandic', 'whale'): 1,
#  ('whale', 'icelandic', 'whale', 'english'): 1,
#  ('icelandic', 'whale', 'english', 'baleine'): 1,
#  ('whale', 'english', 'baleine', 'french'): 1,
#  ('english', 'baleine', 'french', 'UNK'): 1,
#  ('baleine', 'french', 'UNK', 'spanish'): 1,
#  ('french', 'UNK', 'spanish', 'UNK'): 1,
#  ('UNK', 'spanish', 'UNK', 'UNK'): 1,
#  ('spanish', 'UNK', 'UNK', 'UNK'): 1,
#  ('UNK', 'UNK', 'UNK', 'extract'): 1,
#  ('UNK', 'UNK', 'extract', 'supply'): 1,
#  ('UNK', 'extract', 'supply', 'subsublibrarian'): 1,
#  ('extract', 'supply', 'subsublibrarian', 'see'): 1,
#  ('supply', 'subsublibrarian', 'see', 'thi'): 1,
#  ('subsublibrarian', 'see', 'thi', 'mere'): 1,
#  ('see', 'thi', 'mere', 'UNK'): 1,
#  ('thi', 'mere', 'UNK', 'UNK'): 1,
#  ('mere', 'UNK', 'UNK', 'UNK'): 1,
#  ('UNK', 'UNK', 'UNK', 'poor'): 1,
#  ('UNK', 'UNK', 'poor', 'devil'): 1,
#  ('UNK', 'poor', 'devil', 'subsub'): 1,
#  ('poor', 'devil', 'subsub', 'appear'): 1,
#  ('devil', 'subsub', 'appear', 'go'): 1,
#  ('subsub', 'appear', 'go', 'long'): 1,
#  ('appear', 'go', 'long', 'UNK'): 1,
#  ('go', 'long', 'UNK', 'UNK'): 1,
#  ('long', 'UNK', 'UNK', 'earth'): 1,
#  ('UNK', 'UNK', 'earth', 'pick'): 1,
#  ('UNK', 'earth', 'pick', 'whatever'): 1,
#  ('earth', 'pick', 'whatever', 'random'): 1,
#  ('pick', 'whatever', 'random', 'allusion'): 1,
#  ('whatever', 'random', 'allusion', 'whale'): 1,
#  ('random', 'allusion', 'whale', 'anyway'): 1,
#  ('allusion', 'whale', 'anyway', 'find'): 1,
#  ('whale', 'anyway', 'find', 'book'): 1,
#  ('anyway', 'find', 'book', 'whatsoever'): 1,
#  ('find', 'book', 'whatsoever', 'sacre'): 1,
#  ('book', 'whatsoever', 'sacre', 'profane'): 1,
#  ('whatsoever', 'sacre', 'profane', 'therefore'): 1,
#  ('sacre', 'profane', 'therefore', 'must'): 1,
#  ('profane', 'therefore', 'must', 'every'): 1,
#  ('therefore', 'must', 'every', 'case'): 1,
#  ('must', 'every', 'case', 'least'): 1,
#  ('every', 'case', 'least', 'take'): 1,
#  ('case', 'least', 'take', 'UNK'): 1,
#  ('least', 'take', 'UNK', 'whale'): 1,
#  ('take', 'UNK', 'whale', 'statement'): 1,
#  ('UNK', 'whale', 'statement', 'however'): 1,
#  ('whale', 'statement', 'however', 'authentic'): 1,
#  ('statement', 'however', 'authentic', 'extract'): 1,
#  ('however', 'authentic', 'extract', 'veritable'): 1,
#  ('authentic', 'extract', 'veritable', 'gospel'): 1,
#  ('extract', 'veritable', 'gospel', 'cetology'): 1,
#  ('veritable', 'gospel', 'cetology', 'far'): 1,
#  ('gospel', 'cetology', 'far', 'touch'): 1,
#  ('cetology', 'far', 'touch', 'ancient'): 1,
#  ('far', 'touch', 'ancient', 'author'): 1,
#  ('touch', 'ancient', 'author', 'generally'): 1,
#  ('ancient', 'author', 'generally', 'well'): 1,
#  ('author', 'generally', 'well', 'poet'): 1,
#  ('generally', 'well', 'poet', 'appear'): 1,
#  ('well', 'poet', 'appear', 'extract'): 1,
#  ('poet', 'appear', 'extract', 'solely'): 1,
#  ('appear', 'extract', 'solely', 'valuable'): 1,
#  ('extract', 'solely', 'valuable', 'entertain'): 1,
#  ('solely', 'valuable', 'entertain', 'afford'): 1,
#  ('valuable', 'entertain', 'afford', 'glance'): 1,
#  ('entertain', 'afford', 'glance', 'bird'): 1,
#  ('afford', 'glance', 'bird', 'eye'): 1,
#  ('glance', 'bird', 'eye', 'view'): 1,
#  ('bird', 'eye', 'view', 'UNK'): 1,
#  ('eye', 'view', 'UNK', 'say'): 1,
#  ('view', 'UNK', 'say', 'think'): 1,
#  ('UNK', 'say', 'think', 'fancy'): 1,
#  ('say', 'think', 'fancy', 'sing'): 1,
#  ('think', 'fancy', 'sing', 'leviathan'): 1,
#  ('fancy', 'sing', 'leviathan', 'many'): 1,
#  ('sing', 'leviathan', 'many', 'nation'): 1,
#  ('leviathan', 'many', 'nation', 'generation'): 1,
#  ('many', 'nation', 'generation', 'include'): 1,
#  ('nation', 'generation', 'include', 'fare'): 1,
#  ('generation', 'include', 'fare', 'thee'): 1,
#  ('include', 'fare', 'thee', 'well'): 1,
#  ('fare', 'thee', 'well', 'poor'): 1,
#  ('thee', 'well', 'poor', 'devil'): 1,
#  ('well', 'poor', 'devil', 'subsub'): 1,
#  ('poor', 'devil', 'subsub', 'whose'): 1,
#  ('devil', 'subsub', 'whose', 'commentator'): 1,
#  ('subsub', 'whose', 'commentator', 'thou'): 1,
#  ('whose', 'commentator', 'thou', 'UNK'): 1,
#  ('commentator', 'thou', 'UNK', 'hopeles'): 1,
#  ('thou', 'UNK', 'hopeles', 'UNK'): 1,
#  ('UNK', 'hopeles', 'UNK', 'tribe'): 1,
#  ('hopeles', 'UNK', 'tribe', 'wine'): 1,
#  ('UNK', 'tribe', 'wine', 'thi'): 1,
#  ('tribe', 'wine', 'thi', 'world'): 1,
#  ('wine', 'thi', 'world', 'ever'): 1,
#  ('thi', 'world', 'ever', 'warm'): 1,
#  ('world', 'ever', 'warm', 'even'): 1,
#  ('ever', 'warm', 'even', 'pale'): 1,
#  ('warm', 'even', 'pale', 'UNK'): 1,
#  ('even', 'pale', 'UNK', 'would'): 1,
#  ('pale', 'UNK', 'would', 'UNK'): 1,
#  ('UNK', 'would', 'UNK', 'one'): 1,
#  ('would', 'UNK', 'one', 'sometime'): 1,
#  ('UNK', 'one', 'sometime', 'love'): 1,
#  ('one', 'sometime', 'love', 'sit'): 1,
#  ('sometime', 'love', 'sit', 'feel'): 1,
#  ('love', 'sit', 'feel', 'UNK'): 1,
#  ('sit', 'feel', 'UNK', 'grow'): 1,
#  ('feel', 'UNK', 'grow', 'convivial'): 1,
#  ('UNK', 'grow', 'convivial', 'upon'): 1,
#  ('grow', 'convivial', 'upon', 'tear'): 1,
#  ('convivial', 'upon', 'tear', 'say'): 1,
#  ('upon', 'tear', 'say', 'UNK'): 1,
#  ('tear', 'say', 'UNK', 'full'): 1,
#  ('say', 'UNK', 'full', 'eye'): 1,
#  ('UNK', 'full', 'eye', 'empty'): 1,
#  ('full', 'eye', 'empty', 'glass'): 1,
#  ('eye', 'empty', 'glass', 'altogether'): 1,
#  ('empty', 'glass', 'altogether', 'unpleasant'): 1,
#  ('glass', 'altogether', 'unpleasant', 'UNK'): 1,
#  ('altogether', 'unpleasant', 'UNK', 'subsub'): 1,
#  ('unpleasant', 'UNK', 'subsub', 'much'): 1,
#  ('UNK', 'subsub', 'much', 'pain'): 1,
#  ('subsub', 'much', 'pain', 'ye'): 1,
#  ('much', 'pain', 'ye', 'take'): 1,
#  ('pain', 'ye', 'take', 'please'): 1,
#  ('ye', 'take', 'please', 'world'): 1,
#  ('take', 'please', 'world', 'much'): 1,
#  ('please', 'world', 'much', 'shall'): 1,
#  ('world', 'much', 'shall', 'ye'): 1,
#  ('much', 'shall', 'ye', 'ever'): 1,
#  ('shall', 'ye', 'ever', 'go'): 1,
#  ('ye', 'ever', 'go', 'UNK'): 1,
#  ('ever', 'go', 'UNK', 'would'): 1,
#  ('go', 'UNK', 'would', 'clear'): 1,
#  ('UNK', 'would', 'clear', 'UNK'): 1,
#  ('would', 'clear', 'UNK', 'court'): 1,
#  ('clear', 'UNK', 'court', 'tuilery'): 1,
#  ('UNK', 'court', 'tuilery', 'ye'): 1,
#  ('court', 'tuilery', 'ye', 'gulp'): 1,
#  ('tuilery', 'ye', 'gulp', 'tear'): 1,
#  ('ye', 'gulp', 'tear', 'hie'): 1,
#  ('gulp', 'tear', 'hie', 'aloft'): 1,
#  ('tear', 'hie', 'aloft', 'royalmast'): 1,
#  ('hie', 'aloft', 'royalmast', 'heart'): 1,
#  ('aloft', 'royalmast', 'heart', 'friend'): 1,
#  ('royalmast', 'heart', 'friend', 'go'): 1,
#  ('heart', 'friend', 'go', 'clear'): 1,
#  ('friend', 'go', 'clear', 'UNK'): 1,
#  ('go', 'clear', 'UNK', 'heaven'): 1,
#  ('clear', 'UNK', 'heaven', 'make'): 1,
#  ('UNK', 'heaven', 'make', 'UNK'): 1,
#  ('heaven', 'make', 'UNK', 'UNK'): 1,
#  ('make', 'UNK', 'UNK', 'gabriel'): 1,
#  ('UNK', 'UNK', 'gabriel', 'michael'): 1,
#  ('UNK', 'gabriel', 'michael', 'UNK'): 1,
#  ('gabriel', 'michael', 'UNK', 'come'): 1,
#  ('michael', 'UNK', 'come', 'ye'): 1,
#  ('UNK', 'come', 'ye', 'strike'): 1,
#  ('come', 'ye', 'strike', 'splinter'): 1,
#  ('ye', 'strike', 'splinter', 'heart'): 1,
#  ('strike', 'splinter', 'heart', 'UNK'): 1,
#  ('splinter', 'heart', 'UNK', 'ye'): 1,
#  ('heart', 'UNK', 'ye', 'shall'): 1,
#  ('UNK', 'ye', 'shall', 'strike'): 1,
#  ('ye', 'shall', 'strike', 'UNK'): 1,
#  ('shall', 'strike', 'UNK', 'glass'): 1,
#  ('strike', 'UNK', 'glass', 'extract'): 1,
#  ('UNK', 'glass', 'extract', 'god'): 1,
#  ('glass', 'extract', 'god', 'create'): 1,
#  ('extract', 'god', 'create', 'great'): 1,
#  ('god', 'create', 'great', 'whale'): 1,
#  ('create', 'great', 'whale', 'genesi'): 1,
#  ('great', 'whale', 'genesi', 'leviathan'): 1,
#  ('whale', 'genesi', 'leviathan', 'maketh'): 1,
#  ('genesi', 'leviathan', 'maketh', 'path'): 1,
#  ('leviathan', 'maketh', 'path', 'shine'): 1,
#  ('maketh', 'path', 'shine', 'one'): 1,
#  ('path', 'shine', 'one', 'would'): 1,
#  ('shine', 'one', 'would', 'think'): 1,
#  ('one', 'would', 'think', 'deep'): 1,
#  ('would', 'think', 'deep', 'hoary'): 1,
#  ('think', 'deep', 'hoary', 'job'): 1,
#  ('deep', 'hoary', 'job', 'lord'): 1,
#  ('hoary', 'job', 'lord', 'prepare'): 1,
#  ('job', 'lord', 'prepare', 'great'): 1,
#  ('lord', 'prepare', 'great', 'fish'): 1,
#  ('prepare', 'great', 'fish', 'swallow'): 2,
#  ('great', 'fish', 'swallow', 'jonah'): 2,
#  ('fish', 'swallow', 'jonah', 'jonah'): 1,
#  ('swallow', 'jonah', 'jonah', 'go'): 1,
#  ('jonah', 'jonah', 'go', 'ship'): 1,
#  ('jonah', 'go', 'ship', 'leviathan'): 1,
#  ('go', 'ship', 'leviathan', 'thou'): 1,
#  ('ship', 'leviathan', 'thou', 'hast'): 1,
#  ('leviathan', 'thou', 'hast', 'make'): 1,
#  ('thou', 'hast', 'make', 'play'): 1,
#  ('hast', 'make', 'play', 'therein'): 1,
#  ('make', 'play', 'therein', 'psalm'): 1,
#  ('play', 'therein', 'psalm', 'day'): 1,
#  ('therein', 'psalm', 'day', 'lord'): 1,
#  ('psalm', 'day', 'lord', 'hi'): 1,
#  ('day', 'lord', 'hi', 'sore'): 1,
#  ('lord', 'hi', 'sore', 'great'): 1,
#  ('hi', 'sore', 'great', 'strong'): 1,
#  ('sore', 'great', 'strong', 'sword'): 1,
#  ('great', 'strong', 'sword', 'shall'): 1,
#  ('strong', 'sword', 'shall', 'UNK'): 1,
#  ('sword', 'shall', 'UNK', 'leviathan'): 1,
#  ('shall', 'UNK', 'leviathan', 'pierce'): 1,
#  ('UNK', 'leviathan', 'pierce', 'serpent'): 1,
#  ('leviathan', 'pierce', 'serpent', 'even'): 1,
#  ('pierce', 'serpent', 'even', 'leviathan'): 1,
#  ('serpent', 'even', 'leviathan', 'crook'): 1,
#  ('even', 'leviathan', 'crook', 'serpent'): 1,
#  ('leviathan', 'crook', 'serpent', 'shall'): 1,
#  ('crook', 'serpent', 'shall', 'slay'): 1,
#  ('serpent', 'shall', 'slay', 'dragon'): 1,
#  ('shall', 'slay', 'dragon', 'sea'): 1,
#  ('slay', 'dragon', 'sea', 'isaiah'): 1,
#  ('dragon', 'sea', 'isaiah', 'thing'): 1,
#  ('sea', 'isaiah', 'thing', 'UNK'): 1,
#  ('isaiah', 'thing', 'UNK', 'beside'): 1,
#  ('thing', 'UNK', 'beside', 'UNK'): 1,
#  ('UNK', 'beside', 'UNK', 'within'): 1,
#  ('beside', 'UNK', 'within', 'chao'): 1,
#  ('UNK', 'within', 'chao', 'thi'): 1,
#  ('within', 'chao', 'thi', 'monster'): 1,
#  ('chao', 'thi', 'monster', 'mouth'): 1,
#  ('thi', 'monster', 'mouth', 'beast'): 1,
#  ('monster', 'mouth', 'beast', 'boat'): 1,
#  ('mouth', 'beast', 'boat', 'stone'): 1,
#  ('beast', 'boat', 'stone', 'go'): 1,
#  ('boat', 'stone', 'go', 'UNK'): 1,
#  ('stone', 'go', 'UNK', 'foul'): 1,
#  ('go', 'UNK', 'foul', 'great'): 1,
#  ('UNK', 'foul', 'great', 'swallow'): 1,
#  ('foul', 'great', 'swallow', 'hi'): 1,
#  ('great', 'swallow', 'hi', 'UNK'): 1,
#  ('swallow', 'hi', 'UNK', 'bottomles'): 1,
#  ('hi', 'UNK', 'bottomles', 'gulf'): 1,
#  ('UNK', 'bottomles', 'gulf', 'hi'): 1,
#  ('bottomles', 'gulf', 'hi', 'paunch'): 1,
#  ('gulf', 'hi', 'paunch', 'holland'): 1,
#  ('hi', 'paunch', 'holland', 'UNK'): 1,
#  ('paunch', 'holland', 'UNK', 'moral'): 1,
#  ('holland', 'UNK', 'moral', 'indian'): 1,
#  ('UNK', 'moral', 'indian', 'sea'): 1,
#  ('moral', 'indian', 'sea', 'UNK'): 1,
#  ('indian', 'sea', 'UNK', 'biggest'): 1,
#  ('sea', 'UNK', 'biggest', 'fishes'): 1,
#  ('UNK', 'biggest', 'fishes', 'among'): 1,
#  ('biggest', 'fishes', 'among', 'whale'): 1,
#  ('fishes', 'among', 'whale', 'UNK'): 1,
#  ('among', 'whale', 'UNK', 'call'): 1,
#  ('whale', 'UNK', 'call', 'UNK'): 1,
#  ('UNK', 'call', 'UNK', 'take'): 1,
#  ('call', 'UNK', 'take', 'much'): 1,
#  ('UNK', 'take', 'much', 'length'): 1,
#  ('take', 'much', 'length', 'four'): 1,
#  ('much', 'length', 'four', 'acre'): 1,
#  ('length', 'four', 'acre', 'UNK'): 1,
#  ('four', 'acre', 'UNK', 'land'): 1,
#  ('acre', 'UNK', 'land', 'holland'): 1,
#  ('UNK', 'land', 'holland', 'pliny'): 1,
#  ('land', 'holland', 'pliny', 'scarcely'): 1,
#  ('holland', 'pliny', 'scarcely', 'proceed'): 1,
#  ('pliny', 'scarcely', 'proceed', 'two'): 1,
#  ('scarcely', 'proceed', 'two', 'day'): 1,
#  ('proceed', 'two', 'day', 'sea'): 1,
#  ('two', 'day', 'sea', 'sunrise'): 1,
#  ('day', 'sea', 'sunrise', 'great'): 1,
#  ('sea', 'sunrise', 'great', 'many'): 1,
#  ('sunrise', 'great', 'many', 'whale'): 1,
#  ('great', 'many', 'whale', 'monster'): 1,
#  ('many', 'whale', 'monster', 'sea'): 1,
#  ('whale', 'monster', 'sea', 'appear'): 1,
#  ('monster', 'sea', 'appear', 'among'): 1,
#  ('sea', 'appear', 'among', 'former'): 1,
#  ('appear', 'among', 'former', 'one'): 1,
#  ('among', 'former', 'one', 'monstrou'): 1,
#  ('former', 'one', 'monstrou', 'size'): 1,
#  ('one', 'monstrou', 'size', '....'): 1,
#  ('monstrou', 'size', '....', 'thi'): 1,
#  ('size', '....', 'thi', 'come'): 1,
#  ('....', 'thi', 'come', 'toward'): 1,
#  ('thi', 'come', 'toward', 'u'): 1,
#  ('come', 'toward', 'u', 'openmouthe'): 1,
#  ('toward', 'u', 'openmouthe', 'raise'): 1,
#  ('u', 'openmouthe', 'raise', 'wave'): 1,
#  ('openmouthe', 'raise', 'wave', 'side'): 1,
#  ('raise', 'wave', 'side', 'beat'): 1,
#  ('wave', 'side', 'beat', 'sea'): 1,
#  ('side', 'beat', 'sea', 'foam'): 1,
#  ('beat', 'sea', 'foam', 'UNK'): 1,
#  ('sea', 'foam', 'UNK', 'UNK'): 1,
#  ('foam', 'UNK', 'UNK', 'true'): 1,
#  ('UNK', 'UNK', 'true', 'history'): 1,
#  ('UNK', 'true', 'history', 'visit'): 1,
#  ('true', 'history', 'visit', 'thi'): 1,
#  ('history', 'visit', 'thi', 'country'): 1,
#  ('visit', 'thi', 'country', 'also'): 1,
#  ('thi', 'country', 'also', 'view'): 1,
#  ('country', 'also', 'view', 'catch'): 1,
#  ('also', 'view', 'catch', 'UNK'): 1,
#  ('view', 'catch', 'UNK', 'bone'): 1,
#  ('catch', 'UNK', 'bone', 'great'): 1,
#  ('UNK', 'bone', 'great', 'value'): 1,
#  ('bone', 'great', 'value', 'teeth'): 1,
#  ('great', 'value', 'teeth', 'bring'): 1,
#  ('value', 'teeth', 'bring', 'king'): 1,
#  ('teeth', 'bring', 'king', '....'): 1,
#  ('bring', 'king', '....', 'best'): 1,
#  ('king', '....', 'best', 'whale'): 1,
#  ('....', 'best', 'whale', 'catch'): 1,
#  ('best', 'whale', 'catch', 'hi'): 1,
#  ('whale', 'catch', 'hi', 'country'): 1,
#  ('catch', 'hi', 'country', 'fortyeight'): 1,
#  ('hi', 'country', 'fortyeight', 'fifty'): 1,
#  ('country', 'fortyeight', 'fifty', 'yard'): 1,
#  ('fortyeight', 'fifty', 'yard', 'long'): 1,
#  ('fifty', 'yard', 'long', 'say'): 1,
#  ('yard', 'long', 'say', 'one'): 1,
#  ('long', 'say', 'one', 'six'): 1,
#  ('say', 'one', 'six', 'kill'): 1,
#  ('one', 'six', 'kill', 'sixty'): 1,
#  ('six', 'kill', 'sixty', 'two'): 1,
#  ('kill', 'sixty', 'two', 'day'): 1,
#  ('sixty', 'two', 'day', 'verbal'): 1,
#  ('two', 'day', 'verbal', 'narrative'): 1,
#  ('day', 'verbal', 'narrative', 'take'): 1,
#  ('verbal', 'narrative', 'take', 'hi'): 1,
#  ('narrative', 'take', 'hi', 'mouth'): 1,
#  ('take', 'hi', 'mouth', 'king'): 1,
#  ('hi', 'mouth', 'king', 'alfr'): 1,
#  ('mouth', 'king', 'alfr', 'a.d.'): 1,
#  ('king', 'alfr', 'a.d.', 'wherea'): 1,
#  ('alfr', 'a.d.', 'wherea', 'thing'): 1,
#  ('a.d.', 'wherea', 'thing', 'whether'): 1,
#  ('wherea', 'thing', 'whether', 'beast'): 1,
#  ('thing', 'whether', 'beast', 'vessel'): 1,
#  ('whether', 'beast', 'vessel', 'enter'): 1,
#  ('beast', 'vessel', 'enter', 'dreadful'): 1,
#  ('vessel', 'enter', 'dreadful', 'gulf'): 1,
#  ('enter', 'dreadful', 'gulf', 'thi'): 1,
#  ('dreadful', 'gulf', 'thi', 'monster'): 1,
#  ('gulf', 'thi', 'monster', 'whale'): 1,
#  ('thi', 'monster', 'whale', 'mouth'): 1,
#  ('monster', 'whale', 'mouth', 'immediately'): 1,
#  ('whale', 'mouth', 'immediately', 'lose'): 1,
#  ('mouth', 'immediately', 'lose', 'swallow'): 1,
#  ('immediately', 'lose', 'swallow', 'UNK'): 1,
#  ('lose', 'swallow', 'UNK', 'retire'): 1,
#  ('swallow', 'UNK', 'retire', 'great'): 1,
#  ('UNK', 'retire', 'great', 'security'): 1,
#  ('retire', 'great', 'security', 'sleep'): 1,
#  ('great', 'security', 'sleep', 'UNK'): 1,
#  ('security', 'sleep', 'UNK', 'UNK'): 1,
#  ('sleep', 'UNK', 'UNK', 'UNK'): 1,
#  ('UNK', 'UNK', 'UNK', 'let'): 1,
#  ('UNK', 'UNK', 'let', 'u'): 1,
#  ('UNK', 'let', 'u', 'fly'): 1,
#  ('let', 'u', 'fly', 'let'): 1,
#  ('u', 'fly', 'let', 'u'): 1,
#  ('fly', 'let', 'u', 'fly'): 1,
#  ('let', 'u', 'fly', 'old'): 1,
#  ('u', 'fly', 'old', 'UNK'): 1,
#  ('fly', 'old', 'UNK', 'take'): 1,
#  ('old', 'UNK', 'take', 'leviathan'): 1,
#  ('UNK', 'take', 'leviathan', 'describe'): 1,
#  ('take', 'leviathan', 'describe', 'noble'): 1,
#  ('leviathan', 'describe', 'noble', 'prophet'): 1,
#  ('describe', 'noble', 'prophet', 'mose'): 1,
#  ('noble', 'prophet', 'mose', 'life'): 1,
#  ('prophet', 'mose', 'life', 'patient'): 1,
#  ('mose', 'life', 'patient', 'job'): 1,
#  ('life', 'patient', 'job', 'rabelai'): 1,
#  ('patient', 'job', 'rabelai', 'thi'): 1,
#  ('job', 'rabelai', 'thi', 'whale'): 1,
#  ('rabelai', 'thi', 'whale', 'liver'): 1,
#  ('thi', 'whale', 'liver', 'two'): 1,
#  ('whale', 'liver', 'two', 'cartload'): 1,
#  ('liver', 'two', 'cartload', 'UNK'): 1,
#  ('two', 'cartload', 'UNK', 'annal'): 1,
#  ('cartload', 'UNK', 'annal', 'great'): 1,
#  ('UNK', 'annal', 'great', 'leviathan'): 1,
#  ('annal', 'great', 'leviathan', 'maketh'): 1,
#  ('great', 'leviathan', 'maketh', 'sea'): 1,
#  ('leviathan', 'maketh', 'sea', 'seethe'): 1,
#  ('maketh', 'sea', 'seethe', 'like'): 1,
#  ('sea', 'seethe', 'like', 'boil'): 1,
#  ('seethe', 'like', 'boil', 'pan'): 1,
#  ('like', 'boil', 'pan', 'lord'): 1,
#  ('boil', 'pan', 'lord', 'UNK'): 1,
#  ('pan', 'lord', 'UNK', 'version'): 1,
#  ('lord', 'UNK', 'version', 'psalm'): 1,
#  ('UNK', 'version', 'psalm', 'touch'): 1,
#  ('version', 'psalm', 'touch', 'monstrou'): 1,
#  ('psalm', 'touch', 'monstrou', 'bulk'): 1,
#  ('touch', 'monstrou', 'bulk', 'whale'): 1,
#  ('monstrou', 'bulk', 'whale', 'UNK'): 1,
#  ('bulk', 'whale', 'UNK', 'receive'): 1,
#  ('whale', 'UNK', 'receive', 'nothe'): 1,
#  ('UNK', 'receive', 'nothe', 'certain'): 1,
#  ('receive', 'nothe', 'certain', 'grow'): 1,
#  ('nothe', 'certain', 'grow', 'exceed'): 1,
#  ('certain', 'grow', 'exceed', 'fat'): 1,
#  ('grow', 'exceed', 'fat', 'insomuch'): 1,
#  ('exceed', 'fat', 'insomuch', 'incredible'): 1,
#  ('fat', 'insomuch', 'incredible', 'quantity'): 1,
#  ('insomuch', 'incredible', 'quantity', 'oil'): 1,
#  ('incredible', 'quantity', 'oil', 'extract'): 1,
#  ('quantity', 'oil', 'extract', 'one'): 1,
#  ('oil', 'extract', 'one', 'whale'): 1,
#  ('extract', 'one', 'whale', 'ibid'): 1,
#  ('one', 'whale', 'ibid', 'history'): 1,
#  ('whale', 'ibid', 'history', 'life'): 1,
#  ('ibid', 'history', 'life', 'death'): 1,
#  ('history', 'life', 'death', 'UNK'): 1,
#  ...}

# %%
# def generate_next_word(given_trigram):
#     max_count = 0
#     next_word = None
    
#     # Check if the given trigram exists in the four-grams
#     for four_gram, count in four_counts.items():
#         if four_gram[:3] == given_trigram:
#             # Update the most common next word if count is greater
#             if count > max_count:
#                 max_count = count
#                 next_word = (four_gram[3],)
    
#     for tri_gram, count in tri_counts.items():
#         if tri_gram[:2] == given_trigram[1:]:
#             # Update the most common next word if count is greater
#             if count > max_count:
#                 max_count = count
#                 next_word = (tri_gram[2],)
    
#     for bi_gram, count in bi_counts.items():
#         if bi_gram[:1] == given_trigram[2]:
#             # Update the most common next word if count is greater
#             if count > max_count:
#                 max_count = count
#                 next_word = (bi_gram[1],)
#     return next_word

# %%
#GPT last
def generate_next_word(given_trigram):
    max_count = 0
    next_word = None
    
    # Check if the given trigram exists in the four-grams
    for four_gram, count in four_counts.items():
        if four_gram[:3] == given_trigram:
            # Update the most common next word if count is greater
            if count > max_count:
                max_count = count
                next_word = four_gram[3]
    
    # Check if the given trigram exists in the trigrams
    for tri_gram, count in tri_counts.items():
        if tri_gram[:2] == given_trigram[1:]:
            # Update the most common next word if count is greater
            if count > max_count:
                max_count = count
                next_word = tri_gram[2]
    
    # Check if the given trigram exists in the bigrams
    for bi_gram, count in bi_counts.items():
        if bi_gram[:1] == given_trigram[2:]:
            # Update the most common next word if count is greater
            if count > max_count:
                max_count = count
                next_word = bi_gram[1]
    
    # If none of the above cases matched, return the most common word based on unigram counts
    if next_word is None:
        next_word = max(uni_counts, key=uni_counts.get)
    
    return next_word

# %%
def generate_starting_trigram():
    # Start with the most frequent word based on unigram counts
    first_word = random.choices(list(uni_counts.keys()), weights=uni_counts.values())[0]
    # Use this word along with the preceding word from bigram counts to form a bigram
    second_word = max((word[1] for word in bi_counts.keys() if word[0] == first_word), key=lambda x: bi_counts.get((first_word, x), 0))
    # Use the bigram along with the preceding word from trigram counts to form a trigram
    third_word = max((word[2] for word in tri_counts.keys() if word[:2] == (first_word, second_word)), key=lambda x: tri_counts.get((first_word, second_word, x), 0))
    return (first_word, second_word, third_word)

# %%
# def generate_text(starting_trigram, length=10):
#     text = list(starting_trigram)
#     for _ in range(length):
#         next_word = generate_next_word((text[-2], text[-1]))
#         text.append(next_word)
#     return ' '.join(text)

# %%
starting_trigram = generate_starting_trigram()
# starting_trigram+generate_next_word(starting_trigram)

# %%
def generate_text(length):
    text = tuple()
    starting_trigram = generate_starting_trigram()
    
    for _ in range(length - 2):
        next_word = generate_next_word(starting_trigram)
        text+=starting_trigram
        text += (next_word,)
        starting_trigram = text[-2:]
    
    return ' '.join(text)
generated_text = generate_text(length=15)
print(generated_text)
# Out:
# barbarian dine cabin chapter cabin chapter UNK chapter UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK UNK

# %%
def calculate_word_probability(trigram, next_word):
    max_count = 0
    total_count = 0
    
    # Check if the given trigram exists in the four-grams
    for four_gram, count in four_counts.items():
        if four_gram[:3] == trigram:
            total_count += count
            # Update the count of the next word
            if four_gram[3] == next_word:
                max_count = count
    
    # Check if the given trigram exists in the trigrams
    for tri_gram, count in tri_counts.items():
        if tri_gram[:2] == trigram[1:]:
            total_count += count
            # Update the count of the next word
            if tri_gram[2] == next_word:
                max_count = count
    
    # Check if the given trigram exists in the bigrams
    for bi_gram, count in bi_counts.items():
        if bi_gram[:1] == trigram[2:]:
            total_count += count
            # Update the count of the next word
            if bi_gram[1] == next_word:
                max_count = count
    
    # Calculate the probability of the next word given the trigram
    word_probability = max_count / total_count if total_count > 0 else 0.0
    return word_probability

# %%
import math
def calculate_perplexity(generated_text):
    test_words = generated_text  # Tokenize the generated text
    N = len(test_words)  # Total number of words in the generated text
    total_log_probability = 0.0
    
    # Calculate the log probability of each word and sum them
    for i in range(2, N):
        context = (test_words[i-2], test_words[i-1])  # Get the context (last two words)
        word = test_words[i]  # Current word
        word_probability = calculate_word_probability(context, word)  # Calculate the probability of the word
        if word_probability > 0:
            total_log_probability += -1 * math.log2(word_probability)  # Calculate and accumulate the log probability
    
    # Calculate perplexity
    perplexity = pow(2, total_log_probability / N)
    return perplexity

# %%
# import random

# class NGramModelWithBackoff:
#     def n_gram_counts(text, n):
#         n_tokens = len(text)
#         result = dict()
#         for i in range(n_tokens - n + 1):
#             key = tuple(text[i:i+n])
#             if key in result:
#                result[key] += 1
#             else:
#                 result[key] = 1
#         return result
    
#     def __init__(self, text):
#         self.uni_counts = n_gram_counts(text, 1)
#         self.bi_counts = n_gram_counts(text, 2)
#         self.tri_counts = n_gram_counts(text, 3)
#         self.four_counts = n_gram_counts(text, 4)
#         self.total_count = sum(self.uni_counts.values())
#         self.vocab = len(self.uni_counts)

#     def _get_probability(self, ngram):
#         if len(ngram) == 1:
#             return self.uni_counts.get(ngram, 0) / self.total_count
#         elif len(ngram) == 2:
#             return self.bi_counts.get(ngram, 0) / self.uni_counts.get(ngram[0], 1)
#         elif len(ngram) == 3:
#             return self.tri_counts.get(ngram, 0) / self.bi_counts.get(ngram[:2], 1)
#         elif len(ngram) == 4:
#             return self.four_counts.get(ngram, 0) / self.tri_counts.get(ngram[:3], 1)
#         else:
#             return 0
        
#     def generate_starting_trigram():
#         # Start with the most frequent word based on unigram counts
#         first_word = random.choices(list(uni_counts.keys()), weights=uni_counts.values())[0]
#         # Use this word along with the preceding word from bigram counts to form a bigram
#         second_word = max((word[1] for word in bi_counts.keys() if word[0] == first_word), key=lambda x: bi_counts.get((first_word, x), 0))
#         # Use the bigram along with the preceding word from trigram counts to form a trigram
#         third_word = max((word[2] for word in tri_counts.keys() if word[:2] == (first_word, second_word)), key=lambda x: tri_counts.get((first_word, second_word, x), 0))
#         return (first_word, second_word, third_word)

#     def generate_text(length):
#         text = tuple()
#         starting_trigram = generate_starting_trigram()
        
#         for _ in range(length - 2):
#             next_word = generate_next_word(starting_trigram)
#             text+=starting_trigram
#             text += (next_word,)
#             starting_trigram = text[-2:]
        
#         return ' '.join(text)

#     def generate_next_word(given_trigram):
#         max_count = 0
#         next_word = None
        
#         # Check if the given trigram exists in the four-grams
#         for four_gram, count in four_counts.items():
#             if four_gram[:3] == given_trigram:
#                 # Update the most common next word if count is greater
#                 if count > max_count:
#                     max_count = count
#                     next_word = four_gram[3]
        
#         # Check if the given trigram exists in the trigrams
#         for tri_gram, count in tri_counts.items():
#             if tri_gram[:2] == given_trigram[1:]:
#                 # Update the most common next word if count is greater
#                 if count > max_count:
#                     max_count = count
#                     next_word = tri_gram[2]
        
#         # Check if the given trigram exists in the bigrams
#         for bi_gram, count in bi_counts.items():
#             if bi_gram[:1] == given_trigram[2:]:
#                 # Update the most common next word if count is greater
#                 if count > max_count:
#                     max_count = count
#                     next_word = bi_gram[1]
        
#         # If none of the above cases matched, return the most common word based on unigram counts
#         if next_word is None:
#             next_word = max(uni_counts, key=uni_counts.get)
        
#         return next_word


# model = NGramModelWithBackoff(data_train)

# generated_text = model.generate_text(20)
# print(generated_text)

# %%
# def generate_next_token(self, ngram):
#     # Search for the given n-gram
#     if ngram in self.ngram_model:
#         # If the n-gram is found, generate the next token based on it
#         next_token = self.ngram_model[ngram].generate_next_token()
#         return next_token
#     else:
#         # If the n-gram is not found, back off to smaller n-grams
#         for i in range(len(ngram) - 1, 0, -1):
#             smaller_ngram = ngram[:i]
#             if smaller_ngram in self.ngram_model:
#                 # If a smaller n-gram is found, repeat the process with it
#                 return self.generate_next_token(smaller_ngram)
#         # If no match is found for any smaller n-gram, return None or handle appropriately
#         return None
